# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install stable_baselines3
# !pip install yfinance
# !pip install tushare
# !pip install exchange_calendars
# !pip install wrds
# !pip install alpaca_trade_api
# !pip install stockstats
# !pip install pyfolio

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_initial import StockTradingEnv
from finrl.agents.stablebaselines3.models_initial import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)

# %%
df = pd.read_csv('merged_df.csv')
df

# %%
TRAIN_START_DATE = '2012-10-10'
TRAIN_END_DATE = '2020-02-28'
TRADE_START_DATE = '2020-03-01'
TRADE_END_DATE = '2022-05-30'

# %%
import tushare as ts
ts.set_token('6314756019e50a6672690e5a78b2dbf7cfcd27c6f6a6b48a8cf76dae')
pro = ts.pro_api()

# %%
#选择上证50指数的成分股
df_index = pro.index_weight(index_code='000016.sh', start_date='20151010', end_date='20220228')
# df_index.to_csv('SSE_50_index_weight.csv',index=0)

# %%
#选择某个时间点的上证50指数成分股作为参考跟踪股票池
select_date = '20200228' #自定义的时间点为每个月的月末
df_select = df_index[df_index['trade_date']==select_date]
sort_SSEindex = df_select['con_code'].unique()
print(sort_SSEindex,len(sort_SSEindex))
# Out:
# ['603993.SH' '603259.SH' '601989.SH' '601988.SH' '601939.SH' '601888.SH'
#  '601857.SH' '601818.SH' '601766.SH' '601688.SH' '601668.SH' '601628.SH'
#  '601601.SH' '601398.SH' '601390.SH' '601336.SH' '601328.SH' '601319.SH'
#  '601318.SH' '601288.SH' '601236.SH' '601211.SH' '601186.SH' '601166.SH'
#  '601138.SH' '601111.SH' '601088.SH' '601066.SH' '601012.SH' '600887.SH'
#  '600837.SH' '600703.SH' '600690.SH' '600585.SH' '600547.SH' '600519.SH'
#  '600340.SH' '600309.SH' '600276.SH' '600196.SH' '600104.SH' '600050.SH'
#  '600048.SH' '600036.SH' '600031.SH' '600030.SH' '600028.SH' '600016.SH'
#  '600009.SH' '600000.SH'] 50

# %%
#随机选择成分股中的k只股票
import random 
k = 20
# selected_tics = random.sample(list(sort_SSEindex),k)
# print(selected_tics)

# %%
selected_tics = ['601012.SH', '601628.SH', '601318.SH', '600028.SH', '601211.SH', '600050.SH', '601688.SH', '601066.SH', '600585.SH', '600030.SH', '601166.SH', '601766.SH', '601236.SH', '600340.SH', '601319.SH', '600547.SH', '601939.SH', '601601.SH', '600837.SH', '600196.SH']

# %%
#Download随机选择的k只股票数据
df_ts =pd.DataFrame()
for c in selected_tics:
    temp=pro.daily(ts_code=c,start_date=TRAIN_START_DATE,end_date=TRADE_END_DATE)
    df_ts=pd.concat([df_ts,temp])
print(df_ts)
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     601012.SH   20211231  84.00  87.33  84.00  86.20      81.23    4.97
# 1     601012.SH   20211230  82.30  83.99  80.51  81.23      82.01   -0.78
# 2     601012.SH   20211229  81.18  82.95  80.80  82.01      81.55    0.46
# 3     601012.SH   20211228  78.00  81.90  77.60  81.55      78.14    3.41
# 4     601012.SH   20211227  77.70  79.25  77.26  78.14      77.88    0.26
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 2406  600196.SH   20120110   8.32   8.68   8.30   8.66       8.34    0.32
# 2407  600196.SH   20120109   8.10   8.35   8.04   8.34       8.08    0.26
# 2408  600196.SH   20120106   8.15   8.24   7.95   8.08       8.25   -0.17
# 2409  600196.SH   20120105   8.31   8.40   8.20   8.25       8.34   -0.09
# 2410  600196.SH   20120104   8.60   8.68   8.30   8.34       8.54   -0.20
#
#       pct_chg         vol        amount
# 0      6.1184  1213771.67  1.042053e+07
# 1     -0.9511   632874.37  5.210227e+06
# 2      0.5641   528763.70  4.344087e+06
# 3      4.3640   686944.14  5.504813e+06
# 4      0.3338   407901.72  3.192025e+06
# ...       ...         ...           ...
# 2406   3.8400    84768.47  7.225029e+04
# 2407   3.2200    62208.12  5.115314e+04
# 2408  -2.0600    57443.70  4.615346e+04
# 2409  -1.0800    38135.51  3.153240e+04
# 2410  -2.3400    36465.88  3.101384e+04
#
# [42121 rows x 11 columns]

# %%
# 筛选exchange_calender中每个交易节点缺失情况(全部补充0)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) != k:
            missing_tic = set(selected_tics).difference(set(temp_df['ts_code'].tolist()))
#             print(missing_tic)
            for m_tic in missing_tic:
                temp_dict = {'ts_code':m_tic,'trade_date':date,'open':0, 'high':0,'low':0, 'close':0, 'pre_close':0, 'change':0, 'pct_chg':0, 'volume':0, 'amount':0}
                new_data = pd.DataFrame.from_dict(temp_dict,orient='index').T
                temp_df = temp_df.append(new_data)
            processe_df.append(temp_df)
        else :
            processe_df.append(temp_df)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
# 筛选exchange_calender中每个交易节点缺失(激进)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) == k:
            processe_df.append(temp_df)
        else :
            date_unique.remove(date)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
k=20
processed_df,date_unique = processed_date(df_ts,selected_tics,k)
print(processed_df)
# Out:
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      600196.SH   20190705  26.68  26.94  26.58  26.81      26.51    0.30
# 1      601012.SH   20190705  22.40  22.65  22.23  22.41      22.28    0.13
# 2      601628.SH   20190705  28.96  29.50  28.83  29.37      28.75    0.62
# 3      601318.SH   20190705  90.00  91.14  89.83  90.85      89.90    0.95
# 4      600028.SH   20190705   5.44   5.44   5.39   5.42       5.45   -0.03
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 11635  601601.SH   20211231  27.10  27.25  27.02  27.12      27.07    0.05
# 11636  600837.SH   20211231  12.29  12.33  12.24  12.26      12.23    0.03
# 11637  600196.SH   20211231  49.08  49.50  48.89  48.94      48.88    0.06
# 11638  601166.SH   20211231  19.11  19.16  18.98  19.04      19.05   -0.01
# 11639  601012.SH   20211231  84.00  87.33  84.00  86.20      81.23    4.97
#
#        pct_chg         vol        amount
# 0       1.1316   130610.00  3.500944e+05
# 1       0.5835   234298.90  5.267045e+05
# 2       2.1565   107013.64  3.131570e+05
# 3       1.0567   510522.42  4.623825e+06
# 4      -0.5505   627775.69  3.393007e+05
# ...        ...         ...           ...
# 11635   0.1847   189032.27  5.121428e+05
# 11636   0.2453   370912.03  4.556470e+05
# 11637   0.1227   193532.89  9.507004e+05
# 11638  -0.0525   553909.08  1.055757e+06
# 11639   6.1184  1213771.67  1.042053e+07
#
# [11640 rows x 11 columns]

# %%
processed_df1 = processed_df
processed_df1 = processed_df1.sort_values(['ts_code','trade_date'],ascending=True,ignore_index=True)
processed_df1['trade_date'] = pd.to_datetime(processed_df1['trade_date'])
processed_df1
# Out:
#          ts_code trade_date  open  high   low  close  pre_close  change  \
# 0      600028.SH 2019-07-05  5.44  5.44  5.39   5.42       5.45   -0.03
# 1      600028.SH 2019-07-08  5.40  5.40  5.31   5.33       5.42   -0.09
# 2      600028.SH 2019-07-09  5.32  5.33  5.25   5.26       5.33   -0.07
# 3      600028.SH 2019-07-10  5.28  5.28  5.19   5.20       5.26   -0.06
# 4      600028.SH 2019-07-11  5.24  5.25  5.20   5.22       5.20    0.02
# ...          ...        ...   ...   ...   ...    ...        ...     ...
# 11635  601939.SH 2021-12-27  5.89  5.90  5.87   5.87       5.91   -0.04
# 11636  601939.SH 2021-12-28  5.88  5.92  5.87   5.91       5.87    0.04
# 11637  601939.SH 2021-12-29  5.89  5.91  5.86   5.87       5.91   -0.04
# 11638  601939.SH 2021-12-30  5.87  5.88  5.85   5.87       5.87    0.00
# 11639  601939.SH 2021-12-31  5.86  5.87  5.84   5.86       5.87   -0.01
#
#        pct_chg        vol      amount
# 0      -0.5505  627775.69  339300.667
# 1      -1.6605  744931.97  397754.447
# 2      -1.3133  800600.38  422483.926
# 3      -1.1407  875894.77  457463.227
# 4       0.3846  974981.99  509302.550
# ...        ...        ...         ...
# 11635  -0.6768  478058.91  281176.898
# 11636   0.6814  593569.65  350286.115
# 11637  -0.6768  476374.64  280098.450
# 11638   0.0000  471583.95  276509.056
# 11639  -0.1704  490953.91  287442.721
#
# [11640 rows x 11 columns]

# %%
#出现缺失值的个数、占比
count = len(pro_df[pro_df['open'] == 0])
nan_rate = count/len(pro_df)
print(count,'缺失值百分之:',nan_rate)

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=False,
                    use_turbulence=True,
                    user_defined_feature = False)

# %%
processed_df3 = processed_df1.rename(columns={'ts_code':'tic','trade_date':'date','vol':'volume'})
processed_df3 = fe.preprocess_data(processed_df3)
processed_df3 = processed_df3.fillna(method="ffill").fillna(method="bfill")
processed_df3 = processed_df3.sort_values(['tic','date'],ascending=True).reset_index()
# Out:
# Successfully added technical indicators

# %%
def delaydate(dela,full_list):
    grouped = processed_df3.groupby('tic')
    filtered_df = pd.DataFrame()
    for name, group in grouped:
        # 按'trade_date'升序排序  True=升序
        group = group.sort_values('date', ascending=True)
        
        # 丢弃前48个日期的数据
        group = group.iloc[dela:]
        filtered_df = filtered_df.append(group)
    
    filtered_df = filtered_df.reset_index(drop=True)
    filtered_df = filtered_df.sort_values(['tic','date'],ascending=True,ignore_index=True)
    return filtered_df

# %%
pro_df = processed_df1.loc[:,['open','high','low','close','vol']].reset_index(drop=True)

# %%
#计算技术指标到dataset中
#Can be easily expanded
#Currently contains a small set of tech indicators
import talib as ta

def calc_tech_ind(data):
    #overlap 
    data['upbd'], data['midbd'], data['lowbd'] = ta.BBANDS(data["close"])
    data['dema'] = ta.DEMA(data["close"], timeperiod=30)
    data['tema'] = ta.TEMA(data["close"], timeperiod=30)
    data['ema'] = ta.EMA(data["close"], timeperiod=30)
    data['wma'] = ta.WMA(data["close"], timeperiod=30)
    data['sma'] = ta.SMA(data["close"], timeperiod=30)
    data['sarext'] = ta.SAREXT(data["high"], data["low"])
    
    #momentum
    data['adxr'] = ta.ADXR(data["high"], data["low"], data["close"], timeperiod=14)
    data['apo'] = ta.APO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['aroondown'], data['aroonup'] = ta.AROON(data["high"], data["low"], timeperiod=14)
    data['cci'] = ta.CCI(data["high"], data["low"], data["close"], timeperiod=14)
    data['cmo'] = ta.CMO(data["close"], timeperiod=14)
    data['macd'], data['macdsignal'], data['macdhist'] = ta.MACD(data["close"], fastperiod=12, slowperiod=26, signalperiod=9)
    data['MFI'] = ta.MFI(data["high"], data["low"], data["close"], data['vol'], timeperiod=14)
    data['mom'] = ta.MOM(data["close"], timeperiod=10)
    data['plus_di'] = ta.PLUS_DI(data["high"], data["low"], data["close"], timeperiod=14)
    data['ppo'] = ta.PPO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['roc'] = ta.ROC(data["close"], timeperiod=10)
    data['rocp'] = ta.ROCP(data["close"], timeperiod=10)
    data['rsi'] = ta.RSI(data["close"], timeperiod=14)
    data['slowk'], data['slowd'] = ta.STOCH(data["high"], data["low"], data["close"])
    data['fastk'], data['fastd'] = ta.STOCHF(data["high"], data["low"], data["close"])
    data['trix'] = ta.TRIX(data["close"], timeperiod=30)
    data['ultosc'] = ta.ULTOSC(data["high"], data["low"], data["close"], timeperiod1=7, timeperiod2=14, timeperiod3=28)
    data['willr'] = ta.WILLR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #volume
    data['ad'] = ta.AD(data["high"], data["low"], data["close"], data['vol'])
    data['obv'] = ta.OBV(data["close"], data['vol'])
    
    #volitility
    data['atr'] = ta.ATR(data["high"], data["low"], data["close"], timeperiod=14)
    data['natr'] = ta.NATR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #cycle
    data['HT_DCPERIOD'] = ta.HT_DCPERIOD(data["close"])
#     data['HT_DCPHASE'] = ta.HT_DCPHASE(data["close"])
#     data['inphase'], data['quadrature'] = ta.HT_PHASOR(data["close"])
    
    
    return data

# %%
full_list1 = calc_tech_ind(pro_df)
full_list1 = full_list1.fillna(0)

# %%
array_full_list = np.array(full_list1)
array_full_list = array_full_list.reshape(k,int(len(full_list1)/k),full_list1.shape[1])
selected_tics = sorted(selected_tics)

# %%
df.tic.value_counts()

# %% [markdown]
# # Part 2: DeepLearning representation

# %%
#generate x, y, z, zp quadruples
#segment x, y, z trios to sequence according to $timeStep and $gap
#x: historical data w/ technical analysis indicator
#y: closing price of t+1
#z:  difference between t+1 and t step's closing price

def toSequential_train1(idx, full_list, timeStep=48, gap=4):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
#     closingNorm = (closing - closing.mean())/closing.std()
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    for i in range(count):
        #segData dims: [timestep, feature count]       
        segData=data[gap*i:gap*i+timeStep]
        segClosing=closing[gap*i:gap*i+timeStep+1]
        #segDiff=diff[gap*i:gap*i+timeStep]
        #normalization
        
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
#         segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        segDataNorm=np.nan_to_num((segData-segData.mean(axis=0, keepdims=True))/segData.std(axis=0, keepdims=True))
    
        std_close = segClosing.std()
        std_segClosing = np.where(std_close == 0, 1, std_close)
        segClosingNorm=(segClosing-segClosing.mean())/std_segClosing
#         segDiff=(segDiff-segDiff.mean())/segDiff.std()
        
        stockSeq.append(segDataNorm)
        labelSeq.append(segClosingNorm[1:])
        diffSeq.append(segClosingNorm[1:]-segClosingNorm[:-1])
        realDiffSeq.append(segClosing[1:]-segClosing[:-1])
    stockSeq=np.array(stockSeq)
    labelSeq=np.array(labelSeq)
    diffSeq=np.array(diffSeq)
    realDiffSeq=np.array(realDiffSeq)
    return stockSeq.astype('float32') , labelSeq.astype('float32'), diffSeq.astype('float32'), realDiffSeq.astype('float32')

# %%
def toSequential_back(idx, full_list, timeStep = 48, gap = 1,batch_size = 64):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    
    start = data_length - timeStep
    i=0
    while start >= 0:
        segData = data[start:start + timeStep]
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
        segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        #复制batch_size个
        stockSeq.extend([segDataNorm] * batch_size)
#         stockSeq.append(segDataNorm)   
        start = start - gap
        i +=1
    stockSeq=np.array(stockSeq)[::-1]
#     print(i)
    return stockSeq.astype('float32')

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=3):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        closing_cohort=[]
        diff_cohort=[]
        real_diff_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X, y, z, zp=toSequential_train1(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
            closing_cohort.append(y)
            diff_cohort.append(z)
            real_diff_cohort.append(zp)
        self.X=np.concatenate(stock_cohort, axis=0)
        self.y=np.concatenate(closing_cohort, axis=0)
        self.z=np.concatenate(diff_cohort, axis=0)  
        self.zp=np.concatenate(real_diff_cohort, axis=0)
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        label1=self.y[idx]
        label2=self.z[idx]
        label3=self.zp[idx]
        if self.transform:
            data=self.transform(data)
        return (data, label1, label2, label3)
    
    
    def getDS(self):
        return self.X, self.y, self.z, self.zp

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset_back(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=1):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X=toSequential_back(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
        self.X=np.concatenate(stock_cohort, axis=0)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        if self.transform:
            data=self.transform(data)
        return data
        
    def getDS(self):
        return self.X

# %%
#Generation of training, validation, and testing dataset
def DataIterGen(test_id_list, val_id_list, name_list, full_list, demo=False):
    """
    test_id_list: id of subjects for testing
    val_id_list: id of subjects for validation
    other subjects for training
    full_list=get_data_set(name_list), preprocessed
    demo: when demo mode is True, only test_iter is returned, with data from
    first entry of test_id_list (single stock)
    """
    name_count=len(name_list)

    if demo:
        test_iter=DataLoader(StockDataset(test_id_list[0:1], full_list, timestep=24, gap=1), shuffle=False, batch_size=64, num_workers=0)
        print(f'Demo with stock: {name_list[test_id_list[0]]} ')
        return test_iter
    else:
        all_ids = list(range(name_count))
        train_id_list = list(set(all_ids) - set(test_id_list) - set(val_id_list))
#         partial_list=full_list[train_list,:,:]
        test_iter=DataLoader(StockDataset(test_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        val_iter=DataLoader(StockDataset(val_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        train_iter=DataLoader(StockDataset(train_id_list, full_list), shuffle=True, batch_size=64, num_workers=0,drop_last=True)
        print(f'Val: {[name_list[val_id] for val_id in val_id_list]}, Test: {[name_list[test_id] for test_id in test_id_list]}, Train: {[name_list[train_id] for train_id in train_id_list]} ')
        return train_iter, val_iter, test_iter

# %%
train_iter, val_iter, test_iter = DataIterGen([3],[4],selected_tics,array_full_list)
# Out:
# Val: ['600340.SH'], Test: ['600196.SH'], Train: ['600028.SH', '600030.SH', '600050.SH', '600547.SH', '600585.SH', '600837.SH', '601012.SH', '601066.SH', '601166.SH', '601211.SH', '601236.SH', '601318.SH', '601319.SH', '601601.SH', '601628.SH', '601688.SH', '601766.SH', '601939.SH']

# %% [markdown]
# # Part3: Transformer

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class TransformerEncoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers,dropout_rate):
#         super(TransformerEncoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_moedl * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_moedl)
#         self.num_layers = num_layers

#     def forward(self, x):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#         return x

# %%
# class TransformerDecoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, env_size, num_layers, dropout_rate):
#         super(TransformerDecoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.encoder_attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_model * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout3 = nn.Dropout(dropout_rate)
#         self.layer_norm3 = nn.LayerNorm(d_model)
#         self.linear1 = nn.Linear(d_model, env_size)
#         self.linear2 = nn.Linear(env_size,1)
#         self.num_layers = num_layers

#     def forward(self, x, encoder_output, target_mask, target_padding_mask):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x, attn_mask=target_mask)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x, _ = self.encoder_attention(x, encoder_output, encoder_output,key_padding_mask =target_padding_mask)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout3(x)
#             x = self.layer_norm3(x + residual)
#         env_size = self.linear1(x)
#         x = self.linear2(env_size).permute(1,0,2)
#         return x, env_size.permute(1,0,2)[0,-1,:]

# %%
# class Transformer(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers, env_size, dropout_rate):
#         super(Transformer, self).__init__()
#         self.encoder = TransformerEncoder(input_size, d_model, num_heads, num_layers,dropout_rate)
#         self.decoder = TransformerDecoder(input_size, d_model, num_heads, env_size, num_layers,dropout_rate)

#     def forward(self, input_seq, target_seq):
#         encoder_output = self.encoder(input_seq)
#         target_mask = self.generate_attention_mask(target_seq)
#         target_padding_mask = self.generate_padding_mask(target_seq)
#         decoder_output = self.decoder(target_seq, encoder_output)
#         return decoder_output
    
#     def generate_attention_mask(self, sequence):
#         attn_mask = torch.triu(torch.ones(sequence.size(1), sequence.size(1)), diagonal=1).bool().to(sequence.device)
#         return attn_mask

#     def generate_padding_mask(self, sequence):
#         padding_mask = (sequence == 0).to(sequence.device)
#         return padding_mask

# %%
# #模型训练
# def train(model, train_iter, optimizer, num_epochs): 
#     # 训练循环
#     for epoch in range(num_epochs):
#         model.train()
#         total_loss = 0.0
#         enVec_list = []
#         for X, y, z, zp in train_iter:  
#             optimizer.zero_grad()

#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred,enVec = model(inputs,targets)
#             enVec_list.append(enVec)
#             print(pred,targets)
#             loss = nn.MSELoss()(pred, targets)  
#             loss.backward()
#             optimizer.step()
#             total_loss += loss.item()

#         # 打印每个 epoch 的损失
#         print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
#     return enVec_list
# # 模型评估
# def val(model, val_iter):
#     model.eval()
#     total_loss = 0.0
#     enVec_list = []
#     with torch.no_grad():
#         for X, y, z, zp in val_iter: 
#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred, enVec = model(inputs)
#             enVec_list.append(enVec)
#             loss = nn.MSELoss()(pred, targets)  
#             total_loss += loss.item()
#     print(f"val Loss: {total_loss/len(val_iter):.4f}")
#     return enVec_list

# %%
# # 定义模型
# model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, num_heads = 8,env_size =40,dropout_rate=0.2)
# optimizer = optim.Adam(model.parameters(), lr=0.001)
# outcoming =train(model,train_iter,optimizer,5)
# valtest =val(model,val_iter)

# %%
# def predict(model,back_iter):
#     enVec_list = []
#     with torch.no_grad():
#         for X in back_iter:
#             inputs = X.to(device)
#             _,enVec = model(inputs)
#             enVec_list.append(enVec)
#     return enVec_list

# %%
# #define device
# def try_gpu(i=0):
#     """Return gpu(i) if exists, otherwise return cpu()."""
#     if torch.cuda.device_count() >= i + 1:
#         return torch.device(f'cuda:{i}')
#     return torch.device('cpu')
# device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers,dropout_rate):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers,dropout_rate)
        self.linear1 = nn.Linear(d_model, env_size)
        self.rule = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.rule(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers,dropout_rate):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads,dropout_rate) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads,dropout_rate):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = self.dropout1(x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = self.dropout2(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
def predict(model,back_iter):
    enVec_list = []
    with torch.no_grad():
        for X in back_iter:
            inputs = X.to(device)
            _,enVec = model(inputs)
            enVec_list.append(enVec)
    return enVec_list

# %%
#define device
def try_gpu(i=0):
    """Return gpu(i) if exists, otherwise return cpu()."""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers)
        self.linear1 = nn.Linear(d_model, env_size)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.relu(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming =train(model,train_iter,optimizer,5)
valtest =val(model,val_iter)
# Out:
# Epoch 1: Loss: 0.2550
# Epoch 2: Loss: 0.1805
# Epoch 3: Loss: 0.1492
# Epoch 4: Loss: 0.1216
# Epoch 5: Loss: 0.0940
# val Loss: 0.0973

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40,dropout_rate=0.1)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming = train(model,train_iter,optimizer,5)
valtest =val(model,val_iter)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# feature_enginner
import time 
start_time = time.time()
alltic_list = [i for i in range(k)]

def Feature_enginner(model, processed_df, full_list, alltic_list, batch_size=64, k=20, env_size=40,dela = 48):
    back_iter = DataLoader(StockDataset_back([i for i in range(k)],full_list), shuffle=False, batch_size=batch_size, num_workers=0,drop_last=False)
    
    new_state = predict(model,back_iter)
    concatenated_tensor = torch.cat(new_state, dim=0)
    concatenated_tensor = concatenated_tensor.view(-1,env_size)
    feature_df = pd.DataFrame(concatenated_tensor.numpy())
    
    full_delay_df = delaydate(dela ,processed_df)
    
    merged_df = pd.concat([full_delay_df, feature_df], axis=1)
    merged_df = merged_df.loc[:,['tic','date','close'] + INDICATORS + [i for i in range(env_size)]]
    merged_df.columns = ['tic','date','close'] + INDICATORS + [f"temporal_feature_{i}" for i in range(env_size)]
    end_time = time.time()
    print('总计消耗时间:',(end_time - start_time)/60)
    return merged_df

# %%
addfeature_df = Feature_enginner(model, processed_df3, array_full_list, alltic_list, batch_size=64, k=20 ,env_size=40, dela=48)
# Out:
# 总计消耗时间: 2.942937382062276

# %%
addfeature_df.to_csv('724addfeature_df.csv',index=None)

# %%
addfeature_df = pd.read_csv('724addfeature_df.csv')

# %%
addfeature_df['date'] = pd.to_datetime(addfeature_df['date'])

# %%
processed_df3.to_csv('724_processed_best.csv',index=None)

# %%
processed_df3 = pd.read_csv('724_processed_best.csv')

# %%
processed_df3['date'] = pd.to_datetime(processed_df3['date'])

# %%
processed_df3 = fe.add_turbulence(processed_df3)
processed_df3 = processed_df3.fillna(method="ffill").fillna(method="bfill")

# %%
import datetime
processed['date'] = pd.to_datetime(processed['date'],format='%Y%m%d')
processed

# %%
list_ticker = processed["tic"].unique().tolist()
# list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
# combination = list(itertools.product(list_date,list_ticker))

# processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
# processed_full = processed_full[processed_full['date'].isin(processed['date'])]
# processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
selfattn_indicator_list = [f"temporal_feature_{i}" for i in range(40)]

# %%
selected_tics = addfeature_df.tic.unique()
selected_tics
# Out:
# array(['600028.SH', '600030.SH', '600050.SH', '600196.SH', '600340.SH',
#        '600547.SH', '600585.SH', '600837.SH', '601012.SH', '601066.SH',
#        '601166.SH', '601211.SH', '601236.SH', '601318.SH', '601319.SH',
#        '601601.SH', '601628.SH', '601688.SH', '601766.SH', '601939.SH'],
#       dtype=object)

# %%
TRAIN_START_DATE = addfeature_df['date'].unique()[0]

# %%
TRAIN_START_DATE

# %%
stock_dimension = 20
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension + len(selfattn_indicator_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 1001

# %%
stock_dimension = len(processed_df3.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 201

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed_df3,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TRADE_START_DATE,TRADE_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
#                  attn_indicator_list = selfattn_indicator_list,                 
                 **env_kwargs)

# %%
TRADE_END_DATE
# Out:
# '2022-05-30'

# %%
SAC_model_kwargs = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
                }

PPO_model_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
                    }

TD3_model_kwargs = {
    "batch_size": 128, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
                }

timesteps_dict = {'sac' : 10000, 
                 'ppo' : 10000, 
                 'td3' : 10000
                 }

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  0.0
# ======Model training from:  2012-10-10 to  2020-03-02T00:00:00.000000000
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_2
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1118          |
# |    iterations         | 100           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -29.2         |
# |    explained_variance | -2.38e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | -0.0339       |
# |    reward             | -0.0008649304 |
# |    std                | 1.04          |
# |    value_loss         | 4.68e-06      |
# -----------------------------------------
# day: 155, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1020350.40
# total_reward: 20350.40
# total_cost: 3561.97
# total_trades: 2682
# Sharpe: 0.261
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1196          |
# |    iterations         | 200           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -29.5         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | 0.288         |
# |    reward             | -0.0048599876 |
# |    std                | 1.06          |
# |    value_loss         | 7.6e-05       |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1227           |
# |    iterations         | 300            |
# |    time_elapsed       | 1              |
# |    total_timesteps    | 1500           |
# | train/                |                |
# |    entropy_loss       | -29.9          |
# |    explained_variance | -515           |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 299            |
# |    policy_loss        | 2.93           |
# |    reward             | -9.6301635e-05 |
# |    std                | 1.08           |
# |    value_loss         | 0.0158         |
# ------------------------------------------
# day: 155, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1046524.23
# total_reward: 46524.23
# total_cost: 3788.84
# total_trades: 2752
# Sharpe: 0.454
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1194          |
# |    iterations         | 400           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -30.2         |
# |    explained_variance | -854          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | -2.92         |
# |    reward             | -0.0019102301 |
# |    std                | 1.09          |
# |    value_loss         | 0.0173        |
# -----------------------------------------
# day: 155, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1047664.49
# total_reward: 47664.49
# total_cost: 4266.99
# total_trades: 2770
# Sharpe: 0.460
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1208         |
# |    iterations         | 500          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -30.4        |
# |    explained_variance | -28.6        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | -0.862       |
# |    reward             | 8.284141e-06 |
# |    std                | 1.11         |
# |    value_loss         | 0.00212      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1212         |
# |    iterations         | 600          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -30.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | -0.231       |
# |    reward             | -0.006261316 |
# |    std                | 1.12         |
# |    value_loss         | 5.12e-05     |
# ----------------------------------------
# day: 155, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1028432.50
# total_reward: 28432.50
# total_cost: 4165.13
# total_trades: 2714
# Sharpe: 0.324
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1201         |
# |    iterations         | 700          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -31          |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -2.36        |
# |    reward             | 6.908619e-05 |
# |    std                | 1.14         |
# |    value_loss         | 0.00488      |
# ----------------------------------------
# day: 155, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1055177.17
# total_reward: 55177.17
# total_cost: 4382.93
# total_trades: 2756
# Sharpe: 0.548
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1209          |
# |    iterations         | 800           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -31.3         |
# |    explained_variance | -8.45         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 0.093         |
# |    reward             | -0.0022339444 |
# |    std                | 1.16          |
# |    value_loss         | 6.18e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1211          |
# |    iterations         | 900           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -31.6         |
# |    explained_variance | -356          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | -1.39         |
# |    reward             | 0.00026527923 |
# |    std                | 1.18          |
# |    value_loss         | 0.0049        |
# -----------------------------------------
# day: 155, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1047787.30
# total_reward: 47787.30
# total_cost: 4467.84
# total_trades: 2726
# Sharpe: 0.472
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1216          |
# |    iterations         | 1000          |
# |    time_elapsed       | 4             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -31.9         |
# |    explained_variance | -2.69         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | 2.82          |
# |    reward             | -5.463293e-05 |
# |    std                | 1.19          |
# |    value_loss         | 0.0175        |
# -----------------------------------------
# day: 155, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1067632.52
# total_reward: 67632.52
# total_cost: 4203.45
# total_trades: 2670
# Sharpe: 0.604
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1200         |
# |    iterations         | 1100         |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -32.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | -0.138       |
# |    reward             | 0.0008474742 |
# |    std                | 1.21         |
# |    value_loss         | 2.6e-05      |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1180           |
# |    iterations         | 1200           |
# |    time_elapsed       | 5              |
# |    total_timesteps    | 6000           |
# | train/                |                |
# |    entropy_loss       | -32.5          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1199           |
# |    policy_loss        | 0.0126         |
# |    reward             | -0.00016697336 |
# |    std                | 1.23           |
# |    value_loss         | 2.64e-07       |
# ------------------------------------------
# day: 155, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1022329.74
# total_reward: 22329.74
# total_cost: 3964.44
# total_trades: 2695
# Sharpe: 0.281
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1172          |
# |    iterations         | 1300          |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -32.8         |
# |    explained_variance | -289          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | -0.859        |
# |    reward             | -0.0028769635 |
# |    std                | 1.25          |
# |    value_loss         | 0.00425       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1169         |
# |    iterations         | 1400         |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -33.1        |
# |    explained_variance | -328         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | -3.41        |
# |    reward             | 0.0013278923 |
# |    std                | 1.27         |
# |    value_loss         | 0.011        |
# ----------------------------------------
# day: 155, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 984535.63
# total_reward: -15464.37
# total_cost: 3864.88
# total_trades: 2609
# Sharpe: -0.045
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1176          |
# |    iterations         | 1500          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -33.4         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1499          |
# |    policy_loss        | -0.188        |
# |    reward             | -9.238016e-05 |
# |    std                | 1.29          |
# |    value_loss         | 4.1e-05       |
# -----------------------------------------
# day: 155, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 920922.37
# total_reward: -79077.63
# total_cost: 3675.05
# total_trades: 2443
# Sharpe: -0.648
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1182          |
# |    iterations         | 1600          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -33.8         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | -0.127        |
# |    reward             | 0.00013256948 |
# |    std                | 1.31          |
# |    value_loss         | 2.36e-05      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1188         |
# |    iterations         | 1700         |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -34.1        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | 0.296        |
# |    reward             | -0.011582425 |
# |    std                | 1.33         |
# |    value_loss         | 7.98e-05     |
# ----------------------------------------
# day: 155, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 918183.28
# total_reward: -81816.72
# total_cost: 3489.27
# total_trades: 2385
# Sharpe: -0.675
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1193          |
# |    iterations         | 1800          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -34.4         |
# |    explained_variance | -149          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | -0.588        |
# |    reward             | -0.0004520215 |
# |    std                | 1.35          |
# |    value_loss         | 0.000817      |
# -----------------------------------------
# day: 155, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 918869.56
# total_reward: -81130.44
# total_cost: 3587.88
# total_trades: 2311
# Sharpe: -0.699
# =================================
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1199           |
# |    iterations         | 1900           |
# |    time_elapsed       | 7              |
# |    total_timesteps    | 9500           |
# | train/                |                |
# |    entropy_loss       | -34.8          |
# |    explained_variance | -0.0539        |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1899           |
# |    policy_loss        | 0.151          |
# |    reward             | -0.00015545398 |
# |    std                | 1.38           |
# |    value_loss         | 2.73e-05       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1204          |
# |    iterations         | 2000          |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -35.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | 0.0753        |
# |    reward             | -0.0002788408 |
# |    std                | 1.41          |
# |    value_loss         | 8.29e-06      |
# -----------------------------------------
# ======A2C Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# A2C Sharpe Ratio:  0.0
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_68
# day: 155, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 998795.27
# total_reward: -1204.73
# total_cost: 4323.94
# total_trades: 2925
# Sharpe: -0.017
# =================================
# day: 155, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 997570.11
# total_reward: -2429.89
# total_cost: 4277.68
# total_trades: 2895
# Sharpe: -0.060
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 1767          |
# |    iterations      | 1             |
# |    time_elapsed    | 1             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00025889854 |
# --------------------------------------
# day: 155, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1007037.49
# total_reward: 7037.49
# total_cost: 4227.71
# total_trades: 2874
# Sharpe: 0.230
# =================================
# day: 155, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1008900.23
# total_reward: 8900.23
# total_cost: 4364.30
# total_trades: 2947
# Sharpe: 0.259
# =================================
# day: 155, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 989107.50
# total_reward: -10892.50
# total_cost: 4519.44
# total_trades: 2948
# Sharpe: -0.274
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1612         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.01049919   |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.262       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00732     |
# |    reward               | 9.174478e-06 |
# |    std                  | 1            |
# |    value_loss           | 0.0465       |
# ------------------------------------------
# day: 155, episode: 95
# begin_total_asset: 1000000.00
# end_total_asset: 1029523.49
# total_reward: 29523.49
# total_cost: 4431.48
# total_trades: 2957
# Sharpe: 0.770
# =================================
# day: 155, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 998729.43
# total_reward: -1270.57
# total_cost: 4307.48
# total_trades: 2902
# Sharpe: -0.022
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1579          |
# |    iterations           | 3             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.00937924    |
# |    clip_fraction        | 0.112         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.5         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.284        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00977      |
# |    reward               | 0.00023803925 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0277        |
# -------------------------------------------
# day: 155, episode: 105
# begin_total_asset: 1000000.00
# end_total_asset: 1004376.54
# total_reward: 4376.54
# total_cost: 4382.11
# total_trades: 2951
# Sharpe: 0.153
# =================================
# day: 155, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 990386.64
# total_reward: -9613.36
# total_cost: 4381.67
# total_trades: 2878
# Sharpe: -0.191
# =================================
# day: 155, episode: 115
# begin_total_asset: 1000000.00
# end_total_asset: 988998.17
# total_reward: -11001.83
# total_cost: 4429.31
# total_trades: 2940
# Sharpe: -0.314
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1566         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.009477505  |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.289       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00765     |
# |    reward               | -0.000192333 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0144       |
# ------------------------------------------
# day: 155, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 995177.27
# total_reward: -4822.73
# total_cost: 4474.88
# total_trades: 2878
# Sharpe: -0.110
# =================================
# day: 155, episode: 125
# begin_total_asset: 1000000.00
# end_total_asset: 979883.75
# total_reward: -20116.25
# total_cost: 4280.24
# total_trades: 2919
# Sharpe: -0.578
# =================================
# day: 155, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1000162.02
# total_reward: 162.02
# total_cost: 4442.09
# total_trades: 2940
# Sharpe: 0.032
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1559          |
# |    iterations           | 5             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.0084646465  |
# |    clip_fraction        | 0.0948        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.6         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.298        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00856      |
# |    reward               | 3.9749597e-05 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0135        |
# -------------------------------------------
# ======PPO Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# PPO Sharpe Ratio:  0.0
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_2
# day: 155, episode: 135
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 310          |
# |    time_elapsed    | 2            |
# |    total_timesteps | 624          |
# | train/             |              |
# |    actor_loss      | -342         |
# |    critic_loss     | 358          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 468          |
# |    reward          | -0.005410951 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 273          |
# |    time_elapsed    | 4            |
# |    total_timesteps | 1248         |
# | train/             |              |
# |    actor_loss      | -210         |
# |    critic_loss     | 46.8         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 1092         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 262          |
# |    time_elapsed    | 7            |
# |    total_timesteps | 1872         |
# | train/             |              |
# |    actor_loss      | -152         |
# |    critic_loss     | 171          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 1716         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 145
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 257          |
# |    time_elapsed    | 9            |
# |    total_timesteps | 2496         |
# | train/             |              |
# |    actor_loss      | -110         |
# |    critic_loss     | 70.3         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 2340         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 252          |
# |    time_elapsed    | 12           |
# |    total_timesteps | 3120         |
# | train/             |              |
# |    actor_loss      | -78.5        |
# |    critic_loss     | 81.7         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 2964         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 155
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 250          |
# |    time_elapsed    | 14           |
# |    total_timesteps | 3744         |
# | train/             |              |
# |    actor_loss      | -60.9        |
# |    critic_loss     | 6.13e+03     |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 3588         |
# |    reward          | -0.005410951 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 28           |
# |    fps             | 250          |
# |    time_elapsed    | 17           |
# |    total_timesteps | 4368         |
# | train/             |              |
# |    actor_loss      | -32.4        |
# |    critic_loss     | 196          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 4212         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 32           |
# |    fps             | 249          |
# |    time_elapsed    | 20           |
# |    total_timesteps | 4992         |
# | train/             |              |
# |    actor_loss      | -15.9        |
# |    critic_loss     | 1.35e+04     |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 4836         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 165
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 36           |
# |    fps             | 248          |
# |    time_elapsed    | 22           |
# |    total_timesteps | 5616         |
# | train/             |              |
# |    actor_loss      | -6.21        |
# |    critic_loss     | 157          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 5460         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 40           |
# |    fps             | 246          |
# |    time_elapsed    | 25           |
# |    total_timesteps | 6240         |
# | train/             |              |
# |    actor_loss      | 4.14         |
# |    critic_loss     | 7.27e+03     |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 6084         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 175
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 44           |
# |    fps             | 245          |
# |    time_elapsed    | 27           |
# |    total_timesteps | 6864         |
# | train/             |              |
# |    actor_loss      | -121         |
# |    critic_loss     | 30.4         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 6708         |
# |    reward          | -0.005410951 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 48           |
# |    fps             | 245          |
# |    time_elapsed    | 30           |
# |    total_timesteps | 7488         |
# | train/             |              |
# |    actor_loss      | -101         |
# |    critic_loss     | 35.7         |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 7332         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 52           |
# |    fps             | 245          |
# |    time_elapsed    | 33           |
# |    total_timesteps | 8112         |
# | train/             |              |
# |    actor_loss      | -77.8        |
# |    critic_loss     | 164          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 7956         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 185
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 56           |
# |    fps             | 245          |
# |    time_elapsed    | 35           |
# |    total_timesteps | 8736         |
# | train/             |              |
# |    actor_loss      | -51.7        |
# |    critic_loss     | 467          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 8580         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 60           |
# |    fps             | 245          |
# |    time_elapsed    | 38           |
# |    total_timesteps | 9360         |
# | train/             |              |
# |    actor_loss      | -33.4        |
# |    critic_loss     | 480          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 9204         |
# |    reward          | -0.005410951 |
# -------------------------------------
# day: 155, episode: 195
# begin_total_asset: 1000000.00
# end_total_asset: 1016509.87
# total_reward: 16509.87
# total_cost: 999.00
# total_trades: 1395
# Sharpe: 0.236
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 64           |
# |    fps             | 245          |
# |    time_elapsed    | 40           |
# |    total_timesteps | 9984         |
# | train/             |              |
# |    actor_loss      | -19.6        |
# |    critic_loss     | 374          |
# |    learning_rate   | 0.0005       |
# |    n_updates       | 9828         |
# |    reward          | -0.005410951 |
# -------------------------------------
# ======DDPG Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Best Model Retraining from:  2012-10-10 to  2020-06-03T00:00:00.000000000
# ======Trading from:  2020-06-03T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# ============================================
# turbulence_threshold:  0.0
# ======Model training from:  2012-10-10 to  2020-06-03T00:00:00.000000000
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_1
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1165          |
# |    iterations         | 100           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -29.5         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | -0.0173       |
# |    reward             | 2.5811012e-05 |
# |    std                | 1.06          |
# |    value_loss         | 1.13e-06      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1188          |
# |    iterations         | 200           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -30.4         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | -0.126        |
# |    reward             | -0.0008925082 |
# |    std                | 1.1           |
# |    value_loss         | 1.89e-05      |
# -----------------------------------------
# day: 218, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 940165.21
# total_reward: -59834.79
# total_cost: 5987.03
# total_trades: 3762
# Sharpe: -0.369
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1151          |
# |    iterations         | 300           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 1500          |
# | train/                |               |
# |    entropy_loss       | -31           |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 299           |
# |    policy_loss        | 0.335         |
# |    reward             | 0.00021796906 |
# |    std                | 1.14          |
# |    value_loss         | 0.00022       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1138         |
# |    iterations         | 400          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -31.6        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.123        |
# |    reward             | 0.0003217458 |
# |    std                | 1.18         |
# |    value_loss         | 3.52e-05     |
# ----------------------------------------
# day: 218, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 975028.29
# total_reward: -24971.71
# total_cost: 4725.72
# total_trades: 3114
# Sharpe: -0.267
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1151          |
# |    iterations         | 500           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -32.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | 0.232         |
# |    reward             | 0.00010964448 |
# |    std                | 1.22          |
# |    value_loss         | 6.27e-05      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1162          |
# |    iterations         | 600           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -33.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -0.223        |
# |    reward             | -8.698391e-05 |
# |    std                | 1.26          |
# |    value_loss         | 5.77e-05      |
# -----------------------------------------
# day: 218, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1005148.14
# total_reward: 5148.14
# total_cost: 4269.35
# total_trades: 2895
# Sharpe: 0.114
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1170         |
# |    iterations         | 700          |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -33.8        |
# |    explained_variance | -2.78        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | 0.0756       |
# |    reward             | 0.0003146145 |
# |    std                | 1.31         |
# |    value_loss         | 6.8e-06      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1175        |
# |    iterations         | 800         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -34.5       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 0.0975      |
# |    reward             | 0.004093556 |
# |    std                | 1.36        |
# |    value_loss         | 8.95e-06    |
# ---------------------------------------
# day: 218, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 975272.25
# total_reward: -24727.75
# total_cost: 3844.69
# total_trades: 2805
# Sharpe: -0.149
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1178         |
# |    iterations         | 900          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -35.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 0.244        |
# |    reward             | 5.220992e-05 |
# |    std                | 1.41         |
# |    value_loss         | 6.52e-05     |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1181           |
# |    iterations         | 1000           |
# |    time_elapsed       | 4              |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -35.9          |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 999            |
# |    policy_loss        | -0.00514       |
# |    reward             | -0.00065313646 |
# |    std                | 1.46           |
# |    value_loss         | 2.22e-07       |
# ------------------------------------------
# day: 218, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 990821.75
# total_reward: -9178.25
# total_cost: 3845.90
# total_trades: 2746
# Sharpe: -0.045
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1182          |
# |    iterations         | 1100          |
# |    time_elapsed       | 4             |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -36.5         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | 0.187         |
# |    reward             | -0.0021636365 |
# |    std                | 1.5           |
# |    value_loss         | 3.49e-05      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1184           |
# |    iterations         | 1200           |
# |    time_elapsed       | 5              |
# |    total_timesteps    | 6000           |
# | train/                |                |
# |    entropy_loss       | -37.1          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1199           |
# |    policy_loss        | 0.0891         |
# |    reward             | -0.00015534577 |
# |    std                | 1.55           |
# |    value_loss         | 6.71e-06       |
# ------------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1185           |
# |    iterations         | 1300           |
# |    time_elapsed       | 5              |
# |    total_timesteps    | 6500           |
# | train/                |                |
# |    entropy_loss       | -37.7          |
# |    explained_variance | 1.19e-07       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1299           |
# |    policy_loss        | -0.0553        |
# |    reward             | -3.0948882e-05 |
# |    std                | 1.6            |
# |    value_loss         | 2.79e-06       |
# ------------------------------------------
# day: 218, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 973009.69
# total_reward: -26990.31
# total_cost: 3500.32
# total_trades: 2498
# Sharpe: -0.173
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1185         |
# |    iterations         | 1400         |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -38.4        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | 0.0431       |
# |    reward             | 0.0005868395 |
# |    std                | 1.65         |
# |    value_loss         | 1.21e-06     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1187         |
# |    iterations         | 1500         |
# |    time_elapsed       | 6            |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -39.3        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | -0.139       |
# |    reward             | -9.24009e-05 |
# |    std                | 1.72         |
# |    value_loss         | 2.04e-05     |
# ----------------------------------------
# day: 218, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 989992.27
# total_reward: -10007.73
# total_cost: 3659.19
# total_trades: 2627
# Sharpe: -0.119
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1187          |
# |    iterations         | 1600          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -40.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | -0.432        |
# |    reward             | 0.00023280713 |
# |    std                | 1.8           |
# |    value_loss         | 0.000148      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1188         |
# |    iterations         | 1700         |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -41          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | 0.382        |
# |    reward             | 0.0002747521 |
# |    std                | 1.88         |
# |    value_loss         | 0.000259     |
# ----------------------------------------
# day: 218, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 991231.94
# total_reward: -8768.06
# total_cost: 4141.34
# total_trades: 2707
# Sharpe: 0.021
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1189        |
# |    iterations         | 1800        |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 0.0212      |
# |    reward             | 0.001575272 |
# |    std                | 1.93        |
# |    value_loss         | 4.08e-07    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1189          |
# |    iterations         | 1900          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -42.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1899          |
# |    policy_loss        | 0.078         |
# |    reward             | -7.418523e-05 |
# |    std                | 1.99          |
# |    value_loss         | 4.91e-06      |
# -----------------------------------------
# day: 218, episode: 45
# ...
# | time/                 |             |
# |    fps                | 995         |
# |    iterations         | 1200        |
# |    time_elapsed       | 6           |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -33.8       |
# |    explained_variance | -349        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | 0.904       |
# |    reward             | 0.000198863 |
# |    std                | 1.31        |
# |    value_loss         | 0.00203     |
# ---------------------------------------
# day: 407, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1060851.39
# total_reward: 60851.39
# total_cost: 9253.82
# total_trades: 6648
# Sharpe: 0.274
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 996           |
# |    iterations         | 1300          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -34           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | -0.272        |
# |    reward             | 0.00067413785 |
# |    std                | 1.33          |
# |    value_loss         | 6.75e-05      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 997            |
# |    iterations         | 1400           |
# |    time_elapsed       | 7              |
# |    total_timesteps    | 7000           |
# | train/                |                |
# |    entropy_loss       | -34.3          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1399           |
# |    policy_loss        | 0.295          |
# |    reward             | -7.5360495e-06 |
# |    std                | 1.34           |
# |    value_loss         | 8.01e-05       |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 998          |
# |    iterations         | 1500         |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -34.6        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 0.062        |
# |    reward             | 0.0010474293 |
# |    std                | 1.37         |
# |    value_loss         | 8.91e-06     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1000         |
# |    iterations         | 1600         |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -35          |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.0374      |
# |    reward             | 0.0051564854 |
# |    std                | 1.39         |
# |    value_loss         | 0.000118     |
# ----------------------------------------
# day: 407, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1132124.35
# total_reward: 132124.35
# total_cost: 7449.19
# total_trades: 6583
# Sharpe: 0.427
# =================================
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1000           |
# |    iterations         | 1700           |
# |    time_elapsed       | 8              |
# |    total_timesteps    | 8500           |
# | train/                |                |
# |    entropy_loss       | -35.3          |
# |    explained_variance | -1.19e-07      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1699           |
# |    policy_loss        | -0.26          |
# |    reward             | -4.7416266e-05 |
# |    std                | 1.42           |
# |    value_loss         | 6.63e-05       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1001          |
# |    iterations         | 1800          |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -35.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 0.239         |
# |    reward             | 7.9354446e-05 |
# |    std                | 1.45          |
# |    value_loss         | 6.34e-05      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1002         |
# |    iterations         | 1900         |
# |    time_elapsed       | 9            |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -36.1        |
# |    explained_variance | -73.2        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | -0.434       |
# |    reward             | 0.0001483051 |
# |    std                | 1.48         |
# |    value_loss         | 0.00122      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1003          |
# |    iterations         | 2000          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -36.6         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | -0.0695       |
# |    reward             | -0.0017018109 |
# |    std                | 1.51          |
# |    value_loss         | 3.5e-05       |
# -----------------------------------------
# ======A2C Validation from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# A2C Sharpe Ratio:  0.0
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_378_40
# day: 407, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1042259.67
# total_reward: 42259.67
# total_cost: 12993.75
# total_trades: 7943
# Sharpe: 0.263
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 1279          |
# |    iterations      | 1             |
# |    time_elapsed    | 1             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 3.5771645e-05 |
# --------------------------------------
# day: 407, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 948350.78
# total_reward: -51649.22
# total_cost: 12153.39
# total_trades: 7746
# Sharpe: -0.308
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1211           |
# |    iterations           | 2              |
# |    time_elapsed         | 3              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.0128699355   |
# |    clip_fraction        | 0.175          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | 0.408          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.28          |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00928       |
# |    reward               | -0.00070866605 |
# |    std                  | 1.01           |
# |    value_loss           | 0.00755        |
# --------------------------------------------
# day: 407, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1020032.69
# total_reward: 20032.69
# total_cost: 12699.30
# total_trades: 7853
# Sharpe: 0.163
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1189        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016013859 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.32       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0135     |
# |    reward               | 0.001646851 |
# |    std                  | 1.01        |
# |    value_loss           | 0.00357     |
# -----------------------------------------
# day: 407, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 914308.01
# total_reward: -85691.99
# total_cost: 12967.47
# total_trades: 7910
# Sharpe: -0.391
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 4            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.012164072  |
# |    clip_fraction        | 0.175        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | -0.125       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.292       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0148      |
# |    reward               | -0.051404603 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00215      |
# ------------------------------------------
# day: 407, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 916568.72
# total_reward: -83431.28
# total_cost: 12469.69
# total_trades: 7807
# Sharpe: -0.404
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1172         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.011365965  |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.6        |
# |    explained_variance   | -1.37        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.306       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0192      |
# |    reward               | 0.0013529429 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00425      |
# ------------------------------------------
# ======PPO Validation from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# PPO Sharpe Ratio:  0.0
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_378_1
# day: 407, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1372404.68
# total_reward: 372404.68
# total_cost: 999.00
# total_trades: 4165
# Sharpe: 0.764
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 283           |
# |    time_elapsed    | 5             |
# |    total_timesteps | 1632          |
# | train/             |               |
# |    actor_loss      | -2.21e+03     |
# |    critic_loss     | 3.25e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 1224          |
# |    reward          | 0.00020843485 |
# --------------------------------------
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 253           |
# |    time_elapsed    | 12            |
# |    total_timesteps | 3264          |
# | train/             |               |
# |    actor_loss      | -1.39e+03     |
# |    critic_loss     | 1.9e+04       |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 2856          |
# |    reward          | 0.00020843485 |
# --------------------------------------
# day: 407, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1372404.68
# total_reward: 372404.68
# total_cost: 999.00
# total_trades: 4165
# Sharpe: 0.764
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 243           |
# |    time_elapsed    | 20            |
# |    total_timesteps | 4896          |
# | train/             |               |
# |    actor_loss      | -928          |
# |    critic_loss     | 1.06e+04      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 4488          |
# |    reward          | 0.00020843485 |
# --------------------------------------
# day: 407, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1372404.68
# total_reward: 372404.68
# total_cost: 999.00
# total_trades: 4165
# Sharpe: 0.764
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 238           |
# |    time_elapsed    | 27            |
# |    total_timesteps | 6528          |
# | train/             |               |
# |    actor_loss      | -625          |
# |    critic_loss     | 3.51e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 6120          |
# |    reward          | 0.00020843485 |
# --------------------------------------
# day: 407, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1372404.68
# total_reward: 372404.68
# total_cost: 999.00
# total_trades: 4165
# Sharpe: 0.764
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 20            |
# |    fps             | 234           |
# |    time_elapsed    | 34            |
# |    total_timesteps | 8160          |
# | train/             |               |
# |    actor_loss      | -422          |
# |    critic_loss     | 1.5e+03       |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 7752          |
# |    reward          | 0.00020843485 |
# --------------------------------------
# day: 407, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1372404.68
# total_reward: 372404.68
# total_cost: 999.00
# total_trades: 4165
# Sharpe: 0.764
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 24            |
# |    fps             | 232           |
# |    time_elapsed    | 42            |
# |    total_timesteps | 9792          |
# | train/             |               |
# |    actor_loss      | -268          |
# |    critic_loss     | 2.58e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 9384          |
# |    reward          | 0.00020843485 |
# --------------------------------------
# ======DDPG Validation from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Best Model Retraining from:  2012-10-10 to  2021-07-05T00:00:00.000000000
# ======Trading from:  2021-07-05T00:00:00.000000000 to  2021-10-27T00:00:00.000000000
# Ensemble Strategy took:  4.929322552680969  minutes

# %%
import torch
device = torch.device("mps")

# %%
df_summary = ensemble_agent.run_ensemble_strategy_com(SAC_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# ======Model training from:  2019-09-11T00:00:00.000000000 to  2020-03-02T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_56
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 107        |
# |    time_elapsed    | 4          |
# |    total_timesteps | 432        |
# | train/             |            |
# |    actor_loss      | -345       |
# |    critic_loss     | 138        |
# |    ent_coef        | 0.103      |
# |    ent_coef_loss   | 387        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 331        |
# |    reward          | -4.2711935 |
# -----------------------------------
# day: 107, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 925049.05
# total_reward: -74950.95
# total_cost: 2231.36
# total_trades: 1451
# Sharpe: -0.899
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 90        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 864       |
# | train/             |           |
# |    actor_loss      | -191      |
# |    critic_loss     | 155       |
# |    ent_coef        | 0.106     |
# |    ent_coef_loss   | 335       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 763       |
# |    reward          | -4.782584 |
# ----------------------------------
# day: 107, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1009205.65
# total_reward: 9205.65
# total_cost: 2028.20
# total_trades: 1379
# Sharpe: 0.208
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 86        |
# |    time_elapsed    | 14        |
# |    total_timesteps | 1296      |
# | train/             |           |
# |    actor_loss      | -84.1     |
# |    critic_loss     | 183       |
# |    ent_coef        | 0.11      |
# |    ent_coef_loss   | 306       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1195      |
# |    reward          | -4.481525 |
# ----------------------------------
# day: 107, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 923135.18
# total_reward: -76864.82
# total_cost: 1774.68
# total_trades: 1194
# Sharpe: -0.713
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 86        |
# |    time_elapsed    | 20        |
# |    total_timesteps | 1728      |
# | train/             |           |
# |    actor_loss      | -35.9     |
# |    critic_loss     | 89.1      |
# |    ent_coef        | 0.114     |
# |    ent_coef_loss   | 271       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1627      |
# |    reward          | -5.280788 |
# ----------------------------------
# day: 107, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 949853.08
# total_reward: -50146.92
# total_cost: 3706.76
# total_trades: 1731
# Sharpe: -0.502
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 85         |
# |    time_elapsed    | 25         |
# |    total_timesteps | 2160       |
# | train/             |            |
# |    actor_loss      | 38.1       |
# |    critic_loss     | 112        |
# |    ent_coef        | 0.118      |
# |    ent_coef_loss   | 241        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 2059       |
# |    reward          | -4.7179604 |
# -----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 85        |
# |    time_elapsed    | 30        |
# |    total_timesteps | 2592      |
# | train/             |           |
# |    actor_loss      | 93.2      |
# |    critic_loss     | 136       |
# |    ent_coef        | 0.122     |
# |    ent_coef_loss   | 236       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2491      |
# |    reward          | -6.137194 |
# ----------------------------------
# day: 107, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1028906.02
# total_reward: 28906.02
# total_cost: 3005.84
# total_trades: 1324
# Sharpe: 0.405
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 85        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 3024      |
# | train/             |           |
# |    actor_loss      | 99.4      |
# |    critic_loss     | 106       |
# |    ent_coef        | 0.127     |
# |    ent_coef_loss   | 224       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2923      |
# |    reward          | -5.846732 |
# ----------------------------------
# day: 107, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 987238.04
# total_reward: -12761.96
# total_cost: 1679.99
# total_trades: 826
# Sharpe: -0.020
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 85        |
# |    time_elapsed    | 40        |
# |    total_timesteps | 3456      |
# | train/             |           |
# |    actor_loss      | 98.5      |
# |    critic_loss     | 170       |
# |    ent_coef        | 0.132     |
# |    ent_coef_loss   | 212       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3355      |
# |    reward          | -5.810365 |
# ----------------------------------
# day: 107, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1079504.15
# total_reward: 79504.15
# total_cost: 2374.29
# total_trades: 1527
# Sharpe: 0.950
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 84        |
# |    time_elapsed    | 45        |
# |    total_timesteps | 3888      |
# | train/             |           |
# |    actor_loss      | 149       |
# |    critic_loss     | 275       |
# |    ent_coef        | 0.137     |
# |    ent_coef_loss   | 189       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3787      |
# |    reward          | -4.160464 |
# ----------------------------------
# day: 107, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1100575.08
# total_reward: 100575.08
# total_cost: 2963.70
# total_trades: 1434
# Sharpe: 1.059
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 84        |
# |    time_elapsed    | 50        |
# |    total_timesteps | 4320      |
# | train/             |           |
# |    actor_loss      | 174       |
# |    critic_loss     | 147       |
# |    ent_coef        | 0.142     |
# |    ent_coef_loss   | 172       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4219      |
# |    reward          | -5.518701 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 84        |
# |    time_elapsed    | 55        |
# |    total_timesteps | 4752      |
# | train/             |           |
# |    actor_loss      | 201       |
# |    critic_loss     | 419       |
# |    ent_coef        | 0.148     |
# |    ent_coef_loss   | 154       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4651      |
# |    reward          | -4.415532 |
# ----------------------------------
# day: 107, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1118695.75
# total_reward: 118695.75
# total_cost: 3280.31
# total_trades: 1570
# Sharpe: 1.335
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 48         |
# |    fps             | 84         |
# |    time_elapsed    | 61         |
# |    total_timesteps | 5184       |
# | train/             |            |
# |    actor_loss      | 228        |
# |    critic_loss     | 220        |
# |    ent_coef        | 0.151      |
# |    ent_coef_loss   | -61.9      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 5083       |
# |    reward          | -0.9712666 |
# -----------------------------------
# day: 107, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1005540.87
# total_reward: 5540.87
# total_cost: 2412.10
# total_trades: 1993
# Sharpe: 0.414
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 52         |
# |    fps             | 84         |
# |    time_elapsed    | 66         |
# |    total_timesteps | 5616       |
# | train/             |            |
# |    actor_loss      | 186        |
# |    critic_loss     | 295        |
# |    ent_coef        | 0.149      |
# |    ent_coef_loss   | -63.5      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 5515       |
# |    reward          | -1.1412647 |
# -----------------------------------
# day: 107, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1003616.37
# total_reward: 3616.37
# total_cost: 2184.36
# total_trades: 1891
# Sharpe: 0.355
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 56          |
# |    fps             | 84          |
# |    time_elapsed    | 71          |
# |    total_timesteps | 6048        |
# | train/             |             |
# |    actor_loss      | 164         |
# |    critic_loss     | 1.34e+03    |
# |    ent_coef        | 0.146       |
# |    ent_coef_loss   | -64.1       |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 5947        |
# |    reward          | -0.97818416 |
# ------------------------------------
# day: 107, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1016480.81
# total_reward: 16480.81
# total_cost: 2147.70
# total_trades: 1869
# Sharpe: 0.749
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 60         |
# |    fps             | 84         |
# |    time_elapsed    | 76         |
# |    total_timesteps | 6480       |
# | train/             |            |
# |    actor_loss      | 224        |
# |    critic_loss     | 350        |
# |    ent_coef        | 0.142      |
# |    ent_coef_loss   | -64.3      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 6379       |
# |    reward          | -1.1138678 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 64         |
# |    fps             | 83         |
# |    time_elapsed    | 82         |
# |    total_timesteps | 6912       |
# | train/             |            |
# |    actor_loss      | 171        |
# |    critic_loss     | 2.91e+03   |
# |    ent_coef        | 0.139      |
# |    ent_coef_loss   | -64.9      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 6811       |
# |    reward          | -1.1685282 |
# -----------------------------------
# day: 107, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1033743.15
# total_reward: 33743.15
# total_cost: 2028.01
# total_trades: 1853
# Sharpe: 1.249
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 68         |
# |    fps             | 83         |
# |    time_elapsed    | 87         |
# |    total_timesteps | 7344       |
# | train/             |            |
# |    actor_loss      | 173        |
# |    critic_loss     | 1.99e+03   |
# |    ent_coef        | 0.134      |
# |    ent_coef_loss   | -64.9      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7243       |
# |    reward          | -1.6199694 |
# -----------------------------------
# day: 107, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1022605.56
# total_reward: 22605.56
# total_cost: 1844.68
# total_trades: 1737
# Sharpe: 0.907
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 72         |
# |    fps             | 83         |
# |    time_elapsed    | 93         |
# |    total_timesteps | 7776       |
# | train/             |            |
# |    actor_loss      | 124        |
# |    critic_loss     | 995        |
# |    ent_coef        | 0.13       |
# |    ent_coef_loss   | -65.3      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7675       |
# |    reward          | -1.4874371 |
# -----------------------------------
# day: 107, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1013927.03
# total_reward: 13927.03
# total_cost: 1763.70
# total_trades: 1657
# Sharpe: 0.538
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 83        |
# |    time_elapsed    | 98        |
# |    total_timesteps | 8208      |
# | train/             |           |
# |    actor_loss      | 135       |
# |    critic_loss     | 850       |
# |    ent_coef        | 0.126     |
# |    ent_coef_loss   | -65.3     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8107      |
# |    reward          | -1.842313 |
# ----------------------------------
# day: 107, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1020936.97
# total_reward: 20936.97
# total_cost: 1752.67
# total_trades: 1652
# Sharpe: 0.698
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 80         |
# |    fps             | 83         |
# |    time_elapsed    | 103        |
# |    total_timesteps | 8640       |
# | train/             |            |
# |    actor_loss      | 138        |
# |    critic_loss     | 212        |
# |    ent_coef        | 0.121      |
# |    ent_coef_loss   | -66        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 8539       |
# |    reward          | -1.7531226 |
# -----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 84         |
# |    fps             | 83         |
# |    time_elapsed    | 108        |
# |    total_timesteps | 9072       |
# | train/             |            |
# |    actor_loss      | 127        |
# |    critic_loss     | 422        |
# |    ent_coef        | 0.116      |
# |    ent_coef_loss   | -65.3      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 8971       |
# |    reward          | -1.7410636 |
# -----------------------------------
# day: 107, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1028942.64
# total_reward: 28942.64
# total_cost: 1531.46
# total_trades: 1567
# Sharpe: 0.839
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 88         |
# |    fps             | 83         |
# |    time_elapsed    | 113        |
# |    total_timesteps | 9504       |
# | train/             |            |
# |    actor_loss      | 97.6       |
# |    critic_loss     | 804        |
# |    ent_coef        | 0.112      |
# |    ent_coef_loss   | -65.2      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 9403       |
# |    reward          | -2.2196069 |
# -----------------------------------
# day: 107, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1041834.75
# total_reward: 41834.75
# total_cost: 1447.20
# total_trades: 1432
# Sharpe: 1.100
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 92         |
# |    fps             | 83         |
# |    time_elapsed    | 118        |
# |    total_timesteps | 9936       |
# | train/             |            |
# |    actor_loss      | 115        |
# |    critic_loss     | 434        |
# |    ent_coef        | 0.108      |
# |    ent_coef_loss   | -66.7      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 9835       |
# |    reward          | -2.5334177 |
# -----------------------------------
# ======SAC Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# SAC Sharpe Ratio:  -0.02472147368163622
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_46
# day: 107, episode: 95
# begin_total_asset: 1000000.00
# end_total_asset: 998785.62
# total_reward: -1214.38
# total_cost: 2964.68
# total_trades: 2013
# Sharpe: -0.007
# =================================
# day: 107, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 987876.12
# total_reward: -12123.88
# total_cost: 2936.77
# total_trades: 2008
# Sharpe: -0.576
# =================================
# day: 107, episode: 105
# begin_total_asset: 1000000.00
# end_total_asset: 998452.29
# total_reward: -1547.71
# total_cost: 2983.85
# total_trades: 1998
# Sharpe: -0.037
# =================================
# day: 107, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 987226.09
# total_reward: -12773.91
# total_cost: 2980.00
# total_trades: 2049
# Sharpe: -0.475
# =================================
# ------------------------------------
# | time/              |             |
# |    fps             | 1048        |
# |    iterations      | 1           |
# |    time_elapsed    | 1           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.051638275 |
# ------------------------------------
# day: 107, episode: 115
# begin_total_asset: 1000000.00
# end_total_asset: 997119.62
# total_reward: -2880.38
# total_cost: 3024.38
# total_trades: 2001
# Sharpe: -0.164
# =================================
# day: 107, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 987166.29
# total_reward: -12833.71
# total_cost: 3071.26
# total_trades: 1967
# Sharpe: -0.672
# =================================
# day: 107, episode: 125
# begin_total_asset: 1000000.00
# end_total_asset: 1011243.62
# total_reward: 11243.62
# total_cost: 3065.90
# total_trades: 2048
# Sharpe: 0.441
# =================================
# day: 107, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1009665.21
# total_reward: 9665.21
# total_cost: 2877.17
# total_trades: 1984
# Sharpe: 0.505
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.00811934  |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.261       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00715    |
# |    reward               | -0.10958361 |
# |    std                  | 1           |
# |    value_loss           | 1.26        |
# -----------------------------------------
# day: 107, episode: 135
# begin_total_asset: 1000000.00
# end_total_asset: 992304.23
# total_reward: -7695.77
# total_cost: 2869.46
# total_trades: 1989
# Sharpe: -0.291
# =================================
# day: 107, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1004583.27
# total_reward: 4583.27
# total_cost: 2902.93
# total_trades: 1998
# Sharpe: 0.263
# =================================
# day: 107, episode: 145
# begin_total_asset: 1000000.00
# end_total_asset: 990895.01
# total_reward: -9104.99
# total_cost: 2966.35
# total_trades: 1994
# Sharpe: -0.530
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 978         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009660746 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.248       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0107     |
# |    reward               | -0.1302071  |
# |    std                  | 1.01        |
# |    value_loss           | 1.03        |
# -----------------------------------------
# day: 107, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 996872.93
# total_reward: -3127.07
# total_cost: 2943.07
# total_trades: 1993
# Sharpe: -0.224
# =================================
# day: 107, episode: 155
# begin_total_asset: 1000000.00
# end_total_asset: 997983.48
# total_reward: -2016.52
# total_cost: 2942.18
# total_trades: 1964
# Sharpe: -0.058
# =================================
# day: 107, episode: 160
# begin_total_asset: 1000000.00
# end_total_asset: 989816.21
# total_reward: -10183.79
# total_cost: 2966.60
# total_trades: 1973
# Sharpe: -0.467
# =================================
# day: 107, episode: 165
# begin_total_asset: 1000000.00
# end_total_asset: 1008498.11
# total_reward: 8498.11
# total_cost: 2827.55
# total_trades: 1978
# Sharpe: 0.419
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007138987 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.139       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00679    |
# |    reward               | -0.10269018 |
# |    std                  | 1.01        |
# |    value_loss           | 0.813       |
# -----------------------------------------
# day: 107, episode: 170
# begin_total_asset: 1000000.00
# end_total_asset: 990627.86
# total_reward: -9372.14
# total_cost: 3025.45
# total_trades: 2011
# Sharpe: -0.374
# =================================
# day: 107, episode: 175
# begin_total_asset: 1000000.00
# end_total_asset: 993696.82
# total_reward: -6303.18
# total_cost: 2979.37
# total_trades: 1988
# Sharpe: -0.291
# =================================
# day: 107, episode: 180
# begin_total_asset: 1000000.00
# end_total_asset: 1020231.68
# total_reward: 20231.68
# total_cost: 3062.95
# total_trades: 2017
# Sharpe: 0.754
# =================================
# day: 107, episode: 185
# begin_total_asset: 1000000.00
# end_total_asset: 993991.57
# total_reward: -6008.43
# total_cost: 2981.53
# total_trades: 2002
# Sharpe: -0.305
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0075310324 |
# |    clip_fraction        | 0.0708       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.6        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0858       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00778     |
# |    reward               | -1.8261335   |
# |    std                  | 1.01         |
# |    value_loss           | 0.717        |
# ------------------------------------------
# ======PPO Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# PPO Sharpe Ratio:  -0.0047459742533526895
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_46
# day: 107, episode: 190
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 122      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 432      |
# | train/             |          |
# |    actor_loss      | 553      |
# |    critic_loss     | 3.56e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 324      |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 195
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 106      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 864      |
# | train/             |          |
# |    actor_loss      | 355      |
# |    critic_loss     | 1.28e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 756      |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 200
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 103      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1296     |
# | train/             |          |
# |    actor_loss      | 255      |
# |    critic_loss     | 598      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1188     |
# |    reward          | -5.12765 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 101      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1728     |
# | train/             |          |
# |    actor_loss      | 213      |
# |    critic_loss     | 467      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1620     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 205
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 101      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2160     |
# | train/             |          |
# |    actor_loss      | 189      |
# |    critic_loss     | 258      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2052     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 210
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 99       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2592     |
# | train/             |          |
# |    actor_loss      | 178      |
# |    critic_loss     | 145      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2484     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 215
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 99       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 3024     |
# | train/             |          |
# |    actor_loss      | 158      |
# |    critic_loss     | 229      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2916     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 220
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 98       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 3456     |
# | train/             |          |
# |    actor_loss      | 148      |
# |    critic_loss     | 160      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3348     |
# |    reward          | -5.12765 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 98       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 3888     |
# | train/             |          |
# |    actor_loss      | 135      |
# |    critic_loss     | 130      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3780     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 225
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 98       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 4320     |
# | train/             |          |
# |    actor_loss      | 124      |
# |    critic_loss     | 242      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4212     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 230
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 97       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 4752     |
# | train/             |          |
# |    actor_loss      | 115      |
# |    critic_loss     | 1.17e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4644     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 235
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 97       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 5184     |
# | train/             |          |
# |    actor_loss      | 107      |
# |    critic_loss     | 253      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5076     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 240
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 97       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 5616     |
# | train/             |          |
# |    actor_loss      | 112      |
# |    critic_loss     | 369      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5508     |
# |    reward          | -5.12765 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 97       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 6048     |
# | train/             |          |
# |    actor_loss      | 122      |
# |    critic_loss     | 68.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5940     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 245
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 97       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 6480     |
# | train/             |          |
# |    actor_loss      | 111      |
# |    critic_loss     | 140      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6372     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 250
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 97       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6912     |
# | train/             |          |
# |    actor_loss      | 101      |
# |    critic_loss     | 747      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6804     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 255
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 97       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 7344     |
# | train/             |          |
# |    actor_loss      | 97.7     |
# |    critic_loss     | 5.87e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7236     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 260
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 97       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 7776     |
# | train/             |          |
# |    actor_loss      | 94.7     |
# |    critic_loss     | 2.12e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7668     |
# |    reward          | -5.12765 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 97       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 8208     |
# | train/             |          |
# |    actor_loss      | 90.3     |
# |    critic_loss     | 118      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8100     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 265
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 96       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 8640     |
# | train/             |          |
# |    actor_loss      | 81.8     |
# |    critic_loss     | 66       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8532     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 270
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 96       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 9072     |
# | train/             |          |
# |    actor_loss      | 72.4     |
# |    critic_loss     | 100      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8964     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 275
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 96       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 9504     |
# | train/             |          |
# |    actor_loss      | 69.8     |
# |    critic_loss     | 288      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9396     |
# |    reward          | -5.12765 |
# ---------------------------------
# day: 107, episode: 280
# begin_total_asset: 1000000.00
# end_total_asset: 1069892.03
# total_reward: 69892.03
# total_cost: 999.00
# total_trades: 1177
# Sharpe: 0.805
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 96       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 9936     |
# | train/             |          |
# |    actor_loss      | 65.1     |
# |    critic_loss     | 822      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9828     |
# |    reward          | -5.12765 |
# ---------------------------------
# ======TD3 Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Best Model Retraining from:  2019-09-11T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Trading from:  2020-06-03T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# ============================================
# ======Model training from:  2019-09-11T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_43
# ------------------------------------
# | time/              |             |
# |    episodes        | 4           |
# |    fps             | 94          |
# |    time_elapsed    | 7           |
# |    total_timesteps | 684         |
# | train/             |             |
# |    actor_loss      | 85.9        |
# |    critic_loss     | 25          |
# |    ent_coef        | 0.104       |
# |    ent_coef_loss   | 369         |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 583         |
# |    reward          | -0.53519964 |
# ------------------------------------
# day: 170, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1021216.11
# total_reward: 21216.11
# total_cost: 3909.75
# total_trades: 2069
# Sharpe: 0.250
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 86        |
# |    time_elapsed    | 15        |
# |    total_timesteps | 1368      |
# | train/             |           |
# |    actor_loss      | 129       |
# |    critic_loss     | 20.4      |
# |    ent_coef        | 0.11      |
# |    ent_coef_loss   | 297       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1267      |
# |    reward          | 1.7343466 |
# ----------------------------------
# day: 170, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 863949.79
# total_reward: -136050.21
# total_cost: 4237.11
# total_trades: 2400
# Sharpe: -0.873
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 84         |
# |    time_elapsed    | 24         |
# |    total_timesteps | 2052       |
# | train/             |            |
# |    actor_loss      | 170        |
# |    critic_loss     | 34.8       |
# |    ent_coef        | 0.116      |
# |    ent_coef_loss   | 258        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 1951       |
# |    reward          | 0.65056556 |
# -----------------------------------
# day: 170, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1013958.89
# total_reward: 13958.89
# total_cost: 3718.15
# total_trades: 2199
# Sharpe: 0.210
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 16          |
# |    fps             | 83          |
# |    time_elapsed    | 32          |
# |    total_timesteps | 2736        |
# | train/             |             |
# |    actor_loss      | 218         |
# |    critic_loss     | 24.6        |
# |    ent_coef        | 0.123       |
# |    ent_coef_loss   | 216         |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 2635        |
# |    reward          | 0.038203187 |
# ------------------------------------
# day: 170, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 975789.87
# total_reward: -24210.13
# total_cost: 3644.08
# total_trades: 2382
# Sharpe: 0.001
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 82           |
# |    time_elapsed    | 41           |
# |    total_timesteps | 3420         |
# | train/             |              |
# |    actor_loss      | 255          |
# |    critic_loss     | 42.6         |
# |    ent_coef        | 0.13         |
# |    ent_coef_loss   | 171          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 3319         |
# |    reward          | -0.051788624 |
# -------------------------------------
# ------------------------------------
# | time/              |             |
# |    episodes        | 24          |
# |    fps             | 82          |
# |    time_elapsed    | 49          |
# |    total_timesteps | 4104        |
# | train/             |             |
# |    actor_loss      | 293         |
# |    critic_loss     | 54.6        |
# |    ent_coef        | 0.136       |
# |    ent_coef_loss   | 130         |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 4003        |
# |    reward          | -0.14766188 |
# ------------------------------------
# day: 170, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 947486.88
# total_reward: -52513.12
# total_cost: 2795.27
# total_trades: 2832
# Sharpe: -0.209
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 28          |
# |    fps             | 82          |
# |    time_elapsed    | 58          |
# |    total_timesteps | 4788        |
# | train/             |             |
# |    actor_loss      | 282         |
# |    critic_loss     | 100         |
# |    ent_coef        | 0.141       |
# |    ent_coef_loss   | 74.6        |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 4687        |
# |    reward          | -0.31217232 |
# ------------------------------------
# day: 170, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1023887.78
# total_reward: 23887.78
# total_cost: 2711.04
# total_trades: 2527
# Sharpe: 0.265
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 81        |
# |    time_elapsed    | 66        |
# |    total_timesteps | 5472      |
# | train/             |           |
# |    actor_loss      | 275       |
# |    critic_loss     | 64.7      |
# |    ent_coef        | 0.144     |
# |    ent_coef_loss   | -20.5     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5371      |
# |    reward          | 0.5851646 |
# ----------------------------------
# day: 170, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 952084.41
# total_reward: -47915.59
# total_cost: 3675.36
# total_trades: 3127
# Sharpe: -0.305
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 81        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 6156      |
# | train/             |           |
# |    actor_loss      | 252       |
# |    critic_loss     | 53.8      |
# |    ent_coef        | 0.139     |
# |    ent_coef_loss   | -59.8     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6055      |
# |    reward          | 1.1033716 |
# ----------------------------------
# day: 170, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 956468.22
# total_reward: -43531.78
# total_cost: 3184.73
# total_trades: 3039
# Sharpe: -0.202
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 81        |
# |    time_elapsed    | 84        |
# |    total_timesteps | 6840      |
# | train/             |           |
# |    actor_loss      | 266       |
# |    critic_loss     | 289       |
# |    ent_coef        | 0.132     |
# |    ent_coef_loss   | -61.4     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6739      |
# |    reward          | 1.2705564 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 81        |
# |    time_elapsed    | 92        |
# |    total_timesteps | 7524      |
# | train/             |           |
# |    actor_loss      | 240       |
# |    critic_loss     | 66.2      |
# |    ent_coef        | 0.124     |
# |    ent_coef_loss   | -62.5     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7423      |
# |    reward          | 1.2554195 |
# ----------------------------------
# day: 170, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 960395.59
# total_reward: -39604.41
# total_cost: 2735.20
# total_trades: 2954
# Sharpe: -0.137
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 82        |
# |    time_elapsed    | 99        |
# |    total_timesteps | 8208      |
# | train/             |           |
# |    actor_loss      | 219       |
# |    critic_loss     | 46.8      |
# |    ent_coef        | 0.117     |
# |    ent_coef_loss   | -65       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8107      |
# |    reward          | 1.3435979 |
# ----------------------------------
# day: 170, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 967073.17
# total_reward: -32926.83
# total_cost: 2452.12
# total_trades: 2888
# Sharpe: -0.099
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 83        |
# |    time_elapsed    | 107       |
# |    total_timesteps | 8892      |
# | train/             |           |
# |    actor_loss      | 215       |
# |    critic_loss     | 92.5      |
# |    ent_coef        | 0.11      |
# |    ent_coef_loss   | -62.2     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8791      |
# |    reward          | 1.3286693 |
# ----------------------------------
# day: 170, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 969213.60
# total_reward: -30786.40
# total_cost: 2380.00
# total_trades: 2882
# Sharpe: -0.091
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 83        |
# |    time_elapsed    | 114       |
# |    total_timesteps | 9576      |
# | train/             |           |
# |    actor_loss      | 210       |
# |    critic_loss     | 115       |
# |    ent_coef        | 0.103     |
# |    ent_coef_loss   | -65.2     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9475      |
# ...
# total_trades: 2368
# Sharpe: 1.075
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 101       |
# |    time_elapsed    | 81        |
# |    total_timesteps | 8316      |
# | train/             |           |
# |    actor_loss      | 103       |
# |    critic_loss     | 3.41e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8019      |
# |    reward          | -0.144626 |
# ----------------------------------
# day: 296, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1361152.64
# total_reward: 361152.64
# total_cost: 999.00
# total_trades: 2368
# Sharpe: 1.075
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 101       |
# |    time_elapsed    | 93        |
# |    total_timesteps | 9504      |
# | train/             |           |
# |    actor_loss      | 106       |
# |    critic_loss     | 179       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9207      |
# |    reward          | -0.144626 |
# ----------------------------------
# ======TD3 Validation from:  2020-12-10T00:00:00.000000000 to  2021-03-31T00:00:00.000000000
# ======Best Model Retraining from:  2019-09-11T00:00:00.000000000 to  2021-03-31T00:00:00.000000000
# ======Trading from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ============================================
# ======Model training from:  2019-09-11T00:00:00.000000000 to  2021-03-31T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_378_23
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 95         |
# |    time_elapsed    | 15         |
# |    total_timesteps | 1440       |
# | train/             |            |
# |    actor_loss      | 167        |
# |    critic_loss     | 14.2       |
# |    ent_coef        | 0.111      |
# |    ent_coef_loss   | 310        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 1339       |
# |    reward          | -0.4825255 |
# -----------------------------------
# day: 359, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1077566.17
# total_reward: 77566.17
# total_cost: 10105.97
# total_trades: 5395
# Sharpe: 0.333
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 92          |
# |    time_elapsed    | 31          |
# |    total_timesteps | 2880        |
# | train/             |             |
# |    actor_loss      | 236         |
# |    critic_loss     | 147         |
# |    ent_coef        | 0.125       |
# |    ent_coef_loss   | 229         |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 2779        |
# |    reward          | -0.04208916 |
# ------------------------------------
# day: 359, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1140930.57
# total_reward: 140930.57
# total_cost: 10083.73
# total_trades: 6040
# Sharpe: 0.455
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 91       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 4320     |
# | train/             |          |
# |    actor_loss      | 325      |
# |    critic_loss     | 35.6     |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | 167      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4219     |
# |    reward          | 2.423703 |
# ---------------------------------
# day: 359, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1105482.14
# total_reward: 105482.14
# total_cost: 8147.39
# total_trades: 5908
# Sharpe: 0.384
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 90       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 5760     |
# | train/             |          |
# |    actor_loss      | 319      |
# |    critic_loss     | 66.8     |
# |    ent_coef        | 0.153    |
# |    ent_coef_loss   | 33.2     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5659     |
# |    reward          | 1.395919 |
# ---------------------------------
# day: 359, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1165984.52
# total_reward: 165984.52
# total_cost: 9932.49
# total_trades: 6245
# Sharpe: 0.539
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 90        |
# |    time_elapsed    | 79        |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 323       |
# |    critic_loss     | 50.3      |
# |    ent_coef        | 0.158     |
# |    ent_coef_loss   | -9.68     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 7099      |
# |    reward          | 0.5341609 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 89        |
# |    time_elapsed    | 96        |
# |    total_timesteps | 8640      |
# | train/             |           |
# |    actor_loss      | 267       |
# |    critic_loss     | 77.1      |
# |    ent_coef        | 0.15      |
# |    ent_coef_loss   | -32.8     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8539      |
# |    reward          | 3.5804837 |
# ----------------------------------
# day: 359, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1142137.95
# total_reward: 142137.95
# total_cost: 6626.02
# total_trades: 5943
# Sharpe: 0.524
# =================================
# ======SAC Validation from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# SAC Sharpe Ratio:  -0.3622871795495331
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_378_22
# day: 359, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 980955.25
# total_reward: -19044.75
# total_cost: 11276.81
# total_trades: 6939
# Sharpe: -0.084
# =================================
# ------------------------------------
# | time/              |             |
# |    fps             | 849         |
# |    iterations      | 1           |
# |    time_elapsed    | 2           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.42428678 |
# ------------------------------------
# day: 359, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1081391.33
# total_reward: 81391.33
# total_cost: 11454.10
# total_trades: 6932
# Sharpe: 0.445
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008265226 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.000397   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00703    |
# |    reward               | -0.0890503  |
# |    std                  | 1           |
# |    value_loss           | 4.05        |
# -----------------------------------------
# day: 359, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1081845.39
# total_reward: 81845.39
# total_cost: 11204.77
# total_trades: 6955
# Sharpe: 0.473
# =================================
# day: 359, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1072590.34
# total_reward: 72590.34
# total_cost: 11399.57
# total_trades: 6906
# Sharpe: 0.538
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.01157773  |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.000102   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.12        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0116     |
# |    reward               | -0.06955507 |
# |    std                  | 1.01        |
# |    value_loss           | 4.86        |
# -----------------------------------------
# day: 359, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1102511.53
# total_reward: 102511.53
# total_cost: 11234.01
# total_trades: 6891
# Sharpe: 0.572
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009036387 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.82        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00937    |
# |    reward               | 1.7603426   |
# |    std                  | 1.01        |
# |    value_loss           | 6.83        |
# -----------------------------------------
# day: 359, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1088540.26
# total_reward: 88540.26
# total_cost: 11322.43
# total_trades: 6853
# Sharpe: 0.521
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009755852 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.73        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00927    |
# |    reward               | 0.42013448  |
# |    std                  | 1.01        |
# |    value_loss           | 5.7         |
# -----------------------------------------
# ======PPO Validation from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# PPO Sharpe Ratio:  -0.012228016944057559
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_378_22
# day: 359, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1018480.62
# total_reward: 18480.62
# total_cost: 1545.75
# total_trades: 4067
# Sharpe: 0.178
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 119       |
# |    time_elapsed    | 12        |
# |    total_timesteps | 1440      |
# | train/             |           |
# |    actor_loss      | 22.5      |
# |    critic_loss     | 50.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1080      |
# |    reward          | -0.245029 |
# ----------------------------------
# day: 359, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1018480.62
# total_reward: 18480.62
# total_cost: 1545.75
# total_trades: 4067
# Sharpe: 0.178
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 104       |
# |    time_elapsed    | 27        |
# |    total_timesteps | 2880      |
# | train/             |           |
# |    actor_loss      | 43.7      |
# |    critic_loss     | 33.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2520      |
# |    reward          | -0.245029 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 99        |
# |    time_elapsed    | 43        |
# |    total_timesteps | 4320      |
# | train/             |           |
# |    actor_loss      | 52.3      |
# |    critic_loss     | 15.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3960      |
# |    reward          | -0.245029 |
# ----------------------------------
# day: 359, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1018480.62
# total_reward: 18480.62
# total_cost: 1545.75
# total_trades: 4067
# Sharpe: 0.178
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 97        |
# |    time_elapsed    | 58        |
# |    total_timesteps | 5760      |
# | train/             |           |
# |    actor_loss      | 55.9      |
# |    critic_loss     | 66.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5400      |
# |    reward          | -0.245029 |
# ----------------------------------
# day: 359, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1018480.62
# total_reward: 18480.62
# total_cost: 1545.75
# total_trades: 4067
# Sharpe: 0.178
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 96        |
# |    time_elapsed    | 74        |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 52.7      |
# |    critic_loss     | 24.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6840      |
# |    reward          | -0.245029 |
# ----------------------------------
# day: 359, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1018480.62
# total_reward: 18480.62
# total_cost: 1545.75
# total_trades: 4067
# Sharpe: 0.178
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 94        |
# |    time_elapsed    | 91        |
# |    total_timesteps | 8640      |
# | train/             |           |
# |    actor_loss      | 52.1      |
# |    critic_loss     | 12.2      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8280      |
# |    reward          | -0.245029 |
# ----------------------------------
# day: 359, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1018480.62
# total_reward: 18480.62
# total_cost: 1545.75
# total_trades: 4067
# Sharpe: 0.178
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 93        |
# |    time_elapsed    | 107       |
# |    total_timesteps | 10080     |
# | train/             |           |
# |    actor_loss      | 55.1      |
# |    critic_loss     | 55.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9720      |
# |    reward          | -0.245029 |
# ----------------------------------
# ======TD3 Validation from:  2021-03-31T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Best Model Retraining from:  2019-09-11T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Trading from:  2021-07-05T00:00:00.000000000 to  2021-10-27T00:00:00.000000000
# Ensemble Strategy took:  19.418131617705026  minutes

# %%
df_summary

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = addfeature_df[(addfeature_df.date > TRADE_START_DATE)&(addfeature_df.date <= TRADE_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -1.0419258108511433

# %%
df_account_value
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2020-06-03           NaN 2020-06-03
# 1     9.998474e+05  2020-06-04     -0.000153 2020-06-04
# 2     9.998534e+05  2020-06-05      0.000006 2020-06-05
# 3     1.000084e+06  2020-06-08      0.000231 2020-06-08
# 4     1.000156e+06  2020-06-09      0.000072 2020-06-09
# ..             ...         ...           ...        ...
# 310   8.879657e+05  2021-10-20     -0.001851 2021-10-20
# 311   8.945266e+05  2021-10-21      0.007389 2021-10-21
# 312   8.959052e+05  2021-10-22      0.001541 2021-10-22
# 313   8.959535e+05  2021-10-25      0.000054 2021-10-25
# 314   8.909654e+05  2021-10-26     -0.005567 2021-10-26
#
# [315 rows x 4 columns]

# %%
df_account_value = df_account_value.iloc[:,0:2]
df_account_value

# %%
df_returns = pd.read_csv('724_df_returns.csv')
df_returns
# Out:
#      Unnamed: 0        date           td3           sac           ppo  \
# 0             0  2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06
# 1             1  2020-06-04  9.998193e+05  9.998801e+05  9.999384e+05
# 2             2  2020-06-05  1.000270e+06  1.000138e+06  9.999628e+05
# 3             3  2020-06-08  1.001146e+06  1.000495e+06  9.999853e+05
# 4             4  2020-06-09  1.001984e+06  1.000475e+06  1.000168e+06
# ..          ...         ...           ...           ...           ...
# 310         310  2021-10-20  9.350133e+05  7.322613e+05  8.551679e+05
# 311         311  2021-10-21  9.402342e+05  7.448301e+05  8.442385e+05
# 312         312  2021-10-22  9.423141e+05  7.437446e+05  8.507896e+05
# 313         313  2021-10-25  9.537174e+05  7.503635e+05  8.538056e+05
# 314         314  2021-10-26  9.381647e+05  7.432972e+05  8.428542e+05
#
#               sse          ewtf           our
# 0    1.000000e+06  1.000000e+06  1.000000e+06
# 1    9.981757e+05  9.999457e+05  9.997242e+05
# 2    9.999549e+05  1.000020e+06  9.999876e+05
# 3    1.015112e+06  1.000362e+06  1.000681e+06
# 4    1.015740e+06  1.000559e+06  1.001570e+06
# ..            ...           ...           ...
# 310  8.204575e+05  7.673645e+05  1.003999e+06
# 311  8.470124e+05  7.686134e+05  9.914065e+05
# 312  8.494040e+05  7.767603e+05  9.961156e+05
# 313  8.408992e+05  7.685991e+05  1.009016e+06
# 314  8.268356e+05  7.613355e+05  9.946696e+05
#
# [315 rows x 8 columns]

# %%
df_returns = pd.concat([df_returns,df_account_value['account_value']],axis=1)
# df_returns.columns = ['date','td3','sac','ppo','sse','ewtf']

# %%
df_returns
# Out:
#            date           td3           sac           ppo           sse  \
# 0    2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1    2020-06-04  9.998193e+05  9.998801e+05  9.999384e+05  9.981757e+05
# 2    2020-06-05  1.000270e+06  1.000138e+06  9.999628e+05  9.999549e+05
# 3    2020-06-08  1.001146e+06  1.000495e+06  9.999853e+05  1.015112e+06
# 4    2020-06-09  1.001984e+06  1.000475e+06  1.000168e+06  1.015740e+06
# ..          ...           ...           ...           ...           ...
# 310  2021-10-20  9.350133e+05  7.322613e+05  8.551679e+05  8.204575e+05
# 311  2021-10-21  9.402342e+05  7.448301e+05  8.442385e+05  8.470124e+05
# 312  2021-10-22  9.423141e+05  7.437446e+05  8.507896e+05  8.494040e+05
# 313  2021-10-25  9.537174e+05  7.503635e+05  8.538056e+05  8.408992e+05
# 314  2021-10-26  9.381647e+05  7.432972e+05  8.428542e+05  8.268356e+05
#
#              ewtf           our           van
# 0    1.000000e+06  1.000000e+06  1.000000e+06
# 1    9.999457e+05  9.997242e+05  9.998474e+05
# 2    1.000020e+06  9.999876e+05  9.998534e+05
# 3    1.000362e+06  1.000681e+06  1.000084e+06
# 4    1.000559e+06  1.001570e+06  1.000156e+06
# ..            ...           ...           ...
# 310  7.673645e+05  1.003999e+06  8.879657e+05
# 311  7.686134e+05  9.914065e+05  8.945266e+05
# 312  7.767603e+05  9.961156e+05  8.959052e+05
# 313  7.685991e+05  1.009016e+06  8.959535e+05
# 314  7.613355e+05  9.946696e+05  8.909654e+05
#
# [315 rows x 8 columns]

# %%
df_returns.columns = ['date','td3','sac','ppo','sse','ewtf','our','van']

# %%
df_returns = pd.read_csv('724_df_returns.csv')

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
df_returns.to_csv('724_df_returns.csv',index=None)

# %%
df_returns = pd.read_csv('724_df_returns.csv')
df_returns = df_returns.iloc[:,[1,2,3,4,5,6,7]]
df_returns
# Out:
#            date           td3           sac           ppo           sse  \
# 0    2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1    2020-06-04  9.998193e+05  9.998801e+05  9.999384e+05  9.981757e+05
# 2    2020-06-05  1.000270e+06  1.000138e+06  9.999628e+05  9.999549e+05
# 3    2020-06-08  1.001146e+06  1.000495e+06  9.999853e+05  1.015112e+06
# 4    2020-06-09  1.001984e+06  1.000475e+06  1.000168e+06  1.015740e+06
# ..          ...           ...           ...           ...           ...
# 310  2021-10-20  9.350133e+05  7.322613e+05  8.551679e+05  8.204575e+05
# 311  2021-10-21  9.402342e+05  7.448301e+05  8.442385e+05  8.470124e+05
# 312  2021-10-22  9.423141e+05  7.437446e+05  8.507896e+05  8.494040e+05
# 313  2021-10-25  9.537174e+05  7.503635e+05  8.538056e+05  8.408992e+05
# 314  2021-10-26  9.381647e+05  7.432972e+05  8.428542e+05  8.268356e+05
#
#              ewtf           our
# 0    1.000000e+06  1.000000e+06
# 1    9.999457e+05  9.997242e+05
# 2    1.000020e+06  9.999876e+05
# 3    1.000362e+06  1.000681e+06
# 4    1.000559e+06  1.001570e+06
# ..            ...           ...
# 310  7.673645e+05  1.003999e+06
# 311  7.686134e+05  9.914065e+05
# 312  7.767603e+05  9.961156e+05
# 313  7.685991e+05  1.009016e+06
# 314  7.613355e+05  9.946696e+05
#
# [315 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize= (11,6))

plt.plot(df_returns['date'],df_returns['td3'],label = 'TD3TF',color = 'dodgerblue')
plt.plot(df_returns['date'],df_returns['sac'],label = 'SACTF',color = 'red')
plt.plot(df_returns['date'],df_returns['ppo'],label = 'PPOTF',color = 'limegreen')
plt.plot(df_returns['date'],df_returns['sse'],label = 'Buy&Hold',color = 'gold')
plt.plot(df_returns['date'],df_returns['ewtf'],label = 'EWTF',color = 'goldenrod')
plt.plot(df_returns['date'],df_returns['our'],label = 'OUR',color = 'blue')

plt.legend()
plt.title('profit vs')
plt.xlabel('date')
plt.ylabel('Cumulative returns')
# plt.grid()
plt.show()

# %%
df_returns
# Out:
#      Unnamed: 0        date           td3           sac           ppo  \
# 0             0  2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06
# 1             1  2020-06-04  9.998193e+05  9.998801e+05  9.999384e+05
# 2             2  2020-06-05  1.000270e+06  1.000138e+06  9.999628e+05
# 3             3  2020-06-08  1.001146e+06  1.000495e+06  9.999853e+05
# 4             4  2020-06-09  1.001984e+06  1.000475e+06  1.000168e+06
# ..          ...         ...           ...           ...           ...
# 310         310  2021-10-20  9.350133e+05  7.322613e+05  8.551679e+05
# 311         311  2021-10-21  9.402342e+05  7.448301e+05  8.442385e+05
# 312         312  2021-10-22  9.423141e+05  7.437446e+05  8.507896e+05
# 313         313  2021-10-25  9.537174e+05  7.503635e+05  8.538056e+05
# 314         314  2021-10-26  9.381647e+05  7.432972e+05  8.428542e+05
#
#               sse          ewtf           our
# 0    1.000000e+06  1.000000e+06  1.000000e+06
# 1    9.981757e+05  9.999457e+05  9.997242e+05
# 2    9.999549e+05  1.000020e+06  9.999876e+05
# 3    1.015112e+06  1.000362e+06  1.000681e+06
# 4    1.015740e+06  1.000559e+06  1.001570e+06
# ..            ...           ...           ...
# 310  8.204575e+05  7.673645e+05  1.003999e+06
# 311  8.470124e+05  7.686134e+05  9.914065e+05
# 312  8.494040e+05  7.767603e+05  9.961156e+05
# 313  8.408992e+05  7.685991e+05  1.009016e+06
# 314  8.268356e+05  7.613355e+05  9.946696e+05
#
# [315 rows x 8 columns]

# %%
df_returns1 = df_returns.iloc[:,[0,7]]
df_returns1
# Out:
#            date           van
# 0    2020-06-03  1.000000e+06
# 1    2020-06-04  9.998474e+05
# 2    2020-06-05  9.998534e+05
# 3    2020-06-08  1.000084e+06
# 4    2020-06-09  1.000156e+06
# ..          ...           ...
# 310  2021-10-20  8.879657e+05
# 311  2021-10-21  8.945266e+05
# 312  2021-10-22  8.959052e+05
# 313  2021-10-25  8.959535e+05
# 314  2021-10-26  8.909654e+05
#
# [315 rows x 2 columns]

# %%
df_returns1['return'] = df_returns1['van'].pct_change()
df_returns1['return'].fillna(0, inplace=True)

# %%
df_returns1['date'] = pd.to_datetime(df_returns1['date'])
df_returns1.set_index('date',inplace=True)
df_returns1.index = df_returns1.index.tz_localize("UTC")
returns = pd.Series(df_returns1["return"], index=df_returns1.index)

# %%
baseline_sse
# Out:
#                            account_value
# date
# 2020-06-03 00:00:00+00:00    4186.856468
# 2020-06-04 00:00:00+00:00    4179.218450
# 2020-06-05 00:00:00+00:00    4186.667689
# 2020-06-08 00:00:00+00:00    4250.129142
# 2020-06-09 00:00:00+00:00    4252.759074
# ...                                  ...
# 2021-10-20 00:00:00+00:00    3435.137845
# 2021-10-21 00:00:00+00:00    3546.319429
# 2021-10-22 00:00:00+00:00    3556.332484
# 2021-10-25 00:00:00+00:00    3520.724384
# 2021-10-26 00:00:00+00:00    3461.842028
#
# [315 rows x 1 columns]

# %%
baseline_sse1 = baseline_sse
baseline_sse1['date'] = pd.to_datetime(baseline_sse['date'])
baseline_sse1.set_index('date',inplace=True)
baseline_sse1.index = baseline_sse1.index.tz_localize("UTC")

# %%
baseline_sse1['return'] = baseline_sse1['account_value'].pct_change()
baseline_sse1['return'].fillna(0, inplace=True)
baseline_sse1 = baseline_sse1.drop('account_value',axis=1)

# %%
# %matplotlib inline
import pyfolio as py
py.create_returns_tear_sheet(returns,benchmark_rets=baseline_sse1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-8.822%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-10.903%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.529%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.04</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.54</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-16.23%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.50</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>2.02</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.11%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.05</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.23</td>
#       <td>2020-08-17</td>
#       <td>2021-08-30</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.42</td>
#       <td>2020-07-09</td>
#       <td>2020-07-16</td>
#       <td>2020-07-31</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.33</td>
#       <td>2020-08-10</td>
#       <td>2020-08-13</td>
#       <td>2020-08-17</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.26</td>
#       <td>2020-07-06</td>
#       <td>2020-07-07</td>
#       <td>2020-07-08</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.26</td>
#       <td>2020-06-09</td>
#       <td>2020-06-15</td>
#       <td>2020-06-19</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import pyfolio as py
# ----> 3 py.create_returns_tear_sheet(returns,benchmark_rets=baseline_sse1)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:52, in customize.<locals>.call_w_context(*args, **kwargs)
#      50 if set_context:
#      51     with plotting_context(), axes_style():
# ---> 52         return func(*args, **kwargs)
#      53 else:
#      54     return func(*args, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:520, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     517 ax_return_quantiles = plt.subplot(gs[i, :])
#     518 i += 1
# --> 520 plotting.plot_rolling_returns(
#     521     returns,
#     522     factor_returns=benchmark_rets,
#     523     live_start_date=live_start_date,
#     524     cone_std=cone_std,
#     525     ax=ax_rolling_returns)
#     526 ax_rolling_returns.set_title(
#     527     'Cumulative returns')
#     529 plotting.plot_rolling_returns(
#     530     returns,
#     531     factor_returns=benchmark_rets,
#    (...)
#     535     legend_loc=None,
#     536     ax=ax_rolling_returns_vol_match)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:794, in plot_rolling_returns(returns, factor_returns, live_start_date, logy, cone_std, legend_loc, volatility_match, cone_function, ax, **kwargs)
#     790 ax.yaxis.set_major_formatter(FuncFormatter(y_axis_formatter))
#     792 if factor_returns is not None:
#     793     cum_factor_returns = ep.cum_returns(
# --> 794         factor_returns[cum_rets.index], 1.0)
#     795     cum_factor_returns.plot(lw=2, color='gray',
#     796                             label=factor_returns.name, alpha=0.60,
#     797                             ax=ax, **kwargs)
#     799 if live_start_date is not None:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [DatetimeIndex(['2020-06-03 00:00:00+00:00', '2020-06-04 00:00:00+00:00',\n               '2020-06-05 00:00:00+00:00', '2020-06-08 00:00:00+00:00',\n               '2020-06-09 00:00:00+00:00', '2020-06-10 00:00:00+00:00',\n               '2020-06-11 00:00:00+00:00', '2020-06-12 00:00:00+00:00',\n               '2020-06-15 00:00:00+00:00', '2020-06-16 00:00:00+00:00',\n               ...\n               '2021-10-13 00:00:00+00:00', '2021-10-14 00:00:00+00:00',\n               '2021-10-15 00:00:00+00:00', '2021-10-18 00:00:00+00:00',\n               '2021-10-19 00:00:00+00:00', '2021-10-20 00:00:00+00:00',\n               '2021-10-21 00:00:00+00:00', '2021-10-22 00:00:00+00:00',\n               '2021-10-25 00:00:00+00:00', '2021-10-26 00:00:00+00:00'],\n              dtype='datetime64[ns, UTC]', name='date', length=315, freq=None)] are in the [columns]"

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize= (11,6))

plt.plot(df_returns['date'],df_returns['td3'],label = 'td3',color = (254/255,253/255,107/255))
plt.plot(df_returns['date'],df_returns['sac'],label = 'sac',color = (114/255,170/255,207/255))
plt.plot(df_returns['date'],df_returns['ppo'],label = 'ppo',color = 'limegreen')
plt.plot(df_returns['date'],df_returns['sse'],label = 'B&H',color = (168/255,3/255,38/255))
plt.plot(df_returns['date'],df_returns['ewtf'],label = 'ewtf',color = (253/255,183/255,107/255))
plt.plot(df_returns['date'],df_returns['our'],label = 'our',color = (57/255,81/255,162/255))
plt.plot(df_returns['date'],df_returns['van'],label = 'van',color = (200/255,100/255,162/255))

plt.legend()
plt.title('')
plt.xlabel('date')
plt.ylabel('Cumulative returns')
# plt.grid()
plt.show()

# %%
df_returns.to_csv('724_df_returns.csv',index=None)

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.004267
# Cumulative returns    -0.005330
# Annual volatility      0.265635
# Sharpe ratio           0.117551
# Calmar ratio          -0.016889
# Stability              0.117103
# Max drawdown          -0.252619
# Omega ratio            1.020755
# Sortino ratio          0.159259
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.000190
# Daily value at risk   -0.033343
# dtype: float64

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.088223
# Cumulative returns    -0.109035
# Annual volatility      0.085425
# Sharpe ratio          -1.041926
# Calmar ratio          -0.543585
# Stability              0.781609
# Max drawdown          -0.162298
# Omega ratio            0.837572
# Sortino ratio         -1.502347
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.180456
# Daily value at risk   -0.011116
# dtype: float64

# %%
selected_tics = addfeature_df['tic'].unique()

# %%
#获取随机选择的tic在select_date的权重并修正
def get_selected_index_weight(df_index,select_date,selected_tics):
    df = df_index[df_index['trade_date'] == select_date]
    select_df = df[df['con_code'].isin(selected_tics)]
    select_df = select_df.drop('index_code',axis=1).rename(columns={'con_code':'tic','trade_date':'date'})
    select_df = select_df.reset_index()
    weight_sum = select_df['weight'].sum()
#     print(select_df)
    for i in range(len(select_df)):
        select_df.loc[i,'weight'] = (select_df.loc[i,'weight'] / weight_sum)*100
    return select_df.loc[:,['tic','date','weight']]

baseline_weight =get_selected_index_weight(df_index,select_date,selected_tics)
baseline_weight = baseline_weight.sort_values(['tic'],ascending=True).reset_index(drop=True)
print(baseline_weight)
# Out:
#           tic      date     weight
# 0   600028.SH  20200228   2.759371
# 1   600030.SH  20200228   8.255860
# 2   600050.SH  20200228   2.287113
# 3   600196.SH  20200228   1.211552
# 4   600340.SH  20200228   1.275838
# 5   600547.SH  20200228   1.582435
# 6   600585.SH  20200228   4.917911
# 7   600837.SH  20200228   5.155276
# 8   601012.SH  20200228   3.634655
# 9   601066.SH  20200228   0.645337
# 10  601166.SH  20200228  11.272377
# 11  601211.SH  20200228   3.436851
# 12  601236.SH  20200228   0.385719
# 13  601318.SH  20200228  37.743547
# 14  601319.SH  20200228   0.323905
# 15  601601.SH  20200228   4.492632
# 16  601628.SH  20200228   2.200574
# 17  601688.SH  20200228   3.671744
# 18  601766.SH  20200228   2.791514
# 19  601939.SH  20200228   1.955791

# %%
#计算所选股票的buy & hold策略
def calculate_selected_baseline(df,full_date_range,selected_tics):
    df = df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
    baseline = pd.DataFrame({'date':full_date_range['date']})
    for i in range(len(full_date_range)):
        temp_date = full_date_range.loc[i,'date']
        temp_df = df[df['date'] == temp_date].sort_values('tic',ascending=True)
        close = list(temp_df['close'])
        weight = list(baseline_weight['weight'])
        baseline.loc[i,'account_value'] = sum(np.array(close) * np.array(weight)) #注意权重和收盘价对应的股票顺序
    baseline['date'] = pd.to_datetime(baseline['date'])
#     baseline.set_index("date", inplace=True, drop=True)
#     baseline.index = baseline.index.tz_localize("UTC")
    return baseline
# full_date_range = get_trading_days(exchange='SSE',start_date='20210301', end_date='20230227')
# full_date_range = full_date_range.sort_values('trade_date',ascending=True).reset_index(drop=True)
full_date_range1 = pd.DataFrame({'date':df_returns['date'].unique()}).reset_index(drop=True)
baseline_sse = calculate_selected_baseline(addfeature_df,full_date_range1,selected_tics)
baseline_sse
# Out:
#           date  account_value
# 0   2020-06-03    4186.856468
# 1   2020-06-04    4179.218450
# 2   2020-06-05    4186.667689
# 3   2020-06-08    4250.129142
# 4   2020-06-09    4252.759074
# ..         ...            ...
# 310 2021-10-20    3435.137845
# 311 2021-10-21    3546.319429
# 312 2021-10-22    3556.332484
# 313 2021-10-25    3520.724384
# 314 2021-10-26    3461.842028
#
# [315 rows x 2 columns]

# %%
merged_df

# %%
#baseline stats
print("==============Get Baseline Stats===========")
# baseline_df = get_baseline(
#         ticker="^DJI", 
#         start = df_account_value.loc[0,'date'],
#         end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_sse, value_col_name = 'account_value')

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
from copy import deepcopy
def backtest_plot_com(
    account_value,
    baseline,
    baseline_start=TRADE_START_DATE,
    baseline_end=TRADE_END_DATE,
    value_col_name="account_value",
):
    df = deepcopy(account_value)
    df["date"] = pd.to_datetime(df["date"])
    test_returns = get_daily_return(df, value_col_name=value_col_name)
#     pro = ts.pro_api()
#     baseline_df = pro.index_daily(ts_code='000016.sh',start_date = '20200301',end_date='20230227')
#     baseline_df = baseline_df.rename(columns={'trade_date':'date'})
#     baseline_df = baseline_df.sort_values('date',ascending=True)
    baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
    with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(
            returns=test_returns, benchmark_rets=baseline_returns, set_context=False
        )

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-0.427%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-0.533%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.563%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.02</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-25.262%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.16</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.334%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.73</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25.26</td>
#       <td>2021-01-12</td>
#       <td>2021-10-12</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.13</td>
#       <td>2020-10-12</td>
#       <td>2020-11-13</td>
#       <td>2021-01-05</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.50</td>
#       <td>2020-07-09</td>
#       <td>2020-07-16</td>
#       <td>2020-08-10</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6.69</td>
#       <td>2020-08-18</td>
#       <td>2020-09-07</td>
#       <td>2020-09-18</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.66</td>
#       <td>2020-09-18</td>
#       <td>2020-09-24</td>
#       <td>2020-10-12</td>
#       <td>17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-10.65%</td>
#       <td>5.33%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
