# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install stable_baselines3
# !pip install yfinance
# !pip install tushare
# !pip install exchange_calendars
# !pip install wrds
# !pip install alpaca_trade_api
# !pip install stockstats
# !pip install pyfolio

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_add import StockTradingEnv
from finrl.agents.stablebaselines3.models_add import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)

# %%
df = pd.read_csv('merged_df.csv')
df

# %%
TRAIN_START_DATE = '2012-10-10'
TRAIN_END_DATE = '2020-02-28'
TRADE_START_DATE = '2020-03-01'
TRADE_END_DATE = '2022-05-30'

# %%
import tushare as ts
ts.set_token('6314756019e50a6672690e5a78b2dbf7cfcd27c6f6a6b48a8cf76dae')
pro = ts.pro_api()

# %%
#选择上证50指数的成分股
df_index = pro.index_weight(index_code='000016.sh', start_date='20151010', end_date='20220228')
# df_index.to_csv('SSE_50_index_weight.csv',index=0)

# %%
#选择某个时间点的上证50指数成分股作为参考跟踪股票池
select_date = '20200228' #自定义的时间点为每个月的月末
df_select = df_index[df_index['trade_date']==select_date]
sort_SSEindex = df_select['con_code'].unique()
print(sort_SSEindex,len(sort_SSEindex))
# Out:
# ['603993.SH' '603259.SH' '601989.SH' '601988.SH' '601939.SH' '601888.SH'
#  '601857.SH' '601818.SH' '601766.SH' '601688.SH' '601668.SH' '601628.SH'
#  '601601.SH' '601398.SH' '601390.SH' '601336.SH' '601328.SH' '601319.SH'
#  '601318.SH' '601288.SH' '601236.SH' '601211.SH' '601186.SH' '601166.SH'
#  '601138.SH' '601111.SH' '601088.SH' '601066.SH' '601012.SH' '600887.SH'
#  '600837.SH' '600703.SH' '600690.SH' '600585.SH' '600547.SH' '600519.SH'
#  '600340.SH' '600309.SH' '600276.SH' '600196.SH' '600104.SH' '600050.SH'
#  '600048.SH' '600036.SH' '600031.SH' '600030.SH' '600028.SH' '600016.SH'
#  '600009.SH' '600000.SH'] 50

# %%
#随机选择成分股中的k只股票
import random 
k = 20
selected_tics = random.sample(list(sort_SSEindex),k)
print(selected_tics)
# Out:
# ['601166.SH', '601288.SH', '600009.SH', '600690.SH', '601988.SH', '600031.SH', '600104.SH', '600036.SH', '600016.SH', '601601.SH', '601066.SH', '600000.SH', '601318.SH', '601939.SH', '600030.SH', '603993.SH', '601328.SH', '601888.SH', '600887.SH', '601138.SH']

# %%
selected_tics = ['601166.SH', '601288.SH', '600009.SH', '600690.SH', '601988.SH', '600031.SH', '600104.SH', '600036.SH', '600016.SH', '601601.SH', '601066.SH', '600000.SH', '601318.SH', '601939.SH', '600030.SH', '603993.SH', '601328.SH', '601888.SH', '600887.SH', '601138.SH']

# %%
#Download随机选择的k只股票数据
df_ts =pd.DataFrame()
for c in selected_tics:
    temp=pro.daily(ts_code=c,start_date=TRAIN_START_DATE,end_date=TRADE_END_DATE)
    df_ts=pd.concat([df_ts,temp])
print(df_ts)
# Out:
#        ts_code trade_date   open   high    low  close  pre_close  change  \
# 0    601166.SH   20211231  19.11  19.16  18.98  19.04      19.05   -0.01
# 1    601166.SH   20211230  18.94  19.21  18.92  19.05      18.92    0.13
# 2    601166.SH   20211229  19.13  19.13  18.88  18.92      19.04   -0.12
# 3    601166.SH   20211228  18.92  19.18  18.91  19.04      18.85    0.19
# 4    601166.SH   20211227  19.01  19.07  18.81  18.85      19.07   -0.22
# ..         ...        ...    ...    ...    ...    ...        ...     ...
# 864  601138.SH   20180614  24.51  24.86  23.15  23.29      25.72   -2.43
# 865  601138.SH   20180613  24.55  26.36  23.56  25.72      23.99    1.73
# 866  601138.SH   20180612  23.99  23.99  23.99  23.99      21.81    2.18
# 867  601138.SH   20180611  21.81  21.81  21.81  21.81      19.83    1.98
# 868  601138.SH   20180608  16.52  19.83  16.52  19.83      13.77    6.06
#
#      pct_chg         vol        amount
# 0    -0.0525   553909.08  1.055757e+06
# 1     0.6871   798266.08  1.523528e+06
# 2    -0.6303   601637.87  1.142118e+06
# 3     1.0080   930354.68  1.775270e+06
# 4    -1.1536   944857.65  1.787176e+06
# ..       ...         ...           ...
# 864  -9.4500  3477821.05  8.310516e+06
# 865   7.2100  6332171.09  1.580962e+07
# 866  10.0000   144923.91  3.476725e+05
# 867   9.9800    19322.86  4.214316e+04
# 868  44.0100    16726.14  3.303413e+04
#
# [44976 rows x 11 columns]

# %%
# 筛选exchange_calender中每个交易节点缺失情况(全部补充0)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) != k:
            missing_tic = set(selected_tics).difference(set(temp_df['ts_code'].tolist()))
#             print(missing_tic)
            for m_tic in missing_tic:
                temp_dict = {'ts_code':m_tic,'trade_date':date,'open':0, 'high':0,'low':0, 'close':0, 'pre_close':0, 'change':0, 'pct_chg':0, 'volume':0, 'amount':0}
                new_data = pd.DataFrame.from_dict(temp_dict,orient='index').T
                temp_df = temp_df.append(new_data)
            processe_df.append(temp_df)
        else :
            processe_df.append(temp_df)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
# 筛选exchange_calender中每个交易节点缺失(激进)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) == k:
            processe_df.append(temp_df)
        else :
            date_unique.remove(date)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
k=20
processed_df,date_unique = processed_date(df_ts,selected_tics,k)
print(processed_df)
# Out:
#          ts_code trade_date    open    high     low   close  pre_close  \
# 0      601138.SH   20180620   19.80   20.26   19.01   19.86      20.32
# 1      601166.SH   20180620   15.37   15.42   15.25   15.27      15.47
# 2      601288.SH   20180620    3.61    3.62    3.58    3.58       3.63
# 3      600009.SH   20180620   56.50   57.90   55.00   56.36      58.29
# 4      600690.SH   20180620   20.01   20.45   19.85   20.20      20.02
# ...          ...        ...     ...     ...     ...     ...        ...
# 16755  601888.SH   20211231  219.34  221.50  216.66  219.41     217.50
# 16756  600887.SH   20211231   41.30   41.76   40.82   41.46      41.36
# 16757  601138.SH   20211231   11.92   11.95   11.78   11.92      11.90
# 16758  601066.SH   20211231   29.40   29.49   29.20   29.25      29.29
# 16759  601166.SH   20211231   19.11   19.16   18.98   19.04      19.05
#
#        change  pct_chg         vol       amount
# 0       -0.46  -2.2600  1982719.14  3891767.821
# 1       -0.20  -1.2900   479441.72   734336.844
# 2       -0.05  -1.3800  1946871.67   698903.010
# 3       -1.93  -3.3100   127784.94   720254.482
# 4        0.18   0.9000   320990.06   646929.941
# ...       ...      ...         ...          ...
# 16755    1.91   0.8782    61691.15  1352592.731
# 16756    0.10   0.2418   352182.51  1455332.129
# 16757    0.02   0.1681   227339.87   269934.956
# 16758   -0.04  -0.1366   115965.62   339889.888
# 16759   -0.01  -0.0525   553909.08  1055756.726
#
# [16760 rows x 11 columns]

# %%
processed_df1 = processed_df
processed_df1 = processed_df1.sort_values(['ts_code','trade_date'],ascending=True,ignore_index=True)
processed_df1['trade_date'] = pd.to_datetime(processed_df1['trade_date'])
processed_df1
# Out:
#          ts_code trade_date  open  high   low  close  pre_close  change  \
# 0      600000.SH 2018-06-20  9.92  9.98  9.87   9.89       9.92   -0.03
# 1      600000.SH 2018-06-21  9.88  9.98  9.75   9.83       9.89   -0.06
# 2      600000.SH 2018-06-22  9.83  9.83  9.67   9.76       9.83   -0.07
# 3      600000.SH 2018-06-25  9.77  9.82  9.55   9.56       9.76   -0.20
# 4      600000.SH 2018-06-26  9.60  9.60  9.35   9.48       9.56   -0.08
# ...          ...        ...   ...   ...   ...    ...        ...     ...
# 16755  603993.SH 2021-12-27  5.54  5.57  5.51   5.52       5.54   -0.02
# 16756  603993.SH 2021-12-28  5.55  5.61  5.52   5.57       5.52    0.05
# 16757  603993.SH 2021-12-29  5.55  5.59  5.52   5.53       5.57   -0.04
# 16758  603993.SH 2021-12-30  5.54  5.56  5.52   5.53       5.53    0.00
# 16759  603993.SH 2021-12-31  5.55  5.60  5.53   5.58       5.53    0.05
#
#        pct_chg        vol      amount
# 0      -0.3000  189157.40  187504.468
# 1      -0.6100  236369.61  234236.776
# 2      -0.7100  250400.01  243586.307
# 3      -2.0500  242443.80  234851.670
# 4      -0.8400  244240.95  231698.549
# ...        ...        ...         ...
# 16755  -0.3610  763572.67  422781.670
# 16756   0.9058  970692.11  539453.122
# 16757  -0.7181  877208.04  486746.356
# 16758   0.0000  737165.36  408493.643
# 16759   0.9042  862563.77  480126.739
#
# [16760 rows x 11 columns]

# %%
#出现缺失值的个数、占比
count = len(pro_df[pro_df['open'] == 0])
nan_rate = count/len(pro_df)
print(count,'缺失值百分之:',nan_rate)

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=False,
                    use_turbulence=True,
                    user_defined_feature = False)

# %%
processed_df3 = processed_df1.rename(columns={'ts_code':'tic','trade_date':'date','vol':'volume'})
processed_df3 = fe.preprocess_data(processed_df3)
processed_df3 = processed_df3.fillna(method="ffill").fillna(method="bfill")
processed_df3 = processed_df3.sort_values(['tic','date'],ascending=True).reset_index()
# Out:
# Successfully added technical indicators

# %%
def delaydate(dela,full_list):
    grouped = processed_df3.groupby('tic')
    filtered_df = pd.DataFrame()
    for name, group in grouped:
        # 按'trade_date'升序排序  True=升序
        group = group.sort_values('date', ascending=True)
        
        # 丢弃前48个日期的数据
        group = group.iloc[dela:]
        filtered_df = filtered_df.append(group)
    
    filtered_df = filtered_df.reset_index(drop=True)
    filtered_df = filtered_df.sort_values(['tic','date'],ascending=True,ignore_index=True)
    return filtered_df

# %%
pro_df = processed_df1.loc[:,['open','high','low','close','vol']].reset_index(drop=True)

# %%
#计算技术指标到dataset中
#Can be easily expanded
#Currently contains a small set of tech indicators
import talib as ta

def calc_tech_ind(data):
    #overlap 
    data['upbd'], data['midbd'], data['lowbd'] = ta.BBANDS(data["close"])
    data['dema'] = ta.DEMA(data["close"], timeperiod=30)
    data['tema'] = ta.TEMA(data["close"], timeperiod=30)
    data['ema'] = ta.EMA(data["close"], timeperiod=30)
    data['wma'] = ta.WMA(data["close"], timeperiod=30)
    data['sma'] = ta.SMA(data["close"], timeperiod=30)
    data['sarext'] = ta.SAREXT(data["high"], data["low"])
    
    #momentum
    data['adxr'] = ta.ADXR(data["high"], data["low"], data["close"], timeperiod=14)
    data['apo'] = ta.APO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['aroondown'], data['aroonup'] = ta.AROON(data["high"], data["low"], timeperiod=14)
    data['cci'] = ta.CCI(data["high"], data["low"], data["close"], timeperiod=14)
    data['cmo'] = ta.CMO(data["close"], timeperiod=14)
    data['macd'], data['macdsignal'], data['macdhist'] = ta.MACD(data["close"], fastperiod=12, slowperiod=26, signalperiod=9)
    data['MFI'] = ta.MFI(data["high"], data["low"], data["close"], data['vol'], timeperiod=14)
    data['mom'] = ta.MOM(data["close"], timeperiod=10)
    data['plus_di'] = ta.PLUS_DI(data["high"], data["low"], data["close"], timeperiod=14)
    data['ppo'] = ta.PPO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['roc'] = ta.ROC(data["close"], timeperiod=10)
    data['rocp'] = ta.ROCP(data["close"], timeperiod=10)
    data['rsi'] = ta.RSI(data["close"], timeperiod=14)
    data['slowk'], data['slowd'] = ta.STOCH(data["high"], data["low"], data["close"])
    data['fastk'], data['fastd'] = ta.STOCHF(data["high"], data["low"], data["close"])
    data['trix'] = ta.TRIX(data["close"], timeperiod=30)
    data['ultosc'] = ta.ULTOSC(data["high"], data["low"], data["close"], timeperiod1=7, timeperiod2=14, timeperiod3=28)
    data['willr'] = ta.WILLR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #volume
    data['ad'] = ta.AD(data["high"], data["low"], data["close"], data['vol'])
    data['obv'] = ta.OBV(data["close"], data['vol'])
    
    #volitility
    data['atr'] = ta.ATR(data["high"], data["low"], data["close"], timeperiod=14)
    data['natr'] = ta.NATR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #cycle
    data['HT_DCPERIOD'] = ta.HT_DCPERIOD(data["close"])
#     data['HT_DCPHASE'] = ta.HT_DCPHASE(data["close"])
#     data['inphase'], data['quadrature'] = ta.HT_PHASOR(data["close"])
    
    
    return data

# %%
full_list1 = calc_tech_ind(pro_df)
full_list1 = full_list1.fillna(0)

# %%
array_full_list = np.array(full_list1)
array_full_list = array_full_list.reshape(k,int(len(full_list1)/k),full_list1.shape[1])
selected_tics = sorted(selected_tics)

# %%
df.tic.value_counts()

# %% [markdown]
# # Part 2: DeepLearning representation

# %%
#generate x, y, z, zp quadruples
#segment x, y, z trios to sequence according to $timeStep and $gap
#x: historical data w/ technical analysis indicator
#y: closing price of t+1
#z:  difference between t+1 and t step's closing price

def toSequential_train1(idx, full_list, timeStep=48, gap=4):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
#     closingNorm = (closing - closing.mean())/closing.std()
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    for i in range(count):
        #segData dims: [timestep, feature count]       
        segData=data[gap*i:gap*i+timeStep]
        segClosing=closing[gap*i:gap*i+timeStep+1]
        #segDiff=diff[gap*i:gap*i+timeStep]
        #normalization
        
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
#         segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        segDataNorm=np.nan_to_num((segData-segData.mean(axis=0, keepdims=True))/segData.std(axis=0, keepdims=True))
    
        std_close = segClosing.std()
        std_segClosing = np.where(std_close == 0, 1, std_close)
        segClosingNorm=(segClosing-segClosing.mean())/std_segClosing
#         segDiff=(segDiff-segDiff.mean())/segDiff.std()
        
        stockSeq.append(segDataNorm)
        labelSeq.append(segClosingNorm[1:])
        diffSeq.append(segClosingNorm[1:]-segClosingNorm[:-1])
        realDiffSeq.append(segClosing[1:]-segClosing[:-1])
    stockSeq=np.array(stockSeq)
    labelSeq=np.array(labelSeq)
    diffSeq=np.array(diffSeq)
    realDiffSeq=np.array(realDiffSeq)
    return stockSeq.astype('float32') , labelSeq.astype('float32'), diffSeq.astype('float32'), realDiffSeq.astype('float32')

# %%
def toSequential_back(idx, full_list, timeStep = 48, gap = 1,batch_size = 64):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    
    start = data_length - timeStep
    i=0
    while start >= 0:
        segData = data[start:start + timeStep]
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
        segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        #复制batch_size个
        stockSeq.extend([segDataNorm] * batch_size)
#         stockSeq.append(segDataNorm)   
        start = start - gap
        i +=1
    stockSeq=np.array(stockSeq)[::-1]
#     print(i)
    return stockSeq.astype('float32')

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=3):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        closing_cohort=[]
        diff_cohort=[]
        real_diff_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X, y, z, zp=toSequential_train1(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
            closing_cohort.append(y)
            diff_cohort.append(z)
            real_diff_cohort.append(zp)
        self.X=np.concatenate(stock_cohort, axis=0)
        self.y=np.concatenate(closing_cohort, axis=0)
        self.z=np.concatenate(diff_cohort, axis=0)  
        self.zp=np.concatenate(real_diff_cohort, axis=0)
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        label1=self.y[idx]
        label2=self.z[idx]
        label3=self.zp[idx]
        if self.transform:
            data=self.transform(data)
        return (data, label1, label2, label3)
    
    
    def getDS(self):
        return self.X, self.y, self.z, self.zp

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset_back(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=1):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X=toSequential_back(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
        self.X=np.concatenate(stock_cohort, axis=0)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        if self.transform:
            data=self.transform(data)
        return data
        
    def getDS(self):
        return self.X

# %%
#Generation of training, validation, and testing dataset
def DataIterGen(test_id_list, val_id_list, name_list, full_list, demo=False):
    """
    test_id_list: id of subjects for testing
    val_id_list: id of subjects for validation
    other subjects for training
    full_list=get_data_set(name_list), preprocessed
    demo: when demo mode is True, only test_iter is returned, with data from
    first entry of test_id_list (single stock)
    """
    name_count=len(name_list)

    if demo:
        test_iter=DataLoader(StockDataset(test_id_list[0:1], full_list, timestep=24, gap=1), shuffle=False, batch_size=64, num_workers=0)
        print(f'Demo with stock: {name_list[test_id_list[0]]} ')
        return test_iter
    else:
        all_ids = list(range(name_count))
        train_id_list = list(set(all_ids) - set(test_id_list) - set(val_id_list))
#         partial_list=full_list[train_list,:,:]
        test_iter=DataLoader(StockDataset(test_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        val_iter=DataLoader(StockDataset(val_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        train_iter=DataLoader(StockDataset(train_id_list, full_list), shuffle=True, batch_size=64, num_workers=0,drop_last=True)
        print(f'Val: {[name_list[val_id] for val_id in val_id_list]}, Test: {[name_list[test_id] for test_id in test_id_list]}, Train: {[name_list[train_id] for train_id in train_id_list]} ')
        return train_iter, val_iter, test_iter

# %%
train_iter, val_iter, test_iter = DataIterGen([3],[4],selected_tics,array_full_list)
# Out:
# Val: ['600031.SH'], Test: ['600030.SH'], Train: ['600000.SH', '600009.SH', '600016.SH', '600036.SH', '600104.SH', '600690.SH', '600887.SH', '601066.SH', '601138.SH', '601166.SH', '601288.SH', '601318.SH', '601328.SH', '601601.SH', '601888.SH', '601939.SH', '601988.SH', '603993.SH']

# %% [markdown]
# # Part3: Transformer

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class TransformerEncoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers,dropout_rate):
#         super(TransformerEncoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_moedl * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_moedl)
#         self.num_layers = num_layers

#     def forward(self, x):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#         return x

# %%
# class TransformerDecoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, env_size, num_layers, dropout_rate):
#         super(TransformerDecoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.encoder_attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_model * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout3 = nn.Dropout(dropout_rate)
#         self.layer_norm3 = nn.LayerNorm(d_model)
#         self.linear1 = nn.Linear(d_model, env_size)
#         self.linear2 = nn.Linear(env_size,1)
#         self.num_layers = num_layers

#     def forward(self, x, encoder_output, target_mask, target_padding_mask):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x, attn_mask=target_mask)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x, _ = self.encoder_attention(x, encoder_output, encoder_output,key_padding_mask =target_padding_mask)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout3(x)
#             x = self.layer_norm3(x + residual)
#         env_size = self.linear1(x)
#         x = self.linear2(env_size).permute(1,0,2)
#         return x, env_size.permute(1,0,2)[0,-1,:]

# %%
# class Transformer(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers, env_size, dropout_rate):
#         super(Transformer, self).__init__()
#         self.encoder = TransformerEncoder(input_size, d_model, num_heads, num_layers,dropout_rate)
#         self.decoder = TransformerDecoder(input_size, d_model, num_heads, env_size, num_layers,dropout_rate)

#     def forward(self, input_seq, target_seq):
#         encoder_output = self.encoder(input_seq)
#         target_mask = self.generate_attention_mask(target_seq)
#         target_padding_mask = self.generate_padding_mask(target_seq)
#         decoder_output = self.decoder(target_seq, encoder_output)
#         return decoder_output
    
#     def generate_attention_mask(self, sequence):
#         attn_mask = torch.triu(torch.ones(sequence.size(1), sequence.size(1)), diagonal=1).bool().to(sequence.device)
#         return attn_mask

#     def generate_padding_mask(self, sequence):
#         padding_mask = (sequence == 0).to(sequence.device)
#         return padding_mask

# %%
# #模型训练
# def train(model, train_iter, optimizer, num_epochs): 
#     # 训练循环
#     for epoch in range(num_epochs):
#         model.train()
#         total_loss = 0.0
#         enVec_list = []
#         for X, y, z, zp in train_iter:  
#             optimizer.zero_grad()

#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred,enVec = model(inputs,targets)
#             enVec_list.append(enVec)
#             print(pred,targets)
#             loss = nn.MSELoss()(pred, targets)  
#             loss.backward()
#             optimizer.step()
#             total_loss += loss.item()

#         # 打印每个 epoch 的损失
#         print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
#     return enVec_list
# # 模型评估
# def val(model, val_iter):
#     model.eval()
#     total_loss = 0.0
#     enVec_list = []
#     with torch.no_grad():
#         for X, y, z, zp in val_iter: 
#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred, enVec = model(inputs)
#             enVec_list.append(enVec)
#             loss = nn.MSELoss()(pred, targets)  
#             total_loss += loss.item()
#     print(f"val Loss: {total_loss/len(val_iter):.4f}")
#     return enVec_list

# %%
# # 定义模型
# model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, num_heads = 8,env_size =40,dropout_rate=0.2)
# optimizer = optim.Adam(model.parameters(), lr=0.001)
# outcoming =train(model,train_iter,optimizer,5)
# valtest =val(model,val_iter)

# %%
# def predict(model,back_iter):
#     enVec_list = []
#     with torch.no_grad():
#         for X in back_iter:
#             inputs = X.to(device)
#             _,enVec = model(inputs)
#             enVec_list.append(enVec)
#     return enVec_list

# %%
# #define device
# def try_gpu(i=0):
#     """Return gpu(i) if exists, otherwise return cpu()."""
#     if torch.cuda.device_count() >= i + 1:
#         return torch.device(f'cuda:{i}')
#     return torch.device('cpu')
# device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers,dropout_rate):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers,dropout_rate)
        self.linear1 = nn.Linear(d_model, env_size)
        self.rule = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.rule(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers,dropout_rate):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads,dropout_rate) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads,dropout_rate):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = self.dropout1(x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = self.dropout2(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
def predict(model,back_iter):
    enVec_list = []
    with torch.no_grad():
        for X in back_iter:
            inputs = X.to(device)
            _,enVec = model(inputs)
            enVec_list.append(enVec)
    return enVec_list

# %%
#define device
def try_gpu(i=0):
    """Return gpu(i) if exists, otherwise return cpu()."""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers)
        self.linear1 = nn.Linear(d_model, env_size)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.relu(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming =train(model,train_iter,optimizer,5)
valtest =val(model,val_iter)

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40,dropout_rate=0.1)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming = train(model,train_iter,optimizer,5)
valtest =val(model,val_iter)
# Out:
# Epoch 1: Loss: 0.2412
# Epoch 2: Loss: 0.1561
# Epoch 3: Loss: 0.0978
# Epoch 4: Loss: 0.0582
# Epoch 5: Loss: 0.0402
# val Loss: 0.0353

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# feature_enginner
import time 
start_time = time.time()
alltic_list = [i for i in range(k)]

def Feature_enginner(model, processed_df, full_list, alltic_list, batch_size=64, k=20, env_size=40,dela = 48):
    back_iter = DataLoader(StockDataset_back([i for i in range(k)],full_list), shuffle=False, batch_size=batch_size, num_workers=0,drop_last=False)
    
    new_state = predict(model,back_iter)
    concatenated_tensor = torch.cat(new_state, dim=0)
    concatenated_tensor = concatenated_tensor.view(-1,env_size)
    feature_df = pd.DataFrame(concatenated_tensor.numpy())
    
    full_delay_df = delaydate(dela ,processed_df)
    
    merged_df = pd.concat([full_delay_df, feature_df], axis=1)
    merged_df = merged_df.loc[:,['tic','date','close'] + INDICATORS + [i for i in range(env_size)]]
    merged_df.columns = ['tic','date','close'] + INDICATORS + [f"temporal_feature_{i}" for i in range(env_size)]
    end_time = time.time()
    print('总计消耗时间:',(end_time - start_time)/60)
    return merged_df

# %%
addfeature_df = Feature_enginner(model, processed_df3, array_full_list, alltic_list, batch_size=64, k=20 ,env_size=40, dela=48)
# Out:
# 总计消耗时间: 4.8052078286806745

# %%
addfeature_df.to_csv('726addfeature_df.csv',index=None)

# %%
addfeature_df = pd.read_csv('726addfeature_df.csv')

# %%
addfeature_df['date'] = pd.to_datetime(addfeature_df['date'])

# %%
processed_df3.to_csv('726_processed_best.csv',index=None)

# %%
processed_df3 = pd.read_csv('726_processed_best.csv')

# %%
processed_df3['date'] = pd.to_datetime(processed_df3['date'])

# %%
processed_df3 = fe.add_turbulence(processed_df3)
processed_df3 = processed_df3.fillna(method="ffill").fillna(method="bfill")

# %%
import datetime
processed['date'] = pd.to_datetime(processed['date'],format='%Y%m%d')
processed

# %%
list_ticker = processed["tic"].unique().tolist()
# list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
# combination = list(itertools.product(list_date,list_ticker))

# processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
# processed_full = processed_full[processed_full['date'].isin(processed['date'])]
# processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
selfattn_indicator_list = [f"temporal_feature_{i}" for i in range(40)]

# %%
selected_tics = addfeature_df.tic.unique()
selected_tics
# Out:
# array(['600000.SH', '600009.SH', '600016.SH', '600030.SH', '600031.SH',
#        '600036.SH', '600104.SH', '600690.SH', '600887.SH', '601066.SH',
#        '601138.SH', '601166.SH', '601288.SH', '601318.SH', '601328.SH',
#        '601601.SH', '601888.SH', '601939.SH', '601988.SH', '603993.SH'],
#       dtype=object)

# %%
TRAIN_START_DATE = addfeature_df['date'].unique()[0]

# %%
TRAIN_START_DATE
# Out:
# numpy.datetime64('2018-08-27T00:00:00.000000000')

# %%
stock_dimension = 20
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension + len(selfattn_indicator_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 1001

# %%
stock_dimension = len(processed_df3.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 201

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=addfeature_df,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TRADE_START_DATE,TRADE_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 attn_indicator_list = selfattn_indicator_list,                 
                 **env_kwargs)

# %%
TRADE_END_DATE

# %%
SAC_model_kwargs = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
                }

PPO_model_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
                    }

TD3_model_kwargs = {
    "batch_size": 128, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
                }

timesteps_dict = {'sac' : 10000, 
                 'ppo' : 10000, 
                 'td3' : 10000
                 }

# %%
import torch
device = torch.device("mps")

# %%
df_summary = ensemble_agent.run_ensemble_strategy_com(SAC_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2020-03-02T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_80
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 97            |
# |    time_elapsed    | 14            |
# |    total_timesteps | 1408          |
# | train/             |               |
# |    actor_loss      | 675           |
# |    critic_loss     | 1.15e+03      |
# |    ent_coef        | 0.11          |
# |    ent_coef_loss   | 226           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 1307          |
# |    reward          | -0.0019663663 |
# --------------------------------------
# day: 351, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1261168.42
# total_reward: 261168.42
# total_cost: 11890.52
# total_trades: 5824
# Sharpe: 0.806
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 93            |
# |    time_elapsed    | 30            |
# |    total_timesteps | 2816          |
# | train/             |               |
# |    actor_loss      | 456           |
# |    critic_loss     | 422           |
# |    ent_coef        | 0.123         |
# |    ent_coef_loss   | 178           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 2715          |
# |    reward          | 5.5134387e-06 |
# --------------------------------------
# day: 351, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1269953.95
# total_reward: 269953.95
# total_cost: 11381.35
# total_trades: 5994
# Sharpe: 0.803
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 92           |
# |    time_elapsed    | 45           |
# |    total_timesteps | 4224         |
# | train/             |              |
# |    actor_loss      | 534          |
# |    critic_loss     | 3.65e+03     |
# |    ent_coef        | 0.137        |
# |    ent_coef_loss   | 105          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 4123         |
# |    reward          | -0.001045951 |
# -------------------------------------
# day: 351, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1202059.05
# total_reward: 202059.05
# total_cost: 4626.50
# total_trades: 5613
# Sharpe: 0.659
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 92           |
# |    time_elapsed    | 61           |
# |    total_timesteps | 5632         |
# | train/             |              |
# |    actor_loss      | 342          |
# |    critic_loss     | 919          |
# |    ent_coef        | 0.147        |
# |    ent_coef_loss   | 14.6         |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 5531         |
# |    reward          | -0.002878031 |
# -------------------------------------
# day: 351, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1199082.36
# total_reward: 199082.36
# total_cost: 5652.09
# total_trades: 5613
# Sharpe: 0.646
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 20             |
# |    fps             | 91             |
# |    time_elapsed    | 76             |
# |    total_timesteps | 7040           |
# | train/             |                |
# |    actor_loss      | 327            |
# |    critic_loss     | 727            |
# |    ent_coef        | 0.152          |
# |    ent_coef_loss   | 8.15           |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 6939           |
# |    reward          | -0.00044953736 |
# ---------------------------------------
# ---------------------------------------
# | time/              |                |
# |    episodes        | 24             |
# |    fps             | 91             |
# |    time_elapsed    | 92             |
# |    total_timesteps | 8448           |
# | train/             |                |
# |    actor_loss      | 305            |
# |    critic_loss     | 2.29e+03       |
# |    ent_coef        | 0.15           |
# |    ent_coef_loss   | -4.45          |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 8347           |
# |    reward          | -0.00046903963 |
# ---------------------------------------
# day: 351, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1215300.69
# total_reward: 215300.69
# total_cost: 5320.82
# total_trades: 5683
# Sharpe: 0.701
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 28            |
# |    fps             | 91            |
# |    time_elapsed    | 107           |
# |    total_timesteps | 9856          |
# | train/             |               |
# |    actor_loss      | 257           |
# |    critic_loss     | 190           |
# |    ent_coef        | 0.128         |
# |    ent_coef_loss   | -57.3         |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 9755          |
# |    reward          | -0.0005727577 |
# --------------------------------------
# ======SAC Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# SAC Sharpe Ratio:  0.2324406703634042
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_73
# day: 351, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1008876.79
# total_reward: 8876.79
# total_cost: 9888.81
# total_trades: 6689
# Sharpe: 0.146
# =================================
# -------------------------------------
# | time/              |              |
# |    fps             | 888          |
# |    iterations      | 1            |
# |    time_elapsed    | 2            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 7.062404e-05 |
# -------------------------------------
# day: 351, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1001488.69
# total_reward: 1488.69
# total_cost: 10170.65
# total_trades: 6711
# Sharpe: 0.053
# =================================
# day: 351, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1035147.00
# total_reward: 35147.00
# total_cost: 10004.70
# total_trades: 6705
# Sharpe: 0.335
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 838           |
# |    iterations           | 2             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0122525785  |
# |    clip_fraction        | 0.189         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -0.241        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.29         |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00757      |
# |    reward               | 0.00032171817 |
# |    std                  | 1             |
# |    value_loss           | 0.00278       |
# -------------------------------------------
# day: 351, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1020925.32
# total_reward: 20925.32
# total_cost: 10398.60
# total_trades: 6664
# Sharpe: 0.206
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009942476 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.291      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00871    |
# |    reward               | 0.000755536 |
# |    std                  | 1.01        |
# |    value_loss           | 0.0167      |
# -----------------------------------------
# day: 351, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 975274.76
# total_reward: -24725.24
# total_cost: 10367.21
# total_trades: 6770
# Sharpe: -0.128
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.008434661  |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | -0.00694     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.283       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00696     |
# |    reward               | 7.234804e-06 |
# |    std                  | 1            |
# |    value_loss           | 0.0144       |
# ------------------------------------------
# day: 351, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1041422.20
# total_reward: 41422.20
# total_cost: 10271.79
# total_trades: 6702
# Sharpe: 0.299
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 767          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.009804901  |
# |    clip_fraction        | 0.0971       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.269       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00701     |
# |    reward               | 0.0014686516 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00518      |
# ------------------------------------------
# ======PPO Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# PPO Sharpe Ratio:  0.1704466525081938
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_67
# day: 351, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1062701.33
# total_reward: 62701.33
# total_cost: 3335.53
# total_trades: 5195
# Sharpe: 0.339
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 128            |
# |    time_elapsed    | 10             |
# |    total_timesteps | 1408           |
# | train/             |                |
# |    actor_loss      | 422            |
# |    critic_loss     | 375            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 1056           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# day: 351, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1132274.62
# total_reward: 132274.62
# total_cost: 999.00
# total_trades: 4563
# Sharpe: 0.490
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 112            |
# |    time_elapsed    | 25             |
# |    total_timesteps | 2816           |
# | train/             |                |
# |    actor_loss      | 240            |
# |    critic_loss     | 333            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 2464           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# day: 351, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1132274.62
# total_reward: 132274.62
# total_cost: 999.00
# total_trades: 4563
# Sharpe: 0.490
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 108            |
# |    time_elapsed    | 39             |
# |    total_timesteps | 4224           |
# | train/             |                |
# |    actor_loss      | 171            |
# |    critic_loss     | 1.31e+03       |
# |    learning_rate   | 0.001          |
# |    n_updates       | 3872           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# day: 351, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1132274.62
# total_reward: 132274.62
# total_cost: 999.00
# total_trades: 4563
# Sharpe: 0.490
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 105            |
# |    time_elapsed    | 53             |
# |    total_timesteps | 5632           |
# | train/             |                |
# |    actor_loss      | 126            |
# |    critic_loss     | 1.53e+03       |
# |    learning_rate   | 0.001          |
# |    n_updates       | 5280           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# ---------------------------------------
# | time/              |                |
# |    episodes        | 20             |
# |    fps             | 104            |
# |    time_elapsed    | 67             |
# |    total_timesteps | 7040           |
# | train/             |                |
# |    actor_loss      | 95.3           |
# |    critic_loss     | 1.3e+03        |
# |    learning_rate   | 0.001          |
# |    n_updates       | 6688           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# day: 351, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1132274.62
# total_reward: 132274.62
# total_cost: 999.00
# total_trades: 4563
# Sharpe: 0.490
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 24             |
# |    fps             | 103            |
# |    time_elapsed    | 81             |
# |    total_timesteps | 8448           |
# | train/             |                |
# |    actor_loss      | 72             |
# |    critic_loss     | 423            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 8096           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# day: 351, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1132274.62
# total_reward: 132274.62
# total_cost: 999.00
# total_trades: 4563
# Sharpe: 0.490
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 28             |
# |    fps             | 103            |
# |    time_elapsed    | 95             |
# |    total_timesteps | 9856           |
# | train/             |                |
# |    actor_loss      | 56.2           |
# |    critic_loss     | 845            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 9504           |
# |    reward          | -0.00065571896 |
# ---------------------------------------
# ======TD3 Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Trading from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# ============================================
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_64
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 91             |
# |    time_elapsed    | 18             |
# |    total_timesteps | 1660           |
# | train/             |                |
# |    actor_loss      | 120            |
# |    critic_loss     | 28.6           |
# |    ent_coef        | 0.113          |
# |    ent_coef_loss   | 252            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 1559           |
# |    reward          | -0.00014184347 |
# ---------------------------------------
# day: 414, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1204019.58
# total_reward: 204019.58
# total_cost: 11280.08
# total_trades: 5225
# Sharpe: 0.672
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 88             |
# |    time_elapsed    | 37             |
# |    total_timesteps | 3320           |
# | train/             |                |
# |    actor_loss      | 243            |
# |    critic_loss     | 95             |
# |    ent_coef        | 0.129          |
# |    ent_coef_loss   | 204            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 3219           |
# |    reward          | -0.00012676146 |
# ---------------------------------------
# day: 414, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1326045.11
# total_reward: 326045.11
# total_cost: 12503.90
# total_trades: 6641
# Sharpe: 0.804
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 88            |
# |    time_elapsed    | 56            |
# |    total_timesteps | 4980          |
# | train/             |               |
# |    actor_loss      | 320           |
# |    critic_loss     | 81.4          |
# |    ent_coef        | 0.148         |
# |    ent_coef_loss   | 101           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 4879          |
# |    reward          | -0.0005721856 |
# --------------------------------------
# day: 414, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1106928.67
# total_reward: 106928.67
# total_cost: 5539.86
# total_trades: 6084
# Sharpe: 0.386
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 87            |
# |    time_elapsed    | 75            |
# |    total_timesteps | 6640          |
# | train/             |               |
# |    actor_loss      | 330           |
# |    critic_loss     | 69.7          |
# |    ent_coef        | 0.153         |
# |    ent_coef_loss   | -55.6         |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 6539          |
# |    reward          | -0.0014226133 |
# --------------------------------------
# day: 414, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1072372.45
# total_reward: 72372.45
# total_cost: 8707.24
# total_trades: 7571
# Sharpe: 0.327
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 20            |
# |    fps             | 87            |
# |    time_elapsed    | 94            |
# |    total_timesteps | 8300          |
# | train/             |               |
# |    actor_loss      | 313           |
# |    critic_loss     | 84.1          |
# |    ent_coef        | 0.133         |
# |    ent_coef_loss   | -63.6         |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 8199          |
# |    reward          | -0.0020328744 |
# --------------------------------------
# --------------------------------------
# | time/              |               |
# |    episodes        | 24            |
# |    fps             | 87            |
# |    time_elapsed    | 113           |
# |    total_timesteps | 9960          |
# | train/             |               |
# |    actor_loss      | 253           |
# |    critic_loss     | 81            |
# |    ent_coef        | 0.113         |
# |    ent_coef_loss   | -68.6         |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 9859          |
# |    reward          | -0.0012889027 |
# --------------------------------------
# ======SAC Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# SAC Sharpe Ratio:  0.28695931080346937
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_67
# --------------------------------------
# | time/              |               |
# |    fps             | 847           |
# |    iterations      | 1             |
# |    time_elapsed    | 2             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00035117942 |
# --------------------------------------
# day: 414, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1054613.38
# total_reward: 54613.38
# total_cost: 12242.21
# total_trades: 8003
# Sharpe: 0.375
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 800           |
# |    iterations           | 2             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.009847193   |
# |    clip_fraction        | 0.145         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -0.011        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.293        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00842      |
# |    reward               | 0.00017831693 |
# |    std                  | 1             |
# |    value_loss           | 0.00478       |
# -------------------------------------------
# day: 414, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1024010.56
# total_reward: 24010.56
# total_cost: 11934.37
# total_trades: 7955
# Sharpe: 0.225
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 780           |
# |    iterations           | 3             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.008263541   |
# |    clip_fraction        | 0.106         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.293        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00606      |
# |    reward               | 2.2854552e-05 |
# |    std                  | 1             |
# |    value_loss           | 0.00388       |
# -------------------------------------------
# day: 414, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1037445.43
# total_reward: 37445.43
# total_cost: 11767.68
# total_trades: 7983
# Sharpe: 0.339
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 774            |
# |    iterations           | 4              |
# |    time_elapsed         | 10             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.007991377    |
# |    clip_fraction        | 0.0992         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.281         |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.00853       |
# |    reward               | -0.00016666511 |
# |    std                  | 0.999          |
# |    value_loss           | 0.00247        |
# --------------------------------------------
# day: 414, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 995727.53
# total_reward: -4272.47
# total_cost: 11876.94
# total_trades: 7885
# Sharpe: 0.005
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 5            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0094778575 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -0.00863     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.284       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0094      |
# |    reward               | 0.0010656817 |
# |    std                  | 1            |
# |    value_loss           | 0.00233      |
# ------------------------------------------
# ======PPO Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# PPO Sharpe Ratio:  0.2946068921622056
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_62
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 135          |
# |    time_elapsed    | 12           |
# |    total_timesteps | 1660         |
# | train/             |              |
# |    actor_loss      | 795          |
# |    critic_loss     | 551          |
# |    learning_rate   | 0.001        |
# |    n_updates       | 1245         |
# |    reward          | -0.002602469 |
# -------------------------------------
# day: 414, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1240027.51
# total_reward: 240027.51
# total_cost: 1120.58
# total_trades: 4546
# Sharpe: 0.649
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 119          |
# |    time_elapsed    | 27           |
# |    total_timesteps | 3320         |
# | train/             |              |
# |    actor_loss      | 550          |
# |    critic_loss     | 674          |
# |    learning_rate   | 0.001        |
# |    n_updates       | 2905         |
# |    reward          | -0.002602469 |
# -------------------------------------
# day: 414, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1240027.51
# total_reward: 240027.51
# total_cost: 1120.58
# total_trades: 4546
# Sharpe: 0.649
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 114          |
# |    time_elapsed    | 43           |
# |    total_timesteps | 4980         |
# | train/             |              |
# |    actor_loss      | 448          |
# |    critic_loss     | 1.31e+03     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 4565         |
# |    reward          | -0.002602469 |
# -------------------------------------
# day: 414, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1240027.51
# total_reward: 240027.51
# total_cost: 1120.58
# total_trades: 4546
# Sharpe: 0.649
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 112          |
# |    time_elapsed    | 58           |
# |    total_timesteps | 6640         |
# | train/             |              |
# |    actor_loss      | 350          |
# |    critic_loss     | 1.46e+03     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 6225         |
# |    reward          | -0.002602469 |
# -------------------------------------
# day: 414, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1240027.51
# total_reward: 240027.51
# total_cost: 1120.58
# total_trades: 4546
# Sharpe: 0.649
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 111          |
# |    time_elapsed    | 74           |
# |    total_timesteps | 8300         |
# | train/             |              |
# |    actor_loss      | 320          |
# |    critic_loss     | 922          |
# |    learning_rate   | 0.001        |
# |    n_updates       | 7885         |
# |    reward          | -0.002602469 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 110          |
# |    time_elapsed    | 90           |
# |    total_timesteps | 9960         |
# | train/             |              |
# |    actor_loss      | 261          |
# |    critic_loss     | 1.47e+03     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 9545         |
# |    reward          | -0.002602469 |
# -------------------------------------
# day: 414, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1240027.51
# total_reward: 240027.51
# total_cost: 1120.58
# total_trades: 4546
# Sharpe: 0.649
# =================================
# ======TD3 Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# ======Trading from:  2020-09-04T00:00:00.000000000 to  2020-12-10T00:00:00.000000000
# ============================================
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_252_46
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 93            |
# |    time_elapsed    | 20            |
# |    total_timesteps | 1912          |
# | train/             |               |
# |    actor_loss      | 37.9          |
# |    critic_loss     | 59            |
# |    ent_coef        | 0.114         |
# |    ent_coef_loss   | 237           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 1811          |
# |    reward          | 5.7207337e-05 |
# --------------------------------------
# day: 477, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2012903.26
# total_reward: 1012903.26
# total_cost: 17558.59
# total_trades: 8719
# Sharpe: 1.388
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 91            |
# |    time_elapsed    | 41            |
# |    total_timesteps | 3824          |
# | train/             |               |
# |    actor_loss      | 184           |
# |    critic_loss     | 106           |
# |    ent_coef        | 0.131         |
# |    ent_coef_loss   | 110           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 3723          |
# |    reward          | -7.141625e-05 |
# --------------------------------------
# day: 477, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1621457.86
# total_reward: 621457.86
# total_cost: 12180.31
# total_trades: 8002
# Sharpe: 1.113
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 90             |
# |    time_elapsed    | 63             |
# |    total_timesteps | 5736           |
# | train/             |                |
# |    actor_loss      | 188            |
# |    critic_loss     | 161            |
# |    ent_coef        | 0.14           |
# |    ent_coef_loss   | -4.42          |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 5635           |
# |    reward          | -0.00011142928 |
# ---------------------------------------
# day: 477, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1601852.23
# total_reward: 601852.23
# total_cost: 8870.63
# total_trades: 7843
# Sharpe: 1.029
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 90            |
# |    time_elapsed    | 84            |
# |    total_timesteps | 7648          |
# | train/             |               |
# |    actor_loss      | 159           |
# |    critic_loss     | 316           |
# |    ent_coef        | 0.131         |
# |    ent_coef_loss   | -18.9         |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 7547          |
# |    reward          | -9.072106e-05 |
# --------------------------------------
# day: 477, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1655724.83
# total_reward: 655724.83
# total_cost: 4683.70
# total_trades: 6489
# Sharpe: 1.019
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 20             |
# |    fps             | 89             |
# |    time_elapsed    | 106            |
# |    total_timesteps | 9560           |
# | train/             |                |
# |    actor_loss      | 76.7           |
# |    critic_loss     | 106            |
# |    ent_coef        | 0.108          |
# |    ent_coef_loss   | -65.4          |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 9459           |
# |    reward          | -8.8469176e-05 |
# ---------------------------------------
# ======SAC Validation from:  2020-09-04T00:00:00.000000000 to  2020-12-10T00:00:00.000000000
# SAC Sharpe Ratio:  -0.11311921898934449
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_49
# day: 477, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1162785.66
# total_reward: 162785.66
# total_cost: 14387.78
# total_trades: 9234
# Sharpe: 0.811
# =================================
# -------------------------------------
# | time/              |              |
# |    fps             | 767          |
# |    iterations      | 1            |
# |    time_elapsed    | 2            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.017855233 |
# -------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 746            |
# |    iterations           | 2              |
# |    time_elapsed         | 5              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.010203939    |
# |    clip_fraction        | 0.133          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.4          |
# |    explained_variance   | -0.12          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.293         |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00795       |
# |    reward               | -0.00049692584 |
# |    std                  | 1              |
# |    value_loss           | 0.00276        |
# --------------------------------------------
# day: 477, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1293802.32
# total_reward: 293802.32
# total_cost: 14873.64
# total_trades: 9271
# Sharpe: 1.009
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.011723718  |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -0.155       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.291       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00965     |
# |    reward               | 0.0022783345 |
# |    std                  | 1            |
# |    value_loss           | 0.00274      |
# ------------------------------------------
# day: 477, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1229628.85
# total_reward: 229628.85
# total_cost: 14455.20
# total_trades: 9133
# Sharpe: 1.013
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 735            |
# |    iterations           | 4              |
# |    time_elapsed         | 11             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.009966625    |
# |    clip_fraction        | 0.133          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.5          |
# |    explained_variance   | -0.0131        |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.297         |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.00895       |
# |    reward               | -0.00054237107 |
# |    std                  | 1.01           |
# |    value_loss           | 0.00346        |
# --------------------------------------------
# day: 477, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1535132.98
# total_reward: 535132.98
# total_cost: 14765.35
# total_trades: 9187
# Sharpe: 1.413
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 657           |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.010147043   |
# |    clip_fraction        | 0.133         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.6         |
# |    explained_variance   | -0.186        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.29         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00839      |
# |    reward               | -0.0012048881 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00473       |
# -------------------------------------------
# ======PPO Validation from:  2020-09-04T00:00:00.000000000 to  2020-12-10T00:00:00.000000000
# PPO Sharpe Ratio:  0.0569718673841925
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_252_44
# day: 477, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1677875.21
# total_reward: 677875.21
# total_cost: 2012.37
# total_trades: 3821
# Sharpe: 1.072
# =================================
# ----------------------------------------
# | time/              |                 |
# |    episodes        | 4               |
# |    fps             | 135             |
# |    time_elapsed    | 14              |
# |    total_timesteps | 1912            |
# | train/             |                 |
# |    actor_loss      | 179             |
# |    critic_loss     | 46.9            |
# |    learning_rate   | 0.001           |
# |    n_updates       | 1434            |
# |    reward          | -0.000100785874 |
# ----------------------------------------
# day: 477, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1660044.06
# total_reward: 660044.06
# total_cost: 1114.82
# total_trades: 4000
# Sharpe: 1.113
# =================================
# ----------------------------------------
# | time/              |                 |
# |    episodes        | 8               |
# |    fps             | 118             |
# |    time_elapsed    | 32              |
# |    total_timesteps | 3824            |
# | train/             |                 |
# |    actor_loss      | 140             |
# |    critic_loss     | 43.4            |
# |    learning_rate   | 0.001           |
# |    n_updates       | 3346            |
# |    reward          | -0.000100785874 |
# ----------------------------------------
# day: 477, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1660044.06
# total_reward: 660044.06
# total_cost: 1114.82
# total_trades: 4000
# Sharpe: 1.113
# =================================
# ----------------------------------------
# | time/              |                 |
# |    episodes        | 12              |
# |    fps             | 113             |
# |    time_elapsed    | 50              |
# |    total_timesteps | 5736            |
# | train/             |                 |
# |    actor_loss      | 120             |
# |    critic_loss     | 170             |
# |    learning_rate   | 0.001           |
# |    n_updates       | 5258            |
# |    reward          | -0.000100785874 |
# ----------------------------------------
# ----------------------------------------
# | time/              |                 |
# |    episodes        | 16              |
# |    fps             | 111             |
# |    time_elapsed    | 68              |
# |    total_timesteps | 7648            |
# | train/             |                 |
# |    actor_loss      | 134             |
# |    critic_loss     | 44.3            |
# |    learning_rate   | 0.001           |
# |    n_updates       | 7170            |
# |    reward          | -0.000100785874 |
# ----------------------------------------
# day: 477, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1660044.06
# total_reward: 660044.06
# total_cost: 1114.82
# total_trades: 4000
# Sharpe: 1.113
# =================================
# ----------------------------------------
# | time/              |                 |
# |    episodes        | 20              |
# |    fps             | 109             |
# |    time_elapsed    | 86              |
# |    total_timesteps | 9560            |
# | train/             |                 |
# |    actor_loss      | 121             |
# |    critic_loss     | 120             |
# |    learning_rate   | 0.001           |
# |    n_updates       | 9082            |
# |    reward          | -0.000100785874 |
# ----------------------------------------
# ======TD3 Validation from:  2020-09-04T00:00:00.000000000 to  2020-12-10T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2020-12-10T00:00:00.000000000
# ======Trading from:  2020-12-10T00:00:00.000000000 to  2021-03-17T00:00:00.000000000
# ============================================
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2020-12-10T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_42
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 94           |
# |    time_elapsed    | 22           |
# |    total_timesteps | 2164         |
# | train/             |              |
# |    actor_loss      | 90.3         |
# |    critic_loss     | 308          |
# |    ent_coef        | 0.119        |
# |    ent_coef_loss   | 282          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 2063         |
# |    reward          | 0.0001006074 |
# -------------------------------------
# day: 540, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1573732.67
# total_reward: 573732.67
# total_cost: 16680.22
# total_trades: 8505
# Sharpe: 0.991
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 92            |
# |    time_elapsed    | 46            |
# |    total_timesteps | 4328          |
# | train/             |               |
# |    actor_loss      | 267           |
# |    critic_loss     | 138           |
# |    ent_coef        | 0.14          |
# |    ent_coef_loss   | 162           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 4227          |
# |    reward          | 1.4951263e-05 |
# --------------------------------------
# day: 540, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1430018.93
# total_reward: 430018.93
# total_cost: 14074.00
# total_trades: 8721
# Sharpe: 0.816
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 12          |
# |    fps             | 91          |
# |    time_elapsed    | 70          |
# |    total_timesteps | 6492        |
# | train/             |             |
# |    actor_loss      | 277         |
# |    critic_loss     | 513         |
# |    ent_coef        | 0.153       |
# |    ent_coef_loss   | -59.4       |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 6391        |
# |    reward          | 0.009322698 |
# ------------------------------------
# day: 540, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1623510.44
# total_reward: 623510.44
# total_cost: 6762.92
# total_trades: 8897
# Sharpe: 1.065
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 91             |
# |    time_elapsed    | 94             |
# |    total_timesteps | 8656           |
# | train/             |                |
# |    actor_loss      | 238            |
# |    critic_loss     | 132            |
# |    ent_coef        | 0.129          |
# |    ent_coef_loss   | -63.9          |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 8555           |
# |    reward          | -0.00034210176 |
# ---------------------------------------
# ======SAC Validation from:  2020-12-10T00:00:00.000000000 to  2021-03-17T00:00:00.000000000
# SAC Sharpe Ratio:  0.0803814931154963
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_46
# day: 540, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1364443.65
# total_reward: 364443.65
# total_cost: 17471.47
# total_trades: 10503
# Sharpe: 1.142
# =================================
# ---------------------------------------
# | time/              |                |
# |    fps             | 745            |
# |    iterations      | 1              |
# |    time_elapsed    | 2              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -0.00032304096 |
# ---------------------------------------
# day: 540, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1207424.50
# total_reward: 207424.50
# total_cost: 17186.43
# total_trades: 10420
# Sharpe: 0.796
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 713           |
# |    iterations           | 2             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.013656752   |
# |    clip_fraction        | 0.203         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -0.00377      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.28         |
# |    n_updates            | 10            |
# ...
# |    std                  | 1.01          |
# |    value_loss           | 0.0143        |
# -------------------------------------------
# day: 540, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1526108.59
# total_reward: 526108.59
# total_cost: 17411.80
# total_trades: 10404
# Sharpe: 1.270
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 698           |
# |    iterations           | 5             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.010513015   |
# |    clip_fraction        | 0.147         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.6         |
# |    explained_variance   | 0.223         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.295        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.0148       |
# |    reward               | 0.00065788615 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00864       |
# -------------------------------------------
# ======PPO Validation from:  2020-12-10T00:00:00.000000000 to  2021-03-17T00:00:00.000000000
# PPO Sharpe Ratio:  0.036864467049298896
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_41
# day: 540, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1914677.22
# total_reward: 914677.22
# total_cost: 1566.66
# total_trades: 7156
# Sharpe: 1.217
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 131            |
# |    time_elapsed    | 16             |
# |    total_timesteps | 2164           |
# | train/             |                |
# |    actor_loss      | 22.6           |
# |    critic_loss     | 5.02           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 1623           |
# |    reward          | -0.00080658816 |
# ---------------------------------------
# day: 540, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1914677.22
# total_reward: 914677.22
# total_cost: 1566.66
# total_trades: 7156
# Sharpe: 1.217
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 114            |
# |    time_elapsed    | 37             |
# |    total_timesteps | 4328           |
# | train/             |                |
# |    actor_loss      | 26.9           |
# |    critic_loss     | 6.47           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 3787           |
# |    reward          | -0.00080658816 |
# ---------------------------------------
# day: 540, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1914677.22
# total_reward: 914677.22
# total_cost: 1566.66
# total_trades: 7156
# Sharpe: 1.217
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 110            |
# |    time_elapsed    | 58             |
# |    total_timesteps | 6492           |
# | train/             |                |
# |    actor_loss      | 29.3           |
# |    critic_loss     | 10.4           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 5951           |
# |    reward          | -0.00080658816 |
# ---------------------------------------
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 108            |
# |    time_elapsed    | 80             |
# |    total_timesteps | 8656           |
# | train/             |                |
# |    actor_loss      | 35.2           |
# |    critic_loss     | 50.9           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 8115           |
# |    reward          | -0.00080658816 |
# ---------------------------------------
# day: 540, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1914677.22
# total_reward: 914677.22
# total_cost: 1566.66
# total_trades: 7156
# Sharpe: 1.217
# =================================
# ======TD3 Validation from:  2020-12-10T00:00:00.000000000 to  2021-03-17T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2021-03-17T00:00:00.000000000
# ======Trading from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ============================================
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2021-03-17T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_378_41
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 89            |
# |    time_elapsed    | 27            |
# |    total_timesteps | 2416          |
# | train/             |               |
# |    actor_loss      | 373           |
# |    critic_loss     | 299           |
# |    ent_coef        | 0.119         |
# |    ent_coef_loss   | 248           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 2315          |
# |    reward          | 0.00010047983 |
# --------------------------------------
# day: 603, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1404476.28
# total_reward: 404476.28
# total_cost: 15530.44
# total_trades: 8796
# Sharpe: 0.716
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 87           |
# |    time_elapsed    | 55           |
# |    total_timesteps | 4832         |
# | train/             |              |
# |    actor_loss      | 494          |
# |    critic_loss     | 144          |
# |    ent_coef        | 0.145        |
# |    ent_coef_loss   | 141          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 4731         |
# |    reward          | 0.0003136368 |
# -------------------------------------
# day: 603, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3367448.50
# total_reward: 2367448.50
# total_cost: 17528.79
# total_trades: 9919
# Sharpe: 1.465
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 86            |
# |    time_elapsed    | 83            |
# |    total_timesteps | 7248          |
# | train/             |               |
# |    actor_loss      | 603           |
# |    critic_loss     | 203           |
# |    ent_coef        | 0.174         |
# |    ent_coef_loss   | 48.9          |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 7147          |
# |    reward          | 0.00044550683 |
# --------------------------------------
# day: 603, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 2238047.53
# total_reward: 1238047.53
# total_cost: 7859.25
# total_trades: 9605
# Sharpe: 1.262
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 85           |
# |    time_elapsed    | 112          |
# |    total_timesteps | 9664         |
# | train/             |              |
# |    actor_loss      | 512          |
# |    critic_loss     | 144          |
# |    ent_coef        | 0.163        |
# |    ent_coef_loss   | -46.6        |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 9563         |
# |    reward          | 8.994911e-05 |
# -------------------------------------
# ======SAC Validation from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# SAC Sharpe Ratio:  -0.1908440850316785
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_378_45
# day: 603, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1692503.37
# total_reward: 692503.37
# total_cost: 20475.80
# total_trades: 11749
# Sharpe: 1.137
# =================================
# -------------------------------------
# | time/              |              |
# |    fps             | 737          |
# |    iterations      | 1            |
# |    time_elapsed    | 2            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0009606514 |
# -------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 701           |
# |    iterations           | 2             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.011828097   |
# |    clip_fraction        | 0.181         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -0.26         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.315        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0234       |
# |    reward               | 0.00017662617 |
# |    std                  | 1             |
# |    value_loss           | 0.00605       |
# -------------------------------------------
# day: 603, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 2447478.50
# total_reward: 1447478.50
# total_cost: 19952.57
# total_trades: 11645
# Sharpe: 1.334
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 691          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.010391014  |
# |    clip_fraction        | 0.151        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | 0.095        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.3         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0171      |
# |    reward               | 7.976158e-05 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00513      |
# ------------------------------------------
# day: 603, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 2043845.39
# total_reward: 1043845.39
# total_cost: 19554.20
# total_trades: 11509
# Sharpe: 1.203
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 681           |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.012187986   |
# |    clip_fraction        | 0.133         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.5         |
# |    explained_variance   | -2.3          |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.327        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0192       |
# |    reward               | -0.0020181425 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0155        |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015159509 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.6       |
# |    explained_variance   | -2.41       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.296      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0196     |
# |    reward               | 0.001144605 |
# |    std                  | 1.01        |
# |    value_loss           | 0.00945     |
# -----------------------------------------
# ======PPO Validation from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# PPO Sharpe Ratio:  -0.23915305069952839
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_378_40
# day: 603, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 2717266.66
# total_reward: 1717266.66
# total_cost: 3688.98
# total_trades: 7576
# Sharpe: 1.425
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 128            |
# |    time_elapsed    | 18             |
# |    total_timesteps | 2416           |
# | train/             |                |
# |    actor_loss      | 411            |
# |    critic_loss     | 485            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 1812           |
# |    reward          | 0.000120134195 |
# ---------------------------------------
# day: 603, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 2462688.62
# total_reward: 1462688.62
# total_cost: 1402.63
# total_trades: 6158
# Sharpe: 1.382
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 112            |
# |    time_elapsed    | 42             |
# |    total_timesteps | 4832           |
# | train/             |                |
# |    actor_loss      | 244            |
# |    critic_loss     | 1.73e+03       |
# |    learning_rate   | 0.001          |
# |    n_updates       | 4228           |
# |    reward          | 0.000120134195 |
# ---------------------------------------
# day: 603, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 2462688.62
# total_reward: 1462688.62
# total_cost: 1402.63
# total_trades: 6158
# Sharpe: 1.382
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 108            |
# |    time_elapsed    | 66             |
# |    total_timesteps | 7248           |
# | train/             |                |
# |    actor_loss      | 181            |
# |    critic_loss     | 790            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 6644           |
# |    reward          | 0.000120134195 |
# ---------------------------------------
# day: 603, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 2462688.62
# total_reward: 1462688.62
# total_cost: 1402.63
# total_trades: 6158
# Sharpe: 1.382
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 106            |
# |    time_elapsed    | 91             |
# |    total_timesteps | 9664           |
# | train/             |                |
# |    actor_loss      | 142            |
# |    critic_loss     | 804            |
# |    learning_rate   | 0.001          |
# |    n_updates       | 9060           |
# |    reward          | 0.000120134195 |
# ---------------------------------------
# ======TD3 Validation from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Trading from:  2021-07-05T00:00:00.000000000 to  2021-10-11T00:00:00.000000000
# Ensemble Strategy took:  18.964906851450603  minutes

# %%
df_summary

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  53.78078727924392
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2020-03-02T00:00:00.000000000
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_6
# -----------------------------------------
# | time/                 |               |
# |    fps                | 971           |
# |    iterations         | 100           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -29.6         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 99            |
# |    policy_loss        | 0.13          |
# |    reward             | -9.561252e-05 |
# |    std                | 1.06          |
# |    value_loss         | 2.27e-05      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 992            |
# |    iterations         | 200            |
# |    time_elapsed       | 1              |
# |    total_timesteps    | 1000           |
# | train/                |                |
# |    entropy_loss       | -30.3          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 199            |
# |    policy_loss        | 0.432          |
# |    reward             | -5.5395078e-05 |
# |    std                | 1.1            |
# |    value_loss         | 0.000291       |
# ------------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1004           |
# |    iterations         | 300            |
# |    time_elapsed       | 1              |
# |    total_timesteps    | 1500           |
# | train/                |                |
# |    entropy_loss       | -31            |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 299            |
# |    policy_loss        | 0.266          |
# |    reward             | -0.00049378077 |
# |    std                | 1.14           |
# |    value_loss         | 0.0001         |
# ------------------------------------------
# day: 351, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1017854.93
# total_reward: 17854.93
# total_cost: 8214.71
# total_trades: 5648
# Sharpe: 0.193
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1011         |
# |    iterations         | 400          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -31.7        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | -0.113       |
# |    reward             | 0.0067277392 |
# |    std                | 1.18         |
# |    value_loss         | 4.24e-05     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1015          |
# |    iterations         | 500           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -32.4         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | -0.0126       |
# |    reward             | 1.1703738e-05 |
# |    std                | 1.22          |
# |    value_loss         | 3.42e-07      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1019          |
# |    iterations         | 600           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -33           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 1.13          |
# |    reward             | -0.0030973929 |
# |    std                | 1.26          |
# |    value_loss         | 0.00156       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1021         |
# |    iterations         | 700          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 3500         |
# | train/                |              |
# |    entropy_loss       | -33.5        |
# |    explained_variance | -236         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 699          |
# |    policy_loss        | -20.7        |
# |    reward             | 0.0005885426 |
# |    std                | 1.29         |
# |    value_loss         | 0.507        |
# ----------------------------------------
# day: 351, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1121616.89
# total_reward: 121616.89
# total_cost: 8294.91
# total_trades: 5578
# Sharpe: 0.536
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1022          |
# |    iterations         | 800           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -33.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 0.0861        |
# |    reward             | 0.00049001066 |
# |    std                | 1.31          |
# |    value_loss         | 1.15e-05      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1024         |
# |    iterations         | 900          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -34.1        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 0.219        |
# |    reward             | -0.002490299 |
# |    std                | 1.33         |
# |    value_loss         | 4.13e-05     |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1026           |
# |    iterations         | 1000           |
# |    time_elapsed       | 4              |
# |    total_timesteps    | 5000           |
# | train/                |                |
# |    entropy_loss       | -34.5          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 999            |
# |    policy_loss        | -0.0464        |
# |    reward             | -1.9091434e-05 |
# |    std                | 1.36           |
# |    value_loss         | 2.5e-06        |
# ------------------------------------------
# day: 351, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1069945.42
# total_reward: 69945.42
# total_cost: 8338.79
# total_trades: 5239
# Sharpe: 0.399
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 1027        |
# |    iterations         | 1100        |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -35         |
# |    explained_variance | -6.72       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 0.721       |
# |    reward             | 0.000682469 |
# |    std                | 1.39        |
# |    value_loss         | 0.000472    |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1027          |
# |    iterations         | 1200          |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -35.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | 0.434         |
# |    reward             | 0.00042032276 |
# |    std                | 1.4           |
# |    value_loss         | 0.000207      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1029         |
# |    iterations         | 1300         |
# |    time_elapsed       | 6            |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -35.5        |
# |    explained_variance | -1.31        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | 0.408        |
# |    reward             | 0.0004588037 |
# |    std                | 1.43         |
# |    value_loss         | 0.000782     |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1030          |
# |    iterations         | 1400          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -35.8         |
# |    explained_variance | -3.06e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | -1.04         |
# |    reward             | 0.00017407081 |
# |    std                | 1.45          |
# |    value_loss         | 0.0013        |
# -----------------------------------------
# day: 351, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1106363.72
# total_reward: 106363.72
# total_cost: 6654.26
# total_trades: 5262
# Sharpe: 0.524
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1030          |
# |    iterations         | 1500          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -36.2         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1499          |
# |    policy_loss        | -0.0621       |
# |    reward             | -0.0017795999 |
# |    std                | 1.48          |
# |    value_loss         | 7.91e-06      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1030           |
# |    iterations         | 1600           |
# |    time_elapsed       | 7              |
# |    total_timesteps    | 8000           |
# | train/                |                |
# |    entropy_loss       | -36.6          |
# |    explained_variance | -2.8           |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1599           |
# |    policy_loss        | -0.258         |
# |    reward             | -0.00035883207 |
# |    std                | 1.51           |
# |    value_loss         | 0.000201       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 1031          |
# |    iterations         | 1700          |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -37.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1699          |
# |    policy_loss        | 0.028         |
# |    reward             | 0.00027682201 |
# |    std                | 1.55          |
# |    value_loss         | 9.12e-07      |
# -----------------------------------------
# day: 351, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1076680.61
# total_reward: 76680.61
# total_cost: 6788.18
# total_trades: 5294
# Sharpe: 0.399
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1032         |
# |    iterations         | 1800         |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -37.5        |
# |    explained_variance | -3.52e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | 3.53         |
# |    reward             | 0.0044578114 |
# |    std                | 1.58         |
# |    value_loss         | 0.0166       |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 1032         |
# |    iterations         | 1900         |
# |    time_elapsed       | 9            |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -38          |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | -0.0824      |
# |    reward             | 6.188189e-05 |
# |    std                | 1.62         |
# |    value_loss         | 4.86e-06     |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 1028           |
# |    iterations         | 2000           |
# |    time_elapsed       | 9              |
# |    total_timesteps    | 10000          |
# | train/                |                |
# |    entropy_loss       | -38.5          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1999           |
# |    policy_loss        | -0.113         |
# |    reward             | -4.7417325e-05 |
# |    std                | 1.66           |
# |    value_loss         | 1.38e-05       |
# ------------------------------------------
# ======A2C Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# A2C Sharpe Ratio:  0.1340629000927578
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_72
# day: 351, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1062178.22
# total_reward: 62178.22
# total_cost: 10140.17
# total_trades: 6685
# Sharpe: 0.569
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 1320          |
# |    iterations      | 1             |
# |    time_elapsed    | 1             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -9.342581e-05 |
# --------------------------------------
# day: 351, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1031475.33
# total_reward: 31475.33
# total_cost: 10177.15
# total_trades: 6671
# Sharpe: 0.381
# =================================
# day: 351, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1029274.49
# total_reward: 29274.49
# total_cost: 10388.09
# total_trades: 6752
# Sharpe: 0.269
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1246          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.009820471   |
# |    clip_fraction        | 0.144         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.3          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00842      |
# |    reward               | 0.00023179676 |
# |    std                  | 0.999         |
# |    value_loss           | 0.00475       |
# -------------------------------------------
# day: 351, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1057718.22
# total_reward: 57718.22
# total_cost: 10455.11
# total_trades: 6737
# Sharpe: 0.563
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1223         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.008700324  |
# |    clip_fraction        | 0.124        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.3        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.289       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0102      |
# |    reward               | 0.0012493554 |
# |    std                  | 0.998        |
# |    value_loss           | 0.0039       |
# ------------------------------------------
# day: 351, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1070338.35
# total_reward: 70338.35
# total_cost: 10281.94
# total_trades: 6790
# Sharpe: 0.518
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1211          |
# |    iterations           | 4             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.011349237   |
# |    clip_fraction        | 0.138         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0.232         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.291        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0133       |
# |    reward               | 1.3709093e-05 |
# |    std                  | 0.999         |
# |    value_loss           | 0.00303       |
# -------------------------------------------
# day: 351, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1011003.76
# total_reward: 11003.76
# total_cost: 10351.46
# total_trades: 6709
# Sharpe: 0.127
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1205         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.009340992  |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | 0.00569      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.307       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0113      |
# |    reward               | 0.0007110974 |
# |    std                  | 1            |
# |    value_loss           | 0.00713      |
# ------------------------------------------
# ======PPO Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# PPO Sharpe Ratio:  0.16735111170191166
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_6
# day: 351, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1165306.90
# total_reward: 165306.90
# total_cost: 4522.26
# total_trades: 5064
# Sharpe: 0.672
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 294           |
# |    time_elapsed    | 4             |
# |    total_timesteps | 1408          |
# | train/             |               |
# |    actor_loss      | -752          |
# |    critic_loss     | 2.12e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 1056          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# day: 351, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1302936.30
# total_reward: 302936.30
# total_cost: 999.00
# total_trades: 4212
# Sharpe: 0.875
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 256           |
# |    time_elapsed    | 10            |
# |    total_timesteps | 2816          |
# | train/             |               |
# |    actor_loss      | -311          |
# |    critic_loss     | 2.84e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 2464          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# day: 351, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1302936.30
# total_reward: 302936.30
# total_cost: 999.00
# total_trades: 4212
# Sharpe: 0.875
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 247           |
# |    time_elapsed    | 17            |
# |    total_timesteps | 4224          |
# | train/             |               |
# |    actor_loss      | -95.6         |
# |    critic_loss     | 3.63e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 3872          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# day: 351, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1302936.30
# total_reward: 302936.30
# total_cost: 999.00
# total_trades: 4212
# Sharpe: 0.875
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 242           |
# |    time_elapsed    | 23            |
# |    total_timesteps | 5632          |
# | train/             |               |
# |    actor_loss      | -14.2         |
# |    critic_loss     | 2.19e+04      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 5280          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# --------------------------------------
# | time/              |               |
# |    episodes        | 20            |
# |    fps             | 239           |
# |    time_elapsed    | 29            |
# |    total_timesteps | 7040          |
# | train/             |               |
# |    actor_loss      | 22.5          |
# |    critic_loss     | 5.85e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 6688          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# day: 351, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1302936.30
# total_reward: 302936.30
# total_cost: 999.00
# total_trades: 4212
# Sharpe: 0.875
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 24            |
# |    fps             | 238           |
# |    time_elapsed    | 35            |
# |    total_timesteps | 8448          |
# | train/             |               |
# |    actor_loss      | 34.4          |
# |    critic_loss     | 495           |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 8096          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# day: 351, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1302936.30
# total_reward: 302936.30
# total_cost: 999.00
# total_trades: 4212
# Sharpe: 0.875
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 28            |
# |    fps             | 236           |
# |    time_elapsed    | 41            |
# |    total_timesteps | 9856          |
# | train/             |               |
# |    actor_loss      | 27.7          |
# |    critic_loss     | 495           |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 9504          |
# |    reward          | -0.0012324522 |
# --------------------------------------
# ======DDPG Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Trading from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# ============================================
# turbulence_threshold:  53.78078727924392
# ======Model training from:  2018-08-27T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_5
# ------------------------------------------
# | time/                 |                |
# |    fps                | 948            |
# |    iterations         | 100            |
# |    time_elapsed       | 0              |
# |    total_timesteps    | 500            |
# | train/                |                |
# |    entropy_loss       | -29.1          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 99             |
# |    policy_loss        | 1.96           |
# |    reward             | -5.4527332e-05 |
# |    std                | 1.04           |
# |    value_loss         | 0.0056         |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 964           |
# |    iterations         | 200           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -29.3         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 199           |
# |    policy_loss        | -0.0856       |
# |    reward             | -0.0004018638 |
# |    std                | 1.05          |
# |    value_loss         | 1.3e-05       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 970          |
# |    iterations         | 300          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -29.5        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 0.136        |
# |    reward             | 0.0006001741 |
# |    std                | 1.06         |
# |    value_loss         | 3e-05        |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 974           |
# |    iterations         | 400           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -29.8         |
# |    explained_variance | -154          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | -4            |
# |    reward             | -0.0035540757 |
# |    std                | 1.08          |
# |    value_loss         | 0.0161        |
# -----------------------------------------
# day: 414, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1099547.09
# total_reward: 99547.09
# total_cost: 6832.34
# total_trades: 5989
# Sharpe: 0.369
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 974           |
# |    iterations         | 500           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -30.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | -0.173        |
# |    reward             | -0.0003820403 |
# |    std                | 1.09          |
# |    value_loss         | 4.5e-05       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 977          |
# |    iterations         | 600          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -30.4        |
# |    explained_variance | 0.000243     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 0.166        |
# |    reward             | 0.0013408005 |
# |    std                | 1.11         |
# |    value_loss         | 3.8e-05      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 978           |
# |    iterations         | 700           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -30.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | 0.398         |
# |    reward             | -4.806546e-05 |
# |    std                | 1.13          |
# |    value_loss         | 0.000188      |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 979        |
# |    iterations         | 800        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -31.1      |
# |    explained_variance | -1.32      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 4.32       |
# |    reward             | -0.0539848 |
# |    std                | 1.15       |
# |    value_loss         | 0.0708     |
# --------------------------------------
# day: 414, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1253462.81
# total_reward: 253462.81
# total_cost: 7318.33
# total_trades: 6545
# Sharpe: 0.684
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 978         |
# |    iterations         | 900         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -31.4       |
# |    explained_variance | -4.03e+03   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -5.34       |
# |    reward             | 0.006826272 |
# |    std                | 1.16        |
# |    value_loss         | 0.0685      |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 979           |
# |    iterations         | 1000          |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -31.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | -0.137        |
# |    reward             | -0.0005428471 |
# |    std                | 1.18          |
# |    value_loss         | 2.09e-05      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 979            |
# |    iterations         | 1100           |
# |    time_elapsed       | 5              |
# |    total_timesteps    | 5500           |
# | train/                |                |
# |    entropy_loss       | -31.9          |
# |    explained_variance | -5.94e+03      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1099           |
# |    policy_loss        | -0.774         |
# |    reward             | -0.00034767183 |
# |    std                | 1.2            |
# |    value_loss         | 0.000828       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 980           |
# |    iterations         | 1200          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -32.3         |
# |    explained_variance | -112          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | -0.806        |
# |    reward             | 0.00019872274 |
# |    std                | 1.22          |
# |    value_loss         | 0.00108       |
# -----------------------------------------
# day: 414, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1374801.44
# total_reward: 374801.44
# total_cost: 5202.51
# total_trades: 5387
# Sharpe: 0.867
# =================================
# ------------------------------------------
# | time/                 |                |
# |    fps                | 980            |
# |    iterations         | 1300           |
# |    time_elapsed       | 6              |
# |    total_timesteps    | 6500           |
# | train/                |                |
# |    entropy_loss       | -32.7          |
# |    explained_variance | -99.5          |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1299           |
# |    policy_loss        | -0.0555        |
# |    reward             | -0.00043394254 |
# |    std                | 1.24           |
# |    value_loss         | 0.000286       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 981           |
# |    iterations         | 1400          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -33           |
# |    explained_variance | -795          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | 1.12          |
# |    reward             | -7.299035e-05 |
# |    std                | 1.26          |
# |    value_loss         | 0.00259       |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 981            |
# |    iterations         | 1500           |
# |    time_elapsed       | 7              |
# |    total_timesteps    | 7500           |
# | train/                |                |
# |    entropy_loss       | -33.3          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1499           |
# |    policy_loss        | 0.0173         |
# |    reward             | -2.2660928e-05 |
# |    std                | 1.28           |
# |    value_loss         | 1.22e-06       |
# ------------------------------------------
# -------------------------------------------
# | time/                 |                 |
# |    fps                | 982             |
# |    iterations         | 1600            |
# |    time_elapsed       | 8               |
# |    total_timesteps    | 8000            |
# | train/                |                 |
# |    entropy_loss       | -33.7           |
# |    explained_variance | 0               |
# |    learning_rate      | 0.0007          |
# |    n_updates          | 1599            |
# |    policy_loss        | -0.684          |
# |    reward             | -0.000102511935 |
# |    std                | 1.3             |
# |    value_loss         | 0.000791        |
# -------------------------------------------
# day: 414, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1246193.94
# total_reward: 246193.94
# total_cost: 6503.03
# total_trades: 5979
# Sharpe: 0.650
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 982           |
# |    iterations         | 1700          |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -34           |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1699          |
# |    policy_loss        | -3.64         |
# |    reward             | -0.0010153446 |
# |    std                | 1.33          |
# |    value_loss         | 0.0133        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 981           |
# |    iterations         | 1800          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -34.4         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 4.98          |
# |    reward             | -9.701779e-05 |
# |    std                | 1.35          |
# |    value_loss         | 0.0224        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 982           |
# |    iterations         | 1900          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -34.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1899          |
# |    policy_loss        | -4.47         |
# |    reward             | -0.0016038253 |
# |    std                | 1.37          |
# |    value_loss         | 0.0157        |
# -----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 977         |
# |    iterations         | 2000        |
# |    time_elapsed       | 10          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -35.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.897       |
# |    reward             | 0.003989568 |
# |    std                | 1.4         |
# |    value_loss         | 0.00132     |
# ---------------------------------------
# ======A2C Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# A2C Sharpe Ratio:  0.6727408507881093
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_66
# --------------------------------------
# | time/              |               |
# |    fps             | 1215          |
# |    iterations      | 1             |
# |    time_elapsed    | 1             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00010312627 |
# --------------------------------------
# day: 414, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 984653.39
# total_reward: -15346.61
# total_cost: 12206.77
# total_trades: 7997
# Sharpe: -0.057
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1158          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.011665447   |
# |    clip_fraction        | 0.162         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | 0.462         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.289        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0109       |
# |    reward               | 2.2821305e-05 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0101        |
# -------------------------------------------
# day: 414, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1038622.36
# total_reward: 38622.36
# total_cost: 12322.70
# total_trades: 7979
# Sharpe: 0.288
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1120          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.009513919   |
# |    clip_fraction        | 0.129         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.5         |
# |    explained_variance   | 0.0841        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.281        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00992      |
# |    reward               | 1.8352861e-05 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00611       |
# -------------------------------------------
# day: 414, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1057846.96
# total_reward: 57846.96
# total_cost: 12150.42
# total_trades: 8014
# Sharpe: 0.519
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1117           |
# |    iterations           | 4              |
# |    time_elapsed         | 7              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.009031985    |
# |    clip_fraction        | 0.112          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -28.5          |
# |    explained_variance   | 0.567          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.302         |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.0133        |
# |    reward               | -0.00010654344 |
# |    std                  | 1.01           |
# |    value_loss           | 0.00488        |
# --------------------------------------------
# day: 414, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1010344.60
# total_reward: 10344.60
# total_cost: 12271.40
# total_trades: 7974
# Sharpe: 0.112
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.010049464  |
# |    clip_fraction        | 0.0957       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.6        |
# |    explained_variance   | -0.293       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.308       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0176      |
# |    reward               | 0.0012538164 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00465      |
# ------------------------------------------
# ======PPO Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-04T00:00:00.000000000
# PPO Sharpe Ratio:  0.6800113394779396
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_5
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 302            |
# |    time_elapsed    | 5              |
# |    total_timesteps | 1660           |
# | train/             |                |
# |    actor_loss      | -851           |
# |    critic_loss     | 917            |
# |    learning_rate   | 0.0005         |
# |    n_updates       | 1245           |
# |    reward          | -0.00032998397 |
# ---------------------------------------
# day: 414, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1199135.71
# total_reward: 199135.71
# total_cost: 999.00
# total_trades: 4140
# Sharpe: 0.590
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 264            |
# |    time_elapsed    | 12             |
# |    total_timesteps | 3320           |
# | train/             |                |
# |    actor_loss      | -495           |
# |    critic_loss     | 1.88e+03       |
# |    learning_rate   | 0.0005         |
# |    n_updates       | 2905           |
# |    reward          | -0.00032998397 |
# ---------------------------------------
# day: 414, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1199135.71
# total_reward: 199135.71
# total_cost: 999.00
# total_trades: 4140
# Sharpe: 0.590
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 254            |
# |    time_elapsed    | 19             |
# |    total_timesteps | 4980           |
# | train/             |                |
# |    actor_loss      | -290           |
# |    critic_loss     | 347            |
# |    learning_rate   | 0.0005         |
# |    n_updates       | 4565           |
# |    reward          | -0.00032998397 |
# ---------------------------------------
# day: 414, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1199135.71
# total_reward: 199135.71
# total_cost: 999.00
# total_trades: 4140
# Sharpe: 0.590
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 249            |
# |    time_elapsed    | 26             |
# |    total_timesteps | 6640           |
# | train/             |                |
# |    actor_loss      | -173           |
# |    critic_loss     | 1.18e+04       |
# |    learning_rate   | 0.0005         |
# |    n_updates       | 6225           |
# |    reward          | -0.00032998397 |
# ---------------------------------------
# day: 414, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1199135.71
# total_reward: 199135.71
# total_cost: 999.00
# total_trades: 4140
# Sharpe: 0.590
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 20             |
# |    fps             | 246            |
# |    time_elapsed    | 33             |
# ...
# |    value_loss         | 0.00555       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 834           |
# |    iterations         | 1000          |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -31.3         |
# |    explained_variance | -82.8         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 999           |
# |    policy_loss        | -0.226        |
# |    reward             | 0.00014526918 |
# |    std                | 1.16          |
# |    value_loss         | 0.00087       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 835           |
# |    iterations         | 1100          |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -31.7         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -0.0364       |
# |    reward             | -9.484445e-05 |
# |    std                | 1.18          |
# |    value_loss         | 1.56e-06      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 835          |
# |    iterations         | 1200         |
# |    time_elapsed       | 7            |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -32.1        |
# |    explained_variance | -2.78e+04    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | 1.14         |
# |    reward             | -0.015196885 |
# |    std                | 1.2          |
# |    value_loss         | 0.0251       |
# ----------------------------------------
# day: 603, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1756696.14
# total_reward: 756696.14
# total_cost: 8985.88
# total_trades: 9299
# Sharpe: 1.052
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 836           |
# |    iterations         | 1300          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -32.4         |
# |    explained_variance | -850          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | 1.18          |
# |    reward             | 0.00012939655 |
# |    std                | 1.23          |
# |    value_loss         | 0.00434       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 835           |
# |    iterations         | 1400          |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -32.8         |
# |    explained_variance | -75           |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1399          |
# |    policy_loss        | -0.459        |
# |    reward             | -0.0037440618 |
# |    std                | 1.25          |
# |    value_loss         | 0.000929      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 836          |
# |    iterations         | 1500         |
# |    time_elapsed       | 8            |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -33.1        |
# |    explained_variance | -471         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 8.44         |
# |    reward             | 0.0002658762 |
# |    std                | 1.27         |
# |    value_loss         | 0.0717       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 835           |
# |    iterations         | 1600          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -33.5         |
# |    explained_variance | -86.8         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | -1.81         |
# |    reward             | 2.6121448e-05 |
# |    std                | 1.29          |
# |    value_loss         | 0.00421       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 834           |
# |    iterations         | 1700          |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -33.9         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1699          |
# |    policy_loss        | 0.0113        |
# |    reward             | -0.0015024309 |
# |    std                | 1.32          |
# |    value_loss         | 7.56e-06      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 832           |
# |    iterations         | 1800          |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -34.4         |
# |    explained_variance | -56.4         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 1.28          |
# |    reward             | -0.0007136619 |
# |    std                | 1.35          |
# |    value_loss         | 0.00269       |
# -----------------------------------------
# day: 603, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1497986.12
# total_reward: 497986.12
# total_cost: 6842.81
# total_trades: 8474
# Sharpe: 0.796
# =================================
# ------------------------------------------
# | time/                 |                |
# |    fps                | 831            |
# |    iterations         | 1900           |
# |    time_elapsed       | 11             |
# |    total_timesteps    | 9500           |
# | train/                |                |
# |    entropy_loss       | -34.9          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1899           |
# |    policy_loss        | -0.113         |
# |    reward             | -0.00020149873 |
# |    std                | 1.39           |
# |    value_loss         | 1.49e-05       |
# ------------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 829            |
# |    iterations         | 2000           |
# |    time_elapsed       | 12             |
# |    total_timesteps    | 10000          |
# | train/                |                |
# |    entropy_loss       | -35.3          |
# |    explained_variance | 0              |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1999           |
# |    policy_loss        | 0.349          |
# |    reward             | -0.00078532373 |
# |    std                | 1.42           |
# |    value_loss         | 0.000126       |
# ------------------------------------------
# ======A2C Validation from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# A2C Sharpe Ratio:  0.04418854029699678
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_378_44
# day: 603, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1198789.12
# total_reward: 198789.12
# total_cost: 20485.54
# total_trades: 11665
# Sharpe: 0.606
# =================================
# -------------------------------------
# | time/              |              |
# |    fps             | 938          |
# |    iterations      | 1            |
# |    time_elapsed    | 2            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | 0.0006859526 |
# -------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 905           |
# |    iterations           | 2             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.010465227   |
# |    clip_fraction        | 0.161         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.4         |
# |    explained_variance   | -0.775        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.309        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0236       |
# |    reward               | 0.00036053394 |
# |    std                  | 1             |
# |    value_loss           | 0.00992       |
# -------------------------------------------
# day: 603, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1268987.51
# total_reward: 268987.51
# total_cost: 20515.28
# total_trades: 11688
# Sharpe: 0.856
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 895          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.009313811  |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | -0.0809      |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.275       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00626     |
# |    reward               | 9.729671e-05 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00531      |
# ------------------------------------------
# day: 603, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1551486.43
# total_reward: 551486.43
# total_cost: 19844.61
# total_trades: 11615
# Sharpe: 1.144
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 883           |
# |    iterations           | 4             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0100634135  |
# |    clip_fraction        | 0.137         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -28.5         |
# |    explained_variance   | 0.0493        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.283        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0158       |
# |    reward               | -0.0011946054 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00532       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.009837953  |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.6        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.289       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00641     |
# |    reward               | 0.0010006715 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00296      |
# ------------------------------------------
# ======PPO Validation from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# PPO Sharpe Ratio:  -0.193734259968464
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_378_5
# day: 603, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1327611.06
# total_reward: 327611.06
# total_cost: 4776.57
# total_trades: 5830
# Sharpe: 0.657
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 248           |
# |    time_elapsed    | 9             |
# |    total_timesteps | 2416          |
# | train/             |               |
# |    actor_loss      | 1.43e+03      |
# |    critic_loss     | 2.68e+04      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 1812          |
# |    reward          | 0.00016586238 |
# --------------------------------------
# day: 603, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1279636.93
# total_reward: 279636.93
# total_cost: 999.00
# total_trades: 5361
# Sharpe: 0.567
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 223           |
# |    time_elapsed    | 21            |
# |    total_timesteps | 4832          |
# | train/             |               |
# |    actor_loss      | 621           |
# |    critic_loss     | 5.64e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 4228          |
# |    reward          | 0.00016586238 |
# --------------------------------------
# day: 603, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1279636.93
# total_reward: 279636.93
# total_cost: 999.00
# total_trades: 5361
# Sharpe: 0.567
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 216           |
# |    time_elapsed    | 33            |
# |    total_timesteps | 7248          |
# | train/             |               |
# |    actor_loss      | 319           |
# |    critic_loss     | 4.84e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 6644          |
# |    reward          | 0.00016586238 |
# --------------------------------------
# day: 603, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1279636.93
# total_reward: 279636.93
# total_cost: 999.00
# total_trades: 5361
# Sharpe: 0.567
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 212           |
# |    time_elapsed    | 45            |
# |    total_timesteps | 9664          |
# | train/             |               |
# |    actor_loss      | 110           |
# |    critic_loss     | 4.38e+03      |
# |    learning_rate   | 0.0005        |
# |    n_updates       | 9060          |
# |    reward          | 0.00016586238 |
# --------------------------------------
# ======DDPG Validation from:  2021-03-17T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Best Model Retraining from:  2018-08-27T00:00:00.000000000 to  2021-07-05T00:00:00.000000000
# ======Trading from:  2021-07-05T00:00:00.000000000 to  2021-10-11T00:00:00.000000000
# Ensemble Strategy took:  5.714415403207143  minutes

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = addfeature_df[(addfeature_df.date > TRADE_START_DATE)&(addfeature_df.date <= TRADE_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.6311440692126998

# %%
df_account_value
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2020-06-03           NaN 2020-06-03
# 1     9.994723e+05  2020-06-04     -0.000528 2020-06-04
# 2     1.001130e+06  2020-06-05      0.001659 2020-06-05
# 3     1.002104e+06  2020-06-08      0.000973 2020-06-08
# 4     1.004595e+06  2020-06-09      0.002485 2020-06-09
# ..             ...         ...           ...        ...
# 310   1.148203e+06  2021-09-27     -0.018719 2021-09-27
# 311   1.158662e+06  2021-09-28      0.009109 2021-09-28
# 312   1.151994e+06  2021-09-29     -0.005755 2021-09-29
# 313   1.152070e+06  2021-09-30      0.000066 2021-09-30
# 314   1.176609e+06  2021-10-08      0.021299 2021-10-08
#
# [315 rows x 4 columns]

# %%
df_account_value_initial = df_returns.loc[:,['date','van']]
df_account_value_initial
# Out:
#            date           van
# 0    2020-06-03  1.000000e+06
# 1    2020-06-04  9.996860e+05
# 2    2020-06-05  1.000953e+06
# 3    2020-06-08  1.001013e+06
# 4    2020-06-09  1.001743e+06
# ..          ...           ...
# 310  2021-09-27  1.071406e+06
# 311  2021-09-28  1.070505e+06
# 312  2021-09-29  1.065931e+06
# 313  2021-09-30  1.081850e+06
# 314  2021-10-08  1.124322e+06
#
# [315 rows x 2 columns]

# %%
df_account_value_initial.to_csv('726_df_returns.csv',index=None)

# %%
df_returns = pd.read_csv('726_df_returns_youhua.csv')
df_returns
# Out:
#            date          ewtf           our           ppo           sse  \
# 0    2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1    2020-06-04  9.996460e+05  9.996590e+05  9.999676e+05  9.974298e+05
# 2    2020-06-05  1.001088e+06  1.000998e+06  1.000129e+06  1.004237e+06
# 3    2020-06-08  1.001876e+06  1.001854e+06  1.000173e+06  1.020033e+06
# 4    2020-06-09  1.003559e+06  1.003316e+06  1.000377e+06  1.023258e+06
# ..          ...           ...           ...           ...           ...
# 310  2021-09-27  1.038495e+06  1.063572e+06  9.785688e+05  9.628817e+05
# 311  2021-09-28  1.048268e+06  1.073735e+06  9.758652e+05  9.693846e+05
# 312  2021-09-29  1.046590e+06  1.079010e+06  9.700104e+05  9.703724e+05
# 313  2021-09-30  1.037813e+06  1.061851e+06  9.896299e+05  9.650293e+05
# 314  2021-10-08  1.080477e+06  1.116154e+06  1.027769e+06  1.010862e+06
#
#               sac           td3
# 0    1.000000e+06  1.000000e+06
# 1    9.995591e+05  9.998203e+05
# 2    1.001103e+06  1.000203e+06
# 3    1.002315e+06  1.000815e+06
# 4    1.004411e+06  1.001897e+06
# ..            ...           ...
# 310  1.143800e+06  9.187867e+05
# 311  1.141566e+06  9.269151e+05
# 312  1.134602e+06  9.296843e+05
# 313  1.149068e+06  9.306252e+05
# 314  1.196709e+06  9.658109e+05
#
# [315 rows x 7 columns]

# %%
df_returns = df_returns.drop('our',axis=1)

# %%
df_returns
# Out:
#            date          ewtf           ppo           sse           sac  \
# 0    2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1    2020-06-04  9.996460e+05  9.999676e+05  9.974298e+05  9.995591e+05
# 2    2020-06-05  1.001088e+06  1.000129e+06  1.004237e+06  1.001103e+06
# 3    2020-06-08  1.001876e+06  1.000173e+06  1.020033e+06  1.002315e+06
# 4    2020-06-09  1.003559e+06  1.000377e+06  1.023258e+06  1.004411e+06
# ..          ...           ...           ...           ...           ...
# 310  2021-09-27  1.038495e+06  9.785688e+05  9.628817e+05  1.143800e+06
# 311  2021-09-28  1.048268e+06  9.758652e+05  9.693846e+05  1.141566e+06
# 312  2021-09-29  1.046590e+06  9.700104e+05  9.703724e+05  1.134602e+06
# 313  2021-09-30  1.037813e+06  9.896299e+05  9.650293e+05  1.149068e+06
# 314  2021-10-08  1.080477e+06  1.027769e+06  1.010862e+06  1.196709e+06
#
#               td3  account_value           van
# 0    1.000000e+06   1.000000e+06  1.000000e+06
# 1    9.998203e+05   9.994723e+05  9.996860e+05
# 2    1.000203e+06   1.001130e+06  1.000953e+06
# 3    1.000815e+06   1.002104e+06  1.001013e+06
# 4    1.001897e+06   1.004595e+06  1.001743e+06
# ..            ...            ...           ...
# 310  9.187867e+05   1.148203e+06  1.071406e+06
# 311  9.269151e+05   1.158662e+06  1.070505e+06
# 312  9.296843e+05   1.151994e+06  1.065931e+06
# 313  9.306252e+05   1.152070e+06  1.081850e+06
# 314  9.658109e+05   1.176609e+06  1.124322e+06
#
# [315 rows x 8 columns]

# %%
df_returns = pd.concat([df_returns,df_account_value_initial['van']],axis=1)
# df_returns.columns = ['date','td3','sac','ppo','sse','ewtf']

# %%
df_returns = df_returns.reindex(columns=['date','account_value'])

# %%
df_returns.columns = ['date','ewtf','ppo','sse','sac','td3','our','van']

# %%
df_returns = pd.read_csv('724_df_returns.csv')

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
df_returns.to_csv('726_df_returns.csv',index=None)

# %%
df_returns1 = df_returns.iloc[:,[0,7]]
df_returns1
# Out:
#            date           van
# 0    2020-06-03  1.000000e+06
# 1    2020-06-04  9.996860e+05
# 2    2020-06-05  1.000953e+06
# 3    2020-06-08  1.001013e+06
# 4    2020-06-09  1.001743e+06
# ..          ...           ...
# 310  2021-09-27  1.071406e+06
# 311  2021-09-28  1.070505e+06
# 312  2021-09-29  1.065931e+06
# 313  2021-09-30  1.081850e+06
# 314  2021-10-08  1.124322e+06
#
# [315 rows x 2 columns]

# %%
df_returns1['return'] = df_returns1['van'].pct_change()
df_returns1['return'].fillna(0, inplace=True)

# %%
df_returns1['date'] = pd.to_datetime(df_returns1['date'])
df_returns1.set_index('date',inplace=True)
df_returns1.index = df_returns1.index.tz_localize("UTC")
returns = pd.Series(df_returns1["return"], index=df_returns1.index)

# %%
baseline_sse
# Out:
#           date  account_value
# 0   2020-06-03    3760.744653
# 1   2020-06-04    3751.078619
# 2   2020-06-05    3776.679417
# 3   2020-06-08    3836.082830
# 4   2020-06-09    3848.211352
# ..         ...            ...
# 310 2021-09-27    3621.152333
# 311 2021-09-28    3645.607873
# 312 2021-09-29    3649.322661
# 313 2021-09-30    3629.228618
# 314 2021-10-08    3801.595365
#
# [315 rows x 2 columns]

# %%
baseline_sse1 = baseline_sse
baseline_sse1['date'] = pd.to_datetime(baseline_sse['date'])
baseline_sse1.set_index('date',inplace=True)
baseline_sse1.index = baseline_sse1.index.tz_localize("UTC")

# %%
baseline_sse1['return'] = baseline_sse1['account_value'].pct_change()
baseline_sse1['return'].fillna(0, inplace=True)
baseline_sse1 = baseline_sse1.drop('account_value',axis=1)

# %%
# %matplotlib inline
import pyfolio as py
py.create_returns_tear_sheet(returns,benchmark_rets=baseline_sse1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-08</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>9.828%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>12.432%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>27.838%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.48</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.913%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.68</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.09</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.455%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.78</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30.91</td>
#       <td>2021-02-10</td>
#       <td>2021-08-20</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.41</td>
#       <td>2021-01-12</td>
#       <td>2021-01-19</td>
#       <td>2021-02-09</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.27</td>
#       <td>2020-08-03</td>
#       <td>2020-10-27</td>
#       <td>2020-12-23</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5.30</td>
#       <td>2020-07-06</td>
#       <td>2020-07-16</td>
#       <td>2020-07-23</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.59</td>
#       <td>2020-07-23</td>
#       <td>2020-07-27</td>
#       <td>2020-08-03</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import pyfolio as py
# ----> 3 py.create_returns_tear_sheet(returns,benchmark_rets=baseline_sse1)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:52, in customize.<locals>.call_w_context(*args, **kwargs)
#      50 if set_context:
#      51     with plotting_context(), axes_style():
# ---> 52         return func(*args, **kwargs)
#      53 else:
#      54     return func(*args, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:520, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     517 ax_return_quantiles = plt.subplot(gs[i, :])
#     518 i += 1
# --> 520 plotting.plot_rolling_returns(
#     521     returns,
#     522     factor_returns=benchmark_rets,
#     523     live_start_date=live_start_date,
#     524     cone_std=cone_std,
#     525     ax=ax_rolling_returns)
#     526 ax_rolling_returns.set_title(
#     527     'Cumulative returns')
#     529 plotting.plot_rolling_returns(
#     530     returns,
#     531     factor_returns=benchmark_rets,
#    (...)
#     535     legend_loc=None,
#     536     ax=ax_rolling_returns_vol_match)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:794, in plot_rolling_returns(returns, factor_returns, live_start_date, logy, cone_std, legend_loc, volatility_match, cone_function, ax, **kwargs)
#     790 ax.yaxis.set_major_formatter(FuncFormatter(y_axis_formatter))
#     792 if factor_returns is not None:
#     793     cum_factor_returns = ep.cum_returns(
# --> 794         factor_returns[cum_rets.index], 1.0)
#     795     cum_factor_returns.plot(lw=2, color='gray',
#     796                             label=factor_returns.name, alpha=0.60,
#     797                             ax=ax, **kwargs)
#     799 if live_start_date is not None:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [DatetimeIndex(['2020-06-03 00:00:00+00:00', '2020-06-04 00:00:00+00:00',\n               '2020-06-05 00:00:00+00:00', '2020-06-08 00:00:00+00:00',\n               '2020-06-09 00:00:00+00:00', '2020-06-10 00:00:00+00:00',\n               '2020-06-11 00:00:00+00:00', '2020-06-12 00:00:00+00:00',\n               '2020-06-15 00:00:00+00:00', '2020-06-16 00:00:00+00:00',\n               ...\n               '2021-09-16 00:00:00+00:00', '2021-09-17 00:00:00+00:00',\n               '2021-09-22 00:00:00+00:00', '2021-09-23 00:00:00+00:00',\n               '2021-09-24 00:00:00+00:00', '2021-09-27 00:00:00+00:00',\n               '2021-09-28 00:00:00+00:00', '2021-09-29 00:00:00+00:00',\n               '2021-09-30 00:00:00+00:00', '2021-10-08 00:00:00+00:00'],\n              dtype='datetime64[ns, UTC]', name='date', length=315, freq=None)] are in the [columns]"

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize= (11,6))

plt.plot(df_returns['date'],df_returns['td3'],label = 'td3',color = (254/255,253/255,107/255))
plt.plot(df_returns['date'],df_returns['sac'],label = 'sac',color = (114/255,170/255,207/255))
plt.plot(df_returns['date'],df_returns['ppo'],label = 'ppo',color = 'limegreen')
plt.plot(df_returns['date'],df_returns['sse'],label = 'B&H',color = (168/255,3/255,38/255))
plt.plot(df_returns['date'],df_returns['ewtf'],label = 'ewtf',color = (253/255,183/255,107/255))
plt.plot(df_returns['date'],df_returns['our'],label = 'our',color = (57/255,81/255,162/255))
plt.plot(df_returns['date'],df_returns['van'],label = 'van',color = (200/255,100/255,162/255))

plt.legend()
plt.title('')
plt.xlabel('date')
plt.ylabel('Cumulative returns')
# plt.grid()
plt.show()

# %%
df_returns.to_csv('724_df_returns.csv',index=None)

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.236390
# Cumulative returns     0.303750
# Annual volatility      0.306491
# Sharpe ratio           0.847496
# Calmar ratio           0.872575
# Stability              0.323907
# Max drawdown          -0.270911
# Omega ratio            1.149590
# Sortino ratio          1.256135
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.180719
# Daily value at risk   -0.037584
# dtype: float64

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.091891
# Cumulative returns     0.116154
# Annual volatility      0.291696
# Sharpe ratio           0.447431
# Calmar ratio           0.284677
# Stability              0.003831
# Max drawdown          -0.322789
# Omega ratio            1.078889
# Sortino ratio          0.674503
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.252199
# Daily value at risk   -0.036232
# dtype: float64

# %%
selected_tics = addfeature_df['tic'].unique()

# %%
#获取随机选择的tic在select_date的权重并修正
def get_selected_index_weight(df_index,select_date,selected_tics):
    df = df_index[df_index['trade_date'] == select_date]
    select_df = df[df['con_code'].isin(selected_tics)]
    select_df = select_df.drop('index_code',axis=1).rename(columns={'con_code':'tic','trade_date':'date'})
    select_df = select_df.reset_index()
    weight_sum = select_df['weight'].sum()
#     print(select_df)
    for i in range(len(select_df)):
        select_df.loc[i,'weight'] = (select_df.loc[i,'weight'] / weight_sum)*100
    return select_df.loc[:,['tic','date','weight']]

baseline_weight =get_selected_index_weight(df_index,select_date,selected_tics)
baseline_weight = baseline_weight.sort_values(['tic'],ascending=True).reset_index(drop=True)
print(baseline_weight)
# Out:
#           tic      date     weight
# 0   600000.SH  20200228   4.211716
# 1   600009.SH  20200228   2.093095
# 2   600016.SH  20200228   4.693055
# 3   600030.SH  20200228   6.087844
# 4   600031.SH  20200228   3.396722
# 5   600036.SH  20200228  11.661531
# 6   600104.SH  20200228   2.572611
# 7   600690.SH  20200228   2.074863
# 8   600887.SH  20200228   5.827119
# 9   601066.SH  20200228   0.475869
# 10  601138.SH  20200228   1.008259
# 11  601166.SH  20200228   8.312214
# 12  601288.SH  20200228   4.319288
# 13  601318.SH  20200228  27.831969
# 14  601328.SH  20200228   4.722227
# 15  601601.SH  20200228   3.312852
# 16  601888.SH  20200228   2.532499
# 17  601939.SH  20200228   1.442194
# 18  601988.SH  20200228   2.474155
# 19  603993.SH  20200228   0.949915

# %%
#计算所选股票的buy & hold策略
def calculate_selected_baseline(df,full_date_range,selected_tics):
    df = df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
    baseline = pd.DataFrame({'date':full_date_range['date']})
    for i in range(len(full_date_range)):
        temp_date = full_date_range.loc[i,'date']
        temp_df = df[df['date'] == temp_date].sort_values('tic',ascending=True)
        close = list(temp_df['close'])
        weight = list(baseline_weight['weight'])
        baseline.loc[i,'account_value'] = sum(np.array(close) * np.array(weight)) #注意权重和收盘价对应的股票顺序
    baseline['date'] = pd.to_datetime(baseline['date'])
#     baseline.set_index("date", inplace=True, drop=True)
#     baseline.index = baseline.index.tz_localize("UTC")
    return baseline
# full_date_range = get_trading_days(exchange='SSE',start_date='20210301', end_date='20230227')
# full_date_range = full_date_range.sort_values('trade_date',ascending=True).reset_index(drop=True)
full_date_range1 = pd.DataFrame({'date':df_account_value['date'].unique()}).reset_index(drop=True)
baseline_sse = calculate_selected_baseline(addfeature_df,full_date_range1,selected_tics)
baseline_sse
# Out:
#           date  account_value
# 0   2020-06-03    3760.744653
# 1   2020-06-04    3751.078619
# 2   2020-06-05    3776.679417
# 3   2020-06-08    3836.082830
# 4   2020-06-09    3848.211352
# ..         ...            ...
# 310 2021-09-27    3621.152333
# 311 2021-09-28    3645.607873
# 312 2021-09-29    3649.322661
# 313 2021-09-30    3629.228618
# 314 2021-10-08    3801.595365
#
# [315 rows x 2 columns]

# %%
merged_df

# %%
#baseline stats
print("==============Get Baseline Stats===========")
# baseline_df = get_baseline(
#         ticker="^DJI", 
#         start = df_account_value.loc[0,'date'],
#         end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_sse, value_col_name = 'account_value')

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
from copy import deepcopy
def backtest_plot_com(
    account_value,
    baseline,
    baseline_start=TRADE_START_DATE,
    baseline_end=TRADE_END_DATE,
    value_col_name="account_value",
):
    df = deepcopy(account_value)
    df["date"] = pd.to_datetime(df["date"])
    test_returns = get_daily_return(df, value_col_name=value_col_name)
#     pro = ts.pro_api()
#     baseline_df = pro.index_daily(ts_code='000016.sh',start_date = '20200301',end_date='20230227')
#     baseline_df = baseline_df.rename(columns={'trade_date':'date'})
#     baseline_df = baseline_df.sort_values('date',ascending=True)
    baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
    with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(
            returns=test_returns, benchmark_rets=baseline_returns, set_context=False
        )

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-08</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>23.639%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>30.375%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>30.649%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-27.091%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.26</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.758%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.85</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>27.09</td>
#       <td>2021-01-12</td>
#       <td>2021-07-30</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12.75</td>
#       <td>2020-08-28</td>
#       <td>2020-11-18</td>
#       <td>2020-12-14</td>
#       <td>77</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.19</td>
#       <td>2020-07-06</td>
#       <td>2020-07-16</td>
#       <td>2020-07-23</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.05</td>
#       <td>2020-07-23</td>
#       <td>2020-07-27</td>
#       <td>2020-08-03</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.75</td>
#       <td>2020-08-18</td>
#       <td>2020-08-20</td>
#       <td>2020-08-28</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-6.02%</td>
#       <td>5.93%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-08</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>9.189%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>11.615%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>29.17%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.28</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-32.279%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.67</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.25</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.623%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.10</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.94</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>32.28</td>
#       <td>2021-01-12</td>
#       <td>2021-09-22</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11.13</td>
#       <td>2020-07-06</td>
#       <td>2020-07-16</td>
#       <td>2020-07-23</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.25</td>
#       <td>2020-08-03</td>
#       <td>2020-08-20</td>
#       <td>2020-12-01</td>
#       <td>87</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.18</td>
#       <td>2020-07-23</td>
#       <td>2020-07-27</td>
#       <td>2020-08-03</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.31</td>
#       <td>2020-12-07</td>
#       <td>2020-12-11</td>
#       <td>2020-12-14</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.05%</td>
#       <td>-6.81%</td>
#       <td>6.29%</td>
#     </tr>
#   </tbody>
# </table>
