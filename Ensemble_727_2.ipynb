# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install stable_baselines3
# !pip install yfinance
# !pip install tushare
# !pip install exchange_calendars
# !pip install wrds
# !pip install alpaca_trade_api
# !pip install stockstats
# !pip install pyfolio

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_add import StockTradingEnv
from finrl.agents.stablebaselines3.models_add import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)

# %%
df = pd.read_csv('merged_df.csv')
df

# %%
TRAIN_START_DATE = '2012-10-10'
TRAIN_END_DATE = '2020-02-28'
TRADE_START_DATE = '2020-03-01'
TRADE_END_DATE = '2022-05-30'

# %%
import tushare as ts
ts.set_token('6314756019e50a6672690e5a78b2dbf7cfcd27c6f6a6b48a8cf76dae')
pro = ts.pro_api()

# %%
#选择上证50指数的成分股
df_index = pro.index_weight(index_code='000016.sh', start_date='20151010', end_date='20220228')
# df_index.to_csv('SSE_50_index_weight.csv',index=0)

# %%
#选择某个时间点的上证50指数成分股作为参考跟踪股票池
select_date = '20200228' #自定义的时间点为每个月的月末
df_select = df_index[df_index['trade_date']==select_date]
sort_SSEindex = df_select['con_code'].unique()
print(sort_SSEindex,len(sort_SSEindex))
# Out:
# ['603993.SH' '603259.SH' '601989.SH' '601988.SH' '601939.SH' '601888.SH'
#  '601857.SH' '601818.SH' '601766.SH' '601688.SH' '601668.SH' '601628.SH'
#  '601601.SH' '601398.SH' '601390.SH' '601336.SH' '601328.SH' '601319.SH'
#  '601318.SH' '601288.SH' '601236.SH' '601211.SH' '601186.SH' '601166.SH'
#  '601138.SH' '601111.SH' '601088.SH' '601066.SH' '601012.SH' '600887.SH'
#  '600837.SH' '600703.SH' '600690.SH' '600585.SH' '600547.SH' '600519.SH'
#  '600340.SH' '600309.SH' '600276.SH' '600196.SH' '600104.SH' '600050.SH'
#  '600048.SH' '600036.SH' '600031.SH' '600030.SH' '600028.SH' '600016.SH'
#  '600009.SH' '600000.SH'] 50

# %%
#随机选择成分股中的k只股票
import random 
k = 5
selected_tics = random.sample(list(sort_SSEindex),k)
print(selected_tics)
# Out:
# ['600585.SH', '603259.SH', '600703.SH', '601939.SH', '601390.SH']

# %%
selected_tics = ['601166.SH', '601288.SH', '600009.SH', '600690.SH', '601988.SH', '600031.SH', '600104.SH', '600036.SH', '600016.SH', '601601.SH', '601066.SH', '600000.SH', '601318.SH', '601939.SH', '600030.SH', '603993.SH', '601328.SH', '601888.SH', '600887.SH', '601138.SH']

# %%
#Download随机选择的k只股票数据
df_ts =pd.DataFrame()
for c in selected_tics:
    temp=pro.daily(ts_code=c,start_date=TRAIN_START_DATE,end_date=TRADE_END_DATE)
    df_ts=pd.concat([df_ts,temp])
print(df_ts)
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     600585.SH   20211231  40.22  40.67  40.00  40.30      40.45   -0.15
# 1     600585.SH   20211230  40.49  40.99  40.24  40.45      40.47   -0.02
# 2     600585.SH   20211229  40.99  41.26  40.31  40.47      40.89   -0.42
# 3     600585.SH   20211228  41.58  41.72  40.67  40.89      41.49   -0.60
# 4     600585.SH   20211227  41.81  42.60  40.98  41.49      41.78   -0.29
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 2339  601390.SH   20120110   2.48   2.61   2.47   2.60       2.49    0.11
# 2340  601390.SH   20120109   2.43   2.50   2.39   2.49       2.42    0.07
# 2341  601390.SH   20120106   2.41   2.43   2.37   2.42       2.42    0.00
# 2342  601390.SH   20120105   2.46   2.47   2.38   2.42       2.47   -0.05
# 2343  601390.SH   20120104   2.53   2.54   2.46   2.47       2.52   -0.05
#
#       pct_chg        vol      amount
# 0     -0.3708  144458.06  581235.915
# 1     -0.0494  183243.27  743967.981
# 2     -1.0271  140066.28  568454.254
# 3     -1.4461  175871.21  721151.986
# 4     -0.6941  190962.64  797704.998
# ...       ...        ...         ...
# 2339   4.4200  671897.37  171410.382
# 2340   2.8900  428080.19  104646.357
# 2341   0.0000  301943.59   72154.227
# 2342  -2.0200  389638.57   94421.100
# 2343  -1.9800  398666.08  100000.148
#
# [10488 rows x 11 columns]

# %%
# 筛选exchange_calender中每个交易节点缺失情况(全部补充0)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) != k:
            missing_tic = set(selected_tics).difference(set(temp_df['ts_code'].tolist()))
#             print(missing_tic)
            for m_tic in missing_tic:
                temp_dict = {'ts_code':m_tic,'trade_date':date,'open':0, 'high':0,'low':0, 'close':0, 'pre_close':0, 'change':0, 'pct_chg':0, 'volume':0, 'amount':0}
                new_data = pd.DataFrame.from_dict(temp_dict,orient='index').T
                temp_df = temp_df.append(new_data)
            processe_df.append(temp_df)
        else :
            processe_df.append(temp_df)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
# 筛选exchange_calender中每个交易节点缺失(激进)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) == k:
            processe_df.append(temp_df)
        else :
            date_unique.remove(date)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
processed_df,date_unique = processed_date(df_ts,selected_tics,k)
print(processed_df)
# Out:
#         ts_code trade_date    open    high     low   close  pre_close  change  \
# 0     601390.SH   20180820    7.25    7.36    6.88    6.96       7.36   -0.40
# 1     600585.SH   20180820   35.42   36.49   35.29   36.49      35.20    1.29
# 2     601939.SH   20180820    6.55    6.68    6.52    6.66       6.52    0.14
# 3     600703.SH   20180820   16.68   16.96   16.35   16.94      16.80    0.14
# 4     603259.SH   20180820   71.92   73.21   70.39   72.98      71.91    1.07
# ...         ...        ...     ...     ...     ...     ...        ...     ...
# 4090  601390.SH   20211231    5.72    5.82    5.72    5.79       5.72    0.07
# 4091  601939.SH   20211231    5.86    5.87    5.84    5.86       5.87   -0.01
# 4092  600703.SH   20211231   36.60   38.10   36.60   37.56      36.74    0.82
# 4093  603259.SH   20211231  120.37  121.15  117.68  118.58     120.01   -1.43
# 4094  600585.SH   20211231   40.22   40.67   40.00   40.30      40.45   -0.15
#
#       pct_chg        vol       amount
# 0     -5.4348  735787.83   519954.354
# 1      3.6648  295716.91  1063724.403
# 2      2.1472  846437.58   560117.680
# 3      0.8333  276477.80   460141.540
# 4      1.4880   47439.14   341871.277
# ...       ...        ...          ...
# 4090   1.2238  648479.78   374958.155
# 4091  -0.1704  490953.91   287442.721
# 4092   2.2319  634842.28  2379857.342
# 4093  -1.1916  172073.06  2053649.398
# 4094  -0.3708  144458.06   581235.915
#
# [4095 rows x 11 columns]

# %%
processed_df1 = processed_df
processed_df1 = processed_df1.sort_values(['ts_code','trade_date'],ascending=True,ignore_index=True)
processed_df1['trade_date'] = pd.to_datetime(processed_df1['trade_date'])
processed_df1
# Out:
#         ts_code trade_date    open    high     low   close  pre_close  change  \
# 0     600585.SH 2018-08-20   35.42   36.49   35.29   36.49      35.20    1.29
# 1     600585.SH 2018-08-21   36.39   37.29   36.20   37.09      36.49    0.60
# 2     600585.SH 2018-08-22   37.30   37.47   36.90   37.46      37.09    0.37
# 3     600585.SH 2018-08-23   37.68   37.98   36.75   37.22      37.46   -0.24
# 4     600585.SH 2018-08-24   37.26   37.59   37.08   37.35      37.22    0.13
# ...         ...        ...     ...     ...     ...     ...        ...     ...
# 4090  603259.SH 2021-12-27  112.20  114.30  110.80  114.19     112.03    2.16
# 4091  603259.SH 2021-12-28  113.20  119.98  112.60  119.10     114.19    4.91
# 4092  603259.SH 2021-12-29  118.18  122.82  117.99  119.19     119.10    0.09
# 4093  603259.SH 2021-12-30  119.19  121.50  116.88  120.01     119.19    0.82
# 4094  603259.SH 2021-12-31  120.37  121.15  117.68  118.58     120.01   -1.43
#
#       pct_chg        vol       amount
# 0      3.6648  295716.91  1063724.403
# 1      1.6443  204222.39   754456.468
# 2      0.9976  183493.46   683594.524
# 3     -0.6407  274367.07  1021899.132
# 4      0.3493  187729.09   700641.173
# ...       ...        ...          ...
# 4090   1.9281  239176.66  2696496.861
# 4091   4.2999  438049.83  5131430.724
# 4092   0.0756  269864.45  3237142.300
# 4093   0.6880  173291.48  2074422.755
# 4094  -1.1916  172073.06  2053649.398
#
# [4095 rows x 11 columns]

# %%
#出现缺失值的个数、占比
count = len(pro_df[pro_df['open'] == 0])
nan_rate = count/len(pro_df)
print(count,'缺失值百分之:',nan_rate)

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=False,
                    use_turbulence=False,
                    user_defined_feature = False)

# %%
processed_df3 = processed_df1.rename(columns={'ts_code':'tic','trade_date':'date','vol':'volume'})
processed_df3 = fe.preprocess_data(processed_df3)
processed_df3 = processed_df3.fillna(method="ffill").fillna(method="bfill")
processed_df3 = processed_df3.sort_values(['tic','date'],ascending=True).reset_index()
# Out:
# Successfully added technical indicators

# %%
def delaydate(dela,full_list):
    grouped = processed_df3.groupby('tic')
    filtered_df = pd.DataFrame()
    for name, group in grouped:
        # 按'trade_date'升序排序  True=升序
        group = group.sort_values('date', ascending=True)
        
        # 丢弃前48个日期的数据
        group = group.iloc[dela:]
        filtered_df = filtered_df.append(group)
    
    filtered_df = filtered_df.reset_index(drop=True)
    filtered_df = filtered_df.sort_values(['tic','date'],ascending=True,ignore_index=True)
    return filtered_df

# %%
pro_df = processed_df1.loc[:,['open','high','low','close','vol']].reset_index(drop=True)

# %%
#计算技术指标到dataset中
#Can be easily expanded
#Currently contains a small set of tech indicators
import talib as ta

def calc_tech_ind(data):
    #overlap 
    data['upbd'], data['midbd'], data['lowbd'] = ta.BBANDS(data["close"])
    data['dema'] = ta.DEMA(data["close"], timeperiod=30)
    data['tema'] = ta.TEMA(data["close"], timeperiod=30)
    data['ema'] = ta.EMA(data["close"], timeperiod=30)
    data['wma'] = ta.WMA(data["close"], timeperiod=30)
    data['sma'] = ta.SMA(data["close"], timeperiod=30)
    data['sarext'] = ta.SAREXT(data["high"], data["low"])
    
    #momentum
    data['adxr'] = ta.ADXR(data["high"], data["low"], data["close"], timeperiod=14)
    data['apo'] = ta.APO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['aroondown'], data['aroonup'] = ta.AROON(data["high"], data["low"], timeperiod=14)
    data['cci'] = ta.CCI(data["high"], data["low"], data["close"], timeperiod=14)
    data['cmo'] = ta.CMO(data["close"], timeperiod=14)
    data['macd'], data['macdsignal'], data['macdhist'] = ta.MACD(data["close"], fastperiod=12, slowperiod=26, signalperiod=9)
    data['MFI'] = ta.MFI(data["high"], data["low"], data["close"], data['vol'], timeperiod=14)
    data['mom'] = ta.MOM(data["close"], timeperiod=10)
    data['plus_di'] = ta.PLUS_DI(data["high"], data["low"], data["close"], timeperiod=14)
    data['ppo'] = ta.PPO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['roc'] = ta.ROC(data["close"], timeperiod=10)
    data['rocp'] = ta.ROCP(data["close"], timeperiod=10)
    data['rsi'] = ta.RSI(data["close"], timeperiod=14)
    data['slowk'], data['slowd'] = ta.STOCH(data["high"], data["low"], data["close"])
    data['fastk'], data['fastd'] = ta.STOCHF(data["high"], data["low"], data["close"])
    data['trix'] = ta.TRIX(data["close"], timeperiod=30)
    data['ultosc'] = ta.ULTOSC(data["high"], data["low"], data["close"], timeperiod1=7, timeperiod2=14, timeperiod3=28)
    data['willr'] = ta.WILLR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #volume
    data['ad'] = ta.AD(data["high"], data["low"], data["close"], data['vol'])
    data['obv'] = ta.OBV(data["close"], data['vol'])
    
    #volitility
    data['atr'] = ta.ATR(data["high"], data["low"], data["close"], timeperiod=14)
    data['natr'] = ta.NATR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #cycle
    data['HT_DCPERIOD'] = ta.HT_DCPERIOD(data["close"])
#     data['HT_DCPHASE'] = ta.HT_DCPHASE(data["close"])
#     data['inphase'], data['quadrature'] = ta.HT_PHASOR(data["close"])
    
    
    return data

# %%
full_list1 = calc_tech_ind(pro_df)
full_list1 = full_list1.fillna(0)

# %%
array_full_list = np.array(full_list1)
array_full_list = array_full_list.reshape(k,int(len(full_list1)/k),full_list1.shape[1])
selected_tics = sorted(selected_tics)

# %%
df.tic.value_counts()

# %% [markdown]
# # Part 2: DeepLearning representation

# %%
#generate x, y, z, zp quadruples
#segment x, y, z trios to sequence according to $timeStep and $gap
#x: historical data w/ technical analysis indicator
#y: closing price of t+1
#z:  difference between t+1 and t step's closing price

def toSequential_train1(idx, full_list, timeStep=48, gap=4):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
#     closingNorm = (closing - closing.mean())/closing.std()
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    for i in range(count):
        #segData dims: [timestep, feature count]       
        segData=data[gap*i:gap*i+timeStep]
        segClosing=closing[gap*i:gap*i+timeStep+1]
        #segDiff=diff[gap*i:gap*i+timeStep]
        #normalization
        
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
#         segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        segDataNorm=np.nan_to_num((segData-segData.mean(axis=0, keepdims=True))/segData.std(axis=0, keepdims=True))
    
        std_close = segClosing.std()
        std_segClosing = np.where(std_close == 0, 1, std_close)
        segClosingNorm=(segClosing-segClosing.mean())/std_segClosing
#         segDiff=(segDiff-segDiff.mean())/segDiff.std()
        
        stockSeq.append(segDataNorm)
        labelSeq.append(segClosingNorm[1:])
        diffSeq.append(segClosingNorm[1:]-segClosingNorm[:-1])
        realDiffSeq.append(segClosing[1:]-segClosing[:-1])
    stockSeq=np.array(stockSeq)
    labelSeq=np.array(labelSeq)
    diffSeq=np.array(diffSeq)
    realDiffSeq=np.array(realDiffSeq)
    return stockSeq.astype('float32') , labelSeq.astype('float32'), diffSeq.astype('float32'), realDiffSeq.astype('float32')

# %%
def toSequential_back(idx, full_list, timeStep = 48, gap = 1,batch_size = 64):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    
    start = data_length - timeStep
    i=0
    while start >= 0:
        segData = data[start:start + timeStep]
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
        segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        #复制batch_size个
        stockSeq.extend([segDataNorm] * batch_size)
#         stockSeq.append(segDataNorm)   
        start = start - gap
        i +=1
    stockSeq=np.array(stockSeq)[::-1]
#     print(i)
    return stockSeq.astype('float32')

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=3):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        closing_cohort=[]
        diff_cohort=[]
        real_diff_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X, y, z, zp=toSequential_train1(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
            closing_cohort.append(y)
            diff_cohort.append(z)
            real_diff_cohort.append(zp)
        self.X=np.concatenate(stock_cohort, axis=0)
        self.y=np.concatenate(closing_cohort, axis=0)
        self.z=np.concatenate(diff_cohort, axis=0)  
        self.zp=np.concatenate(real_diff_cohort, axis=0)
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        label1=self.y[idx]
        label2=self.z[idx]
        label3=self.zp[idx]
        if self.transform:
            data=self.transform(data)
        return (data, label1, label2, label3)
    
    
    def getDS(self):
        return self.X, self.y, self.z, self.zp

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset_back(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=1):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X=toSequential_back(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
        self.X=np.concatenate(stock_cohort, axis=0)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        if self.transform:
            data=self.transform(data)
        return data
        
    def getDS(self):
        return self.X

# %%
#Generation of training, validation, and testing dataset
def DataIterGen(test_id_list, val_id_list, name_list, full_list, demo=False):
    """
    test_id_list: id of subjects for testing
    val_id_list: id of subjects for validation
    other subjects for training
    full_list=get_data_set(name_list), preprocessed
    demo: when demo mode is True, only test_iter is returned, with data from
    first entry of test_id_list (single stock)
    """
    name_count=len(name_list)

    if demo:
        test_iter=DataLoader(StockDataset(test_id_list[0:1], full_list, timestep=24, gap=1), shuffle=False, batch_size=64, num_workers=0)
        print(f'Demo with stock: {name_list[test_id_list[0]]} ')
        return test_iter
    else:
        all_ids = list(range(name_count))
        train_id_list = list(set(all_ids) - set(test_id_list) - set(val_id_list))
#         partial_list=full_list[train_list,:,:]
        test_iter=DataLoader(StockDataset(test_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        val_iter=DataLoader(StockDataset(val_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        train_iter=DataLoader(StockDataset(train_id_list, full_list), shuffle=True, batch_size=64, num_workers=0,drop_last=True)
        print(f'Val: {[name_list[val_id] for val_id in val_id_list]}, Test: {[name_list[test_id] for test_id in test_id_list]}, Train: {[name_list[train_id] for train_id in train_id_list]} ')
        return train_iter, val_iter, test_iter

# %%
train_iter, val_iter, test_iter = DataIterGen([3],[4],selected_tics,array_full_list)
# Out:
# Val: ['603259.SH'], Test: ['601939.SH'], Train: ['600585.SH', '600703.SH', '601390.SH']

# %% [markdown]
# # Part3: Transformer

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class TransformerEncoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers,dropout_rate):
#         super(TransformerEncoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_moedl * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_moedl)
#         self.num_layers = num_layers

#     def forward(self, x):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#         return x

# %%
# class TransformerDecoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, env_size, num_layers, dropout_rate):
#         super(TransformerDecoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.encoder_attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_model * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout3 = nn.Dropout(dropout_rate)
#         self.layer_norm3 = nn.LayerNorm(d_model)
#         self.linear1 = nn.Linear(d_model, env_size)
#         self.linear2 = nn.Linear(env_size,1)
#         self.num_layers = num_layers

#     def forward(self, x, encoder_output, target_mask, target_padding_mask):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x, attn_mask=target_mask)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x, _ = self.encoder_attention(x, encoder_output, encoder_output,key_padding_mask =target_padding_mask)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout3(x)
#             x = self.layer_norm3(x + residual)
#         env_size = self.linear1(x)
#         x = self.linear2(env_size).permute(1,0,2)
#         return x, env_size.permute(1,0,2)[0,-1,:]

# %%
# class Transformer(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers, env_size, dropout_rate):
#         super(Transformer, self).__init__()
#         self.encoder = TransformerEncoder(input_size, d_model, num_heads, num_layers,dropout_rate)
#         self.decoder = TransformerDecoder(input_size, d_model, num_heads, env_size, num_layers,dropout_rate)

#     def forward(self, input_seq, target_seq):
#         encoder_output = self.encoder(input_seq)
#         target_mask = self.generate_attention_mask(target_seq)
#         target_padding_mask = self.generate_padding_mask(target_seq)
#         decoder_output = self.decoder(target_seq, encoder_output)
#         return decoder_output
    
#     def generate_attention_mask(self, sequence):
#         attn_mask = torch.triu(torch.ones(sequence.size(1), sequence.size(1)), diagonal=1).bool().to(sequence.device)
#         return attn_mask

#     def generate_padding_mask(self, sequence):
#         padding_mask = (sequence == 0).to(sequence.device)
#         return padding_mask

# %%
# #模型训练
# def train(model, train_iter, optimizer, num_epochs): 
#     # 训练循环
#     for epoch in range(num_epochs):
#         model.train()
#         total_loss = 0.0
#         enVec_list = []
#         for X, y, z, zp in train_iter:  
#             optimizer.zero_grad()

#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred,enVec = model(inputs,targets)
#             enVec_list.append(enVec)
#             print(pred,targets)
#             loss = nn.MSELoss()(pred, targets)  
#             loss.backward()
#             optimizer.step()
#             total_loss += loss.item()

#         # 打印每个 epoch 的损失
#         print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
#     return enVec_list
# # 模型评估
# def val(model, val_iter):
#     model.eval()
#     total_loss = 0.0
#     enVec_list = []
#     with torch.no_grad():
#         for X, y, z, zp in val_iter: 
#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred, enVec = model(inputs)
#             enVec_list.append(enVec)
#             loss = nn.MSELoss()(pred, targets)  
#             total_loss += loss.item()
#     print(f"val Loss: {total_loss/len(val_iter):.4f}")
#     return enVec_list

# %%
# # 定义模型
# model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, num_heads = 8,env_size =40,dropout_rate=0.2)
# optimizer = optim.Adam(model.parameters(), lr=0.001)
# outcoming =train(model,train_iter,optimizer,5)
# valtest =val(model,val_iter)

# %%
# def predict(model,back_iter):
#     enVec_list = []
#     with torch.no_grad():
#         for X in back_iter:
#             inputs = X.to(device)
#             _,enVec = model(inputs)
#             enVec_list.append(enVec)
#     return enVec_list

# %%
# #define device
# def try_gpu(i=0):
#     """Return gpu(i) if exists, otherwise return cpu()."""
#     if torch.cuda.device_count() >= i + 1:
#         return torch.device(f'cuda:{i}')
#     return torch.device('cpu')
# device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers,dropout_rate):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers,dropout_rate)
        self.linear1 = nn.Linear(d_model, env_size)
        self.rule = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.rule(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers,dropout_rate):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads,dropout_rate) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads,dropout_rate):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = self.dropout1(x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = self.dropout2(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
def predict(model,back_iter):
    enVec_list = []
    with torch.no_grad():
        for X in back_iter:
            inputs = X.to(device)
            _,enVec = model(inputs)
            enVec_list.append(enVec)
    return enVec_list

# %%
#define device
def try_gpu(i=0):
    """Return gpu(i) if exists, otherwise return cpu()."""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers)
        self.linear1 = nn.Linear(d_model, env_size)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.relu(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming =train(model,train_iter,optimizer,5)
valtest =val(model,val_iter)

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40,dropout_rate=0.1)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming = train(model,train_iter,optimizer,15)
valtest =val(model,val_iter)
# Out:
# Epoch 1: Loss: 0.3864
# Epoch 2: Loss: 0.2439
# Epoch 3: Loss: 0.2121
# Epoch 4: Loss: 0.1923
# Epoch 5: Loss: 0.1798
# Epoch 6: Loss: 0.1657
# Epoch 7: Loss: 0.1544
# Epoch 8: Loss: 0.1430
# Epoch 9: Loss: 0.1303
# Epoch 10: Loss: 0.1187
# Epoch 11: Loss: 0.1078
# Epoch 12: Loss: 0.0990
# Epoch 13: Loss: 0.0897
# Epoch 14: Loss: 0.0801
# Epoch 15: Loss: 0.0705
# val Loss: 0.1516

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# feature_enginner
import time 
start_time = time.time()
alltic_list = [i for i in range(k)]

def Feature_enginner(model, processed_df, full_list, alltic_list, batch_size=64, k=20, env_size=40,dela = 48):
    back_iter = DataLoader(StockDataset_back([i for i in range(k)],full_list), shuffle=False, batch_size=batch_size, num_workers=0,drop_last=False)
    
    new_state = predict(model,back_iter)
    concatenated_tensor = torch.cat(new_state, dim=0)
    concatenated_tensor = concatenated_tensor.view(-1,env_size)
    feature_df = pd.DataFrame(concatenated_tensor.numpy())
    
    full_delay_df = delaydate(dela ,processed_df)
    
    merged_df = pd.concat([full_delay_df, feature_df], axis=1)
    merged_df = merged_df.loc[:,['tic','date','close'] + INDICATORS + [i for i in range(env_size)]]
    merged_df.columns = ['tic','date','close'] + INDICATORS + [f"temporal_feature_{i}" for i in range(env_size)]
    end_time = time.time()
    print('总计消耗时间:',(end_time - start_time)/60)
    return merged_df

# %%
addfeature_df = Feature_enginner(model, processed_df3, array_full_list, alltic_list, batch_size=64, k=5 ,env_size=40, dela=48)
# Out:
# 总计消耗时间: 1.130364445845286

# %%
addfeature_df.to_csv('727_2_addfeature_df.csv',index=None)

# %%
addfeature_df = pd.read_csv('726addfeature_df.csv')

# %%
addfeature_df['date'] = pd.to_datetime(addfeature_df['date'])

# %%
processed_df3.to_csv('727_2_processed_best.csv',index=None)

# %%
processed_df3 = pd.read_csv('726_processed_best.csv')

# %%
processed_df3['date'] = pd.to_datetime(processed_df3['date'])

# %%
addfeature_df = fe.add_turbulence(addfeature_df)
addfeature_df = addfeature_df.fillna(method="ffill").fillna(method="bfill")

# %%
import datetime
processed['date'] = pd.to_datetime(processed['date'],format='%Y%m%d')
processed

# %%
list_ticker = processed["tic"].unique().tolist()
# list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
# combination = list(itertools.product(list_date,list_ticker))

# processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
# processed_full = processed_full[processed_full['date'].isin(processed['date'])]
# processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
selfattn_indicator_list = [f"temporal_feature_{i}" for i in range(40)]

# %%
selected_tics = addfeature_df.tic.unique()
selected_tics
# Out:
# array(['600585.SH', '600703.SH', '601390.SH', '601939.SH', '603259.SH'],
#       dtype=object)

# %%
TRAIN_START_DATE = addfeature_df['date'].unique()[0]

# %%
TRAIN_START_DATE
# Out:
# numpy.datetime64('2018-11-02T00:00:00.000000000')

# %%
stock_dimension = 5
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension + len(selfattn_indicator_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 5, State Space: 251

# %%
stock_dimension = len(processed_df3.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 5, State Space: 51

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=addfeature_df,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TRADE_START_DATE,TRADE_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 attn_indicator_list = selfattn_indicator_list,                 
                 **env_kwargs)

# %%
TRADE_END_DATE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 TRADE_END_DATE
#
# NameError: name 'TRADE_END_DATE' is not defined

# %%
SAC_model_kwargs = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
                }

PPO_model_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
                    }

TD3_model_kwargs = {
    "batch_size": 128, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
                }

timesteps_dict = {'sac' : 10000, 
                 'ppo' : 10000, 
                 'td3' : 10000
                 }

# %%
import torch
device = torch.device("mps")

# %%
df_summary = ensemble_agent.run_ensemble_strategy_com(SAC_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# ======Model training from:  2018-11-02T00:00:00.000000000 to  2020-03-02T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_79
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 180            |
# |    time_elapsed    | 7              |
# |    total_timesteps | 1284           |
# | train/             |                |
# |    actor_loss      | -1.11e+03      |
# |    critic_loss     | 19.1           |
# |    ent_coef        | 0.113          |
# |    ent_coef_loss   | 201            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 1183           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# day: 320, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1289507.54
# total_reward: 289507.54
# total_cost: 670.46
# total_trades: 640
# Sharpe: 1.130
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 168            |
# |    time_elapsed    | 15             |
# |    total_timesteps | 2568           |
# | train/             |                |
# |    actor_loss      | -891           |
# |    critic_loss     | 105            |
# |    ent_coef        | 0.128          |
# |    ent_coef_loss   | 189            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 2467           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# day: 320, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1289507.54
# total_reward: 289507.54
# total_cost: 670.46
# total_trades: 640
# Sharpe: 1.130
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 166            |
# |    time_elapsed    | 23             |
# |    total_timesteps | 3852           |
# | train/             |                |
# |    actor_loss      | -732           |
# |    critic_loss     | 161            |
# |    ent_coef        | 0.145          |
# |    ent_coef_loss   | 177            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 3751           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# day: 320, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1289507.54
# total_reward: 289507.54
# total_cost: 670.46
# total_trades: 640
# Sharpe: 1.130
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 166            |
# |    time_elapsed    | 30             |
# |    total_timesteps | 5136           |
# | train/             |                |
# |    actor_loss      | -521           |
# |    critic_loss     | 159            |
# |    ent_coef        | 0.165          |
# |    ent_coef_loss   | 165            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 5035           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# day: 320, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1289507.54
# total_reward: 289507.54
# total_cost: 670.46
# total_trades: 640
# Sharpe: 1.130
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 20             |
# |    fps             | 167            |
# |    time_elapsed    | 38             |
# |    total_timesteps | 6420           |
# | train/             |                |
# |    actor_loss      | -414           |
# |    critic_loss     | 55.6           |
# |    ent_coef        | 0.188          |
# |    ent_coef_loss   | 154            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 6319           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# ---------------------------------------
# | time/              |                |
# |    episodes        | 24             |
# |    fps             | 168            |
# |    time_elapsed    | 45             |
# |    total_timesteps | 7704           |
# | train/             |                |
# |    actor_loss      | -262           |
# |    critic_loss     | 3.55e+03       |
# |    ent_coef        | 0.214          |
# |    ent_coef_loss   | 142            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 7603           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# day: 320, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1289507.54
# total_reward: 289507.54
# total_cost: 670.46
# total_trades: 640
# Sharpe: 1.130
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 28             |
# |    fps             | 168            |
# |    time_elapsed    | 53             |
# |    total_timesteps | 8988           |
# | train/             |                |
# |    actor_loss      | -70            |
# |    critic_loss     | 3.58e+03       |
# |    ent_coef        | 0.243          |
# |    ent_coef_loss   | 130            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 8887           |
# |    reward          | -0.00013895694 |
# ---------------------------------------
# day: 320, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1289507.54
# total_reward: 289507.54
# total_cost: 670.46
# total_trades: 640
# Sharpe: 1.130
# =================================
# ======SAC Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# SAC Sharpe Ratio:  0.1307737288497913
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_66
# day: 320, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1024399.61
# total_reward: 24399.61
# total_cost: 2756.95
# total_trades: 1505
# Sharpe: 0.699
# =================================
# ---------------------------------------
# | time/              |                |
# |    fps             | 1308           |
# |    iterations      | 1              |
# |    time_elapsed    | 1              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -1.0756136e-05 |
# ---------------------------------------
# day: 320, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1010299.83
# total_reward: 10299.83
# total_cost: 2858.55
# total_trades: 1465
# Sharpe: 0.311
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1227         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0045212433 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0648      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00173     |
# |    reward               | -0.001903688 |
# |    std                  | 0.999        |
# |    value_loss           | 0.00752      |
# ------------------------------------------
# day: 320, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1017564.23
# total_reward: 17564.23
# total_cost: 2863.84
# total_trades: 1510
# Sharpe: 0.634
# =================================
# day: 320, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1023135.82
# total_reward: 23135.82
# total_cost: 2776.07
# total_trades: 1494
# Sharpe: 0.995
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1208          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.006955919   |
# |    clip_fraction        | 0.0814        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0758       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00598      |
# |    reward               | -0.0008126871 |
# |    std                  | 1             |
# |    value_loss           | 0.0071        |
# -------------------------------------------
# day: 320, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1032623.37
# total_reward: 32623.37
# total_cost: 2691.75
# total_trades: 1501
# Sharpe: 1.539
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1200          |
# |    iterations           | 4             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.004643953   |
# |    clip_fraction        | 0.0507        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.09         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0782       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00353      |
# |    reward               | -6.694494e-05 |
# |    std                  | 1             |
# |    value_loss           | 0.00457       |
# -------------------------------------------
# day: 320, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1028375.98
# total_reward: 28375.98
# total_cost: 2791.58
# total_trades: 1458
# Sharpe: 0.620
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1196         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.009390706  |
# |    clip_fraction        | 0.08         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.1         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0894      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00524     |
# |    reward               | 0.0013926589 |
# |    std                  | 1            |
# |    value_loss           | 0.00558      |
# ------------------------------------------
# ======PPO Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# PPO Sharpe Ratio:  0.1059197659230264
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_66
# day: 320, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1225599.98
# total_reward: 225599.98
# total_cost: 3422.52
# total_trades: 1259
# Sharpe: 0.782
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 240          |
# |    time_elapsed    | 5            |
# |    total_timesteps | 1284         |
# | train/             |              |
# |    actor_loss      | 3.54e+03     |
# |    critic_loss     | 5.79e+04     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 963          |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# day: 320, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 964359.73
# total_reward: -35640.27
# total_cost: 207.27
# total_trades: 320
# Sharpe: -1.050
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 211          |
# |    time_elapsed    | 12           |
# |    total_timesteps | 2568         |
# | train/             |              |
# |    actor_loss      | 3.85e+03     |
# |    critic_loss     | 1.03e+05     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 2247         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# day: 320, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 964359.73
# total_reward: -35640.27
# total_cost: 207.27
# total_trades: 320
# Sharpe: -1.050
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 204          |
# |    time_elapsed    | 18           |
# |    total_timesteps | 3852         |
# | train/             |              |
# |    actor_loss      | 4.27e+03     |
# |    critic_loss     | 1.02e+05     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 3531         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# day: 320, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 964359.73
# total_reward: -35640.27
# total_cost: 207.27
# total_trades: 320
# Sharpe: -1.050
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 201          |
# |    time_elapsed    | 25           |
# |    total_timesteps | 5136         |
# | train/             |              |
# |    actor_loss      | 4.28e+03     |
# |    critic_loss     | 8.77e+04     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 4815         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 198          |
# |    time_elapsed    | 32           |
# |    total_timesteps | 6420         |
# | train/             |              |
# |    actor_loss      | 4.33e+03     |
# |    critic_loss     | 7.08e+04     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 6099         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# day: 320, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 964359.73
# total_reward: -35640.27
# total_cost: 207.27
# total_trades: 320
# Sharpe: -1.050
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 197          |
# |    time_elapsed    | 39           |
# |    total_timesteps | 7704         |
# | train/             |              |
# |    actor_loss      | 4.43e+03     |
# |    critic_loss     | 7.04e+04     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 7383         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# day: 320, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 964359.73
# total_reward: -35640.27
# total_cost: 207.27
# total_trades: 320
# Sharpe: -1.050
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 28           |
# |    fps             | 195          |
# |    time_elapsed    | 45           |
# |    total_timesteps | 8988         |
# | train/             |              |
# |    actor_loss      | 4.4e+03      |
# |    critic_loss     | 5.31e+04     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 8667         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# day: 320, episode: 95
# begin_total_asset: 1000000.00
# end_total_asset: 964359.73
# total_reward: -35640.27
# total_cost: 207.27
# total_trades: 320
# Sharpe: -1.050
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 32           |
# |    fps             | 195          |
# |    time_elapsed    | 52           |
# |    total_timesteps | 10272        |
# | train/             |              |
# |    actor_loss      | 4.32e+03     |
# |    critic_loss     | 2.16e+04     |
# |    learning_rate   | 0.001        |
# |    n_updates       | 9951         |
# |    reward          | -3.24457e-05 |
# -------------------------------------
# ======TD3 Validation from:  2020-03-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Best Model Retraining from:  2018-11-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======Trading from:  2020-06-03T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# ============================================
# ======Model training from:  2018-11-02T00:00:00.000000000 to  2020-06-03T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_63
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 169          |
# |    time_elapsed    | 9            |
# |    total_timesteps | 1536         |
# | train/             |              |
# |    actor_loss      | 645          |
# |    critic_loss     | 22.9         |
# |    ent_coef        | 0.115        |
# |    ent_coef_loss   | 199          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 1435         |
# |    reward          | -0.000706416 |
# -------------------------------------
# day: 383, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1267488.14
# total_reward: 267488.14
# total_cost: 999.00
# total_trades: 766
# Sharpe: 0.605
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 167          |
# |    time_elapsed    | 18           |
# |    total_timesteps | 3072         |
# | train/             |              |
# |    actor_loss      | 641          |
# |    critic_loss     | 53.9         |
# |    ent_coef        | 0.134        |
# |    ent_coef_loss   | 185          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 2971         |
# |    reward          | -0.000706416 |
# -------------------------------------
# day: 383, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1267488.14
# total_reward: 267488.14
# total_cost: 999.00
# total_trades: 766
# Sharpe: 0.605
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 166          |
# |    time_elapsed    | 27           |
# |    total_timesteps | 4608         |
# | train/             |              |
# |    actor_loss      | 627          |
# |    critic_loss     | 71.8         |
# |    ent_coef        | 0.156        |
# |    ent_coef_loss   | 171          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 4507         |
# |    reward          | -0.000706416 |
# -------------------------------------
# day: 383, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1267488.14
# total_reward: 267488.14
# total_cost: 999.00
# total_trades: 766
# Sharpe: 0.605
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 16           |
# |    fps             | 165          |
# |    time_elapsed    | 37           |
# |    total_timesteps | 6144         |
# | train/             |              |
# |    actor_loss      | 604          |
# |    critic_loss     | 252          |
# |    ent_coef        | 0.182        |
# |    ent_coef_loss   | 157          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 6043         |
# |    reward          | -0.000706416 |
# -------------------------------------
# day: 383, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1267488.14
# total_reward: 267488.14
# total_cost: 999.00
# total_trades: 766
# Sharpe: 0.605
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 20           |
# |    fps             | 165          |
# |    time_elapsed    | 46           |
# |    total_timesteps | 7680         |
# | train/             |              |
# |    actor_loss      | 682          |
# |    critic_loss     | 316          |
# |    ent_coef        | 0.212        |
# |    ent_coef_loss   | 143          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 7579         |
# |    reward          | -0.000706416 |
# -------------------------------------
# -------------------------------------
# | time/              |              |
# |    episodes        | 24           |
# |    fps             | 165          |
# |    time_elapsed    | 55           |
# |    total_timesteps | 9216         |
# | train/             |              |
# |    actor_loss      | 801          |
# |    critic_loss     | 124          |
# |    ent_coef        | 0.247        |
# |    ent_coef_loss   | 128          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 9115         |
# |    reward          | -0.000706416 |
# -------------------------------------
# day: 383, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1267488.14
# total_reward: 267488.14
# total_cost: 999.00
# total_trades: 766
# Sharpe: 0.605
# =================================
# ======SAC Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# SAC Sharpe Ratio:  0.15512747872749613
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_61
# day: 383, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1047162.59
# total_reward: 47162.59
# total_cost: 3899.65
# total_trades: 1857
# Sharpe: 0.556
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 1270          |
# |    iterations      | 1             |
# |    time_elapsed    | 1             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -0.0014198038 |
# --------------------------------------
# day: 383, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1100963.71
# total_reward: 100963.71
# total_cost: 3903.93
# total_trades: 1853
# Sharpe: 0.849
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1206           |
# |    iterations           | 2              |
# |    time_elapsed         | 3              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.006416658    |
# |    clip_fraction        | 0.0748         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -7.11          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0615        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00447       |
# |    reward               | -0.00013159141 |
# |    std                  | 1.01           |
# |    value_loss           | 0.00296        |
# --------------------------------------------
# day: 383, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1074777.08
# total_reward: 74777.08
# total_cost: 3727.90
# total_trades: 1866
# Sharpe: 0.663
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1184         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0077915154 |
# |    clip_fraction        | 0.0819       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.14        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0823      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00412     |
# |    reward               | -0.001118584 |
# |    std                  | 1.01         |
# |    value_loss           | 0.00243      |
# ------------------------------------------
# day: 383, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1025726.73
# total_reward: 25726.73
# total_cost: 3541.84
# total_trades: 1810
# Sharpe: 0.475
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1169          |
# |    iterations           | 4             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0076620677  |
# |    clip_fraction        | 0.0916        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.16         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.171         |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00204      |
# |    reward               | -0.0012412429 |
# |    std                  | 1.02          |
# |    value_loss           | 0.68          |
# -------------------------------------------
# day: 383, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1047936.26
# total_reward: 47936.26
# total_cost: 3809.49
# total_trades: 1845
# Sharpe: 0.430
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1165          |
# |    iterations           | 5             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.006281349   |
# |    clip_fraction        | 0.0537        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0695       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00274      |
# |    reward               | -0.0003229753 |
# |    std                  | 1.02          |
# |    value_loss           | 0.00741       |
# -------------------------------------------
# ======PPO Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# PPO Sharpe Ratio:  0.07132709516407829
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_61
# day: 383, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1300629.45
# total_reward: 300629.45
# total_cost: 2014.10
# total_trades: 1191
# Sharpe: 0.955
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 222            |
# |    time_elapsed    | 6              |
# |    total_timesteps | 1536           |
# | train/             |                |
# |    actor_loss      | -0.828         |
# |    critic_loss     | 89.3           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 1152           |
# |    reward          | -0.00032506624 |
# ---------------------------------------
# day: 383, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1353135.56
# total_reward: 353135.56
# total_cost: 606.44
# total_trades: 383
# Sharpe: 0.965
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 195            |
# |    time_elapsed    | 15             |
# |    total_timesteps | 3072           |
# | train/             |                |
# |    actor_loss      | -22.7          |
# |    critic_loss     | 74.3           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 2688           |
# |    reward          | -0.00032506624 |
# ---------------------------------------
# day: 383, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1353135.56
# total_reward: 353135.56
# total_cost: 606.44
# total_trades: 383
# Sharpe: 0.965
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 188            |
# |    time_elapsed    | 24             |
# |    total_timesteps | 4608           |
# | train/             |                |
# |    actor_loss      | 25.9           |
# |    critic_loss     | 28.4           |
# |    learning_rate   | 0.001          |
# |    n_updates       | 4224           |
# |    reward          | -0.00032506624 |
# ---------------------------------------
# day: 383, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1353135.56
# total_reward: 353135.56
# total_cost: 606.44
# total_trades: 383
# Sharpe: 0.965
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 184            |
# |    time_elapsed    | 33             |
# |    total_timesteps | 6144           |
# | train/             |                |
# |    actor_loss      | 31             |
# |    critic_loss     | 7.14e+03       |
# |    learning_rate   | 0.001          |
# |    n_updates       | 5760           |
# |    reward          | -0.00032506624 |
# ---------------------------------------
# ---------------------------------------
# | time/              |                |
# |    episodes        | 20             |
# |    fps             | 182            |
# |    time_elapsed    | 41             |
# |    total_timesteps | 7680           |
# | train/             |                |
# |    actor_loss      | 26.7           |
# |    critic_loss     | 5.4e+03        |
# |    learning_rate   | 0.001          |
# |    n_updates       | 7296           |
# |    reward          | -0.00032506624 |
# ---------------------------------------
# day: 383, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1353135.56
# total_reward: 353135.56
# total_cost: 606.44
# total_trades: 383
# Sharpe: 0.965
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 24             |
# |    fps             | 181            |
# |    time_elapsed    | 50             |
# |    total_timesteps | 9216           |
# | train/             |                |
# |    actor_loss      | 47.8           |
# |    critic_loss     | 1.44e+03       |
# |    learning_rate   | 0.001          |
# |    n_updates       | 8832           |
# |    reward          | -0.00032506624 |
# ---------------------------------------
# day: 383, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1353135.56
# total_reward: 353135.56
# total_cost: 606.44
# total_trades: 383
# Sharpe: 0.965
# =================================
# ======TD3 Validation from:  2020-06-03T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# ======Best Model Retraining from:  2018-11-02T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# ======Trading from:  2020-09-02T00:00:00.000000000 to  2020-12-08T00:00:00.000000000
# ============================================
# ======Model training from:  2018-11-02T00:00:00.000000000 to  2020-09-02T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_252_45
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 166           |
# |    time_elapsed    | 10            |
# |    total_timesteps | 1788          |
# | train/             |               |
# |    actor_loss      | 164           |
# |    critic_loss     | 2.92          |
# |    ent_coef        | 0.116         |
# |    ent_coef_loss   | 150           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 1687          |
# |    reward          | -0.0001324049 |
# --------------------------------------
# day: 446, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1428496.53
# total_reward: 428496.53
# total_cost: 1584.29
# total_trades: 1489
# Sharpe: 0.706
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 164            |
# |    time_elapsed    | 21             |
# |    total_timesteps | 3576           |
# | train/             |                |
# |    actor_loss      | 210            |
# |    critic_loss     | 12.1           |
# |    ent_coef        | 0.138          |
# |    ent_coef_loss   | 138            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 3475           |
# |    reward          | -0.00013186311 |
# ---------------------------------------
# day: 446, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1428496.53
# total_reward: 428496.53
# total_cost: 1584.29
# total_trades: 1489
# Sharpe: 0.706
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 163            |
# |    time_elapsed    | 32             |
# |    total_timesteps | 5364           |
# | train/             |                |
# |    actor_loss      | 262            |
# |    critic_loss     | 27.5           |
# |    ent_coef        | 0.165          |
# |    ent_coef_loss   | 125            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 5263           |
# |    reward          | -0.00012442675 |
# ---------------------------------------
# day: 446, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1520683.14
# total_reward: 520683.14
# total_cost: 999.00
# total_trades: 1784
# Sharpe: 0.892
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 163           |
# |    time_elapsed    | 43            |
# |    total_timesteps | 7152          |
# | train/             |               |
# |    actor_loss      | 372           |
# |    critic_loss     | 3.78e+03      |
# |    ent_coef        | 0.197         |
# |    ent_coef_loss   | 113           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 7051          |
# |    reward          | -9.361759e-05 |
# --------------------------------------
# day: 446, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1520683.14
# total_reward: 520683.14
# total_cost: 999.00
# total_trades: 1784
# Sharpe: 0.892
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 20            |
# |    fps             | 162           |
# |    time_elapsed    | 54            |
# |    total_timesteps | 8940          |
# | train/             |               |
# |    actor_loss      | 466           |
# |    critic_loss     | 52.5          |
# |    ent_coef        | 0.236         |
# |    ent_coef_loss   | 100           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 8839          |
# |    reward          | -9.361759e-05 |
# --------------------------------------
# ======SAC Validation from:  2020-09-02T00:00:00.000000000 to  2020-12-08T00:00:00.000000000
# SAC Sharpe Ratio:  0.11249174716374406
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_43
# day: 446, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1061070.81
# total_reward: 61070.81
# total_cost: 4529.57
# total_trades: 2156
# Sharpe: 0.417
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 1254          |
# |    iterations      | 1             |
# |    time_elapsed    | 1             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00011896976 |
# --------------------------------------
# day: 446, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1011142.38
# total_reward: 11142.38
# total_cost: 4460.26
# total_trades: 2151
# Sharpe: 0.312
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1195          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.007917595   |
# |    clip_fraction        | 0.0836        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.11         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0732       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00398      |
# |    reward               | 0.00040193717 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0183        |
# -------------------------------------------
# day: 446, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 996148.77
# total_reward: -3851.23
# total_cost: 4144.71
# total_trades: 2079
# Sharpe: -0.113
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1161         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0061899847 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.13        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0576      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.003       |
# |    reward               | 8.262818e-05 |
# |    std                  | 1.01         |
# |    value_loss           | 0.0136       |
# ------------------------------------------
# day: 446, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1012910.52
# total_reward: 12910.52
# total_cost: 4008.47
# total_trades: 2079
# Sharpe: 0.605
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1155          |
# |    iterations           | 4             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0070377244  |
# |    clip_fraction        | 0.0748        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.14         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0605       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00537      |
# |    reward               | -0.0008533968 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0198        |
# -------------------------------------------
# day: 446, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1053524.90
# total_reward: 53524.90
# total_cost: 4472.75
# total_trades: 2170
# Sharpe: 0.834
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1152          |
# |    iterations           | 5             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00607058    |
# |    clip_fraction        | 0.0578        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.16         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0513       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00407      |
# |    reward               | -0.0007964781 |
# |    std                  | 1.02          |
# |    value_loss           | 0.0122        |
# -------------------------------------------
# ======PPO Validation from:  2020-09-02T00:00:00.000000000 to  2020-12-08T00:00:00.000000000
# PPO Sharpe Ratio:  0.3372968063190017
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_252_43
# day: 446, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 974658.95
# total_reward: -25341.05
# total_cost: 277.05
# total_trades: 446
# Sharpe: -0.326
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 229           |
# |    time_elapsed    | 7             |
# |    total_timesteps | 1788          |
# | train/             |               |
# |    actor_loss      | -402          |
# |    critic_loss     | 366           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 1341          |
# |    reward          | -0.0004990274 |
# --------------------------------------
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 200           |
# |    time_elapsed    | 17            |
# |    total_timesteps | 3576          |
# | train/             |               |
# |    actor_loss      | -382          |
# |    critic_loss     | 3.96e+03      |
# |    learning_rate   | 0.001         |
# |    n_updates       | 3129          |
# |    reward          | -0.0004990274 |
# --------------------------------------
# day: 446, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 974658.95
# total_reward: -25341.05
# total_cost: 277.05
# total_trades: 446
# Sharpe: -0.326
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 192           |
# |    time_elapsed    | 27            |
# |    total_timesteps | 5364          |
# | train/             |               |
# |    actor_loss      | -268          |
# |    critic_loss     | 1.11e+05      |
# |    learning_rate   | 0.001         |
# |    n_updates       | 4917          |
# |    reward          | -0.0004990274 |
# --------------------------------------
# day: 446, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 974658.95
# total_reward: -25341.05
# total_cost: 277.05
# total_trades: 446
# Sharpe: -0.326
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 188           |
# |    time_elapsed    | 37            |
# |    total_timesteps | 7152          |
# | train/             |               |
# |    actor_loss      | -245          |
# |    critic_loss     | 155           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 6705          |
# |    reward          | -0.0004990274 |
# --------------------------------------
# day: 446, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 974658.95
# total_reward: -25341.05
# total_cost: 277.05
# total_trades: 446
# Sharpe: -0.326
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 20            |
# |    fps             | 186           |
# |    time_elapsed    | 47            |
# |    total_timesteps | 8940          |
# | train/             |               |
# |    actor_loss      | -203          |
# |    critic_loss     | 1.45e+03      |
# |    learning_rate   | 0.001         |
# |    n_updates       | 8493          |
# |    reward          | -0.0004990274 |
# --------------------------------------
# ======TD3 Validation from:  2020-09-02T00:00:00.000000000 to  2020-12-08T00:00:00.000000000
# ======Best Model Retraining from:  2018-11-02T00:00:00.000000000 to  2020-12-08T00:00:00.000000000
# ======Trading from:  2020-12-08T00:00:00.000000000 to  2021-03-15T00:00:00.000000000
# ============================================
# ======Model training from:  2018-11-02T00:00:00.000000000 to  2020-12-08T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_41
# ---------------------------------------
# | time/              |                |
# |    episodes        | 4              |
# |    fps             | 170            |
# |    time_elapsed    | 11             |
# |    total_timesteps | 2040           |
# | train/             |                |
# |    actor_loss      | 1.84e+03       |
# |    critic_loss     | 96.1           |
# |    ent_coef        | 0.12           |
# |    ent_coef_loss   | 195            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 1939           |
# |    reward          | -0.00046507537 |
# ---------------------------------------
# day: 509, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1572501.50
# total_reward: 572501.50
# total_cost: 999.00
# total_trades: 1527
# Sharpe: 1.023
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 8              |
# |    fps             | 168            |
# |    time_elapsed    | 24             |
# |    total_timesteps | 4080           |
# | train/             |                |
# |    actor_loss      | 1.21e+03       |
# |    critic_loss     | 1.78e+03       |
# |    ent_coef        | 0.146          |
# |    ent_coef_loss   | 177            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 3979           |
# |    reward          | -0.00046507537 |
# ---------------------------------------
# day: 509, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1572501.50
# total_reward: 572501.50
# total_cost: 999.00
# total_trades: 1527
# Sharpe: 1.023
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 12             |
# |    fps             | 167            |
# |    time_elapsed    | 36             |
# |    total_timesteps | 6120           |
# | train/             |                |
# |    actor_loss      | 1.25e+03       |
# |    critic_loss     | 91.6           |
# |    ent_coef        | 0.18           |
# |    ent_coef_loss   | 158            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 6019           |
# |    reward          | -0.00046507537 |
# ---------------------------------------
# day: 509, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1572501.50
# total_reward: 572501.50
# total_cost: 999.00
# total_trades: 1527
# Sharpe: 1.023
# =================================
# ---------------------------------------
# | time/              |                |
# |    episodes        | 16             |
# |    fps             | 166            |
# |    time_elapsed    | 48             |
# |    total_timesteps | 8160           |
# | train/             |                |
# |    actor_loss      | 1.35e+03       |
# |    critic_loss     | 218            |
# |    ent_coef        | 0.22           |
# |    ent_coef_loss   | 139            |
# |    learning_rate   | 0.0001         |
# |    n_updates       | 8059           |
# |    reward          | -0.00046507537 |
# ---------------------------------------
# ======SAC Validation from:  2020-12-08T00:00:00.000000000 to  2021-03-15T00:00:00.000000000
# SAC Sharpe Ratio:  -0.005772922591394763
# ======PPO Training========
# ...
# |    std                  | 1          |
# |    value_loss           | 0.0293     |
# ----------------------------------------
# day: 572, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1013659.39
# total_reward: 13659.39
# total_cost: 5398.04
# total_trades: 2594
# Sharpe: 0.338
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1132          |
# |    iterations           | 4             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.005294217   |
# |    clip_fraction        | 0.052         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.1          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0739       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00221      |
# |    reward               | -0.0013157846 |
# |    std                  | 1             |
# |    value_loss           | 0.0119        |
# -------------------------------------------
# day: 572, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1056252.84
# total_reward: 56252.84
# total_cost: 5882.47
# total_trades: 2610
# Sharpe: 0.697
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1125         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0075808773 |
# |    clip_fraction        | 0.0704       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.12        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0538      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00289     |
# |    reward               | 0.009989559  |
# |    std                  | 1.01         |
# |    value_loss           | 0.00933      |
# ------------------------------------------
# ======PPO Validation from:  2021-03-15T00:00:00.000000000 to  2021-06-17T00:00:00.000000000
# PPO Sharpe Ratio:  -0.12413295442165508
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_378_39
# day: 572, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1635734.00
# total_reward: 635734.00
# total_cost: 999.00
# total_trades: 2288
# Sharpe: 0.759
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 219           |
# |    time_elapsed    | 10            |
# |    total_timesteps | 2292          |
# | train/             |               |
# |    actor_loss      | 806           |
# |    critic_loss     | 309           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 1719          |
# |    reward          | -0.0018770098 |
# --------------------------------------
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 193           |
# |    time_elapsed    | 23            |
# |    total_timesteps | 4584          |
# | train/             |               |
# |    actor_loss      | 428           |
# |    critic_loss     | 193           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 4011          |
# |    reward          | -0.0018770098 |
# --------------------------------------
# day: 572, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1635734.00
# total_reward: 635734.00
# total_cost: 999.00
# total_trades: 2288
# Sharpe: 0.759
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 185           |
# |    time_elapsed    | 37            |
# |    total_timesteps | 6876          |
# | train/             |               |
# |    actor_loss      | 366           |
# |    critic_loss     | 9.47e+03      |
# |    learning_rate   | 0.001         |
# |    n_updates       | 6303          |
# |    reward          | -0.0018770098 |
# --------------------------------------
# day: 572, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1635734.00
# total_reward: 635734.00
# total_cost: 999.00
# total_trades: 2288
# Sharpe: 0.759
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 182           |
# |    time_elapsed    | 50            |
# |    total_timesteps | 9168          |
# | train/             |               |
# |    actor_loss      | 302           |
# |    critic_loss     | 6.24e+03      |
# |    learning_rate   | 0.001         |
# |    n_updates       | 8595          |
# |    reward          | -0.0018770098 |
# --------------------------------------
# ======TD3 Validation from:  2021-03-15T00:00:00.000000000 to  2021-06-17T00:00:00.000000000
# ======Best Model Retraining from:  2018-11-02T00:00:00.000000000 to  2021-06-17T00:00:00.000000000
# ======Trading from:  2021-06-17T00:00:00.000000000 to  2021-09-14T00:00:00.000000000
# ============================================
# ======Model training from:  2018-11-02T00:00:00.000000000 to  2021-06-17T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_441_16
# -------------------------------------
# | time/              |              |
# |    episodes        | 4            |
# |    fps             | 40           |
# |    time_elapsed    | 62           |
# |    total_timesteps | 2544         |
# | train/             |              |
# |    actor_loss      | 1.54e+03     |
# |    critic_loss     | 163          |
# |    ent_coef        | 0.127        |
# |    ent_coef_loss   | 236          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 2443         |
# |    reward          | 0.0030668864 |
# -------------------------------------
# day: 635, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 951376.75
# total_reward: -48623.25
# total_cost: 814.25
# total_trades: 1270
# Sharpe: -0.165
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 8            |
# |    fps             | 43           |
# |    time_elapsed    | 117          |
# |    total_timesteps | 5088         |
# | train/             |              |
# |    actor_loss      | 1.53e+03     |
# |    critic_loss     | 207          |
# |    ent_coef        | 0.164        |
# |    ent_coef_loss   | 207          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 4987         |
# |    reward          | 0.0030668864 |
# -------------------------------------
# day: 635, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 951376.75
# total_reward: -48623.25
# total_cost: 814.25
# total_trades: 1270
# Sharpe: -0.165
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 12           |
# |    fps             | 42           |
# |    time_elapsed    | 179          |
# |    total_timesteps | 7632         |
# | train/             |              |
# |    actor_loss      | 1.58e+03     |
# |    critic_loss     | 7.23e+03     |
# |    ent_coef        | 0.212        |
# |    ent_coef_loss   | 178          |
# |    learning_rate   | 0.0001       |
# |    n_updates       | 7531         |
# |    reward          | 0.0030668864 |
# -------------------------------------
# day: 635, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 951376.75
# total_reward: -48623.25
# total_cost: 814.25
# total_trades: 1270
# Sharpe: -0.165
# =================================
# ======SAC Validation from:  2021-06-17T00:00:00.000000000 to  2021-09-14T00:00:00.000000000
# SAC Sharpe Ratio:  0.416101503066304
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_441_15
# ---------------------------------------
# | time/              |                |
# |    fps             | 1183           |
# |    iterations      | 1              |
# |    time_elapsed    | 1              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -0.00013420869 |
# ---------------------------------------
# day: 635, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1034517.40
# total_reward: 34517.40
# total_cost: 6992.01
# total_trades: 3067
# Sharpe: 0.426
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1132          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.006465608   |
# |    clip_fraction        | 0.0799        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.11         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0753       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00253      |
# |    reward               | -0.0006352157 |
# |    std                  | 1.01          |
# |    value_loss           | 0.03          |
# -------------------------------------------
# day: 635, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1039796.15
# total_reward: 39796.15
# total_cost: 7015.81
# total_trades: 2990
# Sharpe: 0.255
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1104          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.008022739   |
# |    clip_fraction        | 0.0772        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.14         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.073        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00316      |
# |    reward               | 0.00027353602 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0512        |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1099           |
# |    iterations           | 4              |
# |    time_elapsed         | 7              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.0065791355   |
# |    clip_fraction        | 0.0587         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -7.16          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.07          |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.0032        |
# |    reward               | -5.7675297e-05 |
# |    std                  | 1.02           |
# |    value_loss           | 0.0109         |
# --------------------------------------------
# day: 635, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1054966.29
# total_reward: 54966.29
# total_cost: 6603.01
# total_trades: 3030
# Sharpe: 0.529
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1095          |
# |    iterations           | 5             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.005942378   |
# |    clip_fraction        | 0.0664        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -7.16         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0811       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00469      |
# |    reward               | 0.00011845203 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00506       |
# -------------------------------------------
# ======PPO Validation from:  2021-06-17T00:00:00.000000000 to  2021-09-14T00:00:00.000000000
# PPO Sharpe Ratio:  0.10621738883308866
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_441_15
# day: 635, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1396779.29
# total_reward: 396779.29
# total_cost: 999.00
# total_trades: 1270
# Sharpe: 0.563
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 40            |
# |    time_elapsed    | 63            |
# |    total_timesteps | 2544          |
# | train/             |               |
# |    actor_loss      | -918          |
# |    critic_loss     | 245           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 1908          |
# |    reward          | -8.751392e-05 |
# --------------------------------------
# day: 635, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1396779.29
# total_reward: 396779.29
# total_cost: 999.00
# total_trades: 1270
# Sharpe: 0.563
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 8             |
# |    fps             | 65            |
# |    time_elapsed    | 77            |
# |    total_timesteps | 5088          |
# | train/             |               |
# |    actor_loss      | -738          |
# |    critic_loss     | 3.42e+04      |
# |    learning_rate   | 0.001         |
# |    n_updates       | 4452          |
# |    reward          | -8.751392e-05 |
# --------------------------------------
# day: 635, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1396779.29
# total_reward: 396779.29
# total_cost: 999.00
# total_trades: 1270
# Sharpe: 0.563
# =================================
# --------------------------------------
# | time/              |               |
# |    episodes        | 12            |
# |    fps             | 83            |
# |    time_elapsed    | 91            |
# |    total_timesteps | 7632          |
# | train/             |               |
# |    actor_loss      | -647          |
# |    critic_loss     | 130           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 6996          |
# |    reward          | -8.751392e-05 |
# --------------------------------------
# --------------------------------------
# | time/              |               |
# |    episodes        | 16            |
# |    fps             | 96            |
# |    time_elapsed    | 104           |
# |    total_timesteps | 10176         |
# | train/             |               |
# |    actor_loss      | -590          |
# |    critic_loss     | 2.1e+03       |
# |    learning_rate   | 0.001         |
# |    n_updates       | 9540          |
# |    reward          | -8.751392e-05 |
# --------------------------------------
# ======TD3 Validation from:  2021-06-17T00:00:00.000000000 to  2021-09-14T00:00:00.000000000
# ======Best Model Retraining from:  2018-11-02T00:00:00.000000000 to  2021-09-14T00:00:00.000000000
# ======Trading from:  2021-09-14T00:00:00.000000000 to  2021-12-21T00:00:00.000000000
# Ensemble Strategy took:  16.4798015832901  minutes

# %%
df_summary

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = addfeature_df[(addfeature_df.date > TRADE_START_DATE)&(addfeature_df.date <= TRADE_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  0.7651101982827844

# %%
df_account_value
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2020-06-03           NaN 2020-06-03
# 1     1.000021e+06  2020-06-04      0.000021 2020-06-04
# 2     9.999538e+05  2020-06-05     -0.000067 2020-06-05
# 3     1.000014e+06  2020-06-08      0.000060 2020-06-08
# 4     9.998867e+05  2020-06-09     -0.000127 2020-06-09
# ..             ...         ...           ...        ...
# 373   1.258597e+06  2021-12-14      0.003034 2021-12-14
# 374   1.252392e+06  2021-12-15     -0.004930 2021-12-15
# 375   1.252848e+06  2021-12-16      0.000364 2021-12-16
# 376   1.246447e+06  2021-12-17     -0.005109 2021-12-17
# 377   1.244255e+06  2021-12-20     -0.001758 2021-12-20
#
# [378 rows x 4 columns]

# %%
df_returns = df_returns.iloc[:,[0,2,3]]
df_returns
# Out:
#            date  account_value  account_value
# 0    2020-06-03   1.000000e+06   1.000000e+06
# 1    2020-06-04   9.967819e+05   1.000021e+06
# 2    2020-06-05   9.966770e+05   9.999538e+05
# 3    2020-06-08   9.960032e+05   1.000014e+06
# 4    2020-06-09   9.962425e+05   9.998867e+05
# ..          ...            ...            ...
# 373  2021-12-16   1.305250e+06   1.258597e+06
# 374  2021-12-17   1.269085e+06   1.252392e+06
# 375  2021-12-20   1.272823e+06   1.252848e+06
# 376  2021-12-21   1.272580e+06   1.246447e+06
# 377  2021-12-22   1.248983e+06   1.244255e+06
#
# [378 rows x 3 columns]

# %%
df_returns.to_csv('727_2_df_returns.csv',index=None)

# %%
df_returns
# Out:
#            date  account_value  account_value  account_value
# 0    2020-06-03   1.000000e+06   1.000000e+06   1.000000e+06
# 1    2020-06-04   1.000022e+06   9.967819e+05   1.000021e+06
# 2    2020-06-05   9.999606e+05   9.966770e+05   9.999538e+05
# 3    2020-06-08   1.000011e+06   9.960032e+05   1.000014e+06
# 4    2020-06-09   9.998963e+05   9.962425e+05   9.998867e+05
# ..          ...            ...            ...            ...
# 373  2021-12-16   9.961447e+05   1.305250e+06   1.258597e+06
# 374  2021-12-17   9.942779e+05   1.269085e+06   1.252392e+06
# 375  2021-12-20   9.908061e+05   1.272823e+06   1.252848e+06
# 376  2021-12-21   9.969015e+05   1.272580e+06   1.246447e+06
# 377  2021-12-22   9.925928e+05   1.248983e+06   1.244255e+06
#
# [378 rows x 4 columns]

# %%
df_returns = pd.read_csv('727_2_df_returns.csv')
df_returns
# Out:
#            date          ewtf           our           td3            sac  \
# 0    2020-06-03  1.000000e+06  1.000000e+06  1000000.0000  1000000.00000
# 1    2020-06-04  9.967819e+05  1.000021e+06   999895.7090   999896.60000
# 2    2020-06-05  9.966770e+05  9.999538e+05   999791.5160   999798.29700
# 3    2020-06-08  9.960032e+05  1.000014e+06   999746.3720   999744.04000
# 4    2020-06-09  9.962425e+05  9.998867e+05   999960.2410   999969.79900
# ..          ...           ...           ...           ...            ...
# 373  2021-12-16  1.305250e+06  1.258597e+06   737824.2495   729221.23319
# 374  2021-12-17  1.269085e+06  1.252392e+06   736535.7495   727486.22319
# 375  2021-12-20  1.272823e+06  1.252848e+06   743476.2495   732907.82319
# 376  2021-12-21  1.272580e+06  1.246447e+06   759445.2495   748144.66319
# 377  2021-12-22  1.248983e+06  1.244255e+06   759278.7495   749226.07319
#
#               ppo             sse
# 0    1.000000e+06  1000000.000000
# 1    1.000000e+06   852687.254208
# 2    9.999994e+05   850176.626099
# 3    9.999994e+05   839695.238628
# 4    9.999983e+05   844020.648197
# ..            ...             ...
# 373  1.002110e+06   979986.853724
# 374  1.001381e+06   975437.367229
# 375  1.001079e+06   929100.739831
# 376  1.001533e+06   952990.690772
# 377  1.003238e+06   950674.208968
#
# [378 rows x 7 columns]

# %%
df_returns.columns = ['date','ewtf','our']
df_returns
# Out:
#            date          ewtf           our
# 0    2020-06-03  1.000000e+06  1.000000e+06
# 1    2020-06-04  9.967819e+05  1.000021e+06
# 2    2020-06-05  9.966770e+05  9.999538e+05
# 3    2020-06-08  9.960032e+05  1.000014e+06
# 4    2020-06-09  9.962425e+05  9.998867e+05
# ..          ...           ...           ...
# 373  2021-12-16  1.305250e+06  1.258597e+06
# 374  2021-12-17  1.269085e+06  1.252392e+06
# 375  2021-12-20  1.272823e+06  1.252848e+06
# 376  2021-12-21  1.272580e+06  1.246447e+06
# 377  2021-12-22  1.248983e+06  1.244255e+06
#
# [378 rows x 3 columns]

# %%
df_returns = pd.concat([df_returns,df_account_value['account_value']],axis=1)
# df_returns.columns = ['date','td3','sac','ppo','sse','ewtf']

# %%
df_returns = df_returns.reindex(columns=['date','account_value'])

# %%
df_returns.columns = ['date','td3','sac','ppo','sse','ewtf','our']

# %%
df_returns = pd.read_csv('724_df_returns.csv')

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
df_returns.to_csv('727_df_returns.csv')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (11,6))

plt.plot(df_returns['date'],df_returns['td3'],label = 'td3',color = 'dodgerblue')
plt.plot(df_returns['date'],df_returns['sac'],label = 'sac',color = 'red')
plt.plot(df_returns['date'],df_returns['ppo'],label = 'ppo',color = 'limegreen')
plt.plot(df_returns['date'],df_returns['sse'],label = 'sse',color = 'gold')
plt.plot(df_returns['date'],df_returns['ewtf'],label = 'ewtf',color = 'goldenrod')
plt.plot(df_returns['date'],df_returns['our'],label = 'our',color = 'blue')

plt.legend()
plt.title('profit vs')
plt.xlabel('date')
plt.ylabel('profit')
plt.grid()
plt.show()

# %%
df_returns.to_csv('724_df_returns.csv',index=None)

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.156839
# Cumulative returns     0.244255
# Annual volatility      0.223695
# Sharpe ratio           0.765110
# Calmar ratio           0.614446
# Stability              0.614653
# Max drawdown          -0.255253
# Omega ratio            1.164543
# Sortino ratio          1.089505
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.228038
# Daily value at risk   -0.027504
# dtype: float64

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.159768
# Cumulative returns     0.248983
# Annual volatility      0.415273
# Sharpe ratio           0.568552
# Calmar ratio           0.492134
# Stability              0.456895
# Max drawdown          -0.324643
# Omega ratio            1.109079
# Sortino ratio          0.763247
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.921253
# Daily value at risk   -0.051383
# dtype: float64

# %%
selected_tics = addfeature_df['tic'].unique()

# %%
#获取随机选择的tic在select_date的权重并修正
def get_selected_index_weight(df_index,select_date,selected_tics):
    df = df_index[df_index['trade_date'] == select_date]
    select_df = df[df['con_code'].isin(selected_tics)]
    select_df = select_df.drop('index_code',axis=1).rename(columns={'con_code':'tic','trade_date':'date'})
    select_df = select_df.reset_index()
    weight_sum = select_df['weight'].sum()
#     print(select_df)
    for i in range(len(select_df)):
        select_df.loc[i,'weight'] = (select_df.loc[i,'weight'] / weight_sum)*100
    return select_df.loc[:,['tic','date','weight']]

baseline_weight =get_selected_index_weight(df_index,select_date,selected_tics)
baseline_weight = baseline_weight.sort_values(['tic'],ascending=True).reset_index(drop=True)
print(baseline_weight)
# Out:
#          tic      date     weight
# 0  600585.SH  20200228  32.729965
# 1  600703.SH  20200228  18.002304
# 2  601390.SH  20200228  13.049202
# 3  601939.SH  20200228  13.016291
# 4  603259.SH  20200228  23.202238

# %%
#计算所选股票的buy & hold策略
def calculate_selected_baseline(df,full_date_range,selected_tics):
    df = df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
    baseline = pd.DataFrame({'date':full_date_range['date']})
    for i in range(len(full_date_range)):
        temp_date = full_date_range.loc[i,'date']
        temp_df = df[df['date'] == temp_date].sort_values('tic',ascending=True)
        close = list(temp_df['close'])
        weight = list(baseline_weight['weight'])
        baseline.loc[i,'account_value'] = sum(np.array(close) * np.array(weight)) #注意权重和收盘价对应的股票顺序
    baseline['date'] = pd.to_datetime(baseline['date'])
#     baseline.set_index("date", inplace=True, drop=True)
#     baseline.index = baseline.index.tz_localize("UTC")
    return baseline
# full_date_range = get_trading_days(exchange='SSE',start_date='20210301', end_date='20230227')
# full_date_range = full_date_range.sort_values('trade_date',ascending=True).reset_index(drop=True)
full_date_range1 = pd.DataFrame({'date':df_account_value['date'].unique()}).reset_index(drop=True)
baseline_sse = calculate_selected_baseline(addfeature_df,full_date_range1,selected_tics)
baseline_sse
# Out:
#           date  account_value
# 0   2020-06-03    5107.528057
# 1   2020-06-04    4355.124074
# 2   2020-06-05    4342.300971
# 3   2020-06-08    4288.766990
# 4   2020-06-09    4310.859141
# ..         ...            ...
# 373 2021-12-14    5300.764357
# 374 2021-12-15    4967.451703
# 375 2021-12-16    5005.310351
# 376 2021-12-17    4982.073721
# 377 2021-12-20    4745.408096
#
# [378 rows x 2 columns]

# %%
merged_df

# %%
#baseline stats
print("==============Get Baseline Stats===========")
# baseline_df = get_baseline(
#         ticker="^DJI", 
#         start = df_account_value.loc[0,'date'],
#         end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_sse, value_col_name = 'account_value')

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
from copy import deepcopy
def backtest_plot_com(
    account_value,
    baseline,
    baseline_start=TRADE_START_DATE,
    baseline_end=TRADE_END_DATE,
    value_col_name="account_value",
):
    df = deepcopy(account_value)
    df["date"] = pd.to_datetime(df["date"])
    test_returns = get_daily_return(df, value_col_name=value_col_name)
#     pro = ts.pro_api()
#     baseline_df = pro.index_daily(ts_code='000016.sh',start_date = '20200301',end_date='20230227')
#     baseline_df = baseline_df.rename(columns={'trade_date':'date'})
#     baseline_df = baseline_df.sort_values('date',ascending=True)
    baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
    with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(
            returns=test_returns, benchmark_rets=baseline_returns, set_context=False
        )

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-20</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>15.684%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>24.426%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.369%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.77</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-25.525%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.75%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.40</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>25.53</td>
#       <td>2021-01-25</td>
#       <td>2021-03-24</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.40</td>
#       <td>2020-11-16</td>
#       <td>2020-11-25</td>
#       <td>2020-12-16</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.23</td>
#       <td>2021-01-12</td>
#       <td>2021-01-15</td>
#       <td>2021-01-20</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.10</td>
#       <td>2020-08-17</td>
#       <td>2020-09-28</td>
#       <td>2020-10-29</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.28</td>
#       <td>2020-11-10</td>
#       <td>2020-11-11</td>
#       <td>2020-11-16</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.07%</td>
#       <td>-6.89%</td>
#       <td>7.47%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-20</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>15.977%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>24.898%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>41.527%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.49</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.46</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-32.464%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.76</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-5.138%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.04</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>32.46</td>
#       <td>2021-02-10</td>
#       <td>2021-08-20</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14.66</td>
#       <td>2020-11-16</td>
#       <td>2020-11-25</td>
#       <td>2020-12-17</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13.07</td>
#       <td>2020-08-05</td>
#       <td>2020-09-28</td>
#       <td>2020-11-09</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10.15</td>
#       <td>2021-01-25</td>
#       <td>2021-01-28</td>
#       <td>2021-02-10</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.55</td>
#       <td>2021-01-12</td>
#       <td>2021-01-15</td>
#       <td>2021-01-20</td>
#       <td>7</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.09%</td>
#       <td>-16.09%</td>
#       <td>9.41%</td>
#     </tr>
#   </tbody>
# </table>
