# %%
# 导入数据库
import numpy as np
import pandas as pd

# %%
#读入数据
df = pd.read_csv('50-2012-2022.csv')

# %%
# Out:
# 50

# %%
df
# Out:
#           ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0       600104.SH    20221230  14.42  14.52  14.38  14.41      14.33    0.08
# 1       600104.SH    20221229  14.56  14.60  14.33  14.33      14.63   -0.30
# 2       600104.SH    20221228  14.71  14.74  14.56  14.63      14.76   -0.13
# 3       600104.SH    20221227  14.81  14.83  14.65  14.76      14.71    0.05
# 4       600104.SH    20221226  14.67  14.76  14.63  14.71      14.67    0.04
# ...           ...         ...    ...    ...    ...    ...        ...     ...
# 122913  600030.SH    20120110   9.79  10.25   9.71  10.12       9.75    0.37
# 122914  600030.SH    20120109   9.36   9.79   9.26   9.75       9.39    0.36
# 122915  600030.SH    20120106   9.19   9.43   9.04   9.39       9.29    0.10
# 122916  600030.SH    20120105   9.52   9.72   9.20   9.29       9.56   -0.27
# 122917  600030.SH    20120104   9.79   9.85   9.56   9.56       9.71   -0.15
#
#         pct_chg        vol      amount
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df.iloc[0:3000,5]

# %%
df2 = df.loc[1:3000,'close']

# %%
#筛选条件数据
df1.min()
# Out:
# 11.35

# %%
df3 = df[df['close'] == 14.33]
df3
# Out:
#           ts_code  trade_date   open   high    low  close  pre_close  change  \
# 1       600104.SH    20221229  14.56  14.60  14.33  14.33      14.63   -0.30
# 42      600104.SH    20221102  14.02  14.35  13.96  14.33      14.11    0.22
# 46      600104.SH    20221027  14.26  14.41  14.21  14.33      14.16    0.17
# 2220    600104.SH    20131024  13.60  14.68  13.60  14.33      13.60    0.73
# 9926    600309.SH    20140709  14.74  14.74  14.31  14.33      14.75   -0.42
# 10349   600309.SH    20121009  14.25  14.69  14.18  14.33      14.25    0.08
# 17456   601857.SH    20150428  14.46  15.36  14.05  14.33      14.65   -0.32
# 27115   600703.SH    20190424  13.50  14.69  13.16  14.33      13.50    0.83
# 27239   600703.SH    20181022  13.60  14.36  13.60  14.33      13.38    0.95
# 27650   600703.SH    20170215  14.48  14.79  14.25  14.33      14.52   -0.19
# 27655   600703.SH    20170208  14.28  14.36  14.04  14.33      14.25    0.08
# ...

# %%
df2
# Out:
# 1       14.33
# 2       14.63
# 3       14.76
# 4       14.71
# 5       14.67
#         ...
# 2996    54.01
# 2997    53.67
# 2998    53.25
# 2999    53.11
# 3000    52.67
# Name: close, Length: 3000, dtype: float64
