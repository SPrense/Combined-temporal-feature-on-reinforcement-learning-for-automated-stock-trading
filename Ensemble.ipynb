# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install stable_baselines3
# !pip install yfinance
# !pip install tushare
# !pip install exchange_calendars
# !pip install wrds
# !pip install alpaca_trade_api
# !pip install stockstats
# !pip install pyfolio

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_disharpe import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)

# %%
df = pd.read_csv('merged_df.csv')
df

# %%
TRAIN_START_DATE = '2010-10-10'
TRAIN_END_DATE = '2021-02-28'
TEST_START_DATE = '2021-03-01'
TEST_END_DATE = '2023-02-28'

# %%
import tushare as ts
ts.set_token('6314756019e50a6672690e5a78b2dbf7cfcd27c6f6a6b48a8cf76dae')
pro = ts.pro_api()

# %%
#选择上证50指数的成分股
df_index = pro.index_weight(index_code='000016.sh', start_date='20121010', end_date='20220228')
# df_index.to_csv('SSE_50_index_weight.csv',index=0)

# %%
#选择某个时间点的上证50指数成分股作为参考跟踪股票池
select_date = '20200228' #自定义的时间点为每个月的月末
df_select = df_index[df_index['trade_date']==select_date]
sort_SSEindex = df_select['con_code'].unique()
print(sort_SSEindex,len(sort_SSEindex))
# Out:
# ['603993.SH' '603259.SH' '601989.SH' '601988.SH' '601939.SH' '601888.SH'
#  '601857.SH' '601818.SH' '601766.SH' '601688.SH' '601668.SH' '601628.SH'
#  '601601.SH' '601398.SH' '601390.SH' '601336.SH' '601328.SH' '601319.SH'
#  '601318.SH' '601288.SH' '601236.SH' '601211.SH' '601186.SH' '601166.SH'
#  '601138.SH' '601111.SH' '601088.SH' '601066.SH' '601012.SH' '600887.SH'
#  '600837.SH' '600703.SH' '600690.SH' '600585.SH' '600547.SH' '600519.SH'
#  '600340.SH' '600309.SH' '600276.SH' '600196.SH' '600104.SH' '600050.SH'
#  '600048.SH' '600036.SH' '600031.SH' '600030.SH' '600028.SH' '600016.SH'
#  '600009.SH' '600000.SH'] 50

# %%
#随机选择成分股中的k只股票
import random 
k = 20
selected_tics = random.sample(list(sort_SSEindex),k)
print(selected_tics)
# Out:
# ['601236.SH', '601888.SH', '601288.SH', '600703.SH', '601988.SH', '600837.SH', '600340.SH', '601211.SH', '600519.SH', '601328.SH', '601857.SH', '600196.SH', '601818.SH', '603993.SH', '600031.SH', '600009.SH', '601939.SH', '600309.SH', '601398.SH', '601066.SH']

# %%
#Download随机选择的k只股票数据
df_ts =pd.DataFrame()
for c in selected_tics:
    temp=pro.daily(ts_code=c,start_date='20121010',end_date='20230228')
    df_ts=pd.concat([df_ts,temp])
# df_ts = df_ts.sort_values(['ts_code','trade_date'],ascending=True).reset_index(drop=True)
print(df_ts)
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     601236.SH   20230228   8.50   8.56   8.45   8.56       8.47    0.09
# 1     601236.SH   20230227   8.55   8.56   8.43   8.47       8.60   -0.13
# 2     601236.SH   20230224   8.78   8.80   8.54   8.60       8.78   -0.18
# 3     601236.SH   20230223   8.66   8.88   8.66   8.78       8.67    0.11
# 4     601236.SH   20230222   8.67   8.79   8.62   8.67       8.76   -0.09
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 1135  601066.SH   20180626  11.42  11.42  11.42  11.42      10.38    1.04
# 1136  601066.SH   20180625  10.38  10.38  10.38  10.38       9.44    0.94
# 1137  601066.SH   20180622   9.44   9.44   9.44   9.44       8.58    0.86
# 1138  601066.SH   20180621   8.58   8.58   8.58   8.58       7.80    0.78
# 1139  601066.SH   20180620   6.50   7.80   6.50   7.80       5.42    2.38
#
#       pct_chg        vol      amount
# 0      1.0626  148636.62  126445.623
# 1     -1.5116  171206.38  145336.101
# 2     -2.0501  268768.77  232171.061
# 3      1.2687  482801.13  424415.857
# 4     -1.0274  276606.53  240580.465
# ...       ...        ...         ...
# 1135  10.0200  100722.67  115025.289
# 1136   9.9600   19032.04   19755.258
# 1137  10.0200    9370.87    8846.101
# 1138  10.0000    2747.19    2357.089
# 1139  43.9100    3054.33    2371.717
#
# [46486 rows x 11 columns]

# %%
# 筛选exchange_calender中每个交易节点缺失(激进)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) == k:
            processe_df.append(temp_df)
        else :
            date_unique.remove(date)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    processed_df = processed_df.sort_values(['ts_code','trade_date'],ascending=True).reset_index(drop=True)
    return processed_df,date_unique

# %%
processed_df,date_unique = processed_date(df_ts,selected_tics,k)
print(processed_df)
# Out:
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      600009.SH   20190705  80.00  82.10  79.45  81.40      79.75    1.65
# 1      600009.SH   20190708  80.73  81.00  79.00  79.79      81.40   -1.61
# 2      600009.SH   20190709  79.62  81.11  79.52  80.39      79.79    0.60
# 3      600009.SH   20190710  80.55  81.90  80.10  81.40      80.39    1.01
# 4      600009.SH   20190711  81.78  81.95  80.06  80.18      81.40   -1.22
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 17035  603993.SH   20230222   6.13   6.21   6.07   6.14       6.18   -0.04
# 17036  603993.SH   20230223   6.17   6.23   6.07   6.17       6.14    0.03
# 17037  603993.SH   20230224   6.11   6.13   5.95   5.99       6.17   -0.18
# 17038  603993.SH   20230227   5.91   5.99   5.81   5.87       5.99   -0.12
# 17039  603993.SH   20230228   5.91   5.95   5.83   5.90       5.87    0.03
#
#        pct_chg         vol       amount
# 0       2.0690   156494.97  1259765.768
# 1      -1.9779    96828.85   771884.451
# 2       0.7520    83120.78   667991.039
# 3       1.2564    80795.84   656613.506
# 4      -1.4988    60594.91   490244.704
# ...        ...         ...          ...
# 17035  -0.6472  1410719.50   867941.018
# 17036   0.4886  1472686.94   904600.802
# 17037  -2.9173  1663132.69  1000424.506
# 17038  -2.0033  1432743.70   844312.992
# 17039   0.5111   923517.82   543744.344
#
# [17040 rows x 11 columns]

# %%
def process_fillna(df,selected_tics,k):
    merge_df = []
    for tic in selected_tics:
        temp_df = df[df['ts_code']==tic]
        temp_df = temp_df.reset_index().sort_values('trade_date',ascending=True)
        temp_df = temp_df.fillna({
            'amount' : 0,
            'vol': 0,
            'pct_chg': 0,
            'change':0,
            'ts_code': tic
        })
        for i in range(len(temp_df)):
            if pd.isna(temp_df.loc[i,'close']):
                j = i +1
                while pd.isna(temp_df.loc[j,'close']):
                    j = j + 1
                if j < len(temp_df) :
                    temp_df.loc[i,['close','open','high','low','pre_close']] = temp_df.loc[j,'close']
        merge_df.append(temp_df)
    merged_df = pd.concat(merge_df,ignore_index = True)
    return merged_df

# %%
merged_df = process_fillna(processed_df,selected_tics,k)
merged_df = merged_df.drop('index',axis=1)
merged_df
# Out:
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      601236.SH   20190705   4.15   4.98   4.15   4.98       3.46    1.52
# 1      601236.SH   20190708   5.48   5.48   5.48   5.48       4.98    0.50
# 2      601236.SH   20190709   6.03   6.03   6.03   6.03       5.48    0.55
# 3      601236.SH   20190710   6.63   6.63   6.63   6.63       6.03    0.60
# 4      601236.SH   20190711   7.29   7.29   7.29   7.29       6.63    0.66
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 17035  601066.SH   20230222  26.94  27.30  26.59  26.78      27.10   -0.32
# 17036  601066.SH   20230223  26.79  27.38  26.79  26.97      26.78    0.19
# 17037  601066.SH   20230224  26.95  26.95  26.46  26.51      26.97   -0.46
# 17038  601066.SH   20230227  26.31  26.55  26.01  26.28      26.51   -0.23
# 17039  601066.SH   20230228  26.37  26.78  26.30  26.78      26.28    0.50
#
#        pct_chg        vol      amount
# 0      43.9306    2634.71    1310.841
# 1      10.0402    1839.56    1008.079
# 2      10.0365    2143.79    1292.705
# 3       9.9502    5273.42    3496.277
# 4       9.9548   10041.54    7320.283
# ...        ...        ...         ...
# 17035  -1.1808  201843.24  543373.383
# 17036   0.7095  211560.66  573233.966
# 17037  -1.7056  148496.45  395452.799
# 17038  -0.8676  126334.77  332522.232
# 17039   1.9026  112074.86  297547.812
#
# [17040 rows x 11 columns]

# %%
# merged_df = merged_df.drop('volume',axis=1)
merged_df = merged_df.rename(columns={'trade_date':'date','ts_code':'tic','vol':'volume'})
merged_df = merged_df[['tic','date','open','high','low','close','pre_close','change','pct_chg','volume','amount']]
# merged_df = merged_df.drop('index',axis=1)
merged_df = merged_df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
print(merged_df)
# Out:
#              tic      date   open   high    low  close  pre_close  change  \
# 0      600009.SH  20190705  80.00  82.10  79.45  81.40      79.75    1.65
# 1      600009.SH  20190708  80.73  81.00  79.00  79.79      81.40   -1.61
# 2      600009.SH  20190709  79.62  81.11  79.52  80.39      79.79    0.60
# 3      600009.SH  20190710  80.55  81.90  80.10  81.40      80.39    1.01
# 4      600009.SH  20190711  81.78  81.95  80.06  80.18      81.40   -1.22
# ...          ...       ...    ...    ...    ...    ...        ...     ...
# 17035  603993.SH  20230222   6.13   6.21   6.07   6.14       6.18   -0.04
# 17036  603993.SH  20230223   6.17   6.23   6.07   6.17       6.14    0.03
# 17037  603993.SH  20230224   6.11   6.13   5.95   5.99       6.17   -0.18
# 17038  603993.SH  20230227   5.91   5.99   5.81   5.87       5.99   -0.12
# 17039  603993.SH  20230228   5.91   5.95   5.83   5.90       5.87    0.03
#
#        pct_chg      volume       amount
# 0       2.0690   156494.97  1259765.768
# 1      -1.9779    96828.85   771884.451
# 2       0.7520    83120.78   667991.039
# 3       1.2564    80795.84   656613.506
# 4      -1.4988    60594.91   490244.704
# ...        ...         ...          ...
# 17035  -0.6472  1410719.50   867941.018
# 17036   0.4886  1472686.94   904600.802
# 17037  -2.9173  1663132.69  1000424.506
# 17038  -2.0033  1432743.70   844312.992
# 17039   0.5111   923517.82   543744.344
#
# [17040 rows x 11 columns]

# %%
merged_df[merged_df['date']=='2020']

# %%
df.tail()

# %%
df.shape

# %%
df.sort_values(['date','tic']).head()

# %%
len(df.tic.unique())

# %%
df.tic.value_counts()

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=False,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.add_technical_indicator(merged_df)
processed = fe.add_turbulence(processed)
processed = processed.fillna(method="ffill").fillna(method="bfill")

# %%
import datetime
processed['date'] = pd.to_datetime(processed['date'],format='%Y%m%d')
processed
# Out:
#              tic       date    open    high     low   close  pre_close  \
# 0      600009.SH 2019-07-05   80.00   82.10   79.45   81.40      79.75
# 1      600031.SH 2019-07-05   12.89   12.94   12.77   12.87      12.86
# 2      600196.SH 2019-07-05   26.68   26.94   26.58   26.81      26.51
# 3      600309.SH 2019-07-05   43.06   43.70   42.68   43.48      42.86
# 4      600340.SH 2019-07-05   33.29   33.29   32.35   32.72      33.39
# ...          ...        ...     ...     ...     ...     ...        ...
# 17035  601857.SH 2023-02-28    5.22    5.23    5.19    5.23       5.21
# 17036  601888.SH 2023-02-28  198.30  199.29  194.91  197.58     197.31
# 17037  601939.SH 2023-02-28    5.60    5.64    5.59    5.64       5.59
# 17038  601988.SH 2023-02-28    3.22    3.23    3.21    3.23       3.21
# 17039  603993.SH 2023-02-28    5.91    5.95    5.83    5.90       5.87
#
#        change  pct_chg     volume       amount      macd     boll_ub  \
# 0        1.65   2.0690  156494.97  1259765.768  0.000000   82.871884
# 1        0.01   0.0778  472956.33   607638.106  0.000000   82.871884
# 2        0.30   1.1316  130610.00   350094.412  0.000000   82.871884
# 3        0.62   1.4466  135936.40   589678.234  0.000000   82.871884
# 4       -0.67  -2.0066  127041.89   416496.783  0.000000   82.871884
# ...       ...      ...        ...          ...       ...         ...
# 17035    0.02   0.3839  780918.59   407149.028  0.034798    5.268681
# 17036    0.27   0.1368   88489.10  1739191.785 -4.807180  214.190900
# 17037    0.05   0.8945  349951.06   196505.114  0.003892    5.644186
# 17038    0.02   0.6231  853848.32   274898.437  0.009230    3.244136
# 17039    0.03   0.5111  923517.82   543744.344  0.209411    6.182979
#
#           boll_lb     rsi_30     cci_30       dx_30  close_30_sma  \
# 0       78.318116   0.000000 -66.666667  100.000000     81.400000
# 1       78.318116   0.000000 -66.666667  100.000000     12.870000
# 2       78.318116   0.000000 -66.666667  100.000000     26.810000
# 3       78.318116   0.000000 -66.666667  100.000000     43.480000
# 4       78.318116   0.000000 -66.666667  100.000000     32.720000
# ...           ...        ...        ...         ...           ...
# 17035    5.107319  55.051080  74.675995   37.378042      5.160333
# 17036  194.433100  44.255329 -95.615136   30.966717    211.779333
# 17037    5.558814  53.841443  34.768020   24.251462      5.608000
# 17038    3.186864  56.543761  30.502269   23.055244      3.215000
# 17039    5.643021  60.253829  45.218795   25.030849      5.633000
#
#        close_60_sma  turbulence
# 0         81.400000    0.000000
# 1         12.870000    0.000000
# 2         26.810000    0.000000
# 3         43.480000    0.000000
# 4         32.720000    0.000000
# ...             ...         ...
# 17035      5.118167    3.985424
# 17036    213.524500    3.985424
# 17037      5.598500    3.985424
# 17038      3.183500    3.985424
# 17039      5.172000    3.985424
#
# [17040 rows x 20 columns]

# %%
list_ticker = processed["tic"].unique().tolist()
# list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
# combination = list(itertools.product(list_date,list_ticker))

# processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
# processed_full = processed_full[processed_full['date'].isin(processed['date'])]
# processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 201

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
TEST_END_DATE
# Out:
# '2023-02-28'

# %%
SAC_model_kwargs = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
                }

PPO_model_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
                    }

TD3_model_kwargs = {
    "batch_size": 100, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
                }

timesteps_dict = {'sac' : 10000, 
                 'ppo' : 10000, 
                 'td3' : 10000
                 }

# %%
import torch
device = torch.device("mps")

# %%
df_summary = ensemble_agent.run_ensemble_strategy_com(SAC_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  79.02797945050015
# ======Model training from:  2010-10-10 to  2021-03-02T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_8
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 147      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 1564     |
# | train/             |          |
# |    actor_loss      | 1.65e+03 |
# |    critic_loss     | 1.42e+04 |
# |    ent_coef        | 0.115    |
# |    ent_coef_loss   | 553      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1463     |
# |    reward          | 0.333439 |
# ---------------------------------
# day: 390, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1247374.28
# total_reward: 247374.28
# total_cost: 1291.02
# total_trades: 3223
# Sharpe: 0.639
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 142       |
# |    time_elapsed    | 21        |
# |    total_timesteps | 3128      |
# | train/             |           |
# |    actor_loss      | 1.59e+03  |
# |    critic_loss     | 1.17e+03  |
# |    ent_coef        | 0.134     |
# |    ent_coef_loss   | 514       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3027      |
# |    reward          | -0.014228 |
# ----------------------------------
# day: 390, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1423979.37
# total_reward: 423979.37
# total_cost: 1560.68
# total_trades: 3604
# Sharpe: 0.886
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 141      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 4692     |
# | train/             |          |
# |    actor_loss      | 1.74e+03 |
# |    critic_loss     | 470      |
# |    ent_coef        | 0.156    |
# |    ent_coef_loss   | 474      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4591     |
# |    reward          | 0.756231 |
# ---------------------------------
# day: 390, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1423979.37
# total_reward: 423979.37
# total_cost: 1560.68
# total_trades: 3604
# Sharpe: 0.886
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 140      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 6256     |
# | train/             |          |
# |    actor_loss      | 1.91e+03 |
# |    critic_loss     | 1.28e+03 |
# |    ent_coef        | 0.183    |
# |    ent_coef_loss   | 435      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6155     |
# |    reward          | 0.756209 |
# ---------------------------------
# day: 390, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1423979.37
# total_reward: 423979.37
# total_cost: 1560.68
# total_trades: 3604
# Sharpe: 0.886
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 139      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 7820     |
# | train/             |          |
# |    actor_loss      | 2.19e+03 |
# |    critic_loss     | 1.29e+03 |
# |    ent_coef        | 0.214    |
# |    ent_coef_loss   | 394      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7719     |
# |    reward          | 0.756209 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 140      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 9384     |
# | train/             |          |
# |    actor_loss      | 2.34e+03 |
# |    critic_loss     | 2.03e+03 |
# |    ent_coef        | 0.25     |
# |    ent_coef_loss   | 354      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9283     |
# |    reward          | 4.165931 |
# ---------------------------------
# day: 390, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1924584.45
# total_reward: 924584.45
# total_cost: 1028.40
# total_trades: 4306
# Sharpe: 1.437
# =================================
# ======SAC Validation from:  2021-03-02T00:00:00.000000000 to  2021-06-03T00:00:00.000000000
# SAC Sharpe Ratio:  0.18536399817849888
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_6
# day: 390, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1276372.51
# total_reward: 276372.51
# total_cost: 41449.08
# total_trades: 7561
# Sharpe: 1.142
# =================================
# -------------------------------------
# | time/              |              |
# |    fps             | 1231         |
# |    iterations      | 1            |
# |    time_elapsed    | 1            |
# |    total_timesteps | 2048         |
# | train/             |              |
# |    reward          | -0.032508083 |
# -------------------------------------
# day: 390, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1621211.34
# total_reward: 621211.34
# total_cost: 42979.34
# total_trades: 7484
# Sharpe: 1.513
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011698136 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.011       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.29        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0126     |
# |    reward               | -0.10434817 |
# |    std                  | 1           |
# |    value_loss           | 18.2        |
# -----------------------------------------
# day: 390, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1219921.62
# total_reward: 219921.62
# total_cost: 41621.17
# total_trades: 7376
# Sharpe: 0.787
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1122        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009171622 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.00326     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.23        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | -0.28090456 |
# |    std                  | 1           |
# |    value_loss           | 18          |
# -----------------------------------------
# day: 390, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1447885.17
# total_reward: 447885.17
# total_cost: 40672.01
# total_trades: 7371
# Sharpe: 1.178
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1119        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012607455 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00603    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.47        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | -2.3958457  |
# |    std                  | 1           |
# |    value_loss           | 11.9        |
# -----------------------------------------
# day: 390, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1392105.84
# total_reward: 392105.84
# total_cost: 42243.78
# total_trades: 7412
# Sharpe: 1.098
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1114         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0077625914 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | -0.00207     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.8         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0132      |
# |    reward               | 1.9021671    |
# |    std                  | 1.01         |
# |    value_loss           | 20.8         |
# ------------------------------------------
# ======PPO Validation from:  2021-03-02T00:00:00.000000000 to  2021-06-03T00:00:00.000000000
# PPO Sharpe Ratio:  0.1653104470030351
# ======TD3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_6
# day: 390, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 2322749.87
# total_reward: 1322749.87
# total_cost: 1971.67
# total_trades: 2936
# Sharpe: 1.913
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 233      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1564     |
# | train/             |          |
# |    actor_loss      | 191      |
# |    critic_loss     | 777      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1173     |
# |    reward          | 8.03411  |
# ---------------------------------
# day: 390, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2623858.88
# total_reward: 1623858.88
# total_cost: 7450.02
# total_trades: 2988
# Sharpe: 1.751
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 211      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 3128     |
# | train/             |          |
# |    actor_loss      | 155      |
# |    critic_loss     | 3.79e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2737     |
# |    reward          | 8.03411  |
# ---------------------------------
# day: 390, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 2623858.88
# total_reward: 1623858.88
# total_cost: 7450.02
# total_trades: 2988
# Sharpe: 1.751
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 205      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 4692     |
# | train/             |          |
# |    actor_loss      | 154      |
# |    critic_loss     | 1.06e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4301     |
# |    reward          | 8.03411  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 201      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 6256     |
# | train/             |          |
# |    actor_loss      | 147      |
# |    critic_loss     | 130      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5865     |
# |    reward          | 8.03411  |
# ---------------------------------
# day: 390, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 2623858.88
# total_reward: 1623858.88
# total_cost: 7450.02
# total_trades: 2988
# Sharpe: 1.751
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 200      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 7820     |
# | train/             |          |
# |    actor_loss      | 137      |
# |    critic_loss     | 119      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7429     |
# |    reward          | 8.03411  |
# ---------------------------------
# day: 390, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 2623858.88
# total_reward: 1623858.88
# total_cost: 7450.02
# total_trades: 2988
# Sharpe: 1.751
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 198      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 9384     |
# | train/             |          |
# |    actor_loss      | 127      |
# |    critic_loss     | 902      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8993     |
# |    reward          | 8.03411  |
# ---------------------------------
# ======TD3 Validation from:  2021-03-02T00:00:00.000000000 to  2021-06-03T00:00:00.000000000
# ======Best Model Retraining from:  2010-10-10 to  2021-06-03T00:00:00.000000000
# ======Trading from:  2021-06-03T00:00:00.000000000 to  2021-10-12T00:00:00.000000000
# ============================================
# turbulence_threshold:  79.02797945050015
# ======Model training from:  2010-10-10 to  2021-06-03T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_6
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 143        |
# |    time_elapsed    | 12         |
# |    total_timesteps | 1816       |
# | train/             |            |
# |    actor_loss      | 741        |
# |    critic_loss     | 2.67e+04   |
# |    ent_coef        | 0.113      |
# |    ent_coef_loss   | 207        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 1715       |
# |    reward          | -1.7018564 |
# -----------------------------------
# day: 453, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1360106.43
# total_reward: 360106.43
# total_cost: 22829.42
# total_trades: 6405
# Sharpe: 0.743
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 141        |
# |    time_elapsed    | 25         |
# |    total_timesteps | 3632       |
# | train/             |            |
# |    actor_loss      | 676        |
# |    critic_loss     | 4.02e+03   |
# |    ent_coef        | 0.129      |
# |    ent_coef_loss   | 171        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 3531       |
# |    reward          | -2.8220057 |
# -----------------------------------
# day: 453, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1551866.74
# total_reward: 551866.74
# total_cost: 28279.90
# total_trades: 6530
# Sharpe: 0.933
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 140       |
# |    time_elapsed    | 38        |
# |    total_timesteps | 5448      |
# | train/             |           |
# |    actor_loss      | 643       |
# |    critic_loss     | 842       |
# |    ent_coef        | 0.152     |
# |    ent_coef_loss   | 134       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5347      |
# |    reward          | -2.530357 |
# ----------------------------------
# day: 453, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1981874.90
# total_reward: 981874.90
# total_cost: 17812.74
# total_trades: 5645
# Sharpe: 1.145
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 140        |
# |    time_elapsed    | 51         |
# |    total_timesteps | 7264       |
# | train/             |            |
# |    actor_loss      | 710        |
# |    critic_loss     | 1.38e+03   |
# |    ent_coef        | 0.181      |
# |    ent_coef_loss   | 122        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7163       |
# |    reward          | -2.9185638 |
# -----------------------------------
# day: 453, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1636844.72
# total_reward: 636844.72
# total_cost: 14069.55
# total_trades: 5083
# Sharpe: 1.058
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 139        |
# |    time_elapsed    | 64         |
# |    total_timesteps | 9080       |
# | train/             |            |
# |    actor_loss      | 779        |
# |    critic_loss     | 931        |
# |    ent_coef        | 0.216      |
# |    ent_coef_loss   | 98.5       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 8979       |
# |    reward          | -1.3629813 |
# -----------------------------------
# ======SAC Validation from:  2021-06-03T00:00:00.000000000 to  2021-10-12T00:00:00.000000000
# SAC Sharpe Ratio:  -0.15123242081748006
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_5
# day: 453, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1310238.96
# total_reward: 310238.96
# total_cost: 47383.87
# total_trades: 8684
# Sharpe: 0.787
# =================================
# -----------------------------------
# | time/              |            |
# |    fps             | 1119       |
# |    iterations      | 1          |
# |    time_elapsed    | 1          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.63295084 |
# -----------------------------------
# day: 453, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1253725.79
# total_reward: 253725.79
# total_cost: 47271.38
# total_trades: 8546
# Sharpe: 0.752
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1050        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012194276 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00575    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.6         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0159     |
# |    reward               | 0.28102952  |
# |    std                  | 1           |
# |    value_loss           | 11          |
# -----------------------------------------
# day: 453, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1375191.99
# total_reward: 375191.99
# total_cost: 50265.88
# total_trades: 8684
# Sharpe: 1.242
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1042        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009888509 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00251    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.74        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0111     |
# |    reward               | 4.3401184   |
# |    std                  | 1           |
# |    value_loss           | 11.6        |
# -----------------------------------------
# day: 453, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1207081.15
# total_reward: 207081.15
# total_cost: 50862.51
# total_trades: 8693
# Sharpe: 0.578
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1033        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012616052 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.0206      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.4         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0127     |
# |    reward               | -0.24120887 |
# |    std                  | 1.01        |
# |    value_loss           | 17.1        |
# -----------------------------------------
# day: 453, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1621149.49
# total_reward: 621149.49
# total_cost: 48823.06
# total_trades: 8587
# Sharpe: 1.098
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007840008 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00924    |
# |    reward               | 2.3581524   |
# |    std                  | 1.01        |
# |    value_loss           | 20          |
# -----------------------------------------
# ======PPO Validation from:  2021-06-03T00:00:00.000000000 to  2021-10-12T00:00:00.000000000
# PPO Sharpe Ratio:  0.07390124156358993
# ======TD3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_5
# day: 453, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 695993.58
# total_reward: -304006.42
# total_cost: 999.00
# total_trades: 3171
# Sharpe: -0.669
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 230      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 1816     |
# | train/             |          |
# |    actor_loss      | 21.1     |
# |    critic_loss     | 155      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1362     |
# |    reward          | 0.07946  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 206      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 3632     |
# | train/             |          |
# |    actor_loss      | 34       |
# |    critic_loss     | 2.03e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3178     |
# |    reward          | 0.07946  |
# ---------------------------------
# day: 453, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 695993.58
# total_reward: -304006.42
# total_cost: 999.00
# total_trades: 3171
# Sharpe: -0.669
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 198      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 5448     |
# | train/             |          |
# |    actor_loss      | 63.4     |
# |    critic_loss     | 582      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4994     |
# |    reward          | 0.07946  |
# ---------------------------------
# day: 453, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 695993.58
# total_reward: -304006.42
# total_cost: 999.00
# total_trades: 3171
# Sharpe: -0.669
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 195      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 7264     |
# | train/             |          |
# |    actor_loss      | 68.4     |
# |    critic_loss     | 5.18e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6810     |
# |    reward          | 0.07946  |
# ---------------------------------
# day: 453, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 695993.58
# total_reward: -304006.42
# total_cost: 999.00
# total_trades: 3171
# Sharpe: -0.669
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 193      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 9080     |
# | train/             |          |
# |    actor_loss      | 66       |
# |    critic_loss     | 21.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8626     |
# |    reward          | 0.07946  |
# ---------------------------------
# ======TD3 Validation from:  2021-06-03T00:00:00.000000000 to  2021-10-12T00:00:00.000000000
# ======Best Model Retraining from:  2010-10-10 to  2021-10-12T00:00:00.000000000
# ======Trading from:  2021-10-12T00:00:00.000000000 to  2022-01-10T00:00:00.000000000
# ============================================
# turbulence_threshold:  79.02797945050015
# ======Model training from:  2010-10-10 to  2021-10-12T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_252_4
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 147        |
# |    time_elapsed    | 14         |
# |    total_timesteps | 2068       |
# | train/             |            |
# |    actor_loss      | -131       |
# |    critic_loss     | 6.42e+03   |
# |    ent_coef        | 0.115      |
# |    ent_coef_loss   | 272        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 1967       |
# |    reward          | -1.9655857 |
# -----------------------------------
# day: 516, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1314142.65
# total_reward: 314142.65
# total_cost: 63106.27
# total_trades: 8442
# Sharpe: 0.569
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 144       |
# |    time_elapsed    | 28        |
# |    total_timesteps | 4136      |
# | train/             |           |
# |    actor_loss      | -184      |
# |    critic_loss     | 2.7e+03   |
# |    ent_coef        | 0.137     |
# |    ent_coef_loss   | 230       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4035      |
# |    reward          | 1.7820703 |
# ----------------------------------
# day: 516, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1155699.10
# total_reward: 155699.10
# total_cost: 14390.64
# total_trades: 8121
# Sharpe: 0.402
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 143        |
# |    time_elapsed    | 43         |
# |    total_timesteps | 6204       |
# | train/             |            |
# |    actor_loss      | -91.5      |
# |    critic_loss     | 604        |
# |    ent_coef        | 0.166      |
# |    ent_coef_loss   | 170        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 6103       |
# |    reward          | -1.2211214 |
# -----------------------------------
# day: 516, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1322307.45
# total_reward: 322307.45
# total_cost: 11788.36
# total_trades: 6981
# Sharpe: 0.661
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 143        |
# |    time_elapsed    | 57         |
# |    total_timesteps | 8272       |
# | train/             |            |
# |    actor_loss      | 9.19       |
# |    critic_loss     | 1e+03      |
# |    ent_coef        | 0.198      |
# |    ent_coef_loss   | 91.7       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 8171       |
# |    reward          | -1.4050411 |
# -----------------------------------
# ======SAC Validation from:  2021-10-12T00:00:00.000000000 to  2022-01-10T00:00:00.000000000
# SAC Sharpe Ratio:  0.027036499944141486
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_3
# ----------------------------------
# | time/              |           |
# |    fps             | 1063      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | -1.531931 |
# ----------------------------------
# day: 516, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1588182.29
# total_reward: 588182.29
# total_cost: 55699.84
# total_trades: 9845
# Sharpe: 1.012
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1009        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008988792 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00175    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00926    |
# |    reward               | -0.08861596 |
# |    std                  | 0.999       |
# |    value_loss           | 23.6        |
# -----------------------------------------
# day: 516, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1781425.42
# total_reward: 781425.42
# total_cost: 54858.15
# total_trades: 9973
# Sharpe: 0.974
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 984         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013851541 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.00203     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.61        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0138     |
# |    reward               | -3.67382    |
# |    std                  | 1           |
# |    value_loss           | 21.7        |
# -----------------------------------------
# day: 516, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1353846.94
# total_reward: 353846.94
# total_cost: 58318.85
# total_trades: 9897
# Sharpe: 0.761
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 977         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014454527 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00797    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.014      |
# |    reward               | 2.9342082   |
# |    std                  | 1           |
# |    value_loss           | 42.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 975        |
# |    iterations           | 5          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.011761   |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.4      |
# |    explained_variance   | 0.00157    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 11         |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0142    |
# |    reward               | 0.75888455 |
# |    std                  | 1          |
# |    value_loss           | 22.1       |
# ----------------------------------------
# ======PPO Validation from:  2021-10-12T00:00:00.000000000 to  2022-01-10T00:00:00.000000000
# PPO Sharpe Ratio:  0.101297780189465
# ======TD3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_252_3
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 239      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2068     |
# | train/             |          |
# |    actor_loss      | 694      |
# |    critic_loss     | 9.29e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1551     |
# |    reward          | 1.955741 |
# ---------------------------------
# day: 516, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1530099.85
# total_reward: 530099.85
# total_cost: 1125.56
# total_trades: 4675
# Sharpe: 0.816
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 210      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 4136     |
# | train/             |          |
# |    actor_loss      | 561      |
# |    critic_loss     | 2.54e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3619     |
# |    reward          | 1.955741 |
# ---------------------------------
# day: 516, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1530099.85
# total_reward: 530099.85
# total_cost: 1125.56
# total_trades: 4675
# Sharpe: 0.816
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 201      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 6204     |
# | train/             |          |
# |    actor_loss      | 501      |
# |    critic_loss     | 5.76e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5687     |
# |    reward          | 1.955741 |
# ---------------------------------
# day: 516, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1530099.85
# total_reward: 530099.85
# total_cost: 1125.56
# total_trades: 4675
# Sharpe: 0.816
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 197      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 8272     |
# | train/             |          |
# |    actor_loss      | 478      |
# |    critic_loss     | 2.59e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7755     |
# |    reward          | 1.955741 |
# ---------------------------------
# day: 516, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1530099.85
# total_reward: 530099.85
# total_cost: 1125.56
# total_trades: 4675
# Sharpe: 0.816
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 195      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 10340    |
# | train/             |          |
# |    actor_loss      | 451      |
# |    critic_loss     | 998      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9823     |
# |    reward          | 1.955741 |
# ---------------------------------
# ======TD3 Validation from:  2021-10-12T00:00:00.000000000 to  2022-01-10T00:00:00.000000000
# ======Best Model Retraining from:  2010-10-10 to  2022-01-10T00:00:00.000000000
# ======Trading from:  2022-01-10T00:00:00.000000000 to  2022-04-20T00:00:00.000000000
# ============================================
# turbulence_threshold:  79.02797945050015
# ======Model training from:  2010-10-10 to  2022-01-10T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_2
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 140      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2320     |
# | train/             |          |
# |    actor_loss      | 866      |
# |    critic_loss     | 2.49e+03 |
# |    ent_coef        | 0.119    |
# |    ent_coef_loss   | 250      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2219     |
# |    reward          | 2.784223 |
# ---------------------------------
# day: 579, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1015959.90
# total_reward: 15959.90
# total_cost: 13460.47
# total_trades: 7716
# Sharpe: 0.164
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 138        |
# |    time_elapsed    | 33         |
# |    total_timesteps | 4640       |
# | train/             |            |
# |    actor_loss      | 819        |
# |    critic_loss     | 1.66e+03   |
# |    ent_coef        | 0.145      |
# |    ent_coef_loss   | 173        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 4539       |
# |    reward          | -1.8120708 |
# -----------------------------------
# day: 579, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1523106.39
# total_reward: 523106.39
# total_cost: 46524.43
# total_trades: 8670
# Sharpe: 0.756
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 137       |
# |    time_elapsed    | 50        |
# |    total_timesteps | 6960      |
# | train/             |           |
# |    actor_loss      | 845       |
# |    critic_loss     | 1.63e+03  |
# |    ent_coef        | 0.178     |
# |    ent_coef_loss   | 109       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6859      |
# |    reward          | 1.0076602 |
# ----------------------------------
# day: 579, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1607382.39
# total_reward: 607382.39
# total_cost: 20352.09
# total_trades: 7411
# Sharpe: 0.789
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 136        |
# |    time_elapsed    | 67         |
# |    total_timesteps | 9280       |
# | train/             |            |
# |    actor_loss      | 934        |
# |    critic_loss     | 1.05e+03   |
# |    ent_coef        | 0.215      |
# |    ent_coef_loss   | 76.9       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 9179       |
# |    reward          | 0.07026344 |
# -----------------------------------
# ======SAC Validation from:  2022-01-10T00:00:00.000000000 to  2022-04-20T00:00:00.000000000
# SAC Sharpe Ratio:  -0.09701039267391424
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_2
# day: 579, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1188626.03
# total_reward: 188626.03
# total_cost: 67843.98
# total_trades: 11143
# Sharpe: 0.553
# =================================
# ------------------------------------
# | time/              |             |
# |    fps             | 960         |
# |    iterations      | 1           |
# |    time_elapsed    | 2           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.78225654 |
# ------------------------------------
# day: 579, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1184770.02
# total_reward: 184770.02
# total_cost: 65474.65
# total_trades: 10989
# Sharpe: 0.472
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 933         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011966454 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.51        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    reward               | -0.6774193  |
# |    std                  | 1           |
# |    value_loss           | 17.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008785696 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | -0.017      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.74        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.011      |
# |    reward               | 0.39241007  |
# |    std                  | 1           |
# |    value_loss           | 17.8        |
# -----------------------------------------
# day: 579, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1364467.62
# total_reward: 364467.62
# total_cost: 68685.59
# total_trades: 11065
# Sharpe: 0.728
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010556767 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | -0.00243    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0118     |
# |    reward               | -1.0679874  |
# |    std                  | 1.01        |
# |    value_loss           | 22.4        |
# -----------------------------------------
# day: 579, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1328673.32
# total_reward: 328673.32
# total_cost: 64866.84
# total_trades: 10978
# Sharpe: 0.700
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 910         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009327565 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.000246    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00893    |
# |    reward               | 2.3042963   |
# |    std                  | 1.01        |
# |    value_loss           | 23.4        |
# -----------------------------------------
# ======PPO Validation from:  2022-01-10T00:00:00.000000000 to  2022-04-20T00:00:00.000000000
# PPO Sharpe Ratio:  -0.20688987823542382
# ======TD3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_2
# day: 579, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1476647.15
# total_reward: 476647.15
# total_cost: 1059.78
# total_trades: 7061
# Sharpe: 0.700
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 224      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2320     |
# | train/             |          |
# |    actor_loss      | 35.6     |
# |    critic_loss     | 2.08e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1740     |
# |    reward          | 0.21007  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 200      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 4640     |
# | train/             |          |
# |    actor_loss      | -2.29    |
# |    critic_loss     | 6.61e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4060     |
# |    reward          | 0.21007  |
# ---------------------------------
# day: 579, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1476647.15
# total_reward: 476647.15
# total_cost: 1059.78
# total_trades: 7061
# Sharpe: 0.700
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 194      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 6960     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 1.39e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6380     |
# |    reward          | 0.21007  |
# ---------------------------------
# day: 579, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1476647.15
# total_reward: 476647.15
# total_cost: 1059.78
# total_trades: 7061
# Sharpe: 0.700
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 190      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 9280     |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 359      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8700     |
# |    reward          | 0.21007  |
# ---------------------------------
# ======TD3 Validation from:  2022-01-10T00:00:00.000000000 to  2022-04-20T00:00:00.000000000
# ======Best Model Retraining from:  2010-10-10 to  2022-04-20T00:00:00.000000000
# ======Trading from:  2022-04-20T00:00:00.000000000 to  2022-07-22T00:00:00.000000000
# ============================================
# turbulence_threshold:  79.02797945050015
# ======Model training from:  2010-10-10 to  2022-04-20T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# ...
# begin_total_asset: 1000000.00
# end_total_asset: 1296980.85
# total_reward: 296980.85
# total_cost: 76909.06
# total_trades: 12147
# Sharpe: 0.578
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 898         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012935318 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00874    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.43        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0161     |
# |    reward               | 0.83971316  |
# |    std                  | 1           |
# |    value_loss           | 16.5        |
# -----------------------------------------
# day: 642, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1526294.02
# total_reward: 526294.02
# total_cost: 77128.78
# total_trades: 12125
# Sharpe: 0.808
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 885         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010280955 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.0136     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0109     |
# |    reward               | -0.4731525  |
# |    std                  | 1           |
# |    value_loss           | 27.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012556465 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.00385    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0138     |
# |    reward               | 0.04877584  |
# |    std                  | 1           |
# |    value_loss           | 29.4        |
# -----------------------------------------
# day: 642, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1162806.46
# total_reward: 162806.46
# total_cost: 76190.18
# total_trades: 12144
# Sharpe: 0.366
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011907028 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.00326     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | -0.47260857 |
# |    std                  | 1           |
# |    value_loss           | 27.9        |
# -----------------------------------------
# ======PPO Validation from:  2022-04-20T00:00:00.000000000 to  2022-07-22T00:00:00.000000000
# PPO Sharpe Ratio:  0.45967185057617815
# ======TD3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_378_2
# day: 642, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1176887.38
# total_reward: 176887.38
# total_cost: 1082.01
# total_trades: 9052
# Sharpe: 0.359
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 230       |
# |    time_elapsed    | 11        |
# |    total_timesteps | 2572      |
# | train/             |           |
# |    actor_loss      | -162      |
# |    critic_loss     | 3.87e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1929      |
# |    reward          | -1.704818 |
# ----------------------------------
# day: 642, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1176887.38
# total_reward: 176887.38
# total_cost: 1082.01
# total_trades: 9052
# Sharpe: 0.359
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 204       |
# |    time_elapsed    | 25        |
# |    total_timesteps | 5144      |
# | train/             |           |
# |    actor_loss      | -107      |
# |    critic_loss     | 1.9e+03   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4501      |
# |    reward          | -1.704818 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 196       |
# |    time_elapsed    | 39        |
# |    total_timesteps | 7716      |
# | train/             |           |
# |    actor_loss      | -87.8     |
# |    critic_loss     | 371       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7073      |
# |    reward          | -1.704818 |
# ----------------------------------
# day: 642, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1176887.38
# total_reward: 176887.38
# total_cost: 1082.01
# total_trades: 9052
# Sharpe: 0.359
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 193       |
# |    time_elapsed    | 53        |
# |    total_timesteps | 10288     |
# | train/             |           |
# |    actor_loss      | -67       |
# |    critic_loss     | 35.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9645      |
# |    reward          | -1.704818 |
# ----------------------------------
# ======TD3 Validation from:  2022-04-20T00:00:00.000000000 to  2022-07-22T00:00:00.000000000
# ======Best Model Retraining from:  2010-10-10 to  2022-07-22T00:00:00.000000000
# ======Trading from:  2022-07-22T00:00:00.000000000 to  2022-10-27T00:00:00.000000000
# ============================================
# turbulence_threshold:  79.02797945050015
# ======Model training from:  2010-10-10 to  2022-07-22T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_441_2
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 136       |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2824      |
# | train/             |           |
# |    actor_loss      | 256       |
# |    critic_loss     | 175       |
# |    ent_coef        | 0.126     |
# |    ent_coef_loss   | 289       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2723      |
# |    reward          | -0.772608 |
# ----------------------------------
# day: 705, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 806585.06
# total_reward: -193414.94
# total_cost: 2746.32
# total_trades: 8707
# Sharpe: -0.079
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 133       |
# |    time_elapsed    | 42        |
# |    total_timesteps | 5648      |
# | train/             |           |
# |    actor_loss      | 442       |
# |    critic_loss     | 45.7      |
# |    ent_coef        | 0.161     |
# |    ent_coef_loss   | 162       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5547      |
# |    reward          | -0.897692 |
# ----------------------------------
# day: 705, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 741397.84
# total_reward: -258602.16
# total_cost: 9343.31
# total_trades: 9250
# Sharpe: -0.116
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 131      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 8472     |
# | train/             |          |
# |    actor_loss      | 662      |
# |    critic_loss     | 195      |
# |    ent_coef        | 0.207    |
# |    ent_coef_loss   | 113      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8371     |
# |    reward          | -4.41043 |
# ---------------------------------
# ======SAC Validation from:  2022-07-22T00:00:00.000000000 to  2022-10-27T00:00:00.000000000
# SAC Sharpe Ratio:  -0.5079156037750677
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_441_2
# -----------------------------------
# | time/              |            |
# |    fps             | 736        |
# |    iterations      | 1          |
# |    time_elapsed    | 2          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | -1.9876521 |
# -----------------------------------
# day: 705, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1181305.42
# total_reward: 181305.42
# total_cost: 82821.65
# total_trades: 13610
# Sharpe: 0.411
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010440828 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.00918     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.6        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    reward               | -0.42104554 |
# |    std                  | 1           |
# |    value_loss           | 29.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 702        |
# |    iterations           | 3          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01069225 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.5      |
# |    explained_variance   | -0.0123    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 9.26       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0178    |
# |    reward               | 1.3708961  |
# |    std                  | 1          |
# |    value_loss           | 20.7       |
# ----------------------------------------
# day: 705, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1253477.34
# total_reward: 253477.34
# total_cost: 86180.83
# total_trades: 13514
# Sharpe: 0.535
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010674019 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | -0.0027     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0098     |
# |    reward               | -0.22757952 |
# |    std                  | 1.01        |
# |    value_loss           | 32.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011576708 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.00109     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0161     |
# |    reward               | 0.52428335  |
# |    std                  | 1.01        |
# |    value_loss           | 26.9        |
# -----------------------------------------
# ======PPO Validation from:  2022-07-22T00:00:00.000000000 to  2022-10-27T00:00:00.000000000
# PPO Sharpe Ratio:  -0.5154720244225366
# ======TD3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_441_2
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 200      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2824     |
# | train/             |          |
# |    actor_loss      | 85.8     |
# |    critic_loss     | 2.83e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2118     |
# |    reward          | -2.03134 |
# ---------------------------------
# day: 705, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1204264.91
# total_reward: 204264.91
# total_cost: 1146.91
# total_trades: 8533
# Sharpe: 0.364
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 190      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 5648     |
# | train/             |          |
# |    actor_loss      | 68.6     |
# |    critic_loss     | 1.37e+04 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4942     |
# |    reward          | -2.03134 |
# ---------------------------------
# day: 705, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1204264.91
# total_reward: 204264.91
# total_cost: 1146.91
# total_trades: 8533
# Sharpe: 0.364
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 185      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 8472     |
# | train/             |          |
# |    actor_loss      | 67       |
# |    critic_loss     | 382      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7766     |
# |    reward          | -2.03134 |
# ---------------------------------
# day: 705, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1204264.91
# total_reward: 204264.91
# total_cost: 1146.91
# total_trades: 8533
# Sharpe: 0.364
# =================================
# ======TD3 Validation from:  2022-07-22T00:00:00.000000000 to  2022-10-27T00:00:00.000000000
# ======Best Model Retraining from:  2010-10-10 to  2022-10-27T00:00:00.000000000
# ======Trading from:  2022-10-27T00:00:00.000000000 to  2023-02-01T00:00:00.000000000
# Ensemble Strategy took:  14.1245778799057  minutes

# %%
df_summary
# Out:
#   Iter  Val Start    Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126 2021-03-02 2021-06-03        SAC   0.185364    0.16531    0.081526
# 1  189 2021-06-03 2021-10-12        PPO  -0.151232   0.073901    0.037172
# 2  252 2021-10-12 2022-01-10        PPO   0.027036   0.101298    0.034079
# 3  315 2022-01-10 2022-04-20        SAC   -0.09701   -0.20689   -0.168216
# 4  378 2022-04-20 2022-07-22        PPO   0.290411   0.459672    0.404532
# 5  441 2022-07-22 2022-10-27        TD3  -0.507916  -0.515472   -0.245144

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.5125532583671804

# %%
df_account_value
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2021-06-03           NaN 2021-06-03
# 1     1.001942e+06  2021-06-04      0.001942 2021-06-04
# 2     1.001666e+06  2021-06-07     -0.000275 2021-06-07
# 3     9.935441e+05  2021-06-08     -0.008109 2021-06-08
# 4     9.932688e+05  2021-06-09     -0.000277 2021-06-09
# ..             ...         ...           ...        ...
# 373   8.124299e+05  2023-01-18     -0.002991 2023-01-18
# 374   8.171657e+05  2023-01-19      0.005829 2023-01-19
# 375   8.161072e+05  2023-01-20     -0.001295 2023-01-20
# 376   7.891379e+05  2023-01-30     -0.033046 2023-01-30
# 377   7.774921e+05  2023-01-31     -0.014758 2023-01-31
#
# [378 rows x 4 columns]

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.154467
# Cumulative returns    -0.222508
# Annual volatility      0.261773
# Sharpe ratio          -0.512553
# Calmar ratio          -0.469272
# Stability              0.216026
# Max drawdown          -0.329162
# Omega ratio            0.909522
# Sortino ratio         -0.736343
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.883791
# Daily value at risk   -0.033513
# dtype: float64

# %%
#获取随机选择的tic在select_date的权重并修正
def get_selected_index_weight(df_index,select_date,selected_tics):
    df = df_index[df_index['trade_date'] == select_date]
    select_df = df[df['con_code'].isin(selected_tics)]
    select_df = select_df.drop('index_code',axis=1).rename(columns={'con_code':'tic','trade_date':'date'})
    select_df = select_df.reset_index()
    weight_sum = select_df['weight'].sum()
#     print(select_df)
    for i in range(len(select_df)):
        select_df.loc[i,'weight'] = (select_df.loc[i,'weight'] / weight_sum)*100
    return select_df.loc[:,['tic','date','weight']]

baseline_weight =get_selected_index_weight(df_index,select_date,selected_tics)
baseline_weight = baseline_weight.sort_values(['tic'],ascending=True).reset_index(drop=True)
print(baseline_weight)
# Out:
#           tic      date     weight
# 0   600009.SH  20200228   3.473945
# 1   600031.SH  20200228   5.637596
# 2   600196.SH  20200228   1.482782
# 3   600309.SH  20200228   4.051928
# 4   600340.SH  20200228   1.561460
# 5   600519.SH  20200228  29.141197
# 6   600703.SH  20200228   3.310537
# 7   600837.SH  20200228   6.309387
# 8   601066.SH  20200228   0.789808
# 9   601211.SH  20200228   4.206258
# 10  601236.SH  20200228   0.472069
# 11  601288.SH  20200228   7.168795
# 12  601328.SH  20200228   7.837560
# 13  601398.SH  20200228   6.273074
# 14  601818.SH  20200228   3.301459
# 15  601857.SH  20200228   2.702294
# 16  601888.SH  20200228   4.203232
# 17  601939.SH  20200228   2.393633
# 18  601988.SH  20200228   4.106397
# 19  603993.SH  20200228   1.576590

# %%
#计算所选股票的buy & hold策略
def calculate_selected_baseline(df,full_date_range,selected_tics):
    df = df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
    baseline = pd.DataFrame({'date':full_date_range['date']})
    for i in range(len(full_date_range)):
        temp_date = full_date_range.loc[i,'date']
        temp_df = df[df['date'] == temp_date].sort_values('tic',ascending=True)
        close = list(temp_df['close'])
        weight = list(baseline_weight['weight'])
        baseline.loc[i,'account_value'] = sum(np.array(close) * np.array(weight)) #注意权重和收盘价对应的股票顺序
    baseline['date'] = pd.to_datetime(baseline['date'])
#     baseline.set_index("date", inplace=True, drop=True)
#     baseline.index = baseline.index.tz_localize("UTC")
    return baseline
# full_date_range = get_trading_days(exchange='SSE',start_date='20210301', end_date='20230227')
# full_date_range = full_date_range.sort_values('trade_date',ascending=True).reset_index(drop=True)
full_date_range1 = pd.DataFrame({'date':df_account_value['date'].unique()}).reset_index(drop=True)
baseline_sse = calculate_selected_baseline(processed,full_date_range1,selected_tics)
baseline_sse
# Out:
#           date  account_value
# 0   2021-06-03   67472.696665
# 1   2021-06-04   68300.562731
# 2   2021-06-07   68851.120922
# 3   2021-06-08   66515.558252
# 4   2021-06-09   66753.746384
# ..         ...            ...
# 373 2023-01-18   57235.261787
# 374 2023-01-19   56875.717818
# 375 2023-01-20   56281.132603
# 376 2023-01-30   57048.146372
# 377 2023-01-31   55787.444017
#
# [378 rows x 2 columns]

# %%
merged_df

# %%
#baseline stats
print("==============Get Baseline Stats===========")
# baseline_df = get_baseline(
#         ticker="^DJI", 
#         start = df_account_value.loc[0,'date'],
#         end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_sse, value_col_name = 'account_value')
# Out:
# ==============Get Baseline Stats===========
# Annual return         -0.119075
# Cumulative returns    -0.173185
# Annual volatility      0.325736
# Sharpe ratio          -0.228636
# Calmar ratio          -0.294119
# Stability              0.107979
# Max drawdown          -0.404853
# Omega ratio            0.960278
# Sortino ratio         -0.333243
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.984050
# Daily value at risk   -0.041334
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
from copy import deepcopy
def backtest_plot_com(
    account_value,
    baseline,
    baseline_start=TRADE_START_DATE,
    baseline_end=TRADE_END_DATE,
    value_col_name="account_value",
):
    df = deepcopy(account_value)
    df["date"] = pd.to_datetime(df["date"])
    test_returns = get_daily_return(df, value_col_name=value_col_name)
#     pro = ts.pro_api()
#     baseline_df = pro.index_daily(ts_code='000016.sh',start_date = '20200301',end_date='20230227')
#     baseline_df = baseline_df.rename(columns={'trade_date':'date'})
#     baseline_df = baseline_df.sort_values('date',ascending=True)
    baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
    with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(
            returns=test_returns, benchmark_rets=baseline_returns, set_context=False
        )

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2023-01-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-15.447%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-22.251%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.177%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.51</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.47</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.22</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-32.916%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.74</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.351%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.72</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>32.92</td>
#       <td>2021-06-04</td>
#       <td>2022-11-24</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axis.py:1736, in Axis.convert_units(self, x)
#    1735 try:
# -> 1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:287, in DatetimeConverter.convert(values, unit, axis)
#     286 else:
# --> 287     values = DatetimeConverter._convert_1d(values, unit, axis)
#     288 return values
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:322, in DatetimeConverter._convert_1d(values, unit, axis)
#     320         pass
# --> 322     values = dates.date2num(values)
#     324 return values
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/dates.py:462, in date2num(d)
#     461         d = np.asarray(d)
# --> 462     d = d.astype('datetime64[us]')
#     464 d = np.ma.masked_array(d, mask=mask) if masked else d
#
# ValueError: cannot convert float NaN to integer
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[63], line 7
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 # S&P 500: ^GSPC
#       5 # Dow Jones Index: ^DJI
#       6 # NASDAQ 100: ^NDX
# ----> 7 backtest_plot_com(account_value = df_account_value,
#       8                   baseline = baseline_sse,
#       9                   baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
#      10                   baseline_end = df_account_value.loc[0,'date']
#      11                      )
#
# Cell In[62], line 19, in backtest_plot_com(account_value, baseline, baseline_start, baseline_end, value_col_name)
#      17 baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
#      18 with pyfolio.plotting.plotting_context(font_scale=1.1):
# ---> 19     pyfolio.create_full_tear_sheet(
#      20         returns=test_returns, benchmark_rets=baseline_returns, set_context=False
#      21     )
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:180, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     174     returns = txn.adjust_returns_for_slippage(returns, positions,
#     175                                               transactions, slippage)
#     177 positions = utils.check_intraday(estimate_intraday, returns,
#     178                                  positions, transactions)
# --> 180 create_returns_tear_sheet(
#     181     returns,
#     182     positions=positions,
#     183     transactions=transactions,
#     184     live_start_date=live_start_date,
#     185     cone_std=cone_std,
#     186     benchmark_rets=benchmark_rets,
#     187     bootstrap=bootstrap,
#     188     turnover_denom=turnover_denom,
#     189     header_rows=header_rows,
#     190     set_context=set_context)
#     192 create_interesting_times_tear_sheet(returns,
#     193                                     benchmark_rets=benchmark_rets,
#     194                                     set_context=set_context)
#     196 if positions is not None:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:54, in customize.<locals>.call_w_context(*args, **kwargs)
#      52         return func(*args, **kwargs)
#      53 else:
# ---> 54     return func(*args, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:569, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     565 plotting.plot_rolling_sharpe(
#     566     returns, ax=ax_rolling_sharpe)
#     568 # Drawdowns
# --> 569 plotting.plot_drawdown_periods(
#     570     returns, top=5, ax=ax_drawdown)
#     572 plotting.plot_drawdown_underwater(
#     573     returns=returns, ax=ax_underwater)
#     575 plotting.plot_monthly_returns_heatmap(returns, ax=ax_monthly_heatmap)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:442, in plot_drawdown_periods(returns, top, ax, **kwargs)
#     440     if pd.isnull(recovery):
#     441         recovery = returns.index[-1]
# --> 442     ax.fill_between((peak, recovery),
#     443                     lim[0],
#     444                     lim[1],
#     445                     alpha=.4,
#     446                     color=colors[i])
#     447 ax.set_ylim(lim)
#     448 ax.set_title('Top %i drawdown periods' % top)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5431, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5429 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5430                  step=None, **kwargs):
# -> 5431     return self._fill_between_x_or_y(
#    5432         "x", x, y1, y2,
#    5433         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5337, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5332         kwargs["facecolor"] = \
#    5333             self._get_patches_for_fill.get_next_color()
#    5335 # Handle united data, such as dates
#    5336 ind, dep1, dep2 = map(
# -> 5337     ma.masked_invalid, self._process_unit_info(
#    5338         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5340 for name, array in [
#    5341         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5342     if array.ndim > 1:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_base.py:2569, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2567             if dataset_axis_name == axis_name and data is not None:
#    2568                 axis.update_units(data)
# -> 2569 return [axis_map[axis_name].convert_units(data)
#    2570         if convert and data is not None else data
#    2571         for axis_name, data in datasets]
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_base.py:2569, in <listcomp>(.0)
#    2567             if dataset_axis_name == axis_name and data is not None:
#    2568                 axis.update_units(data)
# -> 2569 return [axis_map[axis_name].convert_units(data)
#    2570         if convert and data is not None else data
#    2571         for axis_name, data in datasets]
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axis.py:1738, in Axis.convert_units(self, x)
#    1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
# -> 1738     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1739                                  f'units: {x!r}') from e
#    1740 return ret
#
# ConversionError: Failed to convert value(s) to axis units: (NaT, Timestamp('2023-01-31 00:00:00+0000', tz='UTC'))
