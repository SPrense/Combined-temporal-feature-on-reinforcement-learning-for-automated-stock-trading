# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install stable_baselines3
# !pip install yfinance
# !pip install tushare
# !pip install exchange_calendars
# !pip install wrds
# !pip install alpaca_trade_api
# !pip install stockstats
# !pip install pyfolio

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_initial import StockTradingEnv
from finrl.agents.stablebaselines3.models_initial import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)

# %%
df = pd.read_csv('merged_df.csv')
df

# %%
TRAIN_START_DATE = '2012-10-10'
TRAIN_END_DATE = '2020-02-28'
TRADE_START_DATE = '2020-03-01'
TRADE_END_DATE = '2023-02-28'

# %%
import tushare as ts
ts.set_token('6314756019e50a6672690e5a78b2dbf7cfcd27c6f6a6b48a8cf76dae')
pro = ts.pro_api()

# %%
#选择上证50指数的成分股
df_index = pro.index_weight(index_code='000016.sh', start_date='20121010', end_date='20220228')
# df_index.to_csv('SSE_50_index_weight.csv',index=0)

# %%
#选择某个时间点的上证50指数成分股作为参考跟踪股票池
select_date = '20200228' #自定义的时间点为每个月的月末
df_select = df_index[df_index['trade_date']==select_date]
sort_SSEindex = df_select['con_code'].unique()
print(sort_SSEindex,len(sort_SSEindex))
# Out:
# ['603993.SH' '603259.SH' '601989.SH' '601988.SH' '601939.SH' '601888.SH'
#  '601857.SH' '601818.SH' '601766.SH' '601688.SH' '601668.SH' '601628.SH'
#  '601601.SH' '601398.SH' '601390.SH' '601336.SH' '601328.SH' '601319.SH'
#  '601318.SH' '601288.SH' '601236.SH' '601211.SH' '601186.SH' '601166.SH'
#  '601138.SH' '601111.SH' '601088.SH' '601066.SH' '601012.SH' '600887.SH'
#  '600837.SH' '600703.SH' '600690.SH' '600585.SH' '600547.SH' '600519.SH'
#  '600340.SH' '600309.SH' '600276.SH' '600196.SH' '600104.SH' '600050.SH'
#  '600048.SH' '600036.SH' '600031.SH' '600030.SH' '600028.SH' '600016.SH'
#  '600009.SH' '600000.SH'] 50

# %%
#随机选择成分股中的k只股票
import random 
k = 10
selected_tics = random.sample(list(sort_SSEindex),k)
print(selected_tics)
# Out:
# ['600837.SH', '601336.SH', '603993.SH', '600585.SH', '600048.SH', '600519.SH', '600031.SH', '600036.SH', '600703.SH', '601766.SH']

# %%
#Download随机选择的k只股票数据
df_ts =pd.DataFrame()
for c in selected_tics:
    temp=pro.daily(ts_code=c,start_date=TRAIN_START_DATE,end_date=TRADE_END_DATE)
    df_ts=pd.concat([df_ts,temp])
print(df_ts)
# Out:
#         ts_code trade_date  open  high   low  close  pre_close  change  \
# 0     600837.SH   20221230  8.64  8.70  8.64   8.69       8.64    0.05
# 1     600837.SH   20221229  8.71  8.71  8.57   8.64       8.66   -0.02
# 2     600837.SH   20221228  8.69  8.74  8.64   8.66       8.70   -0.04
# 3     600837.SH   20221227  8.68  8.72  8.64   8.70       8.63    0.07
# 4     600837.SH   20221226  8.61  8.65  8.57   8.63       8.60    0.03
# ...         ...        ...   ...   ...   ...    ...        ...     ...
# 2581  601766.SH   20120110  4.28  4.52  4.27   4.50       4.29    0.21
# 2582  601766.SH   20120109  4.17  4.30  4.14   4.29       4.17    0.12
# 2583  601766.SH   20120106  4.15  4.19  4.10   4.17       4.15    0.02
# 2584  601766.SH   20120105  4.20  4.21  4.09   4.15       4.17   -0.02
# 2585  601766.SH   20120104  4.36  4.39  4.16   4.17       4.33   -0.16
#
#       pct_chg        vol      amount
# 0      0.5787  196359.06  170463.461
# 1     -0.2309  229794.25  198262.432
# 2     -0.4598  216051.46  187504.521
# 3      0.8111  159098.00  138257.523
# 4      0.3488  185449.00  159761.927
# ...       ...        ...         ...
# 2581   4.9000  800507.86  351957.856
# 2582   2.8800  546736.28  231278.463
# 2583   0.4800  226095.02   93649.698
# 2584  -0.4800  294862.09  122867.918
# 2585  -3.7000  270883.61  115720.972
#
# [26341 rows x 11 columns]

# %%
# 筛选exchange_calender中每个交易节点缺失情况(全部补充0)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) != k:
            missing_tic = set(selected_tics).difference(set(temp_df['ts_code'].tolist()))
#             print(missing_tic)
            for m_tic in missing_tic:
                temp_dict = {'ts_code':m_tic,'trade_date':date,'open':0, 'high':0,'low':0, 'close':0, 'pre_close':0, 'change':0, 'pct_chg':0, 'volume':0, 'amount':0}
                new_data = pd.DataFrame.from_dict(temp_dict,orient='index').T
                temp_df = temp_df.append(new_data)
            processe_df.append(temp_df)
        else :
            processe_df.append(temp_df)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
# 筛选exchange_calender中每个交易节点缺失(激进)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) == k:
            processe_df.append(temp_df)
        else :
            date_unique.remove(date)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
processed_df,date_unique = processed_date(df_ts,selected_tics,k)
print(processed_df)
# Out:
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      601766.SH   20121009   4.07   4.18   4.07   4.18       4.05    0.13
# 1      600837.SH   20121009   9.59   9.86   9.56   9.82       9.49    0.33
# 2      601336.SH   20121009  24.68  25.16  24.60  24.97      24.45    0.52
# 3      603993.SH   20121009   8.70   9.68   8.66   9.63       3.00    6.63
# 4      600585.SH   20121009  15.67  16.12  15.66  16.07      15.61    0.46
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 23095  600048.SH   20221230  14.99  15.20  14.78  15.13      15.01    0.12
# 23096  600585.SH   20221230  27.50  27.75  27.34  27.38      27.38    0.00
# 23097  603993.SH   20221230   4.59   4.62   4.55   4.55       4.57   -0.02
# 23098  601336.SH   20221230  29.10  30.40  29.10  30.08      29.04    1.04
# 23099  600837.SH   20221230   8.64   8.70   8.64   8.69       8.64    0.05
#
#         pct_chg         vol       amount
# 0        3.2100   426401.73   176826.750
# 1        3.4800   599918.36   586413.529
# 2        2.1300    52308.73   130493.323
# 3      221.0000  1750404.18  1571741.690
# 4        2.9500   181642.60   290888.992
# ...         ...         ...          ...
# 23095    0.7995   614805.90   923681.121
# 23096    0.0000   139294.53   382714.745
# 23097   -0.4376   434167.50   198767.597
# 23098    3.5813   113476.54   340722.412
# 23099    0.5787   196359.06   170463.461
#
# [23100 rows x 11 columns]

# %%
# processed_df1 = processed_df.drop('volume',axis=1)
processed_df1 = processed_df.sort_values(['ts_code','trade_date'],ascending=True,ignore_index=True)
processed_df1['trade_date'] = pd.to_datetime(processed_df1['trade_date'])
processed_df1
# Out:
#          ts_code trade_date  open  high   low  close  pre_close  change  \
# 0      600031.SH 2012-10-09  9.48  9.74  9.48   9.68       9.46    0.22
# 1      600031.SH 2012-10-10  9.66  9.72  9.52   9.67       9.68   -0.01
# 2      600031.SH 2012-10-11  9.62  9.78  9.53   9.57       9.67   -0.10
# 3      600031.SH 2012-10-12  9.58  9.83  9.36   9.41       9.57   -0.16
# 4      600031.SH 2012-10-15  9.43  9.46  9.04   9.17       9.41   -0.24
# ...          ...        ...   ...   ...   ...    ...        ...     ...
# 23095  603993.SH 2022-12-26  4.55  4.56  4.50   4.53       4.54   -0.01
# 23096  603993.SH 2022-12-27  4.56  4.63  4.55   4.62       4.53    0.09
# 23097  603993.SH 2022-12-28  4.59  4.70  4.56   4.65       4.62    0.03
# 23098  603993.SH 2022-12-29  4.61  4.65  4.56   4.57       4.65   -0.08
# 23099  603993.SH 2022-12-30  4.59  4.62  4.55   4.55       4.57   -0.02
#
#        pct_chg        vol      amount
# 0       2.3300  288803.04  278903.053
# 1      -0.1000  243882.88  234696.190
# 2      -1.0300  225222.67  217480.253
# 3      -1.6700  314393.31  300090.077
# 4      -2.5500  284591.70  261394.264
# ...        ...        ...         ...
# 23095  -0.2203  490722.21  222140.899
# 23096   1.9868  489426.49  225028.849
# 23097   0.6494  645000.58  299488.590
# 23098  -1.7204  631299.86  290036.792
# 23099  -0.4376  434167.50  198767.597
#
# [23100 rows x 11 columns]

# %%
#出现缺失值的个数、占比
count = len(pro_df[pro_df['open'] == 0])
nan_rate = count/len(pro_df)
print(count,'缺失值百分之:',nan_rate)

# %%
def delaydate(dela,full_list):
    grouped = processed_df1.groupby('ts_code')
    filtered_df = pd.DataFrame()
    for name, group in grouped:
        # 按'trade_date'升序排序  True=升序
        group = group.sort_values('trade_date', ascending=True)
        
        # 丢弃前48个日期的数据
        group = group.iloc[dela:]
        filtered_df = filtered_df.append(group)
    
    filtered_df = filtered_df.reset_index(drop=True)
    filtered_df = filtered_df.sort_values(['ts_code','trade_date'],ascending=True,ignore_index=True)
    return filtered_df

# %%
pro_df = processed_df1.loc[:,['open','high','low','close','vol']].reset_index(drop=True)

# %%
#计算技术指标到dataset中
#Can be easily expanded
#Currently contains a small set of tech indicators
import talib as ta

def calc_tech_ind(data):
    #overlap 
    data['upbd'], data['midbd'], data['lowbd'] = ta.BBANDS(data["close"])
    data['dema'] = ta.DEMA(data["close"], timeperiod=30)
    data['tema'] = ta.TEMA(data["close"], timeperiod=30)
    data['ema'] = ta.EMA(data["close"], timeperiod=30)
    data['wma'] = ta.WMA(data["close"], timeperiod=30)
    data['sma'] = ta.SMA(data["close"], timeperiod=30)
    data['sarext'] = ta.SAREXT(data["high"], data["low"])
    
    #momentum
    data['adxr'] = ta.ADXR(data["high"], data["low"], data["close"], timeperiod=14)
    data['apo'] = ta.APO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['aroondown'], data['aroonup'] = ta.AROON(data["high"], data["low"], timeperiod=14)
    data['cci'] = ta.CCI(data["high"], data["low"], data["close"], timeperiod=14)
    data['cmo'] = ta.CMO(data["close"], timeperiod=14)
    data['macd'], data['macdsignal'], data['macdhist'] = ta.MACD(data["close"], fastperiod=12, slowperiod=26, signalperiod=9)
    data['MFI'] = ta.MFI(data["high"], data["low"], data["close"], data['vol'], timeperiod=14)
    data['mom'] = ta.MOM(data["close"], timeperiod=10)
    data['plus_di'] = ta.PLUS_DI(data["high"], data["low"], data["close"], timeperiod=14)
    data['ppo'] = ta.PPO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['roc'] = ta.ROC(data["close"], timeperiod=10)
    data['rocp'] = ta.ROCP(data["close"], timeperiod=10)
    data['rsi'] = ta.RSI(data["close"], timeperiod=14)
    data['slowk'], data['slowd'] = ta.STOCH(data["high"], data["low"], data["close"])
    data['fastk'], data['fastd'] = ta.STOCHF(data["high"], data["low"], data["close"])
    data['trix'] = ta.TRIX(data["close"], timeperiod=30)
    data['ultosc'] = ta.ULTOSC(data["high"], data["low"], data["close"], timeperiod1=7, timeperiod2=14, timeperiod3=28)
    data['willr'] = ta.WILLR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #volume
    data['ad'] = ta.AD(data["high"], data["low"], data["close"], data['vol'])
    data['obv'] = ta.OBV(data["close"], data['vol'])
    
    #volitility
    data['atr'] = ta.ATR(data["high"], data["low"], data["close"], timeperiod=14)
    data['natr'] = ta.NATR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #cycle
    data['HT_DCPERIOD'] = ta.HT_DCPERIOD(data["close"])
#     data['HT_DCPHASE'] = ta.HT_DCPHASE(data["close"])
#     data['inphase'], data['quadrature'] = ta.HT_PHASOR(data["close"])
    
    
    return data

# %%
full_list1 = calc_tech_ind(pro_df)
full_list1 = full_list1.fillna(0)

# %%
array_full_list = np.array(full_list1)
array_full_list = array_full_list.reshape(k,int(len(full_list1)/k),full_list1.shape[1])
selected_tics = sorted(selected_tics)

# %%
df.tic.value_counts()

# %% [markdown]
# # Part 2: DeepLearning representation

# %%
#generate x, y, z, zp quadruples
#segment x, y, z trios to sequence according to $timeStep and $gap
#x: historical data w/ technical analysis indicator
#y: closing price of t+1
#z:  difference between t+1 and t step's closing price

def toSequential_train1(idx, full_list, timeStep=48, gap=4):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
#     closingNorm = (closing - closing.mean())/closing.std()
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    for i in range(count):
        #segData dims: [timestep, feature count]       
        segData=data[gap*i:gap*i+timeStep]
        segClosing=closing[gap*i:gap*i+timeStep+1]
        #segDiff=diff[gap*i:gap*i+timeStep]
        #normalization
        
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
#         segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        segDataNorm=np.nan_to_num((segData-segData.mean(axis=0, keepdims=True))/segData.std(axis=0, keepdims=True))
    
        std_close = segClosing.std()
        std_segClosing = np.where(std_close == 0, 1, std_close)
        segClosingNorm=(segClosing-segClosing.mean())/std_segClosing
#         segDiff=(segDiff-segDiff.mean())/segDiff.std()
        
        stockSeq.append(segDataNorm)
        labelSeq.append(segClosingNorm[1:])
        diffSeq.append(segClosingNorm[1:]-segClosingNorm[:-1])
        realDiffSeq.append(segClosing[1:]-segClosing[:-1])
    stockSeq=np.array(stockSeq)
    labelSeq=np.array(labelSeq)
    diffSeq=np.array(diffSeq)
    realDiffSeq=np.array(realDiffSeq)
    return stockSeq.astype('float32') , labelSeq.astype('float32'), diffSeq.astype('float32'), realDiffSeq.astype('float32')

# %%
def toSequential_back(idx, full_list, timeStep = 48, gap = 1,batch_size = 64):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    
    start = data_length - timeStep
    i=0
    while start >= 0:
        segData = data[start:start + timeStep]
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
        segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        #复制batch_size个
        stockSeq.extend([segDataNorm] * batch_size)
#         stockSeq.append(segDataNorm)   
        start = start - gap
        i +=1
    stockSeq=np.array(stockSeq)[::-1]
#     print(i)
    return stockSeq.astype('float32')

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=3):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        closing_cohort=[]
        diff_cohort=[]
        real_diff_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X, y, z, zp=toSequential_train1(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
            closing_cohort.append(y)
            diff_cohort.append(z)
            real_diff_cohort.append(zp)
        self.X=np.concatenate(stock_cohort, axis=0)
        self.y=np.concatenate(closing_cohort, axis=0)
        self.z=np.concatenate(diff_cohort, axis=0)  
        self.zp=np.concatenate(real_diff_cohort, axis=0)
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        label1=self.y[idx]
        label2=self.z[idx]
        label3=self.zp[idx]
        if self.transform:
            data=self.transform(data)
        return (data, label1, label2, label3)
    
    
    def getDS(self):
        return self.X, self.y, self.z, self.zp

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset_back(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=1):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X=toSequential_back(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
        self.X=np.concatenate(stock_cohort, axis=0)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        if self.transform:
            data=self.transform(data)
        return data
        
    def getDS(self):
        return self.X

# %%
#Generation of training, validation, and testing dataset
def DataIterGen(test_id_list, val_id_list, name_list, full_list, demo=False):
    """
    test_id_list: id of subjects for testing
    val_id_list: id of subjects for validation
    other subjects for training
    full_list=get_data_set(name_list), preprocessed
    demo: when demo mode is True, only test_iter is returned, with data from
    first entry of test_id_list (single stock)
    """
    name_count=len(name_list)

    if demo:
        test_iter=DataLoader(StockDataset(test_id_list[0:1], full_list, timestep=24, gap=1), shuffle=False, batch_size=64, num_workers=0)
        print(f'Demo with stock: {name_list[test_id_list[0]]} ')
        return test_iter
    else:
        all_ids = list(range(name_count))
        train_id_list = list(set(all_ids) - set(test_id_list) - set(val_id_list))
#         partial_list=full_list[train_list,:,:]
        test_iter=DataLoader(StockDataset(test_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        val_iter=DataLoader(StockDataset(val_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        train_iter=DataLoader(StockDataset(train_id_list, full_list), shuffle=True, batch_size=64, num_workers=0,drop_last=True)
        print(f'Val: {[name_list[val_id] for val_id in val_id_list]}, Test: {[name_list[test_id] for test_id in test_id_list]}, Train: {[name_list[train_id] for train_id in train_id_list]} ')
        return train_iter, val_iter, test_iter

# %%
train_iter, val_iter, test_iter = DataIterGen([3],[4],selected_tics,array_full_list)
# Out:
# Val: ['600585.SH'], Test: ['600519.SH'], Train: ['600031.SH', '600036.SH', '600048.SH', '600703.SH', '600837.SH', '601336.SH', '601766.SH', '603993.SH']

# %% [markdown]
# # Part3: Transformer

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers)
        self.linear1 = nn.Linear(d_model, env_size)
        self.rule = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.rule(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
import matplotlib.pyplot as plt
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            fig, ax = plt.subplots()
            targets1 = targets.squeeze().numpy()
            ax.plot(pred,label='Predicition')
            ax.plot(targets1, label = 'Target')
            ax.legend()
            ax.set_title('Predicition vs Target')
            ax.set_xlabel('index')
            ax.set_ylabel('Value')
            plt.show()
        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
def predict(model,back_iter):
    enVec_list = []
    with torch.no_grad():
        for X in back_iter:
            inputs = X.to(device)
            _,enVec = model(inputs)
            enVec_list.append(enVec)
    return enVec_list

# %%
#define device
def try_gpu(i=0):
    """Return gpu(i) if exists, otherwise return cpu()."""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
device=try_gpu()

# %%
# 定义模型
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming =train(model,train_iter,optimizer,5)
valtest =val(model,val_iter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 4
#       2 model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40)
#       3 optimizer = optim.Adam(model.parameters(), lr=0.001)
# ----> 4 outcoming =train(model,train_iter,optimizer,5)
#       5 valtest =val(model,val_iter)
#
# Cell In[35], line 22, in train(model, train_iter, optimizer, num_epochs)
#      20 total_loss += loss.item()
#      21 fig, ax = plt.subplots()
# ---> 22 ax.plot(pred,label='Predicition')
#      23 ax.plot(targets, label = 'Target')
#      24 ax.legend()
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_base.py:507, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
# --> 507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#     509 if x.ndim == 1:
#     510     x = x[:, np.newaxis]
#
# ValueError: x and y can be no greater than 2D, but have shapes (64,) and torch.Size([64, 48, 1])

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# feature_enginner
alltic_list = [i for i in range(k)]

def Feature_enginner(model, processed_df, full_list, alltic_list, batch_size=64, k=15, env_size=40,dela = 48):
    back_iter = DataLoader(StockDataset_back([i for i in range(k)],full_list), shuffle=False, batch_size=batch_size, num_workers=0,drop_last=False)
    
    new_state = predict(model,back_iter)
    concatenated_tensor = torch.cat(new_state, dim=0)
    concatenated_tensor = concatenated_tensor.view(-1,env_size)
    feature_df = pd.DataFrame(concatenated_tensor.numpy())
    
    full_delay_df = delaydate(dela ,processed_df)
    
    merged_df = pd.concat([full_delay_df, feature_df], axis=1)
    merged_df = merged_df.loc[:,['ts_code','trade_date','close']+[i for i in range(env_size)]]
    merged_df.columns = ['tic','date','close'] + [f"temporal_feature_{i}" for i in range(env_size)]
    return merged_df

# %%
addfeature_df = Feature_enginner(model, processed_df1, array_full_list, alltic_list, batch_size=64, k=10 ,env_size=40, dela=48)

# %%
addfeature_df.to_csv('628addfeature_df.csv',index=None)

# %%
addfeature_df = pd.read_csv('71_best.csv')

# %%
processed_df3 = pd.read_csv('71_processed_best.csv')

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=False,
                    use_turbulence=True,
                    user_defined_feature = False)

# %%
INDICATORS

# %%
addfeature_df = fe.add_turbulence(addfeature_df)
addfeature_df = addfeature_df.fillna(method="ffill").fillna(method="bfill")

# %%
import datetime
processed['date'] = pd.to_datetime(processed['date'],format='%Y%m%d')
processed

# %%
list_ticker = processed["tic"].unique().tolist()
# list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
# combination = list(itertools.product(list_date,list_ticker))

# processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
# processed_full = processed_full[processed_full['date'].isin(processed['date'])]
# processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
selfattn_indicator_list = [f"temporal_feature_{i}" for i in range(40)]

# %%
TRAIN_START_DATE = addfeature_df['date'].unique()[0]

# %%
TRAIN_START_DATE

# %%
stock_dimension = 20
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension + len(selfattn_indicator_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 1001

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=addfeature_df,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TRADE_START_DATE,TRADE_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 attn_indicator_list = selfattn_indicator_list,                 
                 **env_kwargs)

# %%
TEST_END_DATE

# %%
SAC_model_kwargs = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 64,
    "ent_coef": "auto_0.1",
                }

PPO_model_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
                    }

TD3_model_kwargs = {
    "batch_size": 128, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
                }

timesteps_dict = {'sac' : 10000, 
                 'ppo' : 10000, 
                 'td3' : 10000
                 }

# %%
import torch
device = torch.device("mps")

# %%
df_summary = ensemble_agent.run_ensemble_strategy_com(SAC_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# ======Model training from:  2018-11-06 to  2020-03-02
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 64, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_26
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 93        |
# |    time_elapsed    | 12        |
# |    total_timesteps | 1204      |
# | train/             |           |
# |    actor_loss      | 1.08e+03  |
# |    critic_loss     | 151       |
# |    ent_coef        | 0.11      |
# |    ent_coef_loss   | 458       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1139      |
# |    reward          | -3.009255 |
# ----------------------------------
# day: 300, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1118814.13
# total_reward: 118814.13
# total_cost: 1840.97
# total_trades: 3168
# Sharpe: 0.550
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 91        |
# |    time_elapsed    | 26        |
# |    total_timesteps | 2408      |
# | train/             |           |
# |    actor_loss      | 987       |
# |    critic_loss     | 132       |
# |    ent_coef        | 0.122     |
# |    ent_coef_loss   | 315       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 2343      |
# |    reward          | -3.871771 |
# ----------------------------------
# day: 300, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1247298.75
# total_reward: 247298.75
# total_cost: 6719.55
# total_trades: 4573
# Sharpe: 0.881
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 90        |
# |    time_elapsed    | 39        |
# |    total_timesteps | 3612      |
# | train/             |           |
# |    actor_loss      | 846       |
# |    critic_loss     | 189       |
# |    ent_coef        | 0.133     |
# |    ent_coef_loss   | 203       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3547      |
# |    reward          | -5.289304 |
# ----------------------------------
# day: 300, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1115565.03
# total_reward: 115565.03
# total_cost: 8008.83
# total_trades: 5291
# Sharpe: 0.527
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 90         |
# |    time_elapsed    | 53         |
# |    total_timesteps | 4816       |
# | train/             |            |
# |    actor_loss      | 1.07e+03   |
# |    critic_loss     | 538        |
# |    ent_coef        | 0.146      |
# |    ent_coef_loss   | 175        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 4751       |
# |    reward          | -3.8983963 |
# -----------------------------------
# day: 300, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1347867.00
# total_reward: 347867.00
# total_cost: 9606.93
# total_trades: 5222
# Sharpe: 1.272
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 89        |
# |    time_elapsed    | 66        |
# |    total_timesteps | 6020      |
# | train/             |           |
# |    actor_loss      | 811       |
# |    critic_loss     | 425       |
# |    ent_coef        | 0.16      |
# |    ent_coef_loss   | 84.3      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 5955      |
# |    reward          | -4.784648 |
# ----------------------------------
# -----------------------------------
# | time/              |            |
# |    episodes        | 24         |
# |    fps             | 89         |
# |    time_elapsed    | 80         |
# |    total_timesteps | 7224       |
# | train/             |            |
# |    actor_loss      | 824        |
# |    critic_loss     | 473        |
# |    ent_coef        | 0.168      |
# |    ent_coef_loss   | 12.5       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7159       |
# |    reward          | -4.2527046 |
# -----------------------------------
# day: 300, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1088966.02
# total_reward: 88966.02
# total_cost: 7775.89
# total_trades: 5304
# Sharpe: 0.495
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 89        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 8428      |
# | train/             |           |
# |    actor_loss      | 791       |
# |    critic_loss     | 399       |
# |    ent_coef        | 0.165     |
# |    ent_coef_loss   | -54       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8363      |
# |    reward          | -3.243385 |
# ----------------------------------
# day: 300, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1020008.86
# total_reward: 20008.86
# total_cost: 7005.59
# total_trades: 5736
# Sharpe: 0.259
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 32         |
# |    fps             | 89         |
# |    time_elapsed    | 107        |
# |    total_timesteps | 9632       |
# | train/             |            |
# |    actor_loss      | 740        |
# |    critic_loss     | 513        |
# |    ent_coef        | 0.148      |
# |    ent_coef_loss   | -48.7      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 9567       |
# |    reward          | -4.1002774 |
# -----------------------------------
# ======SAC Validation from:  2020-03-02 to  2020-06-03
# SAC Sharpe Ratio:  0.12477708857526962
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_18
# day: 300, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1032908.39
# total_reward: 32908.39
# total_cost: 7764.37
# total_trades: 5786
# Sharpe: 0.409
# =================================
# day: 300, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 999607.71
# total_reward: -392.29
# total_cost: 7802.09
# total_trades: 5772
# Sharpe: 0.030
# =================================
# ------------------------------------
# | time/              |             |
# |    fps             | 952         |
# |    iterations      | 1           |
# |    time_elapsed    | 2           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.34808898 |
# ------------------------------------
# day: 300, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1033471.54
# total_reward: 33471.54
# total_cost: 7833.05
# total_trades: 5814
# Sharpe: 0.450
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 892        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.0093078  |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.4      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.315      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.00668   |
# |    reward               | -0.5067046 |
# |    std                  | 1          |
# |    value_loss           | 1.5        |
# ----------------------------------------
# day: 300, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1035114.31
# total_reward: 35114.31
# total_cost: 7725.10
# total_trades: 5716
# Sharpe: 0.495
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.009005453  |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.999        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00812     |
# |    reward               | -0.040443573 |
# |    std                  | 1            |
# |    value_loss           | 2.08         |
# ------------------------------------------
# day: 300, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 989129.97
# total_reward: -10870.03
# total_cost: 7549.65
# total_trades: 5699
# Sharpe: -0.119
# =================================
# day: 300, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1044380.62
# total_reward: 44380.62
# total_cost: 7689.60
# total_trades: 5724
# Sharpe: 0.731
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0075803837 |
# |    clip_fraction        | 0.092        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.471        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00784     |
# |    reward               | 0.005895892  |
# |    std                  | 1            |
# |    value_loss           | 2.04         |
# ------------------------------------------
# day: 300, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1005474.23
# total_reward: 5474.23
# total_cost: 8046.49
# total_trades: 5790
# Sharpe: 0.096
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.009105662  |
# |    clip_fraction        | 0.0983       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.719        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00714     |
# |    reward               | -0.030419854 |
# |    std                  | 1.01         |
# |    value_loss           | 1.64         |
# ------------------------------------------
# ======PPO Validation from:  2020-03-02 to  2020-06-03
# PPO Sharpe Ratio:  0.06388034063843027
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_18
# day: 300, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1177399.74
# total_reward: 177399.74
# total_cost: 4152.35
# total_trades: 3970
# Sharpe: 0.853
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 134       |
# |    time_elapsed    | 8         |
# |    total_timesteps | 1204      |
# | train/             |           |
# |    actor_loss      | 1.21e+03  |
# |    critic_loss     | 680       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 903       |
# |    reward          | -6.106057 |
# ----------------------------------
# day: 300, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1307860.68
# total_reward: 307860.68
# total_cost: 1084.43
# total_trades: 2469
# Sharpe: 1.045
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 116       |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2408      |
# | train/             |           |
# |    actor_loss      | 828       |
# |    critic_loss     | 414       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2107      |
# |    reward          | -6.106057 |
# ----------------------------------
# day: 300, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1307860.68
# total_reward: 307860.68
# total_cost: 1084.43
# total_trades: 2469
# Sharpe: 1.045
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 111       |
# |    time_elapsed    | 32        |
# |    total_timesteps | 3612      |
# | train/             |           |
# |    actor_loss      | 678       |
# |    critic_loss     | 330       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3311      |
# |    reward          | -6.106057 |
# ----------------------------------
# day: 300, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1307860.68
# total_reward: 307860.68
# total_cost: 1084.43
# total_trades: 2469
# Sharpe: 1.045
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 108       |
# |    time_elapsed    | 44        |
# |    total_timesteps | 4816      |
# | train/             |           |
# |    actor_loss      | 583       |
# |    critic_loss     | 437       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4515      |
# |    reward          | -6.106057 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 107       |
# |    time_elapsed    | 55        |
# |    total_timesteps | 6020      |
# | train/             |           |
# |    actor_loss      | 491       |
# |    critic_loss     | 661       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5719      |
# |    reward          | -6.106057 |
# ----------------------------------
# day: 300, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1307860.68
# total_reward: 307860.68
# total_cost: 1084.43
# total_trades: 2469
# Sharpe: 1.045
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 106       |
# |    time_elapsed    | 67        |
# |    total_timesteps | 7224      |
# | train/             |           |
# |    actor_loss      | 449       |
# |    critic_loss     | 3.82e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6923      |
# |    reward          | -6.106057 |
# ----------------------------------
# day: 300, episode: 95
# begin_total_asset: 1000000.00
# end_total_asset: 1307860.68
# total_reward: 307860.68
# total_cost: 1084.43
# total_trades: 2469
# Sharpe: 1.045
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 106       |
# |    time_elapsed    | 79        |
# |    total_timesteps | 8428      |
# | train/             |           |
# |    actor_loss      | 416       |
# |    critic_loss     | 790       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8127      |
# |    reward          | -6.106057 |
# ----------------------------------
# day: 300, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1307860.68
# total_reward: 307860.68
# total_cost: 1084.43
# total_trades: 2469
# Sharpe: 1.045
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 105       |
# |    time_elapsed    | 91        |
# |    total_timesteps | 9632      |
# | train/             |           |
# |    actor_loss      | 370       |
# |    critic_loss     | 895       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9331      |
# |    reward          | -6.106057 |
# ----------------------------------
# ======TD3 Validation from:  2020-03-02 to  2020-06-03
# ======Best Model Retraining from:  2018-11-06 to  2020-06-03
# ======Trading from:  2020-06-03 to  2020-09-02
# ============================================
# ======Model training from:  2018-11-06 to  2020-06-03
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 64, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_16
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 92         |
# |    time_elapsed    | 15         |
# |    total_timesteps | 1456       |
# | train/             |            |
# |    actor_loss      | 367        |
# |    critic_loss     | 36.4       |
# |    ent_coef        | 0.112      |
# |    ent_coef_loss   | 413        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 1391       |
# |    reward          | 0.16354883 |
# -----------------------------------
# day: 363, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1348302.05
# total_reward: 348302.05
# total_cost: 7321.42
# total_trades: 5334
# Sharpe: 0.907
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 8          |
# |    fps             | 93         |
# |    time_elapsed    | 31         |
# |    total_timesteps | 2912       |
# | train/             |            |
# |    actor_loss      | 445        |
# |    critic_loss     | 72.7       |
# |    ent_coef        | 0.125      |
# |    ent_coef_loss   | 199        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 2847       |
# |    reward          | 0.99319184 |
# -----------------------------------
# day: 363, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1576045.75
# total_reward: 576045.75
# total_cost: 11001.60
# total_trades: 6320
# Sharpe: 1.374
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 94        |
# |    time_elapsed    | 46        |
# |    total_timesteps | 4368      |
# | train/             |           |
# |    actor_loss      | 478       |
# |    critic_loss     | 100       |
# |    ent_coef        | 0.138     |
# |    ent_coef_loss   | 149       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 4303      |
# |    reward          | 1.7690833 |
# ----------------------------------
# day: 363, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1274969.54
# total_reward: 274969.54
# total_cost: 9492.44
# total_trades: 6281
# Sharpe: 0.852
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 16          |
# |    fps             | 94          |
# |    time_elapsed    | 61          |
# |    total_timesteps | 5824        |
# | train/             |             |
# |    actor_loss      | 492         |
# |    critic_loss     | 141         |
# |    ent_coef        | 0.151       |
# |    ent_coef_loss   | 53.1        |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 5759        |
# |    reward          | -0.14526235 |
# ------------------------------------
# day: 363, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1213301.36
# total_reward: 213301.36
# total_cost: 7997.17
# total_trades: 6353
# Sharpe: 0.727
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 94         |
# |    time_elapsed    | 77         |
# |    total_timesteps | 7280       |
# | train/             |            |
# |    actor_loss      | 444        |
# |    critic_loss     | 501        |
# |    ent_coef        | 0.151      |
# |    ent_coef_loss   | -37.5      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7215       |
# |    reward          | -0.3101947 |
# -----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 93       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 8736     |
# | train/             |          |
# |    actor_loss      | 383      |
# |    critic_loss     | 137      |
# |    ent_coef        | 0.133    |
# |    ent_coef_loss   | -59      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8671     |
# |    reward          | 1.208138 |
# ---------------------------------
# day: 363, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1219900.50
# total_reward: 219900.50
# total_cost: 3534.41
# total_trades: 6203
# Sharpe: 0.729
# =================================
# ======SAC Validation from:  2020-06-03 to  2020-09-02
# SAC Sharpe Ratio:  0.28251415623275133
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_15
# day: 363, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1029652.61
# total_reward: 29652.61
# total_cost: 9450.89
# total_trades: 6940
# Sharpe: 0.307
# =================================
# ------------------------------------
# | time/              |             |
# |    fps             | 828         |
# |    iterations      | 1           |
# |    time_elapsed    | 2           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | -0.59638375 |
# ------------------------------------
# day: 363, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1054370.45
# total_reward: 54370.45
# total_cost: 9670.22
# total_trades: 6969
# Sharpe: 0.475
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0067257197 |
# |    clip_fraction        | 0.0936       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.459        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00707     |
# |    reward               | 0.60225815   |
# |    std                  | 1.01         |
# |    value_loss           | 1.35         |
# ------------------------------------------
# day: 363, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1076865.41
# total_reward: 76865.41
# total_cost: 9504.42
# total_trades: 6948
# Sharpe: 0.631
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007019436 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.736       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00732    |
# |    reward               | 0.25248852  |
# |    std                  | 1.01        |
# |    value_loss           | 2.3         |
# -----------------------------------------
# day: 363, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1030043.60
# total_reward: 30043.60
# total_cost: 9595.29
# total_trades: 6910
# Sharpe: 0.316
# =================================
# day: 363, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1014109.17
# total_reward: 14109.17
# total_cost: 9684.08
# total_trades: 6978
# Sharpe: 0.140
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008280287 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | -3.3e-05    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.289       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00585    |
# |    reward               | -0.17219968 |
# |    std                  | 1.01        |
# |    value_loss           | 1.43        |
# -----------------------------------------
# day: 363, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1068006.74
# total_reward: 68006.74
# total_cost: 9808.87
# total_trades: 7001
# Sharpe: 0.479
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008855219 |
# |    clip_fraction        | 0.0844      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 3.93e-06    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.28        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00745    |
# |    reward               | 0.15409912  |
# |    std                  | 1.01        |
# |    value_loss           | 2.78        |
# -----------------------------------------
# ======PPO Validation from:  2020-06-03 to  2020-09-02
# PPO Sharpe Ratio:  0.2288655721801531
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_15
# day: 363, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1343972.30
# total_reward: 343972.30
# total_cost: 999.00
# total_trades: 3993
# Sharpe: 0.976
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 133       |
# |    time_elapsed    | 10        |
# |    total_timesteps | 1456      |
# | train/             |           |
# |    actor_loss      | 849       |
# |    critic_loss     | 557       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1092      |
# |    reward          | -0.496901 |
# ----------------------------------
# day: 363, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1343972.30
# total_reward: 343972.30
# total_cost: 999.00
# total_trades: 3993
# Sharpe: 0.976
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 116       |
# |    time_elapsed    | 25        |
# |    total_timesteps | 2912      |
# | train/             |           |
# |    actor_loss      | 545       |
# |    critic_loss     | 430       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2548      |
# |    reward          | -0.496901 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 111       |
# |    time_elapsed    | 39        |
# |    total_timesteps | 4368      |
# | train/             |           |
# |    actor_loss      | 397       |
# |    critic_loss     | 504       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4004      |
# |    reward          | -0.496901 |
# ----------------------------------
# day: 363, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1343972.30
# total_reward: 343972.30
# total_cost: 999.00
# total_trades: 3993
# Sharpe: 0.976
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 109       |
# |    time_elapsed    | 53        |
# |    total_timesteps | 5824      |
# | train/             |           |
# |    actor_loss      | 328       |
# |    critic_loss     | 1.23e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5460      |
# |    reward          | -0.496901 |
# ----------------------------------
# day: 363, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1343972.30
# total_reward: 343972.30
# total_cost: 999.00
# total_trades: 3993
# Sharpe: 0.976
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 108       |
# |    time_elapsed    | 67        |
# |    total_timesteps | 7280      |
# | train/             |           |
# |    actor_loss      | 274       |
# |    critic_loss     | 1.2e+03   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6916      |
# |    reward          | -0.496901 |
# ----------------------------------
# day: 363, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1343972.30
# total_reward: 343972.30
# total_cost: 999.00
# total_trades: 3993
# Sharpe: 0.976
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 106       |
# |    time_elapsed    | 81        |
# |    total_timesteps | 8736      |
# | train/             |           |
# |    actor_loss      | 219       |
# |    critic_loss     | 553       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8372      |
# |    reward          | -0.496901 |
# ----------------------------------
# day: 363, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1343972.30
# total_reward: 343972.30
# total_cost: 999.00
# total_trades: 3993
# Sharpe: 0.976
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 106       |
# |    time_elapsed    | 95        |
# |    total_timesteps | 10192     |
# | train/             |           |
# |    actor_loss      | 178       |
# |    critic_loss     | 387       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9828      |
# |    reward          | -0.496901 |
# ----------------------------------
# ======TD3 Validation from:  2020-06-03 to  2020-09-02
# ======Best Model Retraining from:  2018-11-06 to  2020-09-02
# ======Trading from:  2020-09-02 to  2020-12-08
# ============================================
# ======Model training from:  2018-11-06 to  2020-09-02
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 64, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_252_6
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 94        |
# |    time_elapsed    | 18        |
# |    total_timesteps | 1708      |
# | train/             |           |
# |    actor_loss      | -19.4     |
# |    critic_loss     | 44.3      |
# |    ent_coef        | 0.112     |
# |    ent_coef_loss   | 194       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1643      |
# |    reward          | 7.0495887 |
# ----------------------------------
# day: 426, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1278912.49
# total_reward: 278912.49
# total_cost: 7845.70
# total_trades: 6554
# Sharpe: 0.710
# =================================
# ------------------------------------
# | time/              |             |
# |    episodes        | 8           |
# |    fps             | 93          |
# |    time_elapsed    | 36          |
# |    total_timesteps | 3416        |
# | train/             |             |
# |    actor_loss      | 103         |
# |    critic_loss     | 41.4        |
# |    ent_coef        | 0.129       |
# |    ent_coef_loss   | 142         |
# |    learning_rate   | 0.0001      |
# |    n_updates       | 3351        |
# |    reward          | -0.18339148 |
# ------------------------------------
# day: 426, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1780283.14
# total_reward: 780283.14
# total_cost: 14718.83
# total_trades: 7365
# Sharpe: 1.357
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 92         |
# |    time_elapsed    | 55         |
# |    total_timesteps | 5124       |
# | train/             |            |
# |    actor_loss      | 187        |
# |    critic_loss     | 610        |
# |    ent_coef        | 0.146      |
# |    ent_coef_loss   | 18.7       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 5059       |
# |    reward          | 0.44074526 |
# -----------------------------------
# day: 426, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1411627.01
# total_reward: 411627.01
# total_cost: 8858.95
# total_trades: 7480
# Sharpe: 1.052
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 91        |
# |    time_elapsed    | 74        |
# |    total_timesteps | 6832      |
# | train/             |           |
# |    actor_loss      | 136       |
# |    critic_loss     | 86        |
# |    ent_coef        | 0.138     |
# |    ent_coef_loss   | -56.7     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6767      |
# |    reward          | 1.9137503 |
# ----------------------------------
# day: 426, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1284600.95
# total_reward: 284600.95
# total_cost: 5158.14
# total_trades: 7019
# Sharpe: 0.780
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 91         |
# |    time_elapsed    | 93         |
# |    total_timesteps | 8540       |
# | train/             |            |
# |    actor_loss      | 120        |
# |    critic_loss     | 1.27e+03   |
# |    ent_coef        | 0.117      |
# |    ent_coef_loss   | -62.6      |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 8475       |
# |    reward          | -0.5142485 |
# -----------------------------------
# ======SAC Validation from:  2020-09-02 to  2020-12-08
# SAC Sharpe Ratio:  0.08050315283704071
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_5
# day: 426, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1150997.34
# total_reward: 150997.34
# total_cost: 11818.64
# total_trades: 8262
# Sharpe: 0.858
# =================================
# -----------------------------------
# | time/              |            |
# |    fps             | 862        |
# |    iterations      | 1          |
# |    time_elapsed    | 2          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.08832016 |
# -----------------------------------
# day: 426, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1144267.73
# total_reward: 144267.73
# total_cost: 11754.46
# total_trades: 8223
# Sharpe: 0.883
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0108921565 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -0.000206    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.74         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0106      |
# |    reward               | 0.6615611    |
# |    std                  | 1            |
# |    value_loss           | 2.22         |
# ------------------------------------------
# day: 426, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1285419.30
# total_reward: 285419.30
# total_cost: 11657.18
# total_trades: 8237
# Sharpe: 1.096
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012019475 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.0155      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.4         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.011      |
# |    reward               | -1.1898172  |
# |    std                  | 1           |
# |    value_loss           | 4.92        |
# -----------------------------------------
# day: 426, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1405779.48
# total_reward: 405779.48
# total_cost: 11413.64
# total_trades: 8062
# Sharpe: 1.668
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.009949772  |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | 0.000478     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.18         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0105      |
# |    reward               | -0.010168629 |
# |    std                  | 1.01         |
# |    value_loss           | 7.16         |
# ------------------------------------------
# day: 426, episode: 45
# begin_total_asset: 1000000.00
# end_total_asset: 1293975.70
# total_reward: 293975.70
# total_cost: 11606.72
# total_trades: 8086
# Sharpe: 1.449
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009641897 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.44        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00974    |
# |    reward               | 1.2543669   |
# |    std                  | 1.01        |
# |    value_loss           | 7.8         |
# -----------------------------------------
# ======PPO Validation from:  2020-09-02 to  2020-12-08
# PPO Sharpe Ratio:  5.544173983496681e-05
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_252_5
# day: 426, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1459377.48
# total_reward: 459377.48
# total_cost: 999.00
# total_trades: 4211
# Sharpe: 1.056
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 138      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1708     |
# | train/             |          |
# |    actor_loss      | 204      |
# |    critic_loss     | 105      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1281     |
# |    reward          | 1.767546 |
# ---------------------------------
# day: 426, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1459377.48
# total_reward: 459377.48
# total_cost: 999.00
# total_trades: 4211
# Sharpe: 1.056
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 121      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 3416     |
# | train/             |          |
# |    actor_loss      | 124      |
# |    critic_loss     | 121      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2989     |
# |    reward          | 1.767546 |
# ---------------------------------
# day: 426, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1459377.48
# total_reward: 459377.48
# total_cost: 999.00
# total_trades: 4211
# Sharpe: 1.056
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 116      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 5124     |
# | train/             |          |
# |    actor_loss      | 87.7     |
# |    critic_loss     | 284      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4697     |
# |    reward          | 1.767546 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 114      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 6832     |
# | train/             |          |
# |    actor_loss      | 79.1     |
# |    critic_loss     | 169      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6405     |
# |    reward          | 1.767546 |
# ---------------------------------
# day: 426, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 1459377.48
# total_reward: 459377.48
# total_cost: 999.00
# total_trades: 4211
# Sharpe: 1.056
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 113      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 8540     |
# | train/             |          |
# |    actor_loss      | 62.7     |
# |    critic_loss     | 299      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8113     |
# |    reward          | 1.767546 |
# ---------------------------------
# day: 426, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1459377.48
# total_reward: 459377.48
# total_cost: 999.00
# total_trades: 4211
# Sharpe: 1.056
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 112      |
# |    time_elapsed    | 91       |
# |    total_timesteps | 10248    |
# | train/             |          |
# |    actor_loss      | 58.4     |
# |    critic_loss     | 134      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9821     |
# |    reward          | 1.767546 |
# ---------------------------------
# ======TD3 Validation from:  2020-09-02 to  2020-12-08
# ======Best Model Retraining from:  2018-11-06 to  2020-12-08
# ======Trading from:  2020-12-08 to  2021-03-15
# ============================================
# ======Model training from:  2018-11-06 to  2020-12-08
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 64, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_3
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 93        |
# |    time_elapsed    | 20        |
# |    total_timesteps | 1960      |
# | train/             |           |
# |    actor_loss      | 305       |
# |    critic_loss     | 112       |
# |    ent_coef        | 0.115     |
# |    ent_coef_loss   | 246       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 1895      |
# |    reward          | -2.592944 |
# ----------------------------------
# day: 489, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1437572.28
# total_reward: 437572.28
# total_cost: 3580.53
# total_trades: 6611
# Sharpe: 0.804
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 92       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 3920     |
# | train/             |          |
# |    actor_loss      | 465      |
# |    critic_loss     | 202      |
# |    ent_coef        | 0.138    |
# |    ent_coef_loss   | 216      |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3855     |
# |    reward          | -2.61584 |
# ---------------------------------
# day: 489, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1471727.73
# total_reward: 471727.73
# total_cost: 4329.33
# total_trades: 6443
# Sharpe: 0.824
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 12         |
# |    fps             | 92         |
# |    time_elapsed    | 63         |
# |    total_timesteps | 5880       |
# | train/             |            |
# |    actor_loss      | 551        |
# |    critic_loss     | 772        |
# |    ent_coef        | 0.162      |
# |    ent_coef_loss   | 132        |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 5815       |
# |    reward          | -2.3725383 |
# -----------------------------------
# day: 489, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1772137.57
# total_reward: 772137.57
# total_cost: 15297.54
# total_trades: 8311
# Sharpe: 1.310
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 16         |
# |    fps             | 92         |
# |    time_elapsed    | 84         |
# |    total_timesteps | 7840       |
# | train/             |            |
# |    actor_loss      | 619        |
# |    critic_loss     | 355        |
# |    ent_coef        | 0.188      |
# |    ent_coef_loss   | 85.5       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 7775       |
# |    reward          | -0.1366085 |
# -----------------------------------
# day: 489, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1799072.59
# total_reward: 799072.59
# total_cost: 11550.21
# total_trades: 8194
# Sharpe: 1.337
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 20         |
# |    fps             | 92         |
# |    time_elapsed    | 106        |
# |    total_timesteps | 9800       |
# | train/             |            |
# |    actor_loss      | 628        |
# |    critic_loss     | 525        |
# |    ent_coef        | 0.209      |
# |    ent_coef_loss   | 31.3       |
# |    learning_rate   | 0.0001     |
# |    n_updates       | 9735       |
# |    reward          | -2.0621552 |
# -----------------------------------
# ======SAC Validation from:  2020-12-08 to  2021-03-15
# SAC Sharpe Ratio:  0.06599287675654522
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_3
# day: 489, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1145654.00
# total_reward: 145654.00
# total_cost: 13739.01
# total_trades: 9345
# Sharpe: 0.927
# =================================
# -----------------------------------
# | time/              |            |
# |    fps             | 821        |
# |    iterations      | 1          |
# |    time_elapsed    | 2          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.10046976 |
# -----------------------------------
# -----------------------------------------
# ...
# |    ent_coef_loss   | -44.8     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 8839      |
# |    reward          | -0.572552 |
# ----------------------------------
# ======SAC Validation from:  2022-01-05 to  2022-04-25
# SAC Sharpe Ratio:  -0.3452478941291344
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_567_1
# day: 741, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1175331.40
# total_reward: 175331.40
# total_cost: 22340.90
# total_trades: 14317
# Sharpe: 0.581
# =================================
# ---------------------------------
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 2.480701 |
# ---------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 667          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0073004733 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.4        |
# |    explained_variance   | -5.25e-06    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.16         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00521     |
# |    reward               | -0.558295    |
# |    std                  | 1            |
# |    value_loss           | 5.7          |
# ------------------------------------------
# day: 741, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1022368.21
# total_reward: 22368.21
# total_cost: 22663.29
# total_trades: 14427
# Sharpe: 0.125
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 653        |
# |    iterations           | 3          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00989331 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.4      |
# |    explained_variance   | 0.0333     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 2.54       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00987   |
# |    reward               | 0.5305226  |
# |    std                  | 1          |
# |    value_loss           | 8.39       |
# ----------------------------------------
# day: 741, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 1156765.38
# total_reward: 156765.38
# total_cost: 22325.64
# total_trades: 14377
# Sharpe: 0.391
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.007457903  |
# |    clip_fraction        | 0.0844       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -28.5        |
# |    explained_variance   | 0.0239       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.12         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00609     |
# |    reward               | -0.054851387 |
# |    std                  | 1.01         |
# |    value_loss           | 6.61         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005986956 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.64        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00719    |
# |    reward               | 1.8045112   |
# |    std                  | 1.01        |
# |    value_loss           | 7.73        |
# -----------------------------------------
# ======PPO Validation from:  2022-01-05 to  2022-04-25
# PPO Sharpe Ratio:  -0.23306896888126158
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_567_1
# day: 741, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1685745.00
# total_reward: 685745.00
# total_cost: 999.00
# total_trades: 5187
# Sharpe: 0.762
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 131       |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2968      |
# | train/             |           |
# |    actor_loss      | -96.5     |
# |    critic_loss     | 80.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2226      |
# |    reward          | -1.153636 |
# ----------------------------------
# day: 741, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1685745.00
# total_reward: 685745.00
# total_cost: 999.00
# total_trades: 5187
# Sharpe: 0.762
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 118       |
# |    time_elapsed    | 50        |
# |    total_timesteps | 5936      |
# | train/             |           |
# |    actor_loss      | -42.7     |
# |    critic_loss     | 1.03e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5194      |
# |    reward          | -1.153636 |
# ----------------------------------
# day: 741, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1685745.00
# total_reward: 685745.00
# total_cost: 999.00
# total_trades: 5187
# Sharpe: 0.762
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 114       |
# |    time_elapsed    | 77        |
# |    total_timesteps | 8904      |
# | train/             |           |
# |    actor_loss      | -20.5     |
# |    critic_loss     | 214       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8162      |
# |    reward          | -1.153636 |
# ----------------------------------
# ======TD3 Validation from:  2022-01-05 to  2022-04-25
# ======Best Model Retraining from:  2018-11-06 to  2022-04-25
# ======Trading from:  2022-04-25 to  2022-07-27
# ============================================
# ======Model training from:  2018-11-06 to  2022-04-25
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 64, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_630_1
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 88        |
# |    time_elapsed    | 36        |
# |    total_timesteps | 3220      |
# | train/             |           |
# |    actor_loss      | 554       |
# |    critic_loss     | 92.1      |
# |    ent_coef        | 0.131     |
# |    ent_coef_loss   | 285       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 3155      |
# |    reward          | 1.3106186 |
# ----------------------------------
# day: 804, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1106312.46
# total_reward: 106312.46
# total_cost: 11679.08
# total_trades: 11927
# Sharpe: 0.251
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 88        |
# |    time_elapsed    | 72        |
# |    total_timesteps | 6440      |
# | train/             |           |
# |    actor_loss      | 750       |
# |    critic_loss     | 2.11e+03  |
# |    ent_coef        | 0.175     |
# |    ent_coef_loss   | 174       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 6375      |
# |    reward          | 1.1672065 |
# ----------------------------------
# day: 804, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1236669.27
# total_reward: 236669.27
# total_cost: 25068.32
# total_trades: 13529
# Sharpe: 0.414
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 87        |
# |    time_elapsed    | 109       |
# |    total_timesteps | 9660      |
# | train/             |           |
# |    actor_loss      | 980       |
# |    critic_loss     | 2.21e+03  |
# |    ent_coef        | 0.236     |
# |    ent_coef_loss   | 125       |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 9595      |
# |    reward          | 1.1432837 |
# ----------------------------------
# ======SAC Validation from:  2022-04-25 to  2022-07-27
# SAC Sharpe Ratio:  -0.057314127444549695
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_630_1
# day: 804, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 948427.63
# total_reward: -51572.37
# total_cost: 24207.05
# total_trades: 15589
# Sharpe: -0.095
# =================================
# -----------------------------------
# | time/              |            |
# |    fps             | 660        |
# |    iterations      | 1          |
# |    time_elapsed    | 3          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.16790757 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008840414 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | -0.0038     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.9         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00725    |
# |    reward               | -0.8119248  |
# |    std                  | 1           |
# |    value_loss           | 5.67        |
# -----------------------------------------
# day: 804, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1019091.48
# total_reward: 19091.48
# total_cost: 23685.92
# total_trades: 15496
# Sharpe: 0.109
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010548246 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.4       |
# |    explained_variance   | 0.0203      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.56        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00959    |
# |    reward               | 0.0713855   |
# |    std                  | 1           |
# |    value_loss           | 6.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 4           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010923783 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.017       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.37        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00964    |
# |    reward               | -0.08180079 |
# |    std                  | 1.01        |
# |    value_loss           | 4.81        |
# -----------------------------------------
# day: 804, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 861542.46
# total_reward: -138457.54
# total_cost: 23789.93
# total_trades: 15487
# Sharpe: -0.190
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011173479 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.5       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.41        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00929    |
# |    reward               | -1.2920647  |
# |    std                  | 1.01        |
# |    value_loss           | 8.27        |
# -----------------------------------------
# ======PPO Validation from:  2022-04-25 to  2022-07-27
# PPO Sharpe Ratio:  0.0010268787253452966
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_630_1
# day: 804, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1246989.47
# total_reward: 246989.47
# total_cost: 1442.42
# total_trades: 8165
# Sharpe: 0.396
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 110      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 3220     |
# | train/             |          |
# |    actor_loss      | -50.2    |
# |    critic_loss     | 29.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2415     |
# |    reward          | 0.305336 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 97       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 6440     |
# | train/             |          |
# |    actor_loss      | -19.8    |
# |    critic_loss     | 347      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5635     |
# |    reward          | 0.305336 |
# ---------------------------------
# day: 804, episode: 35
# begin_total_asset: 1000000.00
# end_total_asset: 1246989.47
# total_reward: 246989.47
# total_cost: 1442.42
# total_trades: 8165
# Sharpe: 0.396
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 93       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 9660     |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 140      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8855     |
# |    reward          | 0.305336 |
# ---------------------------------
# ======TD3 Validation from:  2022-04-25 to  2022-07-27
# ======Best Model Retraining from:  2018-11-06 to  2022-07-27
# ======Trading from:  2022-07-27 to  2022-11-01
# Ensemble Strategy took:  34.24129038651784  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2020-03-02  2020-06-03        SAC   0.124777    0.06388    0.093603
# 1  189  2020-06-03  2020-09-02        TD3   0.282514   0.228866    0.305847
# 2  252  2020-09-02  2020-12-08        TD3   0.080503   0.000055    0.253033
# 3  315  2020-12-08  2021-03-15        SAC   0.065993    -0.0049    -0.00688
# 4  378  2021-03-15  2021-07-01        TD3  -0.207411  -0.322241   -0.146199
# 5  441  2021-07-01  2021-09-30        PPO  -0.183778  -0.148228   -0.201312
# 6  504  2021-09-30  2022-01-05        SAC  -0.021491   -0.12729   -0.037173
# 7  567  2022-01-05  2022-04-25        PPO  -0.345248  -0.233069   -0.426652
# 8  630  2022-04-25  2022-07-27        PPO  -0.057314   0.001027    -0.01936

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = addfeature_df[(addfeature_df.date > TRADE_START_DATE)&(addfeature_df.date <= TRADE_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.5158480453998056

# %%
df_account_value

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.131875
# Cumulative returns    -0.272539
# Annual volatility      0.225352
# Sharpe ratio          -0.515848
# Calmar ratio          -0.297050
# Stability              0.726135
# Max drawdown          -0.443949
# Omega ratio            0.916769
# Sortino ratio         -0.706542
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.946694
# Daily value at risk   -0.028853
# dtype: float64

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')

# %%
selected_tics = addfeature_df['tic'].unique()

# %%
#获取随机选择的tic在select_date的权重并修正
def get_selected_index_weight(df_index,select_date,selected_tics):
    df = df_index[df_index['trade_date'] == select_date]
    select_df = df[df['con_code'].isin(selected_tics)]
    select_df = select_df.drop('index_code',axis=1).rename(columns={'con_code':'tic','trade_date':'date'})
    select_df = select_df.reset_index()
    weight_sum = select_df['weight'].sum()
#     print(select_df)
    for i in range(len(select_df)):
        select_df.loc[i,'weight'] = (select_df.loc[i,'weight'] / weight_sum)*100
    return select_df.loc[:,['tic','date','weight']]

baseline_weight =get_selected_index_weight(df_index,select_date,selected_tics)
baseline_weight = baseline_weight.sort_values(['tic'],ascending=True).reset_index(drop=True)
print(baseline_weight)
# Out:
#           tic      date     weight
# 0   600009.SH  20200228   2.690037
# 1   600028.SH  20200228   2.615053
# 2   600030.SH  20200228   7.824070
# 3   600031.SH  20200228   4.365451
# 4   600050.SH  20200228   2.167495
# 5   600104.SH  20200228   3.306308
# 6   600309.SH  20200228   3.137595
# 7   600585.SH  20200228   4.660699
# 8   601012.SH  20200228   3.444559
# 9   601066.SH  20200228   0.611585
# 10  601186.SH  20200228   1.858187
# 11  601318.SH  20200228  35.769519
# 12  601328.SH  20200228   6.068985
# 13  601390.SH  20200228   1.858187
# 14  601398.SH  20200228   4.857531
# 15  601601.SH  20200228   4.257662
# 16  601668.SH  20200228   4.787234
# 17  601766.SH  20200228   2.645515
# 18  601939.SH  20200228   1.853501
# 19  603993.SH  20200228   1.220827

# %%
#计算所选股票的buy & hold策略
def calculate_selected_baseline(df,full_date_range,selected_tics):
    df = df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
    baseline = pd.DataFrame({'date':full_date_range['date']})
    for i in range(len(full_date_range)):
        temp_date = full_date_range.loc[i,'date']
        temp_df = df[df['date'] == temp_date].sort_values('tic',ascending=True)
        close = list(temp_df['close'])
        weight = list(baseline_weight['weight'])
        baseline.loc[i,'account_value'] = sum(np.array(close) * np.array(weight)) #注意权重和收盘价对应的股票顺序
    baseline['date'] = pd.to_datetime(baseline['date'])
#     baseline.set_index("date", inplace=True, drop=True)
#     baseline.index = baseline.index.tz_localize("UTC")
    return baseline
# full_date_range = get_trading_days(exchange='SSE',start_date='20210301', end_date='20230227')
# full_date_range = full_date_range.sort_values('trade_date',ascending=True).reset_index(drop=True)
full_date_range1 = pd.DataFrame({'date':df_account_value['date'].unique()}).reset_index(drop=True)
baseline_sse = calculate_selected_baseline(addfeature_df,full_date_range1,selected_tics)
baseline_sse
# Out:
#           date  account_value
# 0   2020-06-03    4043.726099
# 1   2020-06-04    4033.556074
# 2   2020-06-05    4043.033204
# 3   2020-06-08    4105.227880
# 4   2020-06-09    4109.365732
# ..         ...            ...
# 562 2022-10-25    2538.684905
# 563 2022-10-26    2539.953651
# 564 2022-10-27    2544.820531
# 565 2022-10-28    2485.820016
# 566 2022-10-31    2439.141086
#
# [567 rows x 2 columns]

# %%
merged_df

# %%
#baseline stats
print("==============Get Baseline Stats===========")
# baseline_df = get_baseline(
#         ticker="^DJI", 
#         start = df_account_value.loc[0,'date'],
#         end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_sse, value_col_name = 'account_value')

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
from copy import deepcopy
def backtest_plot_com(
    account_value,
    baseline,
    baseline_start=TRADE_START_DATE,
    baseline_end=TRADE_END_DATE,
    value_col_name="account_value",
):
    df = deepcopy(account_value)
    df["date"] = pd.to_datetime(df["date"])
    test_returns = get_daily_return(df, value_col_name=value_col_name)
#     pro = ts.pro_api()
#     baseline_df = pro.index_daily(ts_code='000016.sh',start_date = '20200301',end_date='20230227')
#     baseline_df = baseline_df.rename(columns={'trade_date':'date'})
#     baseline_df = baseline_df.sort_values('date',ascending=True)
    baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
    with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(
            returns=test_returns, benchmark_rets=baseline_returns, set_context=False
        )

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-10-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>27</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-13.188%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-27.254%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>22.535%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.52</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.30</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.73</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-44.395%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.71</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.885%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.03</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.72</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>44.39</td>
#       <td>2021-01-13</td>
#       <td>2022-10-31</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7.16</td>
#       <td>2020-08-28</td>
#       <td>2020-09-30</td>
#       <td>2020-11-04</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.02</td>
#       <td>2020-11-20</td>
#       <td>2020-12-22</td>
#       <td>2021-01-06</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.07</td>
#       <td>2020-07-20</td>
#       <td>2020-07-24</td>
#       <td>2020-08-14</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.00</td>
#       <td>2020-07-06</td>
#       <td>2020-07-16</td>
#       <td>2020-07-20</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.05%</td>
#       <td>-4.75%</td>
#       <td>5.59%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
