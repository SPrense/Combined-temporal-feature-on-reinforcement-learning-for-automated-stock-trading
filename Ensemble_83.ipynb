# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# !pip install stable_baselines3
# !pip install yfinance
# !pip install tushare
# !pip install exchange_calendars
# !pip install wrds
# !pip install alpaca_trade_api
# !pip install stockstats
# !pip install pyfolio

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime
from torch import nn
from torch import optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading_add import StockTradingEnv
from finrl.agents.stablebaselines3.models_add import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)

# %%
df = pd.read_csv('merged_df.csv')
df

# %%
TRAIN_START_DATE = '2012-2-28'
TRAIN_END_DATE = '2020-02-28'
TRADE_START_DATE = '2021-7-30'
TRADE_END_DATE = '2023-08-30'

# %%
import tushare as ts
ts.set_token('6314756019e50a6672690e5a78b2dbf7cfcd27c6f6a6b48a8cf76dae')
pro = ts.pro_api()

# %%
#选择上证50指数的成分股
df_index = pro.index_weight(index_code='000016.sh', start_date='20151010', end_date='20220228')
# df_index.to_csv('SSE_50_index_weight.csv',index=0)

# %%
#选择某个时间点的上证50指数成分股作为参考跟踪股票池
select_date = '20220228' #自定义的时间点为每个月的月末
df_select = df_index[df_index['trade_date']==select_date]
sort_SSEindex = df_select['con_code'].unique()
print(sorted(sort_SSEindex),len(sort_SSEindex))
# Out:
# ['600000.SH', '600028.SH', '600030.SH', '600031.SH', '600036.SH', '600048.SH', '600050.SH', '600104.SH', '600196.SH', '600276.SH', '600309.SH', '600436.SH', '600438.SH', '600519.SH', '600547.SH', '600570.SH', '600585.SH', '600588.SH', '600690.SH', '600745.SH', '600809.SH', '600837.SH', '600887.SH', '600893.SH', '600900.SH', '601012.SH', '601066.SH', '601088.SH', '601138.SH', '601166.SH', '601211.SH', '601288.SH', '601318.SH', '601336.SH', '601398.SH', '601601.SH', '601628.SH', '601633.SH', '601668.SH', '601688.SH', '601728.SH', '601857.SH', '601888.SH', '601899.SH', '601919.SH', '601995.SH', '603259.SH', '603288.SH', '603501.SH', '603986.SH'] 50

# %%
#随机选择成分股中的k只股票
import random 
k = 10
selected_tics = random.sample(list(sort_SSEindex),k)
print(selected_tics)
# Out:
# ['600809.SH', '600036.SH', '601336.SH', '600436.SH', '601012.SH', '600887.SH', '600893.SH', '600900.SH', '601728.SH', '600048.SH']

# %%
selected_tics = ['600000.SH', '600028.SH', '600030.SH', '600031.SH', '600036.SH', '600048.SH', '600050.SH', '600104.SH', '600196.SH', '600276.SH']

# %%
#Download随机选择的k只股票数据
df_ts =pd.DataFrame()
for c in selected_tics:
    temp=pro.daily(ts_code=c,start_date=TRAIN_START_DATE,end_date=TRADE_END_DATE)
    df_ts=pd.concat([df_ts,temp])
print(df_ts)
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     600000.SH   20221230   7.23   7.30   7.22   7.28       7.24    0.04
# 1     600000.SH   20221229   7.27   7.29   7.18   7.24       7.30   -0.06
# 2     600000.SH   20221228   7.22   7.30   7.20   7.30       7.22    0.08
# 3     600000.SH   20221227   7.13   7.29   7.12   7.22       7.10    0.12
# 4     600000.SH   20221226   7.19   7.21   7.08   7.10       7.19   -0.09
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 1454  600276.SH   20170109  45.91  46.03  45.20  45.57      45.99   -0.42
# 1455  600276.SH   20170106  46.54  46.74  45.88  45.99      46.59   -0.60
# 1456  600276.SH   20170105  46.54  46.77  46.37  46.59      46.58    0.01
# 1457  600276.SH   20170104  46.14  46.84  46.01  46.58      46.00    0.58
# 1458  600276.SH   20170103  45.40  46.40  45.30  46.00      45.50    0.50
#
#       pct_chg        vol      amount
# 0      0.5525  203523.97  147932.731
# 1     -0.8219  183670.88  132652.083
# 2      1.1080  209013.64  152167.734
# 3      1.6901  240651.92  173516.852
# 4     -1.2517  201385.33  143606.824
# ...       ...        ...         ...
# 1454  -0.9100   71542.84  326091.518
# 1455  -1.2900   41927.87  193329.661
# 1456   0.0200   48903.06  227644.166
# 1457   1.2600   47645.91  221356.008
# 1458   1.1000   45691.77  209815.374
#
# [14478 rows x 11 columns]

# %%
def processed_date_range(df,selected_tics,k):
    longth = []
    for tic in selected_tics:
        temp_df = df[df['ts_code'] == tic]
        temp_long = temp_df['trade_date'].iloc[-1]
        longth.append(temp_long)
    minlong = max(longth)
    date_unique = [date for date in df['trade_date'].unique() if date >= minlong]
    full_date_range = pd.DataFrame(date_unique,columns=['trade_date'])
    
    return full_date_range
#     date_unique = df['trade_date'].unique()

# %%
full_date_range = processed_date_range(df_ts,selected_tics,k)

# %%
#遍历扩充股票的完整交易日期
def add_exchange_calendars(df,full_date_range,selected_tics):
    count = 0
    merge_df = []
    for tic in selected_tics:
        temp_df = df[df['ts_code'] == tic]
        temp_full_date_range = full_date_range
        temp_df = temp_df.set_index('trade_date')
        temp_full_date_range = temp_full_date_range.set_index('trade_date')
        temp_df = pd.merge(temp_full_date_range,temp_df,how='left',left_index=True,right_index=True)
        temp_df = temp_df.reset_index().sort_values('trade_date',ascending=True)
        temp_df = temp_df.fillna({
            'amount' : 0,
            'vol': 0,
            'pct_chg': 0,
            'change':0,
            'ts_code': tic
        })
        for i in range(len(temp_df)):
            if pd.isna(temp_df.loc[i,'close']):
                j = i -1
                while pd.isna(temp_df.loc[j,'close']):
                    j = j - 1
                if j > 0 :
                    temp_df.loc[i,['close','open','high','low','pre_close']] = temp_df.loc[j,'close']
                    count+=1
        merge_df.append(temp_df)
    merged_df = pd.concat(merge_df,ignore_index = True)
    print(count)
    return merged_df

merged_df =  add_exchange_calendars(df_ts,full_date_range,selected_tics)
# merged_df = merged_df.rename(columns={'trade_date':'date','ts_code':'tic','vol':'volume'})
merged_df = merged_df[['ts_code','trade_date','open','high','low','close','pre_close','change','pct_chg','vol','amount']]
print(merged_df)
# Out:
# 112
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      600000.SH   20170103  16.21  16.44  16.17  16.30      16.21    0.09
# 1      600000.SH   20170104  16.29  16.35  16.18  16.33      16.30    0.03
# 2      600000.SH   20170105  16.30  16.38  16.24  16.30      16.33   -0.03
# 3      600000.SH   20170106  16.30  16.30  16.13  16.18      16.30   -0.12
# 4      600000.SH   20170109  16.24  16.29  16.13  16.20      16.18    0.02
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 14585  600276.SH   20221226  36.71  38.00  36.68  37.56      36.75    0.81
# 14586  600276.SH   20221227  37.88  37.89  36.88  37.07      37.56   -0.49
# 14587  600276.SH   20221228  36.99  37.85  36.92  37.40      37.07    0.33
# 14588  600276.SH   20221229  37.25  38.31  37.05  38.13      37.40    0.73
# 14589  600276.SH   20221230  38.17  38.85  38.17  38.53      38.13    0.40
#
#        pct_chg        vol       amount
# 0       0.5600  162371.25   265043.268
# 1       0.1800  296587.34   482612.222
# 2      -0.1800  264376.46   431449.126
# 3      -0.7400  171955.98   278864.536
# 4       0.1200  149087.45   241579.598
# ...        ...        ...          ...
# 14585   2.2041  316401.83  1188097.328
# 14586  -1.3046  320140.23  1187739.097
# 14587   0.8902  247494.78   927033.305
# 14588   1.9519  357508.43  1356125.789
# 14589   1.0490  282411.27  1088042.969
#
# [14590 rows x 11 columns]

# %%
processed_df = merged_df

# %%
# 筛选exchange_calender中每个交易节点缺失情况
def processed_date(df,selected_tics,k):
    longth = []
    for tic in selected_tics:
        temp_df = df[df['ts_code'] == tic]
        temp_long = temp_df['trade_date'].iloc[-1]
        longth.append(temp_long)
    minlong = max(longth)
    date_unique = [date for date in df['trade_date'].unique() if date > minlong]
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) < int(0.9*k):
            date_unique.remove(date)
        elif len(temp_df) >= int(0.9*k) and len(temp_df) < k:
            missing_tic = set(selected_tics).difference(set(temp_df['ts_code'].tolist()))
            print(missing_tic)
            for m_tic in missing_tic:
                temp_dict = {'ts_code':m_tic,'trade_date':date,'open':np.nan, 'high':np.nan,'low':np.nan, 'close':np.nan, 'pre_close':np.nan, 'change':np.nan, 'pct_chg':np.nan, 'volume':np.nan, 'amount':np.nan}
                new_data = pd.DataFrame.from_dict(temp_dict,orient='index').T
                temp_df = temp_df.append(new_data)
#             print(len(temp_df))
            processe_df.append(temp_df)
        else :
            count += 1
            processe_df.append(temp_df)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
# 筛选exchange_calender中每个交易节点缺失情况(全部补充0)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) != k:
            missing_tic = set(selected_tics).difference(set(temp_df['ts_code'].tolist()))
#             print(missing_tic)
            for m_tic in missing_tic:
                temp_dict = {'ts_code':m_tic,'trade_date':date,'open':0, 'high':0,'low':0, 'close':0, 'pre_close':0, 'change':0, 'pct_chg':0, 'volume':0, 'amount':0}
                new_data = pd.DataFrame.from_dict(temp_dict,orient='index').T
                temp_df = temp_df.append(new_data)
            processe_df.append(temp_df)
        else :
            processe_df.append(temp_df)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
# 筛选exchange_calender中每个交易节点缺失(激进)
def processed_date(df,selected_tics,k):
    date_unique = list(df['trade_date'].unique())
    date_sum = len(date_unique)
    count = 0
    processe_df =[]
    processed_df = pd.DataFrame()
    for date in date_unique:
        temp_df = df[df['trade_date'] == date]
        if len(temp_df) == k:
            processe_df.append(temp_df)
        else :
            date_unique.remove(date)
        processed_df = pd.concat(processe_df,ignore_index = True)       
    processed_df = processed_df.sort_values('trade_date',ascending=True).reset_index()
    processed_df = processed_df.drop('index',axis=1)
    return processed_df,date_unique

# %%
processed_df,date_unique = processed_date(df_ts,selected_tics,k=20)
print(processed_df)
# Out:
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      600196.SH   20190705  26.68  26.94  26.58  26.81      26.51    0.30
# 1      601012.SH   20190705  22.40  22.65  22.23  22.41      22.28    0.13
# 2      601628.SH   20190705  28.96  29.50  28.83  29.37      28.75    0.62
# 3      601318.SH   20190705  90.00  91.14  89.83  90.85      89.90    0.95
# 4      600028.SH   20190705   5.44   5.44   5.39   5.42       5.45   -0.03
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 11635  601601.SH   20211231  27.10  27.25  27.02  27.12      27.07    0.05
# 11636  600837.SH   20211231  12.29  12.33  12.24  12.26      12.23    0.03
# 11637  600196.SH   20211231  49.08  49.50  48.89  48.94      48.88    0.06
# 11638  601166.SH   20211231  19.11  19.16  18.98  19.04      19.05   -0.01
# 11639  601012.SH   20211231  84.00  87.33  84.00  86.20      81.23    4.97
#
#        pct_chg         vol        amount
# 0       1.1316   130610.00  3.500944e+05
# 1       0.5835   234298.90  5.267045e+05
# 2       2.1565   107013.64  3.131570e+05
# 3       1.0567   510522.42  4.623825e+06
# 4      -0.5505   627775.69  3.393007e+05
# ...        ...         ...           ...
# 11635   0.1847   189032.27  5.121428e+05
# 11636   0.2453   370912.03  4.556470e+05
# 11637   0.1227   193532.89  9.507004e+05
# 11638  -0.0525   553909.08  1.055757e+06
# 11639   6.1184  1213771.67  1.042053e+07
#
# [11640 rows x 11 columns]

# %%
processed_df1 = processed_df
processed_df1 = processed_df1.sort_values(['ts_code','trade_date'],ascending=True,ignore_index=True)
processed_df1['trade_date'] = pd.to_datetime(processed_df1['trade_date'])
processed_df1
# Out:
#          ts_code trade_date   open   high    low  close  pre_close  change  \
# 0      600000.SH 2017-01-03  16.21  16.44  16.17  16.30      16.21    0.09
# 1      600000.SH 2017-01-04  16.29  16.35  16.18  16.33      16.30    0.03
# 2      600000.SH 2017-01-05  16.30  16.38  16.24  16.30      16.33   -0.03
# 3      600000.SH 2017-01-06  16.30  16.30  16.13  16.18      16.30   -0.12
# 4      600000.SH 2017-01-09  16.24  16.29  16.13  16.20      16.18    0.02
# ...          ...        ...    ...    ...    ...    ...        ...     ...
# 14585  600276.SH 2022-12-26  36.71  38.00  36.68  37.56      36.75    0.81
# 14586  600276.SH 2022-12-27  37.88  37.89  36.88  37.07      37.56   -0.49
# 14587  600276.SH 2022-12-28  36.99  37.85  36.92  37.40      37.07    0.33
# 14588  600276.SH 2022-12-29  37.25  38.31  37.05  38.13      37.40    0.73
# 14589  600276.SH 2022-12-30  38.17  38.85  38.17  38.53      38.13    0.40
#
#        pct_chg        vol       amount
# 0       0.5600  162371.25   265043.268
# 1       0.1800  296587.34   482612.222
# 2      -0.1800  264376.46   431449.126
# 3      -0.7400  171955.98   278864.536
# 4       0.1200  149087.45   241579.598
# ...        ...        ...          ...
# 14585   2.2041  316401.83  1188097.328
# 14586  -1.3046  320140.23  1187739.097
# 14587   0.8902  247494.78   927033.305
# 14588   1.9519  357508.43  1356125.789
# 14589   1.0490  282411.27  1088042.969
#
# [14590 rows x 11 columns]

# %%
#出现缺失值的个数、占比
count = len(pro_df[pro_df['open'] == 0])
nan_rate = count/len(pro_df)
print(count,'缺失值百分之:',nan_rate)

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=False,
                    use_turbulence=False,
                    user_defined_feature = False)

# %%
processed_df3 = processed_df1.rename(columns={'ts_code':'tic','trade_date':'date','vol':'volume'})
processed_df3 = fe.preprocess_data(processed_df3)
processed_df3 = processed_df3.fillna(method="ffill").fillna(method="bfill")
processed_df3 = processed_df3.sort_values(['tic','date'],ascending=True).reset_index()
# Out:
# Successfully added technical indicators

# %%
def delaydate(dela,full_list):
    grouped = processed_df3.groupby('tic')
    filtered_df = pd.DataFrame()
    for name, group in grouped:
        # 按'trade_date'升序排序  True=升序
        group = group.sort_values('date', ascending=True)
        
        # 丢弃前48个日期的数据
        group = group.iloc[dela:]
        filtered_df = filtered_df.append(group)
    
    filtered_df = filtered_df.reset_index(drop=True)
    filtered_df = filtered_df.sort_values(['tic','date'],ascending=True,ignore_index=True)
    return filtered_df

# %%
pro_df = processed_df1.loc[:,['open','high','low','close','vol']].reset_index(drop=True)

# %%
#计算技术指标到dataset中
#Can be easily expanded
#Currently contains a small set of tech indicators
import talib as ta

def calc_tech_ind(data):
    #overlap 
    data['upbd'], data['midbd'], data['lowbd'] = ta.BBANDS(data["close"])
    data['dema'] = ta.DEMA(data["close"], timeperiod=30)
    data['tema'] = ta.TEMA(data["close"], timeperiod=30)
    data['ema'] = ta.EMA(data["close"], timeperiod=30)
    data['wma'] = ta.WMA(data["close"], timeperiod=30)
    data['sma'] = ta.SMA(data["close"], timeperiod=30)
    data['sarext'] = ta.SAREXT(data["high"], data["low"])
    
    #momentum
    data['adxr'] = ta.ADXR(data["high"], data["low"], data["close"], timeperiod=14)
    data['apo'] = ta.APO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['aroondown'], data['aroonup'] = ta.AROON(data["high"], data["low"], timeperiod=14)
    data['cci'] = ta.CCI(data["high"], data["low"], data["close"], timeperiod=14)
    data['cmo'] = ta.CMO(data["close"], timeperiod=14)
    data['macd'], data['macdsignal'], data['macdhist'] = ta.MACD(data["close"], fastperiod=12, slowperiod=26, signalperiod=9)
    data['MFI'] = ta.MFI(data["high"], data["low"], data["close"], data['vol'], timeperiod=14)
    data['mom'] = ta.MOM(data["close"], timeperiod=10)
    data['plus_di'] = ta.PLUS_DI(data["high"], data["low"], data["close"], timeperiod=14)
    data['ppo'] = ta.PPO(data["close"], fastperiod=12, slowperiod=26, matype=0)
    data['roc'] = ta.ROC(data["close"], timeperiod=10)
    data['rocp'] = ta.ROCP(data["close"], timeperiod=10)
    data['rsi'] = ta.RSI(data["close"], timeperiod=14)
    data['slowk'], data['slowd'] = ta.STOCH(data["high"], data["low"], data["close"])
    data['fastk'], data['fastd'] = ta.STOCHF(data["high"], data["low"], data["close"])
    data['trix'] = ta.TRIX(data["close"], timeperiod=30)
    data['ultosc'] = ta.ULTOSC(data["high"], data["low"], data["close"], timeperiod1=7, timeperiod2=14, timeperiod3=28)
    data['willr'] = ta.WILLR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #volume
    data['ad'] = ta.AD(data["high"], data["low"], data["close"], data['vol'])
    data['obv'] = ta.OBV(data["close"], data['vol'])
    
    #volitility
    data['atr'] = ta.ATR(data["high"], data["low"], data["close"], timeperiod=14)
    data['natr'] = ta.NATR(data["high"], data["low"], data["close"], timeperiod=14)
    
    #cycle
    data['HT_DCPERIOD'] = ta.HT_DCPERIOD(data["close"])
#     data['HT_DCPHASE'] = ta.HT_DCPHASE(data["close"])
#     data['inphase'], data['quadrature'] = ta.HT_PHASOR(data["close"])
    
    
    return data

# %%
full_list1 = calc_tech_ind(pro_df)
full_list1 = full_list1.fillna(0)

# %%
full_list1[full_list1['vol']==0]
# Out:
#        open   high    low  close  vol       upbd   midbd      lowbd  \
# 3401  16.80  16.80  16.80  16.80  0.0  16.936417  16.366  15.795583
# 3402  16.80  16.80  16.80  16.80  0.0  17.113285  16.442  15.770715
# 3403  16.80  16.80  16.80  16.80  0.0  17.234164  16.502  15.769836
# 3404  16.80  16.80  16.80  16.80  0.0  17.274000  16.642  16.010000
# 3405  16.80  16.80  16.80  16.80  0.0  16.800000  16.800  16.800000
# ...     ...    ...    ...    ...  ...        ...     ...        ...
# 8903   8.22   8.22   8.22   8.22  0.0   8.220000   8.220   8.220000
# 8904   8.22   8.22   8.22   8.22  0.0   8.220000   8.220   8.220000
# 8905   8.22   8.22   8.22   8.22  0.0   8.220000   8.220   8.220000
# 8906   8.22   8.22   8.22   8.22  0.0   8.220000   8.220   8.220000
# 8907   8.22   8.22   8.22   8.22  0.0   8.220000   8.220   8.220000
#
#            dema       tema  ...  fastk         fastd      trix     ultosc  \
# 3401  16.749641  16.542900  ...  100.0  4.350356e+01  0.065227  53.524112
# 3402  16.752973  16.562603  ...  100.0  7.064220e+01  0.059759  53.165143
# 3403  16.756084  16.580830  ...  100.0  1.000000e+02  0.054732  56.213570
# 3404  16.758989  16.597688  ...  100.0  1.000000e+02  0.050111  61.852803
# 3405  16.761702  16.613278  ...    0.0  6.666667e+01  0.045863  62.016540
# ...         ...        ...  ...    ...           ...       ...        ...
# 8903   8.226801   8.215634  ...    0.0 -2.178998e-13  0.016471   0.000000
# 8904   8.226458   8.215595  ...    0.0 -2.178998e-13  0.015838   0.000000
# 8905   8.226131   8.215574  ...    0.0 -2.178998e-13  0.015222   0.000000
# 8906   8.225820   8.215568  ...    0.0 -2.178998e-13  0.014625   0.000000
# 8907   8.225523   8.215576  ...    0.0 -2.178998e-13  0.014045   0.000000
#
#           willr            ad           obv       atr      natr  HT_DCPERIOD
# 3401 -36.111111  6.921856e+07  1.845309e+08  0.457493  2.723171    12.985647
# 3402 -36.111111  6.921856e+07  1.845309e+08  0.424815  2.528659    13.204835
# 3403 -36.111111  6.921856e+07  1.845309e+08  0.394471  2.348040    13.573024
# 3404 -36.111111  6.921856e+07  1.845309e+08  0.366294  2.180323    14.101555
# 3405 -36.111111  6.921856e+07  1.845309e+08  0.340130  2.024586    14.449232
# ...         ...           ...           ...       ...       ...          ...
# 8903   0.000000  6.193499e+07  4.149460e+08  0.000386  0.004692    19.898910
# 8904   0.000000  6.193499e+07  4.149460e+08  0.000358  0.004357    19.898911
# 8905   0.000000  6.193499e+07  4.149460e+08  0.000333  0.004046    19.898912
# 8906   0.000000  6.193499e+07  4.149460e+08  0.000309  0.003757    19.898912
# 8907   0.000000  6.193499e+07  4.149460e+08  0.000287  0.003488    19.898913
#
# [112 rows x 42 columns]

# %%
k=20

# %%
array_full_list = np.array(full_list1)
array_full_list = array_full_list.reshape(k,int(len(full_list1)/k),full_list1.shape[1])
selected_tics = sorted(selected_tics)

# %%
df.tic.value_counts()

# %% [markdown]
# # Part 2: DeepLearning representation

# %%
#generate x, y, z, zp quadruples
#segment x, y, z trios to sequence according to $timeStep and $gap
#x: historical data w/ technical analysis indicator
#y: closing price of t+1
#z:  difference between t+1 and t step's closing price

def toSequential_train1(idx, full_list, timeStep=48, gap=4):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
#     closingNorm = (closing - closing.mean())/closing.std()
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    for i in range(count):
        #segData dims: [timestep, feature count]       
        segData=data[gap*i:gap*i+timeStep]
        segClosing=closing[gap*i:gap*i+timeStep+1]
        #segDiff=diff[gap*i:gap*i+timeStep]
        #normalization
        
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
#         segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        segDataNorm=np.nan_to_num((segData-segData.mean(axis=0, keepdims=True))/segData.std(axis=0, keepdims=True))
    
        std_close = segClosing.std()
        std_segClosing = np.where(std_close == 0, 1, std_close)
        segClosingNorm=(segClosing-segClosing.mean())/std_segClosing
#         segDiff=(segDiff-segDiff.mean())/segDiff.std()
        
        stockSeq.append(segDataNorm)
        labelSeq.append(segClosingNorm[1:])
        diffSeq.append(segClosingNorm[1:]-segClosingNorm[:-1])
        realDiffSeq.append(segClosing[1:]-segClosing[:-1])
    stockSeq=np.array(stockSeq)
    labelSeq=np.array(labelSeq)
    diffSeq=np.array(diffSeq)
    realDiffSeq=np.array(realDiffSeq)
    return stockSeq.astype('float32') , labelSeq.astype('float32'), diffSeq.astype('float32'), realDiffSeq.astype('float32')

# %%
def toSequential_back(idx, full_list, timeStep = 48, gap = 1,batch_size = 64):
    #closing: from id=0 to last
    closing=full_list[idx][:, 3]
    #data from id=0 to second to last
    data=full_list[idx][:-1]
    #calculating number of available sequential samples
    data_length=len(data)
    count=(data_length-timeStep)//gap+1
    stockSeq=[]
    labelSeq=[]
    diffSeq=[]
    realDiffSeq=[]
    
    start = data_length - timeStep
    i=0
    while start >= 0:
        segData = data[start:start + timeStep]
        std_dev = segData.std(axis=0, keepdims=True)
        std_dev_nonzero = np.where(std_dev == 0, 1, std_dev)  # 处理分母为零的情况
        segDataNorm = np.nan_to_num((segData - segData.mean(axis=0, keepdims=True)) / std_dev_nonzero)
        #复制batch_size个
        stockSeq.extend([segDataNorm] * batch_size)
#         stockSeq.append(segDataNorm)   
        start = start - gap
        i +=1
    stockSeq=np.array(stockSeq)[::-1]
#     print(i)
    return stockSeq.astype('float32')

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=3):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        closing_cohort=[]
        diff_cohort=[]
        real_diff_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X, y, z, zp=toSequential_train1(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
            closing_cohort.append(y)
            diff_cohort.append(z)
            real_diff_cohort.append(zp)
        self.X=np.concatenate(stock_cohort, axis=0)
        self.y=np.concatenate(closing_cohort, axis=0)
        self.z=np.concatenate(diff_cohort, axis=0)  
        self.zp=np.concatenate(real_diff_cohort, axis=0)
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        label1=self.y[idx]
        label2=self.z[idx]
        label3=self.zp[idx]
        if self.transform:
            data=self.transform(data)
        return (data, label1, label2, label3)
    
    
    def getDS(self):
        return self.X, self.y, self.z, self.zp

# %%
#input each step:  vector including [stock info, tech indicators]
#output each step: closing price t+1, price diff between t+1 and t
#full_list: output from get_data_set

class StockDataset_back(Dataset):
    def __init__(self, id_list, full_list, transform=None, timestep=48, gap=1):
        self.transform=transform
        self.id_list=id_list
        
        stock_cohort=[]
        
        #load data into cohort
        for i in self.id_list:
            X=toSequential_back(i, full_list, timeStep=timestep, gap=gap)
            stock_cohort.append(X)
        self.X=np.concatenate(stock_cohort, axis=0)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        """
        data returned in the format of 
        """
        if torch.is_tensor(idx):
            idx=idx.tolist()
        
        data=self.X[idx]
        if self.transform:
            data=self.transform(data)
        return data
        
    def getDS(self):
        return self.X

# %%
#Generation of training, validation, and testing dataset
def DataIterGen(test_id_list, val_id_list, name_list, full_list, demo=False):
    """
    test_id_list: id of subjects for testing
    val_id_list: id of subjects for validation
    other subjects for training
    full_list=get_data_set(name_list), preprocessed
    demo: when demo mode is True, only test_iter is returned, with data from
    first entry of test_id_list (single stock)
    """
    name_count=len(name_list)

    if demo:
        test_iter=DataLoader(StockDataset(test_id_list[0:1], full_list, timestep=24, gap=1), shuffle=False, batch_size=64, num_workers=0)
        print(f'Demo with stock: {name_list[test_id_list[0]]} ')
        return test_iter
    else:
        all_ids = list(range(name_count))
        train_id_list = list(set(all_ids) - set(test_id_list) - set(val_id_list))
#         partial_list=full_list[train_list,:,:]
        test_iter=DataLoader(StockDataset(test_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        val_iter=DataLoader(StockDataset(val_id_list, full_list), batch_size=64, num_workers=0,drop_last=True)
        train_iter=DataLoader(StockDataset(train_id_list, full_list), shuffle=True, batch_size=64, num_workers=0,drop_last=True)
        print(f'Val: {[name_list[val_id] for val_id in val_id_list]}, Test: {[name_list[test_id] for test_id in test_id_list]}, Train: {[name_list[train_id] for train_id in train_id_list]} ')
        return train_iter, val_iter, test_iter

# %%
train_iter, val_iter, test_iter = DataIterGen([2,9],[5,6],selected_tics,array_full_list)
# Out:
# Val: ['600048.SH', '600050.SH'], Test: ['600030.SH', '600276.SH'], Train: ['600000.SH', '600028.SH', '600031.SH', '600036.SH', '600104.SH', '600196.SH']

# %% [markdown]
# # Part3: Transformer

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F

# class TransformerEncoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers,dropout_rate):
#         super(TransformerEncoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_moedl * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_moedl)
#         self.num_layers = num_layers

#     def forward(self, x):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#         return x

# %%
# class TransformerDecoder(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, env_size, num_layers, dropout_rate):
#         super(TransformerDecoder, self).__init__()
#         self.embedding = nn.Linear(input_size, d_model)
#         self.attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout1 = nn.Dropout(dropout_rate)
#         self.layer_norm1 = nn.LayerNorm(d_model)
#         self.encoder_attention = nn.MultiheadAttention(d_model, num_heads)
#         self.dropout2 = nn.Dropout(dropout_rate)
#         self.layer_norm2 = nn.LayerNorm(d_model)
#         self.feed_forward = nn.Sequential(
#             nn.Linear(d_model, d_model * 4),
#             nn.ReLU(),
#             nn.Linear(d_model * 4, d_model)
#         )
#         self.dropout3 = nn.Dropout(dropout_rate)
#         self.layer_norm3 = nn.LayerNorm(d_model)
#         self.linear1 = nn.Linear(d_model, env_size)
#         self.linear2 = nn.Linear(env_size,1)
#         self.num_layers = num_layers

#     def forward(self, x, encoder_output, target_mask, target_padding_mask):
#         x = self.embedding(x)
#         for _ in range(self.num_layers):
#             residual = x
#             x, _ = self.attention(x, x, x, attn_mask=target_mask)
#             x = self.dropout1(x)
#             x = self.layer_norm1(x + residual)
#             residual = x
#             x, _ = self.encoder_attention(x, encoder_output, encoder_output,key_padding_mask =target_padding_mask)
#             x = self.dropout2(x)
#             x = self.layer_norm2(x + residual)
#             residual = x
#             x = self.feed_forward(x)
#             x = self.dropout3(x)
#             x = self.layer_norm3(x + residual)
#         env_size = self.linear1(x)
#         x = self.linear2(env_size).permute(1,0,2)
#         return x, env_size.permute(1,0,2)[0,-1,:]

# %%
# class Transformer(nn.Module):
#     def __init__(self, input_size, d_model, num_heads, num_layers, env_size, dropout_rate):
#         super(Transformer, self).__init__()
#         self.encoder = TransformerEncoder(input_size, d_model, num_heads, num_layers,dropout_rate)
#         self.decoder = TransformerDecoder(input_size, d_model, num_heads, env_size, num_layers,dropout_rate)

#     def forward(self, input_seq, target_seq):
#         encoder_output = self.encoder(input_seq)
#         target_mask = self.generate_attention_mask(target_seq)
#         target_padding_mask = self.generate_padding_mask(target_seq)
#         decoder_output = self.decoder(target_seq, encoder_output)
#         return decoder_output
    
#     def generate_attention_mask(self, sequence):
#         attn_mask = torch.triu(torch.ones(sequence.size(1), sequence.size(1)), diagonal=1).bool().to(sequence.device)
#         return attn_mask

#     def generate_padding_mask(self, sequence):
#         padding_mask = (sequence == 0).to(sequence.device)
#         return padding_mask

# %%
# #模型训练
# def train(model, train_iter, optimizer, num_epochs): 
#     # 训练循环
#     for epoch in range(num_epochs):
#         model.train()
#         total_loss = 0.0
#         enVec_list = []
#         for X, y, z, zp in train_iter:  
#             optimizer.zero_grad()

#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred,enVec = model(inputs,targets)
#             enVec_list.append(enVec)
#             print(pred,targets)
#             loss = nn.MSELoss()(pred, targets)  
#             loss.backward()
#             optimizer.step()
#             total_loss += loss.item()

#         # 打印每个 epoch 的损失
#         print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
#     return enVec_list
# # 模型评估
# def val(model, val_iter):
#     model.eval()
#     total_loss = 0.0
#     enVec_list = []
#     with torch.no_grad():
#         for X, y, z, zp in val_iter: 
#             inputs = X.to(device)
#             targets = y.unsqueeze(2).to(device)
#             pred, enVec = model(inputs)
#             enVec_list.append(enVec)
#             loss = nn.MSELoss()(pred, targets)  
#             total_loss += loss.item()
#     print(f"val Loss: {total_loss/len(val_iter):.4f}")
#     return enVec_list

# %%
# # 定义模型
# model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, num_heads = 8,env_size =40,dropout_rate=0.2)
# optimizer = optim.Adam(model.parameters(), lr=0.001)
# outcoming =train(model,train_iter,optimizer,5)
# valtest =val(model,val_iter)

# %%
# def predict(model,back_iter):
#     enVec_list = []
#     with torch.no_grad():
#         for X in back_iter:
#             inputs = X.to(device)
#             _,enVec = model(inputs)
#             enVec_list.append(enVec)
#     return enVec_list

# %%
# #define device
# def try_gpu(i=0):
#     """Return gpu(i) if exists, otherwise return cpu()."""
#     if torch.cuda.device_count() >= i + 1:
#         return torch.device(f'cuda:{i}')
#     return torch.device('cpu')
# device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers,dropout_rate):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers,dropout_rate)
        self.linear1 = nn.Linear(d_model, env_size)
        self.rule = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.rule(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers,dropout_rate):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads,dropout_rate) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads,dropout_rate):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接
        encoder_mask = torch.triu(torch.ones(x.size(0), x.size(0)), diagonal=1).bool().to(device)
        # Self-Attention
        x, _ = self.self_attention(x, x, x,attn_mask=encoder_mask)
        x = self.dropout1(x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = self.dropout2(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads,dropout_rate):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.dropout2 = nn.Dropout(dropout_rate)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接
#         encoder_mask = torch.triu(torch.ones(x.size(0), x.size(0)), diagonal=1).bool().to(device)
        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = self.dropout1(x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)
        x = self.dropout2(x)
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.L1Loss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.L1Loss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
def predict(model,back_iter):
    enVec_list = []
    with torch.no_grad():
        for X in back_iter:
            inputs = X.to(device)
            _,enVec = model(inputs)
            enVec_list.append(enVec)
    return enVec_list

# %%
#define device
def try_gpu(i=0):
    """Return gpu(i) if exists, otherwise return cpu()."""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
device=try_gpu()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Transformer(nn.Module):
    def __init__(self, input_size, d_model, d_ff, num_heads,env_size, num_layers):
        super(Transformer, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.encode = Encoder(d_model, d_ff, num_heads, num_layers)
        self.linear1 = nn.Linear(d_model, env_size)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(env_size,1)
        

    def forward(self, x):
        x = self.embedding(x)
#         print(x.shape)
        x = x.permute(1,0,2)
        encoded = self.encode(x)
        encoded = self.linear1(encoded)
        x = self.relu(encoded)
        x = self.linear2(x)
#         print(x.shape)
        decoded = x.permute(1,0,2)
        return decoded, encoded.permute(1,0,2)[0,-1,:]

# %%
class Encoder(nn.Module):
    def __init__(self, d_model, d_ff, num_heads, num_layers):
        super(Encoder, self).__init__()
        self.layers = nn.ModuleList([EncoderLayer(d_model, d_ff, num_heads) for _ in range(num_layers)])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, d_ff, num_heads):
        super(EncoderLayer, self).__init__()
        self.self_attention = nn.MultiheadAttention(d_model, num_heads)
        self.feed_forward = FeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        residual = x  # 保存输入的残差连接

        # Self-Attention
        x, _ = self.self_attention(x, x, x)
        x = x + residual  # 残差连接
        x = self.norm1(x)  # Add & Norm

        residual = x  # 保存 Self-Attention 后的残差连接

        # Feed-Forward
        x = self.feed_forward(x)48
        x = x + residual  # 残差连接
        x = self.norm2(x)  # Add & Norm

        return x

# %%
class FeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(FeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = self.linear2(x)
        return x

# %%
#模型训练
def train(model, train_iter, optimizer, num_epochs): 
    # 训练循环
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        enVec_list = []
        for X, y, z, zp in train_iter:  
            optimizer.zero_grad()

            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred,enVec = model(inputs)
            enVec_list.append(enVec)
#             print(pred,targets)
            loss = nn.MSELoss()(pred, targets)  
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        # 打印每个 epoch 的损失
        print(f"Epoch {epoch+1}: Loss: {total_loss/len(train_iter):.4f}")
    return enVec_list
# 模型评估
def val(model, val_iter):
    model.eval()
    total_loss = 0.0
    enVec_list = []
    with torch.no_grad():
        for X, y, z, zp in val_iter: 
            inputs = X.to(device)
            targets = y.unsqueeze(2).to(device)
            pred, enVec = model(inputs)
            enVec_list.append(enVec)
            loss = nn.MSELoss()(pred, targets)  
            total_loss += loss.item()
    print(f"val Loss: {total_loss/len(val_iter):.4f}")
    return enVec_list

# %%
# 定义模型  d=3
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40,dropout_rate=0.2)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming = train(model,train_iter,optimizer,20)
valtest =val(model,val_iter)
# Out:
# Epoch 1: Loss: 0.3742
# Epoch 2: Loss: 0.3094
# Epoch 3: Loss: 0.2731
# Epoch 4: Loss: 0.2268
# Epoch 5: Loss: 0.1834
# Epoch 6: Loss: 0.1553
# Epoch 7: Loss: 0.1337
# Epoch 8: Loss: 0.1192
# Epoch 9: Loss: 0.1076
# Epoch 10: Loss: 0.0995
# Epoch 11: Loss: 0.0930
# Epoch 12: Loss: 0.0894
# Epoch 13: Loss: 0.0867
# Epoch 14: Loss: 0.0788
# Epoch 15: Loss: 0.0765
# Epoch 16: Loss: 0.0749
# Epoch 17: Loss: 0.0711
# Epoch 18: Loss: 0.0681
# Epoch 19: Loss: 0.0653
# Epoch 20: Loss: 0.0645
# val Loss: 0.0765

# %%
# 定义模型  d = 8
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40,dropout_rate=0.2)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming = train(model,train_iter,optimizer,20)
valtest =val(model,val_iter)
# Out:
# Epoch 1: Loss: 0.3513
# Epoch 2: Loss: 0.2779
# Epoch 3: Loss: 0.1948
# Epoch 4: Loss: 0.1416
# Epoch 5: Loss: 0.1130
# Epoch 6: Loss: 0.0975
# Epoch 7: Loss: 0.0881
# Epoch 8: Loss: 0.0796
# Epoch 9: Loss: 0.0750
# Epoch 10: Loss: 0.0736
# Epoch 11: Loss: 0.0675
# Epoch 12: Loss: 0.0642
# Epoch 13: Loss: 0.0641
# Epoch 14: Loss: 0.0608
# Epoch 15: Loss: 0.0600
# Epoch 16: Loss: 0.0572
# Epoch 17: Loss: 0.0564
# Epoch 18: Loss: 0.0544
# Epoch 19: Loss: 0.0527
# Epoch 20: Loss: 0.0542
# val Loss: 0.0536

# %%
# 定义模型 补充Group1
model = Transformer(input_size = 42, d_model = 128 , num_layers = 2, d_ff = 512 ,num_heads = 8,env_size =40,dropout_rate=0.2)
optimizer = optim.Adam(model.parameters(), lr=0.001)
outcoming = train(model,train_iter,optimizer,15)
valtest =val(model,val_iter)
# Out:
# Epoch 1: Loss: 0.4027
# Epoch 2: Loss: 0.3215
# Epoch 3: Loss: 0.2972
# Epoch 4: Loss: 0.2711
# Epoch 5: Loss: 0.2384
# Epoch 6: Loss: 0.2085
# Epoch 7: Loss: 0.1793
# Epoch 8: Loss: 0.1572
# Epoch 9: Loss: 0.1429
# Epoch 10: Loss: 0.1257
# Epoch 11: Loss: 0.1140
# Epoch 12: Loss: 0.1061
# Epoch 13: Loss: 0.1017
# Epoch 14: Loss: 0.0949
# Epoch 15: Loss: 0.0912
# val Loss: 0.1038

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
# feature_enginner
import time 
start_time = time.time()
alltic_list = [i for i in range(k)]

def Feature_enginner(model, processed_df, full_list, alltic_list, batch_size=64, k=20, env_size=40,dela = 48):
    back_iter = DataLoader(StockDataset_back([i for i in range(k)],full_list), shuffle=False, batch_size=batch_size, num_workers=0,drop_last=False)
    
    new_state = predict(model,back_iter)
    concatenated_tensor = torch.cat(new_state, dim=0)
    concatenated_tensor = concatenated_tensor.view(-1,env_size)
    feature_df = pd.DataFrame(concatenated_tensor.numpy())
    
    full_delay_df = delaydate(dela ,processed_df)
    
    merged_df = pd.concat([full_delay_df, feature_df], axis=1)
    merged_df = merged_df.loc[:,['tic','date','close'] + INDICATORS + [i for i in range(env_size)]]
    merged_df.columns = ['tic','date','close'] + INDICATORS + [f"temporal_feature_{i}" for i in range(env_size)]
    end_time = time.time()
    print('总计消耗时间:',(end_time - start_time)/60)
    return merged_df

# %%
addfeature_df = Feature_enginner(model, processed_df3, array_full_list, alltic_list, batch_size=64, k=10 ,env_size=40, dela=48)
# Out:
# 总计消耗时间: 203.12221349875134

# %%
addfeature_df
# Out:
#              tic       date  close      macd    boll_ub    boll_lb     rsi_30  \
# 0      600000.SH 2012-03-19   9.28 -0.007486   9.702450   9.155550  52.781711
# 1      600000.SH 2012-03-20   9.12 -0.025853   9.720888   9.121112  49.247007
# 2      600000.SH 2012-03-21   9.08 -0.043076   9.743154   9.074846  48.408599
# 3      600000.SH 2012-03-22   9.12 -0.052936   9.755521   9.041479  49.301481
# 4      600000.SH 2012-03-23   9.06 -0.064766   9.759194   8.992806  48.012098
# ...          ...        ...    ...       ...        ...        ...        ...
# 26245  600276.SH 2022-12-26  37.56 -0.745802  41.458185  35.673815  47.649703
# 26246  600276.SH 2022-12-27  37.07 -0.733293  41.294287  35.539713  46.213692
# 26247  600276.SH 2022-12-28  37.40 -0.688810  41.126408  35.464592  47.319771
# 26248  600276.SH 2022-12-29  38.13 -0.587876  40.817952  35.539048  49.687451
# 26249  600276.SH 2022-12-30  38.53 -0.470189  40.491900  35.668100  50.937383
#
#            cci_30      dx_30  close_30_sma  ...  temporal_feature_30  \
# 0      -66.219440   6.223238      9.381333  ...            -1.090220
# 1     -132.100672   6.007276      9.377333  ...            -1.422704
# 2     -159.747755  14.751008      9.365000  ...             0.332324
# 3     -134.118258  12.513316      9.355667  ...             1.270435
# 4     -141.235724  13.415752      9.345333  ...             0.811425
# ...           ...        ...           ...  ...                  ...
# 26245  -88.387712   0.362279     39.037333  ...             2.501439
# 26246 -104.818882   0.362279     38.931667  ...             0.921751
# 26247  -77.845197   0.362279     38.828333  ...             1.543848
# 26248  -47.318552   7.169210     38.752667  ...             0.898872
# 26249  -10.772955  15.158670     38.694667  ...            -0.181151
#
#        temporal_feature_31  temporal_feature_32  temporal_feature_33  \
# 0                -2.809197            -1.693281            -0.193225
# 1                -2.850570            -1.696935            -0.369169
# 2                -2.295831            -1.845397             1.309676
# 3                -1.890949            -1.858904             2.120840
# 4                -1.846535            -1.965367             1.676640
# ...                    ...                  ...                  ...
# 26245            -0.798083            -1.353738             2.812301
# 26246            -1.077155            -1.438103             1.427288
# 26247            -1.090703            -1.467035             2.051308
# 26248            -1.237428            -1.585381             1.504652
# 26249            -1.483668            -1.624704             0.414043
#
#        temporal_feature_34  temporal_feature_35  temporal_feature_36  \
# 0                -0.646475            -0.725374            -1.233342
# 1                -0.710004            -0.985651            -1.290114
# 2                 0.124838             0.748277            -1.766717
# 3                 0.333257             1.617122            -1.742426
# 4                -0.085132             1.069371            -1.705094
# ...                    ...                  ...                  ...
# 26245             0.903126             2.609782            -1.507535
# 26246             0.537062             1.584602            -1.428544
# 26247             0.888000             2.169729            -1.451540
# 26248             0.702732             1.702091            -1.340579
# 26249             0.369900             0.968695            -1.050619
#
#        temporal_feature_37  temporal_feature_38  temporal_feature_39
# 0                -1.944781            -0.729144            -0.763430
# 1                -2.011599            -0.958796            -0.921299
# 2                -2.276608            -0.474365            -1.745295
# 3                -2.144922            -0.114407            -1.931581
# 4                -2.162189            -0.258906            -1.875170
# ...                    ...                  ...                  ...
# 26245            -1.819790             0.417614            -2.177744
# 26246            -1.911434            -0.047558            -1.985457
# 26247            -1.811239            -0.089215            -2.004872
# 26248            -1.895176            -0.207489            -1.894227
# 26249            -1.830081            -0.437319            -1.732886
#
# [26250 rows x 51 columns]

# %%
addfeature_df.to_csv('82addfeature_df.csv',index=None)

# %%
addfeature_df = pd.read_csv('82addfeature_df.csv')

# %%
addfeature_df['date'] = pd.to_datetime(addfeature_df['date'])

# %%
processed_df3.to_csv('82_processed_best.csv',index=None)

# %%
processed_df3 = pd.read_csv('82_processed_best.csv')

# %%
processed_df3['date'] = pd.to_datetime(processed_df3['date'])

# %%
addfeature_df = fe.add_turbulence(addfeature_df)
addfeature_df = addfeature_df.fillna(method="ffill").fillna(method="bfill")

# %%
import datetime
processed['date'] = pd.to_datetime(processed['date'],format='%Y%m%d')
processed

# %%
list_ticker = processed["tic"].unique().tolist()
# list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
# combination = list(itertools.product(list_date,list_ticker))

# processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
# processed_full = processed_full[processed_full['date'].isin(processed['date'])]
# processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
selfattn_indicator_list = [f"temporal_feature_{i}" for i in range(40)]

# %%
selected_tics = addfeature_df.tic.unique()
selected_tics

# %%
TRAIN_START_DATE = addfeature_df['date'].unique()[0]

# %%
TRAIN_START_DATE
# Out:
# '2012-2-28'

# %%
stock_dimension = 10
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension + len(selfattn_indicator_list)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 10, State Space: 501

# %%
stock_dimension = len(processed_df3.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=addfeature_df,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TRADE_START_DATE,TRADE_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 attn_indicator_list = selfattn_indicator_list,                 
                 **env_kwargs)

# %%
TRADE_START_DATE
# Out:
# '2021-7-30'

# %%
SAC_model_kwargs = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
                }

PPO_model_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
                    }

TD3_model_kwargs = {
    "batch_size": 128, 
    "buffer_size": 1000000, 
    "learning_rate": 0.001
                }

timesteps_dict = {'sac' : 10000, 
                 'ppo' : 10000, 
                 'td3' : 10000
                 }

# %%
import torch
device = torch.device("mps")

# %%
df_summary = ensemble_agent.run_ensemble_strategy_com(SAC_model_kwargs,
                                                 PPO_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# ======Model training from:  2012-2-28 to  2021-08-02T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_120
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 110           |
# |    time_elapsed    | 82            |
# |    total_timesteps | 9120          |
# | train/             |               |
# |    actor_loss      | 839           |
# |    critic_loss     | 88.6          |
# |    ent_coef        | 0.24          |
# |    ent_coef_loss   | 166           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 9019          |
# |    reward          | 9.9223704e-05 |
# --------------------------------------
# ======SAC Validation from:  2021-08-02T00:00:00.000000000 to  2021-11-08T00:00:00.000000000
# SAC Sharpe Ratio:  -0.2613995254059698
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_111
# ---------------------------------------
# | time/              |                |
# |    fps             | 572            |
# |    iterations      | 1              |
# |    time_elapsed    | 3              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -0.00020430905 |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 559           |
# |    iterations           | 2             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.010193974   |
# |    clip_fraction        | 0.161         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.141        |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00769      |
# |    reward               | 0.00010759737 |
# |    std                  | 1             |
# |    value_loss           | 0.0155        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 551           |
# |    iterations           | 3             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.007135648   |
# |    clip_fraction        | 0.0756        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.142        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00418      |
# |    reward               | 0.00025898128 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00568       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 545           |
# |    iterations           | 4             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.009960533   |
# |    clip_fraction        | 0.113         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.3         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.124        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00485      |
# |    reward               | 0.00016151195 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0108        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 544           |
# |    iterations           | 5             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.011218658   |
# |    clip_fraction        | 0.133         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.3         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.158        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00575      |
# |    reward               | 0.00012756916 |
# |    std                  | 1.01          |
# |    value_loss           | 0.0119        |
# -------------------------------------------
# ======PPO Validation from:  2021-08-02T00:00:00.000000000 to  2021-11-08T00:00:00.000000000
# PPO Sharpe Ratio:  -0.20651364982731094
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_104
# ------------------------------------
# | time/              |             |
# |    episodes        | 4           |
# |    fps             | 147         |
# |    time_elapsed    | 61          |
# |    total_timesteps | 9120        |
# | train/             |             |
# |    actor_loss      | 109         |
# |    critic_loss     | 65          |
# |    learning_rate   | 0.001       |
# |    n_updates       | 6840        |
# |    reward          | 0.000107113 |
# ------------------------------------
# day: 2279, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 4813858.44
# total_reward: 3813858.44
# total_cost: 999.00
# total_trades: 4558
# Sharpe: 0.671
# =================================
# ======TD3 Validation from:  2021-08-02T00:00:00.000000000 to  2021-11-08T00:00:00.000000000
# ======Best Model Retraining from:  2012-2-28 to  2021-11-08T00:00:00.000000000
# ======Trading from:  2021-11-08T00:00:00.000000000 to  2022-02-11T00:00:00.000000000
# ============================================
# ======Model training from:  2012-2-28 to  2021-11-08T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_101
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 106           |
# |    time_elapsed    | 87            |
# |    total_timesteps | 9372          |
# | train/             |               |
# |    actor_loss      | 655           |
# |    critic_loss     | 19.4          |
# |    ent_coef        | 0.245         |
# |    ent_coef_loss   | 132           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 9271          |
# |    reward          | -7.229425e-05 |
# --------------------------------------
# ======SAC Validation from:  2021-11-08T00:00:00.000000000 to  2022-02-11T00:00:00.000000000
# SAC Sharpe Ratio:  0.15466961596507683
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_105
# ---------------------------------------
# | time/              |                |
# |    fps             | 566            |
# |    iterations      | 1              |
# |    time_elapsed    | 3              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -0.00069250766 |
# ---------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 548            |
# |    iterations           | 2              |
# |    time_elapsed         | 7              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.007611387    |
# |    clip_fraction        | 0.113          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -14.2          |
# |    explained_variance   | -0.167         |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.156         |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.0042        |
# |    reward               | -0.00031908482 |
# |    std                  | 1              |
# |    value_loss           | 0.00452        |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 541           |
# |    iterations           | 3             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.008728091   |
# |    clip_fraction        | 0.0895        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.127        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.0042       |
# |    reward               | -0.0008217889 |
# |    std                  | 1             |
# |    value_loss           | 0.00351       |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 534            |
# |    iterations           | 4              |
# |    time_elapsed         | 15             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.010998254    |
# |    clip_fraction        | 0.0958         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -14.2          |
# |    explained_variance   | 0.0133         |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0966        |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.00305       |
# |    reward               | -0.00018268595 |
# |    std                  | 1.01           |
# |    value_loss           | 0.113          |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 535          |
# |    iterations           | 5            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0101311    |
# |    clip_fraction        | 0.0905       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.2        |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.131       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0124      |
# |    reward               | -8.21885e-05 |
# |    std                  | 1            |
# |    value_loss           | 0.00941      |
# ------------------------------------------
# ======PPO Validation from:  2021-11-08T00:00:00.000000000 to  2022-02-11T00:00:00.000000000
# PPO Sharpe Ratio:  -0.3905653195373211
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_99
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 145           |
# |    time_elapsed    | 64            |
# |    total_timesteps | 9372          |
# | train/             |               |
# |    actor_loss      | 105           |
# |    critic_loss     | 38.3          |
# |    learning_rate   | 0.001         |
# |    n_updates       | 7029          |
# |    reward          | 1.4481919e-05 |
# --------------------------------------
# day: 2342, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 3099775.37
# total_reward: 2099775.37
# total_cost: 999.00
# total_trades: 4684
# Sharpe: 0.515
# =================================
# ======TD3 Validation from:  2021-11-08T00:00:00.000000000 to  2022-02-11T00:00:00.000000000
# ======Best Model Retraining from:  2012-2-28 to  2022-02-11T00:00:00.000000000
# ======Trading from:  2022-02-11T00:00:00.000000000 to  2022-05-18T00:00:00.000000000
# ============================================
# ======Model training from:  2012-2-28 to  2022-02-11T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_252_82
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 110           |
# |    time_elapsed    | 86            |
# |    total_timesteps | 9624          |
# | train/             |               |
# |    actor_loss      | 1.24e+03      |
# |    critic_loss     | 493           |
# |    ent_coef        | 0.253         |
# |    ent_coef_loss   | 222           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 9523          |
# |    reward          | 0.00012934074 |
# --------------------------------------
# ======SAC Validation from:  2022-02-11T00:00:00.000000000 to  2022-05-18T00:00:00.000000000
# SAC Sharpe Ratio:  -0.08367605567764608
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_86
# ---------------------------------------
# | time/              |                |
# |    fps             | 551            |
# |    iterations      | 1              |
# |    time_elapsed    | 3              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -0.00015342505 |
# ---------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 538            |
# |    iterations           | 2              |
# |    time_elapsed         | 7              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.00826576     |
# |    clip_fraction        | 0.101          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -14.2          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.169         |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00714       |
# |    reward               | -0.00037716533 |
# |    std                  | 1.01           |
# |    value_loss           | 0.004          |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 529           |
# |    iterations           | 3             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.008194404   |
# |    clip_fraction        | 0.0952        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.3         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.171        |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00554      |
# |    reward               | -0.0029815896 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00445       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 527           |
# |    iterations           | 4             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.008328346   |
# |    clip_fraction        | 0.113         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.3         |
# |    explained_variance   | -0.000202     |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.162        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00529      |
# |    reward               | 1.7850978e-05 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00242       |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 525            |
# |    iterations           | 5              |
# |    time_elapsed         | 19             |
# |    total_timesteps      | 10240          |
# | train/                  |                |
# |    approx_kl            | 0.010018367    |
# |    clip_fraction        | 0.118          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -14.3          |
# |    explained_variance   | 0.209          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.156         |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -0.00713       |
# |    reward               | -0.00047429668 |
# |    std                  | 1.01           |
# |    value_loss           | 0.00743        |
# --------------------------------------------
# ======PPO Validation from:  2022-02-11T00:00:00.000000000 to  2022-05-18T00:00:00.000000000
# PPO Sharpe Ratio:  -0.13626420399399636
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_252_80
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 155           |
# |    time_elapsed    | 61            |
# |    total_timesteps | 9624          |
# | train/             |               |
# |    actor_loss      | -180          |
# |    critic_loss     | 505           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 7218          |
# |    reward          | -0.0021109942 |
# --------------------------------------
# day: 2405, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1807430.29
# total_reward: 807430.29
# total_cost: 999.00
# total_trades: 14430
# Sharpe: 0.364
# =================================
# ======TD3 Validation from:  2022-02-11T00:00:00.000000000 to  2022-05-18T00:00:00.000000000
# ======Best Model Retraining from:  2012-2-28 to  2022-05-18T00:00:00.000000000
# ======Trading from:  2022-05-18T00:00:00.000000000 to  2022-08-16T00:00:00.000000000
# ============================================
# ======Model training from:  2012-2-28 to  2022-05-18T00:00:00.000000000
# ======SAC Training========
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_78
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 112           |
# |    time_elapsed    | 87            |
# |    total_timesteps | 9876          |
# | train/             |               |
# |    actor_loss      | 657           |
# |    critic_loss     | 15.4          |
# |    ent_coef        | 0.251         |
# |    ent_coef_loss   | 130           |
# |    learning_rate   | 0.0001        |
# |    n_updates       | 9775          |
# |    reward          | 1.2609293e-05 |
# --------------------------------------
# ======SAC Validation from:  2022-05-18T00:00:00.000000000 to  2022-08-16T00:00:00.000000000
# SAC Sharpe Ratio:  -0.10117186591052629
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_83
# ---------------------------------------
# | time/              |                |
# |    fps             | 542            |
# |    iterations      | 1              |
# |    time_elapsed    | 3              |
# |    total_timesteps | 2048           |
# | train/             |                |
# |    reward          | -0.00020083503 |
# ---------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 526            |
# |    iterations           | 2              |
# |    time_elapsed         | 7              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.008895967    |
# |    clip_fraction        | 0.101          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -14.2          |
# |    explained_variance   | 0.376          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.162         |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00643       |
# |    reward               | -0.00022299291 |
# |    std                  | 1              |
# |    value_loss           | 0.00666        |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 522            |
# |    iterations           | 3              |
# |    time_elapsed         | 11             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | 0.008774832    |
# |    clip_fraction        | 0.085          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -14.2          |
# |    explained_variance   | 0.376          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.133         |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -0.00231       |
# |    reward               | -0.00028681254 |
# |    std                  | 1              |
# |    value_loss           | 0.0047         |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 516           |
# |    iterations           | 4             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.010416286   |
# |    clip_fraction        | 0.144         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.127        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.00732      |
# |    reward               | -0.0011908057 |
# |    std                  | 1             |
# |    value_loss           | 0.0126        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 517           |
# |    iterations           | 5             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.008194586   |
# |    clip_fraction        | 0.0892        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -14.2         |
# |    explained_variance   | 0.0194        |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.144        |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00363      |
# |    reward               | 0.00016040473 |
# |    std                  | 1             |
# |    value_loss           | 0.017         |
# -------------------------------------------
# ======PPO Validation from:  2022-05-18T00:00:00.000000000 to  2022-08-16T00:00:00.000000000
# PPO Sharpe Ratio:  0.03564889555094165
# ======TD3 Training========
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_77
# --------------------------------------
# | time/              |               |
# |    episodes        | 4             |
# |    fps             | 157           |
# |    time_elapsed    | 62            |
# |    total_timesteps | 9876          |
# | train/             |               |
# |    actor_loss      | -185          |
# |    critic_loss     | 583           |
# |    learning_rate   | 0.001         |
# |    n_updates       | 7407          |
# |    reward          | 6.1902305e-05 |
# --------------------------------------
# day: 2468, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 1265554.81
# total_reward: 265554.81
# total_cost: 999.00
# total_trades: 14808
# Sharpe: 0.226
# =================================
# ======TD3 Validation from:  2022-05-18T00:00:00.000000000 to  2022-08-16T00:00:00.000000000
# ======Best Model Retraining from:  2012-2-28 to  2022-08-16T00:00:00.000000000
# ======Trading from:  2022-08-16T00:00:00.000000000 to  2022-11-21T00:00:00.000000000
# Ensemble Strategy took:  13.895912353197733  minutes

# %%
df_summary

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = addfeature_df[(addfeature_df.date > TRADE_START_DATE)&(addfeature_df.date <= TRADE_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.419646748333244

# %%
df_account_value
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2021-11-08           NaN 2021-11-08
# 1     9.999280e+05  2021-11-09     -0.000072 2021-11-09
# 2     1.000348e+06  2021-11-10      0.000420 2021-11-10
# 3     1.000675e+06  2021-11-11      0.000327 2021-11-11
# 4     1.000573e+06  2021-11-12     -0.000102 2021-11-12
# ..             ...         ...           ...        ...
# 247   9.728626e+05  2022-11-14      0.007911 2022-11-14
# 248   9.734881e+05  2022-11-15      0.000643 2022-11-15
# 249   9.652687e+05  2022-11-16     -0.008443 2022-11-16
# 250   9.649026e+05  2022-11-17     -0.000379 2022-11-17
# 251   9.611668e+05  2022-11-18     -0.003872 2022-11-18
#
# [252 rows x 4 columns]

# %%
df_returns = df_account_value.iloc[:,0:2]
df_returns
# Out:
#      account_value        date
# 0     1.000000e+06  2021-11-08
# 1     9.999280e+05  2021-11-09
# 2     1.000348e+06  2021-11-10
# 3     1.000675e+06  2021-11-11
# 4     1.000573e+06  2021-11-12
# ..             ...         ...
# 247   9.728626e+05  2022-11-14
# 248   9.734881e+05  2022-11-15
# 249   9.652687e+05  2022-11-16
# 250   9.649026e+05  2022-11-17
# 251   9.611668e+05  2022-11-18
#
# [252 rows x 2 columns]

# %%
df_returns.to_csv('83_df_returns.csv',index=None)

# %%
df_account_value1
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2021-11-08           NaN 2021-11-08
# 1     9.999765e+05  2021-11-09     -0.000023 2021-11-09
# 2     9.997680e+05  2021-11-10     -0.000208 2021-11-10
# 3     1.000651e+06  2021-11-11      0.000883 2021-11-11
# 4     1.000306e+06  2021-11-12     -0.000344 2021-11-12
# ..             ...         ...           ...        ...
# 247   8.130892e+05  2022-11-14      0.018525 2022-11-14
# 248   8.141954e+05  2022-11-15      0.001361 2022-11-15
# 249   8.172590e+05  2022-11-16      0.003763 2022-11-16
# 250   8.146184e+05  2022-11-17     -0.003231 2022-11-17
# 251   8.401860e+05  2022-11-18      0.031386 2022-11-18
#
# [252 rows x 4 columns]

# %%
df_account_value2 = df_account_value
df_account_value2
# Out:
#      account_value        date  daily_return   datadate
# 0     1.000000e+06  2021-11-08           NaN 2021-11-08
# 1     9.998749e+05  2021-11-09     -0.000125 2021-11-09
# 2     9.998279e+05  2021-11-10     -0.000047 2021-11-10
# 3     1.000857e+06  2021-11-11      0.001029 2021-11-11
# 4     1.000716e+06  2021-11-12     -0.000141 2021-11-12
# ..             ...         ...           ...        ...
# 247   8.672181e+05  2022-11-14      0.006107 2022-11-14
# 248   8.729964e+05  2022-11-15      0.006663 2022-11-15
# 249   8.702993e+05  2022-11-16     -0.003089 2022-11-16
# 250   8.687102e+05  2022-11-17     -0.001826 2022-11-17
# 251   8.645018e+05  2022-11-18     -0.004844 2022-11-18
#
# [252 rows x 4 columns]

# %%
df_returns1 = df_returns.iloc[:,[1,2]]
df_returns1
# Out:
#            date            3+
# 0    2021-11-08  1.000000e+06
# 1    2021-11-09  9.999765e+05
# 2    2021-11-10  9.997680e+05
# 3    2021-11-11  1.000651e+06
# 4    2021-11-12  1.000306e+06
# ..          ...           ...
# 247  2022-11-14  8.130892e+05
# 248  2022-11-15  8.141954e+05
# 249  2022-11-16  8.172590e+05
# 250  2022-11-17  8.146184e+05
# 251  2022-11-18  8.401860e+05
#
# [252 rows x 2 columns]

# %%
df_returns1['return'] = df_returns1['3+'].pct_change()
df_returns1['return'].fillna(0, inplace=True)

# %%
df_returns1['date'] = pd.to_datetime(df_returns1['date'])
df_returns1.set_index('date',inplace=True)
df_returns1.index = df_returns1.index.tz_localize("UTC")
returns = pd.Series(df_returns1["return"], index=df_returns1.index)

# %%
baseline_sse
# Out:
#           date  account_value
# 0   2021-11-08    3472.675898
# 1   2021-11-09    3460.514921
# 2   2021-11-10    3486.857376
# 3   2021-11-11    3585.111614
# 4   2021-11-12    3556.070238
# ..         ...            ...
# 247 2022-11-14    2474.684818
# 248 2022-11-15    2484.935273
# 249 2022-11-16    2481.591230
# 250 2022-11-17    2439.442815
# 251 2022-11-18    2430.704012
#
# [252 rows x 2 columns]

# %%
baseline_sse['account_value'] = baseline_sse['account_value']*(1000000/baseline_sse.iloc[0,1])
baseline_sse
# Out:
#           date  account_value
# 0   2021-11-08   1.000000e+06
# 1   2021-11-09   9.964981e+05
# 2   2021-11-10   1.004084e+06
# 3   2021-11-11   1.032377e+06
# 4   2021-11-12   1.024014e+06
# ..         ...            ...
# 247 2022-11-14   7.126161e+05
# 248 2022-11-15   7.155679e+05
# 249 2022-11-16   7.146049e+05
# 250 2022-11-17   7.024677e+05
# 251 2022-11-18   6.999513e+05
#
# [252 rows x 2 columns]

# %%
baseline_sse1 = baseline_sse
baseline_sse1['date'] = pd.to_datetime(baseline_sse['date'])
baseline_sse1.set_index('date',inplace=True)
baseline_sse1.index = baseline_sse1.index.tz_localize("UTC")

# %%
baseline_sse1['return'] = baseline_sse1['account_value'].pct_change()
baseline_sse1['return'].fillna(0, inplace=True)
baseline_sse1 = baseline_sse1.drop('account_value',axis=1)

# %%
# %matplotlib inline
import pyfolio as py
py.create_returns_tear_sheet(returns,benchmark_rets=baseline_sse1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-11-08</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-11-18</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-15.981%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-15.981%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.67%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.03</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.55</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-29.155%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.81</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.45</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>4.51</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.08</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.038%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.39</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>29.16</td>
#       <td>2022-02-11</td>
#       <td>2022-10-11</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.38</td>
#       <td>2021-12-09</td>
#       <td>2022-01-14</td>
#       <td>2022-02-11</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.57</td>
#       <td>2021-11-11</td>
#       <td>2021-11-30</td>
#       <td>2021-12-06</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.02</td>
#       <td>2021-11-08</td>
#       <td>2021-11-10</td>
#       <td>2021-11-11</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[496], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import pyfolio as py
# ----> 3 py.create_returns_tear_sheet(returns,benchmark_rets=baseline_sse1)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:52, in customize.<locals>.call_w_context(*args, **kwargs)
#      50 if set_context:
#      51     with plotting_context(), axes_style():
# ---> 52         return func(*args, **kwargs)
#      53 else:
#      54     return func(*args, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:520, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     517 ax_return_quantiles = plt.subplot(gs[i, :])
#     518 i += 1
# --> 520 plotting.plot_rolling_returns(
#     521     returns,
#     522     factor_returns=benchmark_rets,
#     523     live_start_date=live_start_date,
#     524     cone_std=cone_std,
#     525     ax=ax_rolling_returns)
#     526 ax_rolling_returns.set_title(
#     527     'Cumulative returns')
#     529 plotting.plot_rolling_returns(
#     530     returns,
#     531     factor_returns=benchmark_rets,
#    (...)
#     535     legend_loc=None,
#     536     ax=ax_rolling_returns_vol_match)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:794, in plot_rolling_returns(returns, factor_returns, live_start_date, logy, cone_std, legend_loc, volatility_match, cone_function, ax, **kwargs)
#     790 ax.yaxis.set_major_formatter(FuncFormatter(y_axis_formatter))
#     792 if factor_returns is not None:
#     793     cum_factor_returns = ep.cum_returns(
# --> 794         factor_returns[cum_rets.index], 1.0)
#     795     cum_factor_returns.plot(lw=2, color='gray',
#     796                             label=factor_returns.name, alpha=0.60,
#     797                             ax=ax, **kwargs)
#     799 if live_start_date is not None:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [DatetimeIndex(['2021-11-08 00:00:00+00:00', '2021-11-09 00:00:00+00:00',\n               '2021-11-10 00:00:00+00:00', '2021-11-11 00:00:00+00:00',\n               '2021-11-12 00:00:00+00:00', '2021-11-15 00:00:00+00:00',\n               '2021-11-16 00:00:00+00:00', '2021-11-17 00:00:00+00:00',\n               '2021-11-18 00:00:00+00:00', '2021-11-19 00:00:00+00:00',\n               ...\n               '2022-11-07 00:00:00+00:00', '2022-11-08 00:00:00+00:00',\n               '2022-11-09 00:00:00+00:00', '2022-11-10 00:00:00+00:00',\n               '2022-11-11 00:00:00+00:00', '2022-11-14 00:00:00+00:00',\n               '2022-11-15 00:00:00+00:00', '2022-11-16 00:00:00+00:00',\n               '2022-11-17 00:00:00+00:00', '2022-11-18 00:00:00+00:00'],\n              dtype='datetime64[ns, UTC]', name='date', length=252, freq=None)] are in the [columns]"

# %%
df_returns = df_account_value.iloc[:,[0,2,3]]
df_returns
# Out:
#      account_value  daily_return   datadate
# 0     1.000000e+06           NaN 2021-11-08
# 1     9.999280e+05     -0.000072 2021-11-09
# 2     1.000348e+06      0.000420 2021-11-10
# 3     1.000675e+06      0.000327 2021-11-11
# 4     1.000573e+06     -0.000102 2021-11-12
# ..             ...           ...        ...
# 247   9.728626e+05      0.007911 2022-11-14
# 248   9.734881e+05      0.000643 2022-11-15
# 249   9.652687e+05     -0.008443 2022-11-16
# 250   9.649026e+05     -0.000379 2022-11-17
# 251   9.611668e+05     -0.003872 2022-11-18
#
# [252 rows x 3 columns]

# %%
df_returns.to_csv('724_2_df_returns.csv',index=None)

# %%
df_returns1 = df_returns
df_returns1
# Out:
#            date           td3           sac           ppo           sse  \
# 0    2020-06-03  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1    2020-06-04  9.998193e+05  9.998801e+05  9.999384e+05  9.981757e+05
# 2    2020-06-05  1.000270e+06  1.000138e+06  9.999628e+05  9.999549e+05
# 3    2020-06-08  1.001146e+06  1.000495e+06  9.999853e+05  1.015112e+06
# 4    2020-06-09  1.001984e+06  1.000475e+06  1.000168e+06  1.015740e+06
# ..          ...           ...           ...           ...           ...
# 310  2021-10-20  9.350133e+05  7.322613e+05  8.551679e+05  8.204575e+05
# 311  2021-10-21  9.402342e+05  7.448301e+05  8.442385e+05  8.470124e+05
# 312  2021-10-22  9.423141e+05  7.437446e+05  8.507896e+05  8.494040e+05
# 313  2021-10-25  9.537174e+05  7.503635e+05  8.538056e+05  8.408992e+05
# 314  2021-10-26  9.381647e+05  7.432972e+05  8.428542e+05  8.268356e+05
#
#              ewtf           van           our
# 0    1.000000e+06  1.000000e+06  1.000000e+06
# 1    9.999457e+05  9.998474e+05  9.998956e+05
# 2    1.000020e+06  9.998534e+05  9.998884e+05
# 3    1.000362e+06  1.000084e+06  1.000983e+06
# 4    1.000559e+06  1.000156e+06  1.001173e+06
# ..            ...           ...           ...
# 310  7.673645e+05  8.879657e+05  9.935646e+05
# 311  7.686134e+05  8.945266e+05  1.012208e+06
# 312  7.767603e+05  8.959052e+05  1.018695e+06
# 313  7.685991e+05  8.959535e+05  1.010964e+06
# 314  7.613355e+05  8.909654e+05  9.977065e+05
#
# [315 rows x 8 columns]

# %%
df_returns
# Out:
#                8+        date            3+
# 0    1.000000e+06  2021-11-08  1.000000e+06
# 1    9.999280e+05  2021-11-09  9.999765e+05
# 2    1.000348e+06  2021-11-10  9.997680e+05
# 3    1.000675e+06  2021-11-11  1.000651e+06
# 4    1.000573e+06  2021-11-12  1.000306e+06
# ..            ...         ...           ...
# 247  9.728626e+05  2022-11-14  8.130892e+05
# 248  9.734881e+05  2022-11-15  8.141954e+05
# 249  9.652687e+05  2022-11-16  8.172590e+05
# 250  9.649026e+05  2022-11-17  8.146184e+05
# 251  9.611668e+05  2022-11-18  8.401860e+05
#
# [252 rows x 3 columns]

# %%
df_returns.columns = ['8+','date','3+']

# %%
df_returns = pd.read_csv('83_df_returns.csv')
df_returns
# Out:
#                8+        date            3+
# 0    1.000000e+06  2021-11-08  1.000000e+06
# 1    9.999280e+05  2021-11-09  9.999765e+05
# 2    1.000348e+06  2021-11-10  9.997680e+05
# 3    1.000675e+06  2021-11-11  1.000651e+06
# 4    1.000573e+06  2021-11-12  1.000306e+06
# ..            ...         ...           ...
# 247  9.728626e+05  2022-11-14  8.130892e+05
# 248  9.734881e+05  2022-11-15  8.141954e+05
# 249  9.652687e+05  2022-11-16  8.172590e+05
# 250  9.649026e+05  2022-11-17  8.146184e+05
# 251  9.611668e+05  2022-11-18  8.401860e+05
#
# [252 rows x 3 columns]

# %%
df_returns = df_returns[['date','8+','3+']]
# Out:
#            date            8+            3+
# 0    2021-11-08  1.000000e+06  1.000000e+06
# 1    2021-11-09  9.999280e+05  9.999765e+05
# 2    2021-11-10  1.000348e+06  9.997680e+05
# 3    2021-11-11  1.000675e+06  1.000651e+06
# 4    2021-11-12  1.000573e+06  1.000306e+06
# ..          ...           ...           ...
# 247  2022-11-14  9.728626e+05  8.130892e+05
# 248  2022-11-15  9.734881e+05  8.141954e+05
# 249  2022-11-16  9.652687e+05  8.172590e+05
# 250  2022-11-17  9.649026e+05  8.146184e+05
# 251  2022-11-18  9.611668e+05  8.401860e+05
#
# [252 rows x 3 columns]

# %%
df_returns = pd.concat([df_returns,baseline_sse['account_value']],axis=1)
# df_returns.columns = ['date','td3','sac','ppo','sse','ewtf']

# %%
df_returns.columns = ('date','8+','3+','sse')

# %%
df_returns = df_returns.drop('sse',axis=1)

# %%
df_returns
# Out:
#            date            8+            3+           sse
# 0    2021-11-08  1.000000e+06  1.000000e+06  1.000000e+06
# 1    2021-11-09  9.999280e+05  9.999765e+05  9.964981e+05
# 2    2021-11-10  1.000348e+06  9.997680e+05  1.004084e+06
# 3    2021-11-11  1.000675e+06  1.000651e+06  1.032377e+06
# 4    2021-11-12  1.000573e+06  1.000306e+06  1.024014e+06
# ..          ...           ...           ...           ...
# 247  2022-11-14  9.728626e+05  8.130892e+05  7.126161e+05
# 248  2022-11-15  9.734881e+05  8.141954e+05  7.155679e+05
# 249  2022-11-16  9.652687e+05  8.172590e+05  7.146049e+05
# 250  2022-11-17  9.649026e+05  8.146184e+05  7.024677e+05
# 251  2022-11-18  9.611668e+05  8.401860e+05  6.999513e+05
#
# [252 rows x 4 columns]

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize= (11,6))

plt.plot(df_returns['date'],df_returns['8+'],label = 'D=8',color = (57/255,81/255,162/255))
plt.plot(df_returns['date'],df_returns['3+'],label = 'D=3',color = (168/255,3/255,38/255))
plt.plot(df_returns['date'],df_returns['sse'],label = 'sse',color = (253/255,183/255,107/255))
# plt.plot(df_returns['date'],df_returns['sse'],label = 'B&H',color = (168/255,3/255,38/255))
# plt.plot(df_returns['date'],df_returns['ewtf'],label = 'ewtf',color = (253/255,183/255,107/255))
# plt.plot(df_returns['date'],df_returns['our'],label = 'our',color = (57/255,81/255,162/255))
# plt.plot(df_returns['date'],df_returns['van'],label = 'van',color = (200/255,100/255,162/255))

plt.legend()
plt.title('')
plt.xlabel('date')
plt.ylabel('Cumulative returns')
# plt.grid()
plt.show()

# %%
df_returns = df_returns.reindex(columns=['date','account_value'])

# %%
df_returns.columns = ['date','td3','sac','ppo','sse','ewtf','van','our']

# %%
df_returns = pd.read_csv('724_df_returns.csv')

# %%
df_returns['date'] = pd.to_datetime(df_returns['date'])

# %%
df_returns.to_csv('727_df_returns.csv')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (11,6))

plt.plot(df_returns['date'],df_returns['td3'],label = 'td3',color = 'dodgerblue')
plt.plot(df_returns['date'],df_returns['sac'],label = 'sac',color = 'red')
plt.plot(df_returns['date'],df_returns['ppo'],label = 'ppo',color = 'limegreen')
plt.plot(df_returns['date'],df_returns['sse'],label = 'sse',color = 'gold')
plt.plot(df_returns['date'],df_returns['ewtf'],label = 'ewtf',color = 'goldenrod')
plt.plot(df_returns['date'],df_returns['our'],label = 'our',color = 'blue')

plt.legend()
plt.title('profit vs')
plt.xlabel('date')
plt.ylabel('profit')
plt.grid()
plt.show()

# %%
df_returns.to_csv('724_df_returns.csv',index=None)

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.054710
# Cumulative returns    -0.054710
# Annual volatility      0.130050
# Sharpe ratio          -0.369557
# Calmar ratio          -0.343501
# Stability              0.775220
# Max drawdown          -0.159273
# Omega ratio            0.928388
# Sortino ratio         -0.525980
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.017221
# Daily value at risk   -0.016575
# dtype: float64

# %%
print("==============Get Backtest Results===========")
#now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
#perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.043290
# Cumulative returns    -0.064228
# Annual volatility      0.143533
# Sharpe ratio          -0.237280
# Calmar ratio          -0.266716
# Stability              0.093941
# Max drawdown          -0.162309
# Omega ratio            0.950767
# Sortino ratio         -0.317188
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.976161
# Daily value at risk   -0.018219
# dtype: float64

# %%
selected_tics = addfeature_df['tic'].unique()

# %%
#获取随机选择的tic在select_date的权重并修正
def get_selected_index_weight(df_index,select_date,selected_tics):
    df = df_index[df_index['trade_date'] == select_date]
    select_df = df[df['con_code'].isin(selected_tics)]
    select_df = select_df.drop('index_code',axis=1).rename(columns={'con_code':'tic','trade_date':'date'})
    select_df = select_df.reset_index()
    weight_sum = select_df['weight'].sum()
#     print(select_df)
    for i in range(len(select_df)):
        select_df.loc[i,'weight'] = (select_df.loc[i,'weight'] / weight_sum)*100
    return select_df.loc[:,['tic','date','weight']]

baseline_weight =get_selected_index_weight(df_index,select_date,selected_tics)
baseline_weight = baseline_weight.sort_values(['tic'],ascending=True).reset_index(drop=True)
print(baseline_weight)
# Out:
#          tic      date     weight
# 0  600000.SH  20220228   6.089759
# 1  600028.SH  20220228   3.581936
# 2  600030.SH  20220228  14.126932
# 3  600031.SH  20220228   7.205903
# 4  600036.SH  20220228  38.098351
# 5  600048.SH  20220228   7.023771
# 6  600050.SH  20220228   4.389857
# 7  600104.SH  20220228   5.230467
# 8  600196.SH  20220228   3.161631
# 9  600276.SH  20220228  11.091393

# %%
#计算所选股票的buy & hold策略
def calculate_selected_baseline(df,full_date_range,selected_tics):
    df = df.sort_values(['tic','date'],ascending=True).reset_index(drop=True)
    baseline = pd.DataFrame({'date':full_date_range['date']})
    for i in range(len(full_date_range)):
        temp_date = full_date_range.loc[i,'date']
        temp_df = df[df['date'] == temp_date].sort_values('tic',ascending=True)
        close = list(temp_df['close'])
        weight = list(baseline_weight['weight'])
        baseline.loc[i,'account_value'] = sum(np.array(close) * np.array(weight)) #注意权重和收盘价对应的股票顺序
    baseline['date'] = pd.to_datetime(baseline['date'])
#     baseline.set_index("date", inplace=True, drop=True)
#     baseline.index = baseline.index.tz_localize("UTC")
    return baseline
# full_date_range = get_trading_days(exchange='SSE',start_date='20210301', end_date='20230227')
# full_date_range = full_date_range.sort_values('trade_date',ascending=True).reset_index(drop=True)
full_date_range1 = pd.DataFrame({'date':df_account_value['date'].unique()}).reset_index(drop=True)
baseline_sse = calculate_selected_baseline(addfeature_df,full_date_range1,selected_tics)
baseline_sse
# Out:
#           date  account_value
# 0   2021-11-08    3472.675898
# 1   2021-11-09    3460.514921
# 2   2021-11-10    3486.857376
# 3   2021-11-11    3585.111614
# 4   2021-11-12    3556.070238
# ..         ...            ...
# 247 2022-11-14    2474.684818
# 248 2022-11-15    2484.935273
# 249 2022-11-16    2481.591230
# 250 2022-11-17    2439.442815
# 251 2022-11-18    2430.704012
#
# [252 rows x 2 columns]

# %%
#baseline stats
print("==============Get Baseline Stats===========")
# baseline_df = get_baseline(
#         ticker="^DJI", 
#         start = df_account_value.loc[0,'date'],
#         end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_sse, value_col_name = 'account_value')

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
from copy import deepcopy
def backtest_plot_com(
    account_value,
    baseline,
    baseline_start=TRADE_START_DATE,
    baseline_end=TRADE_END_DATE,
    value_col_name="account_value",
):
    df = deepcopy(account_value)
    df["date"] = pd.to_datetime(df["date"])
    test_returns = get_daily_return(df, value_col_name=value_col_name)
#     pro = ts.pro_api()
#     baseline_df = pro.index_daily(ts_code='000016.sh',start_date = '20200301',end_date='20230227')
#     baseline_df = baseline_df.rename(columns={'trade_date':'date'})
#     baseline_df = baseline_df.sort_values('date',ascending=True)
    baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
    with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(
            returns=test_returns, benchmark_rets=baseline_returns, set_context=False
        )

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-0.184%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-0.229%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.622%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.13</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.01</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-30.776%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.17</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.341%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.14</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.83</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>30.78</td>
#       <td>2021-02-19</td>
#       <td>2021-10-18</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>8.06</td>
#       <td>2020-10-12</td>
#       <td>2020-11-13</td>
#       <td>2020-11-27</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.39</td>
#       <td>2020-07-09</td>
#       <td>2020-07-17</td>
#       <td>2020-08-17</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.71</td>
#       <td>2020-08-17</td>
#       <td>2020-08-20</td>
#       <td>2020-09-01</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.56</td>
#       <td>2020-09-18</td>
#       <td>2020-09-24</td>
#       <td>2020-10-09</td>
#       <td>16</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-8.75%</td>
#       <td>5.51%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-20</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-12.284%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-17.848%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.729%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.36</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.36</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-34.498%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.49</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.405%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.15</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.69</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>34.50</td>
#       <td>2021-02-10</td>
#       <td>2021-11-02</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11.23</td>
#       <td>2020-08-06</td>
#       <td>2020-09-14</td>
#       <td>2020-10-15</td>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.09</td>
#       <td>2021-01-22</td>
#       <td>2021-01-29</td>
#       <td>2021-02-10</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6.82</td>
#       <td>2020-10-16</td>
#       <td>2020-11-06</td>
#       <td>2020-11-10</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.05</td>
#       <td>2020-11-12</td>
#       <td>2020-11-18</td>
#       <td>2021-01-22</td>
#       <td>52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.04%</td>
#       <td>-5.94%</td>
#       <td>4.81%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-11-08</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-11-18</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-3.883%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-3.883%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.598%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.42</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.40</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-9.785%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.59</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.20</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.098%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9.78</td>
#       <td>2022-07-01</td>
#       <td>2022-10-31</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.00</td>
#       <td>2022-04-15</td>
#       <td>2022-06-13</td>
#       <td>2022-07-01</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.20</td>
#       <td>2021-12-09</td>
#       <td>2022-03-15</td>
#       <td>2022-04-01</td>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.55</td>
#       <td>2022-04-06</td>
#       <td>2022-04-12</td>
#       <td>2022-04-14</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.27</td>
#       <td>2021-11-16</td>
#       <td>2021-11-30</td>
#       <td>2021-12-09</td>
#       <td>18</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.01%</td>
#       <td>-3.06%</td>
#       <td>3.12%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("==============Compare to SSE50===========")
# from finrl.plot import backtest_plot_com
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot_com(account_value = df_account_value, 
                  baseline = baseline_sse,
                  baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
                  baseline_end = df_account_value.loc[0,'date']
                     )
# Out:
# ==============Compare to SSE50===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-11-08</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-11-18</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-13.55%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-13.55%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>12.846%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.07</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.77</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-17.668%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.82</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.41</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.673%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.42</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17.67</td>
#       <td>2022-02-11</td>
#       <td>2022-10-31</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.57</td>
#       <td>2021-12-10</td>
#       <td>2022-01-14</td>
#       <td>2022-02-11</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.66</td>
#       <td>2021-11-11</td>
#       <td>2021-11-30</td>
#       <td>2021-12-06</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.02</td>
#       <td>2021-11-08</td>
#       <td>2021-11-10</td>
#       <td>2021-11-11</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axis.py:1736, in Axis.convert_units(self, x)
#    1735 try:
# -> 1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:287, in DatetimeConverter.convert(values, unit, axis)
#     286 else:
# --> 287     values = DatetimeConverter._convert_1d(values, unit, axis)
#     288 return values
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:322, in DatetimeConverter._convert_1d(values, unit, axis)
#     320         pass
# --> 322     values = dates.date2num(values)
#     324 return values
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/dates.py:462, in date2num(d)
#     461         d = np.asarray(d)
# --> 462     d = d.astype('datetime64[us]')
#     464 d = np.ma.masked_array(d, mask=mask) if masked else d
#
# ValueError: cannot convert float NaN to integer
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[423], line 7
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 # S&P 500: ^GSPC
#       5 # Dow Jones Index: ^DJI
#       6 # NASDAQ 100: ^NDX
# ----> 7 backtest_plot_com(account_value = df_account_value,
#       8                   baseline = baseline_sse,
#       9                   baseline_start = df_account_value.loc[len(df_account_value)-1,'date'],
#      10                   baseline_end = df_account_value.loc[0,'date']
#      11                      )
#
# Cell In[417], line 19, in backtest_plot_com(account_value, baseline, baseline_start, baseline_end, value_col_name)
#      17 baseline_returns = get_daily_return(baseline, value_col_name=value_col_name)
#      18 with pyfolio.plotting.plotting_context(font_scale=1.1):
# ---> 19     pyfolio.create_full_tear_sheet(
#      20         returns=test_returns, benchmark_rets=baseline_returns, set_context=False
#      21     )
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:180, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     174     returns = txn.adjust_returns_for_slippage(returns, positions,
#     175                                               transactions, slippage)
#     177 positions = utils.check_intraday(estimate_intraday, returns,
#     178                                  positions, transactions)
# --> 180 create_returns_tear_sheet(
#     181     returns,
#     182     positions=positions,
#     183     transactions=transactions,
#     184     live_start_date=live_start_date,
#     185     cone_std=cone_std,
#     186     benchmark_rets=benchmark_rets,
#     187     bootstrap=bootstrap,
#     188     turnover_denom=turnover_denom,
#     189     header_rows=header_rows,
#     190     set_context=set_context)
#     192 create_interesting_times_tear_sheet(returns,
#     193                                     benchmark_rets=benchmark_rets,
#     194                                     set_context=set_context)
#     196 if positions is not None:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:54, in customize.<locals>.call_w_context(*args, **kwargs)
#      52         return func(*args, **kwargs)
#      53 else:
# ---> 54     return func(*args, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/tears.py:569, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     565 plotting.plot_rolling_sharpe(
#     566     returns, ax=ax_rolling_sharpe)
#     568 # Drawdowns
# --> 569 plotting.plot_drawdown_periods(
#     570     returns, top=5, ax=ax_drawdown)
#     572 plotting.plot_drawdown_underwater(
#     573     returns=returns, ax=ax_underwater)
#     575 plotting.plot_monthly_returns_heatmap(returns, ax=ax_monthly_heatmap)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/pyfolio/plotting.py:442, in plot_drawdown_periods(returns, top, ax, **kwargs)
#     440     if pd.isnull(recovery):
#     441         recovery = returns.index[-1]
# --> 442     ax.fill_between((peak, recovery),
#     443                     lim[0],
#     444                     lim[1],
#     445                     alpha=.4,
#     446                     color=colors[i])
#     447 ax.set_ylim(lim)
#     448 ax.set_title('Top %i drawdown periods' % top)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5431, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5429 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5430                  step=None, **kwargs):
# -> 5431     return self._fill_between_x_or_y(
#    5432         "x", x, y1, y2,
#    5433         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py:5337, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5332         kwargs["facecolor"] = \
#    5333             self._get_patches_for_fill.get_next_color()
#    5335 # Handle united data, such as dates
#    5336 ind, dep1, dep2 = map(
# -> 5337     ma.masked_invalid, self._process_unit_info(
#    5338         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5340 for name, array in [
#    5341         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5342     if array.ndim > 1:
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_base.py:2569, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2567             if dataset_axis_name == axis_name and data is not None:
#    2568                 axis.update_units(data)
# -> 2569 return [axis_map[axis_name].convert_units(data)
#    2570         if convert and data is not None else data
#    2571         for axis_name, data in datasets]
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axes/_base.py:2569, in <listcomp>(.0)
#    2567             if dataset_axis_name == axis_name and data is not None:
#    2568                 axis.update_units(data)
# -> 2569 return [axis_map[axis_name].convert_units(data)
#    2570         if convert and data is not None else data
#    2571         for axis_name, data in datasets]
#
# File ~/Documents/anaconda/anaconda3/envs/rl_env/lib/python3.8/site-packages/matplotlib/axis.py:1738, in Axis.convert_units(self, x)
#    1736     ret = self.converter.convert(x, self.units, self)
#    1737 except Exception as e:
# -> 1738     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1739                                  f'units: {x!r}') from e
#    1740 return ret
#
# ConversionError: Failed to convert value(s) to axis units: (NaT, Timestamp('2022-11-18 00:00:00+0000', tz='UTC'))
